# %%
import numpy as np
import pandas as pd

dataFrame = pd.read_csv('world.csv')
dataFrame.dtypes
# Out:
# ID                  int64
# iso_code           object
# 洲名                 object
# 國家                 object
# 日期                 object
# 總確診數                int64
# 新增確診數               int64
# 七天移動平均新增確診數       float64
# 總死亡數                int64
# 新增死亡數               int64
# 七天移動平均新增死亡數       float64
# 每百萬人確診數           float64
# 每百萬人死亡數           float64
# 傳染率               float64
# 新增檢驗件數              int64
# 總檢驗件數               int64
# 每千人檢驗件數           float64
# 七天移動平均新增檢驗件數      float64
# 陽性率               float64
# 每確診案例相對檢驗數量       float64
# 疫苗總接種總劑數            int64
# 疫苗總接種人數             int64
# 疫苗新增接種劑數            int64
# 七天移動平均疫苗新增接種劑數    float64
# 每百人接種疫苗劑數         float64
# 每百人接種疫苗人數         float64
# 疫情控管指數            float64
# 總人口數                int64
# 中位數年紀             float64
# 70歲以上人口比例         float64
# 平均壽命              float64
# 解除隔離數               int64
# 解封指數              float64
# dtype: object

# %%
dataFrame.shape
# Out:
# (187885, 33)

# %%
dataFrame = dataFrame.reindex(columns=['洲名','國家','日期','總確診數','新增確診數','新增死亡數','總人口數'])
dataFrame.tail(20)
# Out:
#         洲名   國家          日期    總確診數  新增確診數  新增死亡數      總人口數
# 187865  非洲  辛巴威  2022-06-17  254753    251      7  15092171
# 187866  非洲  辛巴威  2022-06-18  254753      0      0  15092171
# 187867  非洲  辛巴威  2022-06-19  254801     48      1  15092171
# 187868  非洲  辛巴威  2022-06-20  254831     30      0  15092171
# 187869  非洲  辛巴威  2022-06-21  254919     88      2  15092171
# 187870  非洲  辛巴威  2022-06-22  255049    130      5  15092171
# 187871  非洲  辛巴威  2022-06-23  255136     87      1  15092171
# 187872  非洲  辛巴威  2022-06-24  255309    173      7  15092171
# 187873  非洲  辛巴威  2022-06-25  255309      0      0  15092171
# 187874  非洲  辛巴威  2022-06-26  255355     46      0  15092171
# 187875  非洲  辛巴威  2022-06-27  255383     28      0  15092171
# 187876  非洲  辛巴威  2022-06-28  255383      0      0  15092171
# 187877  非洲  辛巴威  2022-06-29  255520    137      4  15092171
# 187878  非洲  辛巴威  2022-06-30  255586     66      2  15092171
# 187879  非洲  辛巴威  2022-07-01  255586      0      0  15092171
# ...

# %%
tw_covid19 = dataFrame[dataFrame['國家'] == "台灣"]
tw_covid19
#tw_covid19[tw_covid19['日期'] >= '2022-05-10']
# Out:
#         洲名  國家          日期     總確診數   新增確診數  新增死亡數      總人口數
# 164831  亞洲  台灣  2022-05-10   448323   50819     12  23855008
# 164832  亞洲  台灣  2022-05-11   505455   57132      8  23855008
# 164833  亞洲  台灣  2022-05-12   570870   65415     17  23855008
# 164834  亞洲  台灣  2022-05-13   570870       0      0  23855008
# 164835  亞洲  台灣  2022-05-14   699824  128954     81  23855008
# 164836  亞洲  台灣  2022-05-15   768543   68719     19  23855008
# 164837  亞洲  台灣  2022-05-16   830257   61714     29  23855008
# 164838  亞洲  台灣  2022-05-17   896059   65802     38  23855008
# 164839  亞洲  台灣  2022-05-18   981141   85082     41  23855008
# 164840  亞洲  台灣  2022-05-19  1070561   89420     59  23855008
# 164841  亞洲  台灣  2022-05-20  1156291   85730     49  23855008
# 164842  亞洲  台灣  2022-05-21  1240897   84606     59  23855008
# 164843  亞洲  台灣  2022-05-22  1320371   79474     53  23855008
# 164844  亞洲  台灣  2022-05-23  1386640   66269     40  23855008
# ...

# %%
tw1=tw_covid19[['日期','新增確診數','新增死亡數']].sort_values(by='日期',ascending=True)
tw2=tw1.set_index('日期').loc['2022-04-01':]
latest_n = tw2['新增確診數'].max()
latest_d = tw2[tw2['新增確診數'] == latest_n].index[0]
tw3=tw2['新增確診數'].shift(1)
tw3_different = tw2['新增確診數']-tw3
second_value=tw3_different.sort_values(ascending=False)[1]
second_date = tw3_different.sort_values(ascending=False).index[1]
second_date
# Out:
# '2022-05-09'

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=12)

figure = plt.figure(figsize=(8,5))
ax1 = figure.add_subplot(1,1,1)
ax1.plot(tw2.index,tw2['新增確診數'])
plt.title("台灣新增確診數",fontproperties=font)
plt.xlabel("日期",fontproperties=font)
plt.ylabel("人數",fontproperties=font)
plt.xticks(ticks=[0,50,100],labels=['2022-04-01','2022-05-10','2022-07-06'])
plt.text(1, 120000, f'最多{latest_d},人數:{latest_n:,}',fontproperties=font)
plt.text(1, 100000, f'最多新增{second_date},新增人數:{second_value:,}',fontproperties=font)
plt.grid()
