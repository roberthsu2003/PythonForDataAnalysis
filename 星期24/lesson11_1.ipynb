# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot([7,9,11,13,21,8])
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.plot([0,1,2],[3, 4, 5])
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,3,1)
ax1.set_title('1')

ax2 = fig.add_subplot(1,3,2)
ax2.set_title('2')

ax3 = fig.add_subplot(1,3,3)
ax3.set_title('3')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,1,1)
ax1.plot([-1, -4.3, 15, 21, 31])
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(1,1,1)
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [78, 92, 69, 72, 85]
y2 = [83, 74, 92, 65, 91]
ax1.plot(x,y1,x,y2)
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(1,1,1)
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [78, 92, 69, 72, 85]
y2 = [83, 74, 92, 65, 91]
ax1.plot(x,y1,'r-o',x,y2,'g--o')
plt.show()

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(1,1,1)
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [78, 92, 69, 72, 85]
y2 = [83, 74, 92, 65, 91]
ax1.plot(x,y1,'r-o',x,y2,'g--o')
plt.grid()

# %%
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_subplot(1,1,1)

x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [78, 92, 69, 72, 85]
y2 = [83, 74, 92, 65, 91]
ax1.plot(x,y1,'r-o',x,y2,'g--o')
plt.title("My First Plot")
plt.show()
