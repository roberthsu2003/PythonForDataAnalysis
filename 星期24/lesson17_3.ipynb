# %%
import requests
url = "https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000"
response = requests.get(url)
if response.status_code == 200:
    json_data = response.json()

# %%
import pandas as pd 
import numpy as np

allRecords = pd.DataFrame(json_data)
allRecords
# Out:
#       sno          sna tot sbi sarea            mday        lat         lng  \
# 0    1001         大鵬華城  28  11   新店區  20220705200425   24.99116   121.53398
# 1    1002        汐止火車站  44  27   汐止區  20220705200417  25.068914  121.662748
# 2    1003        汐止區公所  46  23   汐止區  20220705200430  25.064162  121.658301
# 3    1004       國泰綜合醫院  48  43   汐止區  20220705200423   25.07315  121.662555
# 4    1005         裕隆公園  32   0   新店區  20220513093721  24.979649  121.546319
# ..    ...          ...  ..  ..   ...             ...        ...         ...
# 662  1758       中山溫泉公園  44  12   金山區  20220705200424  25.221080  121.641770
# 663  1760        龍米停車場  30   5   八里區  20220705200435  25.156780  121.436040
# 664  1761         雙和醫院  30  19   中和區  20220705200441  24.993670  121.494110
# 665  1762     寶高智慧產業園區  60   4   新店區  20220705200430  24.977500  121.551330
# 666  1763  捷運三重站(1號出口)  40  18   三重區  20220705200443  25.054640  121.483220
#
#                                   ar         sareaen  \
# 0                    新北市新店區中正路700巷3號   Xindian Dist.
# 1                     南昌街/新昌路口(西側廣場)     Xizhi Dist.
# 2    新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)     Xizhi Dist.
# 3                        建成路78號對面停車場     Xizhi Dist.
# 4                      寶中路/品牌路口(東南側)   Xindian Dist.
# ..                               ...             ...
# 662                       民生路204號(旁)   Jinshan Dist.
# 663                     龍米路二段150號(旁)      Bali Dist.
# 664                    中正路281號(公車亭旁)   Zhonghe Dist.
# 665                        寶高路10號(旁)   Xindian Dist.
# 666                        捷運路36號(旁)  Sanchong Dist.
#
#                                   snaen  \
# 0                      Dapeng Community
# 1                 Xizhi Railway Station
# 2                    Xizhi Dist. Office
# 3               Cathay General Hospital
# 4                            Yulon Park
# ..                                  ...
# 662              Zhongshan Spring Park
# 663                  Longmi Parking Lot
# 664                  Shuang Ho Hospital
# 665  Baogao Intelligent Industrial Park
# 666       MRT Sanchong Station (Exit.1)
#
#                                                   aren bemp act
# 0    No. 3, Lane 700 Chung Cheng Road, Xindian Dist...   13   1
# 1                            Nanchang St./Xinchang Rd.   14   1
# 2                    Sec. 1, Xintai 5th Rd./Ren’ai Rd.   22   1
# 3                                   No78, Jiancheng Rd    4   1
# 4                                        Baozhong Rd./    2   1
# ..                                                 ...  ...  ..
# 662                              No. 204, Minsheng Rd.   29   1
# 663                        No. 150, Sec. 2, Longmi Rd.   25   1
# 664                            No. 281, Zhongzheng Rd.   10   1
# 665                                 No. 10, Baogao Rd.   49   1
# 666                          No. 36, Jieyun Rd. (Side)   20   1
#
# [667 rows x 14 columns]
