# %%
#氣象開放平台開發指南 
#https://opendata.cwb.gov.tw/devManual/insrtuction

#自動氣象站-氣象觀測資料(下載檔案)
#https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON

#自動氣象站-氣象觀測資料(api)
#https://opendata.cwb.gov.tw/api/v1/rest/datastore/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON
import requests
#import requests.exceptions
from requests.exceptions import *


downloadUrlPath = "https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
urlPathApi = "https://opendata.cwb.gov.tw/api/v1/rest/datastore/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
try:
    response = requests.get(urlPathApi)
    response.raise_for_status()
    
except ConnectionError:
    print("連線錯誤")
except  HTTPError as e:
    print("HTTPError")
    print(e)
except:
    print("發生錯誤")    
else:
    print("沒有發生任何錯誤")
    root = response.json()

        
#轉換成要使用的資料
locations = root['records']['location']
weatherList = []
for location in locations:
    itemDic = {}
    itemDic['縣市'] = location['parameter'][0]['parameterValue']
    itemDic['區域'] = location['parameter'][2]['parameterValue']
    itemDic['時間'] = location['time']['obsTime']
    itemDic['溫度'] = float(location['weatherElement'][3]['elementValue'])
    weatherList.append(itemDic)
# Out:
# 沒有發生任何錯誤

# %%
import numpy as np
import pandas as pd
weathers = pd.DataFrame(weatherList)
weathers
# Out:
#       縣市   區域                   時間    溫度
# 0    新北市  烏來區  2021-11-17 18:00:00  18.6
# 1    臺南市  安平區  2021-11-17 18:00:00  24.5
# 2    臺東縣  東河鄉  2021-11-17 18:00:00  20.8
# 3    新北市  貢寮區  2021-11-17 18:00:00  21.4
# 4    南投縣  仁愛鄉  2021-11-17 18:00:00   6.2
# ..   ...  ...                  ...   ...
# 426  新北市  三重區  2021-11-17 18:00:00  24.2
# 427  宜蘭縣  大同鄉  2021-11-17 18:00:00  11.2
# 428  花蓮縣  壽豐鄉  2021-11-17 18:00:00  19.0
# 429  新竹縣  五峰鄉  2021-11-17 18:00:00  12.5
# 430  桃園市  大溪區  2021-11-17 18:00:00  22.4
#
# [431 rows x 4 columns]

# %%
weathers.dtypes
# Out:
# 縣市     object
# 區域     object
# 時間     object
# 溫度    float64
# dtype: object

# %%
lower20=weathers[weathers['溫度'] < 20]
lower20.shape
for item in lower20.values:
    print(item)
# Out:
# ['新北市' '烏來區' '2021-11-17 18:00:00' 18.6]
# ['南投縣' '仁愛鄉' '2021-11-17 18:00:00' 6.2]
# ['臺東縣' '海端鄉' '2021-11-17 18:00:00' 10.7]
# ['宜蘭縣' '頭城鎮' '2021-11-17 18:00:00' 18.4]
# ['宜蘭縣' '礁溪鄉' '2021-11-17 18:00:00' 19.0]
# ['宜蘭縣' '南澳鄉' '2021-11-17 18:00:00' 15.5]
# ['南投縣' '仁愛鄉' '2021-11-17 18:00:00' 5.0]
# ['花蓮縣' '壽豐鄉' '2021-11-17 18:00:00' 19.3]
# ['嘉義縣' '竹崎鄉' '2021-11-17 18:00:00' 15.9]
# ['臺北市' '北投區' '2021-11-17 18:00:00' -99.0]
# ['宜蘭縣' '大同鄉' '2021-11-17 18:00:00' 11.4]
# ['臺中市' '和平區' '2021-11-17 18:00:00' 6.2]
# ['宜蘭縣' '頭城鎮' '2021-11-17 18:00:00' 16.0]
# ['臺東縣' '達仁鄉' '2021-11-17 18:00:00' 17.0]
# ['臺東縣' '海端鄉' '2021-11-17 18:00:00' 13.5]
# ['屏東縣' '春日鄉' '2021-11-17 18:00:00' 13.7]
# ['新北市' '汐止區' '2021-11-17 18:00:00' 18.3]
# ['花蓮縣' '秀林鄉' '2021-11-17 18:00:00' 18.9]
# ['新竹縣' '尖石鄉' '2021-11-17 18:00:00' 19.6]
# ['花蓮縣' '秀林鄉' '2021-11-17 18:00:00' 19.3]
# ['花蓮縣' '卓溪鄉' '2021-11-17 18:00:00' 18.4]
# ['雲林縣' '古坑鄉' '2021-11-17 18:00:00' 17.4]
# ['新北市' '坪林區' '2021-11-17 18:00:00' 19.3]
# ...

# %%
greater20 = weathers[weathers['溫度'] > 20]
greater20.shape

for item in greater20.values:
    print(item)
# Out:
# ['臺南市' '安平區' '2021-11-17 18:00:00' 24.5]
# ['臺東縣' '東河鄉' '2021-11-17 18:00:00' 20.8]
# ['新北市' '貢寮區' '2021-11-17 18:00:00' 21.4]
# ['嘉義縣' '大林鎮' '2021-11-17 18:00:00' 24.1]
# ['花蓮縣' '玉里鎮' '2021-11-17 18:00:00' 21.9]
# ['嘉義市' '東區' '2021-11-17 18:00:00' 24.8]
# ['宜蘭縣' '頭城鎮' '2021-11-17 18:00:00' 20.4]
# ['新北市' '平溪區' '2021-11-17 18:00:00' 20.1]
# ['雲林縣' '斗六市' '2021-11-17 18:00:00' 24.5]
# ['南投縣' '魚池鄉' '2021-11-17 18:00:00' 21.2]
# ['屏東縣' '竹田鄉' '2021-11-17 18:00:00' 26.0]
# ['苗栗縣' '造橋鄉' '2021-11-17 18:00:00' 23.8]
# ['新北市' '石門區' '2021-11-17 18:00:00' 22.3]
# ['苗栗縣' '頭屋鄉' '2021-11-17 18:00:00' 23.0]
# ['臺南市' '下營區' '2021-11-17 18:00:00' 23.0]
# ['屏東縣' '萬丹鄉' '2021-11-17 18:00:00' 25.9]
# ['新北市' '三峽區' '2021-11-17 18:00:00' 23.4]
# ['彰化縣' '大城鄉' '2021-11-17 18:00:00' 23.0]
# ['臺中市' '大里區' '2021-11-17 18:00:00' 25.2]
# ['臺中市' '西屯區' '2021-11-17 18:00:00' 24.0]
# ['臺東縣' '鹿野鄉' '2021-11-17 18:00:00' 21.6]
# ['嘉義縣' '太保市' '2021-11-17 18:00:00' 23.6]
# ['臺南市' '學甲區' '2021-11-17 18:00:00' 23.1]
# ...

# %%
a = weathers['溫度'] >= 21
b = weathers['溫度'] <= 22
weathers[ a & b]
# Out:
#       縣市    區域                   時間    溫度
# 3    新北市   貢寮區  2021-11-17 18:00:00  21.4
# 6    花蓮縣   玉里鎮  2021-11-17 18:00:00  21.9
# 11   南投縣   魚池鄉  2021-11-17 18:00:00  21.2
# 24   臺東縣   鹿野鄉  2021-11-17 18:00:00  21.6
# 35   臺東縣   卑南鄉  2021-11-17 18:00:00  21.2
# 66   花蓮縣   卓溪鄉  2021-11-17 18:00:00  22.0
# 67   花蓮縣   壽豐鄉  2021-11-17 18:00:00  21.7
# 73   澎湖縣   西嶼鄉  2021-11-17 18:00:00  21.7
# 100  宜蘭縣   南澳鄉  2021-11-17 18:00:00  21.8
# 104  宜蘭縣   員山鄉  2021-11-17 18:00:00  21.7
# 107  屏東縣   車城鄉  2021-11-17 18:00:00  21.9
# 118  桃園市   大溪區  2021-11-17 18:00:00  21.7
# 120  桃園市   龜山區  2021-11-17 18:00:00  21.9
# 129  高雄市   桃源區  2021-11-17 18:00:00  21.3
# 140  屏東縣   滿州鄉  2021-11-17 18:00:00  21.3
# 154  新北市   雙溪區  2021-11-17 18:00:00  21.2
# 159  花蓮縣   豐濱鄉  2021-11-17 18:00:00  21.4
# 176  金門縣   金寧鄉  2021-11-17 18:00:00  21.5
# 177  臺中市   大肚區  2021-11-17 18:00:00  21.8
# 182  臺東縣   長濱鄉  2021-11-17 18:00:00  21.2
# 183  臺東縣   金峰鄉  2021-11-17 18:00:00  21.3
# ...

# %%
#sqlite 資料庫
import sqlite3
query = """
CREATE TABLE 氣象觀測資料(縣市 VARCHAR(20), 區域 VARCHAR(20), 時間 VARCHAR(30), 溫度 REAL);
"""

#建立方法只能建立一次，無法覆蓋原來檔案
con = sqlite3.connect('氣象觀測資料.sqlite')
con.execute(query)
con.commit()
con.close()

# %%
#新增資料
import sqlite3
con = sqlite3.connect('氣象觀測資料.sqlite')
for one in weatherList:    
    stmt = "INSERT INTO 氣象觀測資料 VALUES(?,?,?,?)"
    con.execute(stmt,(one['縣市'],one['區域'],one['時間'],one['溫度']))
    con.commit()
con.close()

# %%
#讀取sqlite資料
con = sqlite3.connect('氣象觀測資料.sqlite')
cursor=con.execute('select * from 氣象觀測資料') # 'select * from 氣象觀測資料 limit 10'
rows=cursor.fetchall()
print(rows.__class__)

print(cursor.description)
pd.DataFrame(rows,columns=[x[0] for x in cursor.description])
# Out:
# <class 'list'>
# (('縣市', None, None, None, None, None, None), ('區域', None, None, None, None, None, None), ('時間', None, None, None, None, None, None), ('溫度', None, None, None, None, None, None))
#       縣市   區域                   時間    溫度
# 0    新北市  烏來區  2021-11-17 18:00:00  18.6
# 1    臺南市  安平區  2021-11-17 18:00:00  24.5
# 2    臺東縣  東河鄉  2021-11-17 18:00:00  20.8
# 3    新北市  貢寮區  2021-11-17 18:00:00  21.4
# 4    南投縣  仁愛鄉  2021-11-17 18:00:00   6.2
# ..   ...  ...                  ...   ...
# 426  新北市  三重區  2021-11-17 18:00:00  24.2
# 427  宜蘭縣  大同鄉  2021-11-17 18:00:00  11.2
# 428  花蓮縣  壽豐鄉  2021-11-17 18:00:00  19.0
# 429  新竹縣  五峰鄉  2021-11-17 18:00:00  12.5
# 430  桃園市  大溪區  2021-11-17 18:00:00  22.4
#
# [431 rows x 4 columns]
