# %% [markdown]
# [abc](#abc)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

index = [('California', 2000), ('California', 2010),
         ('New York', 2000), ('New York', 2010),
         ('Texas', 2000), ('Texas', 2010)]
populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]

index = pd.MultiIndex.from_tuples(index,names=['state','year'])
pop = pd.Series(populations,index=index)
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
pop[:, 2010]
# Out:
# state
# California    37253956
# New York      19378102
# Texas         25145561
# dtype: int64

# %%
pop
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %%
pop_df = pop.unstack()
pop_df
# Out:
# year            2000      2010
# state
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
pop_df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure = plt.figure()
ax1 = figure.add_subplot(2,1,1)
ax2 = figure.add_subplot(2,1,2)
pop_df.plot.bar(ax = ax1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pop_df.T.plot.bar(ax = ax2)

# %%
pop_df
# Out:
# year            2000      2010
# state
# California  33871648  37253956
# New York    18976457  19378102
# Texas       20851820  25145561

# %%
pop_df.stack()
# Out:
# state       year
# California  2000    33871648
#             2010    37253956
# New York    2000    18976457
#             2010    19378102
# Texas       2000    20851820
#             2010    25145561
# dtype: int64

# %% [markdown]
# <a id='abc'></a>

# %%
pop_df = pd.DataFrame({'total':pop,
                       'under18':[9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})
pop_df
# Out:
#                     total  under18
# state      year
# California 2000  33871648  9267089
#            2010  37253956  9284094
# New York   2000  18976457  4687374
#            2010  19378102  4318033
# Texas      2000  20851820  5906301
#            2010  25145561  6879014

# %%
pop_df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id="abc">位置abc</a>

# %%
f_u18 = pop_df['under18'] / pop_df['total']
f_u18
# Out:
# state       year
# California  2000    0.273594
#             2010    0.249211
# New York    2000    0.247010
#             2010    0.222831
# Texas       2000    0.283251
#             2010    0.273568
# dtype: float64

# %%
f_u18_unstack=f_u18.unstack()
f_u18_unstack.columns=({'year':year['2000<18','2010<18']})
f_u18_unstack
# Out:
# year            2000      2010
# state
# California  0.273594  0.249211
# New York    0.247010  0.222831
# Texas       0.283251  0.273568

# %%
figure1 = plt.figure()
ax3 = figure1.add_subplot()
f_u18_unstack.plot.bar(ax = ax3)
# Out:
# <img src="data:image/png;base64,..." width="640">
