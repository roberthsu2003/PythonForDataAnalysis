# %%
#!cat 'datasets/bitly_usagov/example.txt'

# %%
#分析文字檔內容,顯示第一行內容
path = 'datasets/bitly_usagov/example.txt'
with open(path) as file:
    print(file.readline())
# Out:
# { "a": "Mozilla\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\/535.11 (KHTML, like Gecko) Chrome\/17.0.963.78 Safari\/535.11", "c": "US", "nk": 1, "tz": "America\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\/\/www.facebook.com\/l\/7AQEFzjSi\/1.usa.gov\/wfLQtf", "u": "http:\/\/www.ncbi.nlm.nih.gov\/pubmed\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }

# %%
#將第一行的文字轉為Dictionary,並且放置到list內
#產生list內有Dictionary

import json
path = 'datasets/bitly_usagov/example.txt'
records = [json.loads(line) for line in open(path)]
records[0]
# Out:
# {'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  'c': 'US',
#  'nk': 1,
#  'tz': 'America/New_York',
#  'gr': 'MA',
#  'g': 'A6qOVH',
#  'h': 'wfLQtf',
#  'l': 'orofrog',
#  'al': 'en-US,en;q=0.8',
#  'hh': '1.usa.gov',
#  'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991',
#  't': 1331923247,
#  'hc': 1331822918,
#  'cy': 'Danvers',
#  'll': [42.576698, -70.954903]}

# %%
#目標收集dictionary的'tz'的value,成為list
#使用list comprehension過濾出資料

#time_zones = [rec['tz'] for rec in records] #出現錯誤,有些Dictionary沒有key:'tz'

# %%
#加上檢查是否Dictionary有key:tz
time_zones = [rec['tz'] for rec in records if 'tz' in rec]
time_zones[:10]
# Out:
# ['America/New_York',
#  'America/Denver',
#  'America/New_York',
#  'America/Sao_Paulo',
#  'America/New_York',
#  'America/New_York',
#  'Europe/Warsaw',
#  '',
#  '',
#  '']

# %%
import pandas as pd #使用pandas取出前10名
frame = pd.DataFrame(records) #pandas的Structure
frame.info()#使用info()方法查看index,查看筆數3560,查看columns的label名和每個columns資料的dtype和數量
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3560 entries, 0 to 3559
# Data columns (total 18 columns):
# a              3440 non-null object
# c              2919 non-null object
# nk             3440 non-null float64
# tz             3440 non-null object
# gr             2919 non-null object
# g              3440 non-null object
# h              3440 non-null object
# l              3440 non-null object
# al             3094 non-null object
# hh             3440 non-null object
# r              3440 non-null object
# u              3440 non-null object
# t              3440 non-null float64
# hc             3440 non-null float64
# cy             2919 non-null object
# ll             2919 non-null object
# _heartbeat_    120 non-null float64
# kw             93 non-null object
# dtypes: float64(4), object(14)
# memory usage: 500.8+ KB

# %%
#取出key:'tz'前10筆
frame['tz'][:10]
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
#取出各區域的筆數
tz_counts = frame['tz'].value_counts() #value_counts計算內容相同的數量,產生新的Series,原來的值成為Series的index,value成為數量
tz_counts
# Out:
# America/New_York                  1251
#                                    521
# America/Chicago                    400
# America/Los_Angeles                382
# America/Denver                     191
#                                   ...
# Africa/Johannesburg                  1
# Africa/Casablanca                    1
# America/Costa_Rica                   1
# Europe/Uzhgorod                      1
# America/Argentina/Buenos_Aires       1
# Name: tz, Length: 97, dtype: int64

# %%
#將內容是None的填入'遺失的資料'
clean_tz = frame['tz'].fillna('遺失的資料')

#將空字串的區域填入'不明'
clean_tz[clean_tz == ''] = '不明'
clean_tz[:20]
# Out:
# 0        America/New_York
# 1          America/Denver
# 2        America/New_York
# 3       America/Sao_Paulo
# 4        America/New_York
# 5        America/New_York
# 6           Europe/Warsaw
# 7                      不明
# 8                      不明
# 9                      不明
# 10    America/Los_Angeles
# 11       America/New_York
# 12       America/New_York
# 13                  遺失的資料
# 14       America/New_York
# 15         Asia/Hong_Kong
# 16         Asia/Hong_Kong
# 17       America/New_York
# 18         America/Denver
# 19            Europe/Rome
# Name: tz, dtype: object

# %%
tz_counts = clean_tz.value_counts()
tz_counts
# Out:
# America/New_York       1251
# 不明                      521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
#                        ...
# Asia/Pontianak            1
# Asia/Yekaterinburg        1
# America/Tegucigalpa       1
# Europe/Uzhgorod           1
# America/La_Paz            1
# Name: tz, Length: 98, dtype: int64

# %%
#只分析前10筆
tz_counts[:10]
# Out:
# America/New_York       1251
# 不明                      521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# 遺失的資料                   120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot(tz_counts[:10]) #線圖不符合需求
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tz_counts[:10]
# Out:
# America/New_York       1251
# 不明                      521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# 遺失的資料                   120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
fig, ax1 = plt.subplots(1,1)
tz_counts[:10].plot(ax=ax1, kind='bar')

ax1.set_title('數量前10個地區',fontproperties=font)
ax1.set_xticklabels(tz_counts[:10].index,fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(0, 0, 'America/New_York'),
#  Text(0, 0, '不明'),
#  Text(0, 0, 'America/Chicago'),
#  Text(0, 0, 'America/Los_Angeles'),
#  Text(0, 0, 'America/Denver'),
#  Text(0, 0, '遺失的資料'),
#  Text(0, 0, 'Europe/London'),
#  Text(0, 0, 'Asia/Tokyo'),
#  Text(0, 0, 'Pacific/Honolulu'),
#  Text(0, 0, 'Europe/Madrid')]

# %%
fig, ax1 = plt.subplots(1,1)
tz_counts[:10].plot(ax=ax1, kind='barh')

ax1.set_title('數量前10個地區',fontproperties=font)
ax1.set_yticklabels(tz_counts[:10].index,fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(0, 0, 'America/New_York'),
#  Text(0, 0, '不明'),
#  Text(0, 0, 'America/Chicago'),
#  Text(0, 0, 'America/Los_Angeles'),
#  Text(0, 0, 'America/Denver'),
#  Text(0, 0, '遺失的資料'),
#  Text(0, 0, 'Europe/London'),
#  Text(0, 0, 'Asia/Tokyo'),
#  Text(0, 0, 'Pacific/Honolulu'),
#  Text(0, 0, 'Europe/Madrid')]

# %%
#做用seaborn

import seaborn as sns
fig, ax1 = plt.subplots(1,1)
subset = tz_counts[:10]
sns.barplot(y=subset.index, x=subset.values)
ax1.set_title('數量前10個地區',fontproperties=font)
ax1.set_yticklabels(tz_counts[:10].index,fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(0, 0, 'America/New_York'),
#  Text(0, 0, '不明'),
#  Text(0, 0, 'America/Chicago'),
#  Text(0, 0, 'America/Los_Angeles'),
#  Text(0, 0, 'America/Denver'),
#  Text(0, 0, '遺失的資料'),
#  Text(0, 0, 'Europe/London'),
#  Text(0, 0, 'Asia/Tokyo'),
#  Text(0, 0, 'Pacific/Honolulu'),
#  Text(0, 0, 'Europe/Madrid')]
