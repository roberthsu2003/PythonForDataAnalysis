# %% [markdown]
# ## 火車站進出站總人數
#
#
# ```
# 透過政府資料開放平台取得json資料
# 取出進站人數和出站人數超過500000人次的火車站
# https://data.gov.tw/datasets/search?qs=%E6%AF%8F%E6%97%A5%E5%90%84%E7%AB%99%E9%80%B2%E5%87%BA%E7%AB%99%E4%BA%BA%E6%95%B8
# ```

# %%
# %matplotlib notebook
import urllib3
import certifi
import json 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#下載進出站人數資料
jsonUrl = 'http://ods.railway.gov.tw/tra-ods-web/ods/download/dataResource/8ae4cabf6973990e0169947ed32454b9'

#透過requests.get()方法取得requests.responces物件
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
r = http.request('GET', jsonUrl)

if r.status == 200:
    #使用json.loads()方法,取得python的list物件
    jsObject = json.loads(r.data)
else:
    print('下載錯誤')
# Out:
# [{'trnOpDate': '20190423',
#   'staCode': '0900',
#   'gateInComingCnt': '8437',
#   'gateOutGoingCnt': '7739'},
#  {'trnOpDate': '20190423',
#   'staCode': '0910',
#   'gateInComingCnt': '1393',
#   'gateOutGoingCnt': '1347'},
#  {'trnOpDate': '20190423',
#   'staCode': '0920',
#   'gateInComingCnt': '2756',
#   'gateOutGoingCnt': '2416'},
#  {'trnOpDate': '20190423',
#   'staCode': '0930',
#   'gateInComingCnt': '6086',
#   'gateOutGoingCnt': '6306'},
#  {'trnOpDate': '20190423',
#   'staCode': '0940',
#   'gateInComingCnt': '2677',
#   'gateOutGoingCnt': '2723'},
#  {'trnOpDate': '20190423',
#   'staCode': '0950',
#   'gateInComingCnt': '2067',
#   'gateOutGoingCnt': '1775'},
#  {'trnOpDate': '20190423',
#   'staCode': '0960',
#   'gateInComingCnt': '10026',
#   'gateOutGoingCnt': '10534'},
#  {'trnOpDate': '20190423',
#   'staCode': '0970',
#   'gateInComingCnt': '10153',
#   'gateOutGoingCnt': '10441'},
#  {'trnOpDate': '20190423',
#   'staCode': '0980',
#   'gateInComingCnt': '10896',
#   'gateOutGoingCnt': '11101'},
#  {'trnOpDate': '20190423',
#   'staCode': '0990',
#   'gateInComingCnt': '17993',
#   'gateOutGoingCnt': '17898'},
#  {'trnOpDate': '20190423',
#   'staCode': '1000',
#   'gateInComingCnt': '55745',
#   'gateOutGoingCnt': '53726'},
#  {'trnOpDate': '20190423',
#   'staCode': '1010',
#   'gateInComingCnt': '4559',
#   'gateOutGoingCnt': '4452'},
#  {'trnOpDate': '20190423',
#   'staCode': '1020',
#   'gateInComingCnt': '18463',
#   'gateOutGoingCnt': '18479'},
#  {'trnOpDate': '20190423',
#   'staCode': '1030',
#   'gateInComingCnt': '3046',
#   'gateOutGoingCnt': '2917'},
#  {'trnOpDate': '20190423',
#   'staCode': '1040',
#   'gateInComingCnt': '13725',
#   'gateOutGoingCnt': '14047'},
#  {'trnOpDate': '20190423',
#   'staCode': '1050',
#   'gateInComingCnt': '1052',
#   'gateOutGoingCnt': '1053'},
#  {'trnOpDate': '20190423',
#   'staCode': '1060',
#   'gateInComingCnt': '1418',
#   'gateOutGoingCnt': '1392'},
#  {'trnOpDate': '20190423',
#   'staCode': '1070',
#   'gateInComingCnt': '7930',
#   'gateOutGoingCnt': '8100'},
#  {'trnOpDate': '20190423',
#   'staCode': '1080',
#   'gateInComingCnt': '24530',
#   'gateOutGoingCnt': '25392'},
#  {'trnOpDate': '20190423',
#   'staCode': '1090',
#   'gateInComingCnt': '8872',
#   'gateOutGoingCnt': '8498'},
#  {'trnOpDate': '20190423',
#   'staCode': '1100',
#   'gateInComingCnt': '21964',
#   'gateOutGoingCnt': '22544'},
#  {'trnOpDate': '20190423',
#   'staCode': '1110',
#   'gateInComingCnt': '5673',
#   'gateOutGoingCnt': '5255'},
#  {'trnOpDate': '20190423',
#   'staCode': '1120',
#   'gateInComingCnt': '4869',
#   'gateOutGoingCnt': '4551'},
#  {'trnOpDate': '20190423',
#   'staCode': '1130',
#   'gateInComingCnt': '1423',
#   'gateOutGoingCnt': '1504'},
#  {'trnOpDate': '20190423',
#   'staCode': '1140',
#   'gateInComingCnt': '61',
#   'gateOutGoingCnt': '99'},
#  {'trnOpDate': '20190423',
#   'staCode': '1150',
#   'gateInComingCnt': '992',
#   'gateOutGoingCnt': '1001'},
#  {'trnOpDate': '20190423',
#   'staCode': '1160',
#   'gateInComingCnt': '3196',
#   'gateOutGoingCnt': '3298'},
#  {'trnOpDate': '20190423',
#   'staCode': '1170',
#   'gateInComingCnt': '4436',
#   'gateOutGoingCnt': '4492'},
#  {'trnOpDate': '20190423',
#   'staCode': '1180',
#   'gateInComingCnt': '4589',
#   'gateOutGoingCnt': '4652'},
#  {'trnOpDate': '20190423',
#   'staCode': '1190',
#   'gateInComingCnt': '2187',
#   'gateOutGoingCnt': '2266'},
#  {'trnOpDate': '20190423',
#   'staCode': '1191',
#   'gateInComingCnt': '237',
#   'gateOutGoingCnt': '254'},
#  {'trnOpDate': '20190423',
#   'staCode': '1192',
#   'gateInComingCnt': '1527',
#   'gateOutGoingCnt': '1557'},
#  {'trnOpDate': '20190423',
#   'staCode': '1193',
#   'gateInComingCnt': '545',
#   'gateOutGoingCnt': '565'},
#  {'trnOpDate': '20190423',
#   'staCode': '1194',
#   'gateInComingCnt': '2258',
#   'gateOutGoingCnt': '2162'},
#  {'trnOpDate': '20190423',
#   'staCode': '1201',
#   'gateInComingCnt': '45',
#   'gateOutGoingCnt': '53'},
#  {'trnOpDate': '20190423',
#   'staCode': '1202',
#   'gateInComingCnt': '117',
#   'gateOutGoingCnt': '116'},
#  {'trnOpDate': '20190423',
#   'staCode': '1203',
#   'gateInComingCnt': '391',
#   'gateOutGoingCnt': '337'},
#  {'trnOpDate': '20190423',
#   'staCode': '1204',
#   'gateInComingCnt': '65',
#   'gateOutGoingCnt': '63'},
#  {'trnOpDate': '20190423',
#   'staCode': '1205',
#   'gateInComingCnt': '38',
#   'gateOutGoingCnt': '39'},
#  {'trnOpDate': '20190423',
#   'staCode': '1206',
#   'gateInComingCnt': '87',
#   'gateOutGoingCnt': '36'},
#  {'trnOpDate': '20190423',
#   'staCode': '1207',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20190423',
#   'staCode': '1208',
#   'gateInComingCnt': '245',
#   'gateOutGoingCnt': '293'},
#  {'trnOpDate': '20190423',
#   'staCode': '1210',
#   'gateInComingCnt': '15629',
#   'gateOutGoingCnt': '15467'},
#  {'trnOpDate': '20190423',
#   'staCode': '1220',
#   'gateInComingCnt': '1068',
#   'gateOutGoingCnt': '958'},
#  {'trnOpDate': '20190423',
#   'staCode': '1230',
#   'gateInComingCnt': '550',
#   'gateOutGoingCnt': '512'},
#  {'trnOpDate': '20190423',
#   'staCode': '1240',
#   'gateInComingCnt': '188',
#   'gateOutGoingCnt': '261'},
#  {'trnOpDate': '20190423',
#   'staCode': '1250',
#   'gateInComingCnt': '6927',
#   'gateOutGoingCnt': '6982'},
#  {'trnOpDate': '20190423',
#   'staCode': '2110',
#   'gateInComingCnt': '44',
#   'gateOutGoingCnt': '52'},
#  {'trnOpDate': '20190423',
#   'staCode': '2120',
#   'gateInComingCnt': '106',
#   'gateOutGoingCnt': '128'},
#  {'trnOpDate': '20190423',
#   'staCode': '2130',
#   'gateInComingCnt': '994',
#   'gateOutGoingCnt': '985'},
#  {'trnOpDate': '20190423',
#   'staCode': '2140',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20190423',
#   'staCode': '2150',
#   'gateInComingCnt': '435',
#   'gateOutGoingCnt': '428'},
#  {'trnOpDate': '20190423',
#   'staCode': '2160',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '49'},
#  {'trnOpDate': '20190423',
#   'staCode': '2170',
#   'gateInComingCnt': '678',
#   'gateOutGoingCnt': '729'},
#  {'trnOpDate': '20190423',
#   'staCode': '2180',
#   'gateInComingCnt': '1380',
#   'gateOutGoingCnt': '1244'},
#  {'trnOpDate': '20190423',
#   'staCode': '2190',
#   'gateInComingCnt': '187',
#   'gateOutGoingCnt': '214'},
#  {'trnOpDate': '20190423',
#   'staCode': '2200',
#   'gateInComingCnt': '2215',
#   'gateOutGoingCnt': '2220'},
#  {'trnOpDate': '20190423',
#   'staCode': '2210',
#   'gateInComingCnt': '79',
#   'gateOutGoingCnt': '79'},
#  {'trnOpDate': '20190423',
#   'staCode': '2220',
#   'gateInComingCnt': '861',
#   'gateOutGoingCnt': '892'},
#  {'trnOpDate': '20190423',
#   'staCode': '2230',
#   'gateInComingCnt': '1988',
#   'gateOutGoingCnt': '1820'},
#  {'trnOpDate': '20190423',
#   'staCode': '2240',
#   'gateInComingCnt': '318',
#   'gateOutGoingCnt': '335'},
#  {'trnOpDate': '20190423',
#   'staCode': '2250',
#   'gateInComingCnt': '584',
#   'gateOutGoingCnt': '521'},
#  {'trnOpDate': '20190423',
#   'staCode': '2260',
#   'gateInComingCnt': '189',
#   'gateOutGoingCnt': '172'},
#  {'trnOpDate': '20190423',
#   'staCode': '3140',
#   'gateInComingCnt': '263',
#   'gateOutGoingCnt': '310'},
#  {'trnOpDate': '20190423',
#   'staCode': '3150',
#   'gateInComingCnt': '703',
#   'gateOutGoingCnt': '723'},
#  {'trnOpDate': '20190423',
#   'staCode': '3160',
#   'gateInComingCnt': '4963',
#   'gateOutGoingCnt': '4880'},
#  {'trnOpDate': '20190423',
#   'staCode': '3170',
#   'gateInComingCnt': '102',
#   'gateOutGoingCnt': '110'},
#  {'trnOpDate': '20190423',
#   'staCode': '3180',
#   'gateInComingCnt': '642',
#   'gateOutGoingCnt': '627'},
#  {'trnOpDate': '20190423',
#   'staCode': '3190',
#   'gateInComingCnt': '736',
#   'gateOutGoingCnt': '759'},
#  {'trnOpDate': '20190423',
#   'staCode': '3210',
#   'gateInComingCnt': '384',
#   'gateOutGoingCnt': '356'},
#  {'trnOpDate': '20190423',
#   'staCode': '3220',
#   'gateInComingCnt': '7339',
#   'gateOutGoingCnt': '6991'},
#  {'trnOpDate': '20190423',
#   'staCode': '3230',
#   'gateInComingCnt': '7722',
#   'gateOutGoingCnt': '8042'},
#  {'trnOpDate': '20190423',
#   'staCode': '3240',
#   'gateInComingCnt': '527',
#   'gateOutGoingCnt': '529'},
#  {'trnOpDate': '20190423',
#   'staCode': '3250',
#   'gateInComingCnt': '2318',
#   'gateOutGoingCnt': '2230'},
#  {'trnOpDate': '20190423',
#   'staCode': '3260',
#   'gateInComingCnt': '432',
#   'gateOutGoingCnt': '452'},
#  {'trnOpDate': '20190423',
#   'staCode': '3270',
#   'gateInComingCnt': '1017',
#   'gateOutGoingCnt': '998'},
#  {'trnOpDate': '20190423',
#   'staCode': '3280',
#   'gateInComingCnt': '2889',
#   'gateOutGoingCnt': '2862'},
#  {'trnOpDate': '20190423',
#   'staCode': '3290',
#   'gateInComingCnt': '977',
#   'gateOutGoingCnt': '947'},
#  {'trnOpDate': '20190423',
#   'staCode': '3300',
#   'gateInComingCnt': '18671',
#   'gateOutGoingCnt': '18215'},
#  {'trnOpDate': '20190423',
#   'staCode': '3310',
#   'gateInComingCnt': '1252',
#   'gateOutGoingCnt': '1297'},
#  {'trnOpDate': '20190423',
#   'staCode': '3320',
#   'gateInComingCnt': '2773',
#   'gateOutGoingCnt': '2743'},
#  {'trnOpDate': '20190423',
#   'staCode': '3330',
#   'gateInComingCnt': '728',
#   'gateOutGoingCnt': '741'},
#  {'trnOpDate': '20190423',
#   'staCode': '3340',
#   'gateInComingCnt': '5109',
#   'gateOutGoingCnt': '4972'},
#  {'trnOpDate': '20190423',
#   'staCode': '3350',
#   'gateInComingCnt': '499',
#   'gateOutGoingCnt': '527'},
#  {'trnOpDate': '20190423',
#   'staCode': '3360',
#   'gateInComingCnt': '10953',
#   'gateOutGoingCnt': '11087'},
#  {'trnOpDate': '20190423',
#   'staCode': '3370',
#   'gateInComingCnt': '912',
#   'gateOutGoingCnt': '984'},
#  {'trnOpDate': '20190423',
#   'staCode': '3380',
#   'gateInComingCnt': '688',
#   'gateOutGoingCnt': '734'},
#  {'trnOpDate': '20190423',
#   'staCode': '3390',
#   'gateInComingCnt': '6807',
#   'gateOutGoingCnt': '6493'},
#  {'trnOpDate': '20190423',
#   'staCode': '3400',
#   'gateInComingCnt': '374',
#   'gateOutGoingCnt': '415'},
#  {'trnOpDate': '20190423',
#   'staCode': '3410',
#   'gateInComingCnt': '952',
#   'gateOutGoingCnt': '1005'},
#  {'trnOpDate': '20190423',
#   'staCode': '3420',
#   'gateInComingCnt': '2230',
#   'gateOutGoingCnt': '2090'},
#  {'trnOpDate': '20190423',
#   'staCode': '3430',
#   'gateInComingCnt': '868',
#   'gateOutGoingCnt': '824'},
#  {'trnOpDate': '20190423',
#   'staCode': '3431',
#   'gateInComingCnt': '17',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20190423',
#   'staCode': '3432',
#   'gateInComingCnt': '70',
#   'gateOutGoingCnt': '63'},
#  {'trnOpDate': '20190423',
#   'staCode': '3433',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20190423',
#   'staCode': '3434',
#   'gateInComingCnt': '299',
#   'gateOutGoingCnt': '127'},
#  {'trnOpDate': '20190423',
#   'staCode': '3435',
#   'gateInComingCnt': '134',
#   'gateOutGoingCnt': '118'},
#  {'trnOpDate': '20190423',
#   'staCode': '3436',
#   'gateInComingCnt': '169',
#   'gateOutGoingCnt': '363'},
#  {'trnOpDate': '20190423',
#   'staCode': '3450',
#   'gateInComingCnt': '537',
#   'gateOutGoingCnt': '593'},
#  {'trnOpDate': '20190423',
#   'staCode': '3460',
#   'gateInComingCnt': '106',
#   'gateOutGoingCnt': '137'},
#  {'trnOpDate': '20190423',
#   'staCode': '3470',
#   'gateInComingCnt': '4351',
#   'gateOutGoingCnt': '4333'},
#  {'trnOpDate': '20190423',
#   'staCode': '3480',
#   'gateInComingCnt': '1428',
#   'gateOutGoingCnt': '1427'},
#  {'trnOpDate': '20190423',
#   'staCode': '3490',
#   'gateInComingCnt': '116',
#   'gateOutGoingCnt': '134'},
#  {'trnOpDate': '20190423',
#   'staCode': '4050',
#   'gateInComingCnt': '1380',
#   'gateOutGoingCnt': '1392'},
#  {'trnOpDate': '20190423',
#   'staCode': '4060',
#   'gateInComingCnt': '1313',
#   'gateOutGoingCnt': '1456'},
#  {'trnOpDate': '20190423',
#   'staCode': '4070',
#   'gateInComingCnt': '887',
#   'gateOutGoingCnt': '931'},
#  {'trnOpDate': '20190423',
#   'staCode': '4080',
#   'gateInComingCnt': '7719',
#   'gateOutGoingCnt': '7631'},
#  {'trnOpDate': '20190423',
#   'staCode': '4090',
#   'gateInComingCnt': '539',
#   'gateOutGoingCnt': '597'},
#  {'trnOpDate': '20190423',
#   'staCode': '4100',
#   'gateInComingCnt': '135',
#   'gateOutGoingCnt': '145'},
#  {'trnOpDate': '20190423',
#   'staCode': '4110',
#   'gateInComingCnt': '447',
#   'gateOutGoingCnt': '475'},
#  {'trnOpDate': '20190423',
#   'staCode': '4120',
#   'gateInComingCnt': '4398',
#   'gateOutGoingCnt': '4315'},
#  {'trnOpDate': '20190423',
#   'staCode': '4130',
#   'gateInComingCnt': '972',
#   'gateOutGoingCnt': '939'},
#  {'trnOpDate': '20190423',
#   'staCode': '4140',
#   'gateInComingCnt': '480',
#   'gateOutGoingCnt': '506'},
#  {'trnOpDate': '20190423',
#   'staCode': '4150',
#   'gateInComingCnt': '1184',
#   'gateOutGoingCnt': '1183'},
#  {'trnOpDate': '20190423',
#   'staCode': '4160',
#   'gateInComingCnt': '131',
#   'gateOutGoingCnt': '134'},
#  {'trnOpDate': '20190423',
#   'staCode': '4170',
#   'gateInComingCnt': '3037',
#   'gateOutGoingCnt': '3094'},
#  {'trnOpDate': '20190423',
#   'staCode': '4180',
#   'gateInComingCnt': '1344',
#   'gateOutGoingCnt': '1295'},
#  {'trnOpDate': '20190423',
#   'staCode': '4190',
#   'gateInComingCnt': '2180',
#   'gateOutGoingCnt': '2179'},
#  {'trnOpDate': '20190423',
#   'staCode': '4200',
#   'gateInComingCnt': '2206',
#   'gateOutGoingCnt': '2357'},
#  {'trnOpDate': '20190423',
#   'staCode': '4210',
#   'gateInComingCnt': '3474',
#   'gateOutGoingCnt': '3325'},
#  {'trnOpDate': '20190423',
#   'staCode': '4220',
#   'gateInComingCnt': '19776',
#   'gateOutGoingCnt': '20011'},
#  {'trnOpDate': '20190423',
#   'staCode': '4250',
#   'gateInComingCnt': '1254',
#   'gateOutGoingCnt': '1264'},
#  {'trnOpDate': '20190423',
#   'staCode': '4260',
#   'gateInComingCnt': '685',
#   'gateOutGoingCnt': '679'},
#  {'trnOpDate': '20190423',
#   'staCode': '4270',
#   'gateInComingCnt': '420',
#   'gateOutGoingCnt': '412'},
#  {'trnOpDate': '20190423',
#   'staCode': '4271',
#   'gateInComingCnt': '912',
#   'gateOutGoingCnt': '956'},
#  {'trnOpDate': '20190423',
#   'staCode': '4272',
#   'gateInComingCnt': '1623',
#   'gateOutGoingCnt': '1531'},
#  {'trnOpDate': '20190423',
#   'staCode': '4290',
#   'gateInComingCnt': '2116',
#   'gateOutGoingCnt': '1709'},
#  {'trnOpDate': '20190423',
#   'staCode': '4300',
#   'gateInComingCnt': '1397',
#   'gateOutGoingCnt': '1522'},
#  {'trnOpDate': '20190423',
#   'staCode': '4310',
#   'gateInComingCnt': '2240',
#   'gateOutGoingCnt': '2232'},
#  {'trnOpDate': '20190423',
#   'staCode': '4320',
#   'gateInComingCnt': '1133',
#   'gateOutGoingCnt': '1326'},
#  {'trnOpDate': '20190423',
#   'staCode': '4330',
#   'gateInComingCnt': '1987',
#   'gateOutGoingCnt': '2055'},
#  {'trnOpDate': '20190423',
#   'staCode': '4340',
#   'gateInComingCnt': '8017',
#   'gateOutGoingCnt': '9541'},
#  {'trnOpDate': '20190423',
#   'staCode': '4350',
#   'gateInComingCnt': '817',
#   'gateOutGoingCnt': '742'},
#  {'trnOpDate': '20190423',
#   'staCode': '4360',
#   'gateInComingCnt': '553',
#   'gateOutGoingCnt': '551'},
#  {'trnOpDate': '20190423',
#   'staCode': '4370',
#   'gateInComingCnt': '704',
#   'gateOutGoingCnt': '633'},
#  {'trnOpDate': '20190423',
#   'staCode': '4380',
#   'gateInComingCnt': '144',
#   'gateOutGoingCnt': '157'},
#  {'trnOpDate': '20190423',
#   'staCode': '4390',
#   'gateInComingCnt': '356',
#   'gateOutGoingCnt': '358'},
#  {'trnOpDate': '20190423',
#   'staCode': '4400',
#   'gateInComingCnt': '12919',
#   'gateOutGoingCnt': '12237'},
#  {'trnOpDate': '20190423',
#   'staCode': '4410',
#   'gateInComingCnt': '490',
#   'gateOutGoingCnt': '487'},
#  {'trnOpDate': '20190423',
#   'staCode': '4420',
#   'gateInComingCnt': '746',
#   'gateOutGoingCnt': '758'},
#  {'trnOpDate': '20190423',
#   'staCode': '4430',
#   'gateInComingCnt': '793',
#   'gateOutGoingCnt': '714'},
#  {'trnOpDate': '20190423',
#   'staCode': '4440',
#   'gateInComingCnt': '4331',
#   'gateOutGoingCnt': '3978'},
#  {'trnOpDate': '20190423',
#   'staCode': '4450',
#   'gateInComingCnt': '469',
#   'gateOutGoingCnt': '557'},
#  {'trnOpDate': '20190423',
#   'staCode': '4460',
#   'gateInComingCnt': '931',
#   'gateOutGoingCnt': '989'},
#  {'trnOpDate': '20190423',
#   'staCode': '4470',
#   'gateInComingCnt': '138',
#   'gateOutGoingCnt': '142'},
#  {'trnOpDate': '20190423',
#   'staCode': '5000',
#   'gateInComingCnt': '7688',
#   'gateOutGoingCnt': '8131'},
#  {'trnOpDate': '20190423',
#   'staCode': '5010',
#   'gateInComingCnt': '181',
#   'gateOutGoingCnt': '187'},
#  {'trnOpDate': '20190423',
#   'staCode': '5020',
#   'gateInComingCnt': '119',
#   'gateOutGoingCnt': '142'},
#  {'trnOpDate': '20190423',
#   'staCode': '5030',
#   'gateInComingCnt': '494',
#   'gateOutGoingCnt': '446'},
#  {'trnOpDate': '20190423',
#   'staCode': '5040',
#   'gateInComingCnt': '246',
#   'gateOutGoingCnt': '247'},
#  {'trnOpDate': '20190423',
#   'staCode': '5050',
#   'gateInComingCnt': '2897',
#   'gateOutGoingCnt': '2908'},
#  {'trnOpDate': '20190423',
#   'staCode': '5060',
#   'gateInComingCnt': '113',
#   'gateOutGoingCnt': '167'},
#  {'trnOpDate': '20190423',
#   'staCode': '5070',
#   'gateInComingCnt': '449',
#   'gateOutGoingCnt': '340'},
#  {'trnOpDate': '20190423',
#   'staCode': '5080',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20190423',
#   'staCode': '5090',
#   'gateInComingCnt': '321',
#   'gateOutGoingCnt': '278'},
#  {'trnOpDate': '20190423',
#   'staCode': '5100',
#   'gateInComingCnt': '74',
#   'gateOutGoingCnt': '74'},
#  {'trnOpDate': '20190423',
#   'staCode': '5110',
#   'gateInComingCnt': '58',
#   'gateOutGoingCnt': '42'},
#  {'trnOpDate': '20190423',
#   'staCode': '5120',
#   'gateInComingCnt': '604',
#   'gateOutGoingCnt': '560'},
#  {'trnOpDate': '20190423',
#   'staCode': '5130',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20190423',
#   'staCode': '5140',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20190423',
#   'staCode': '5160',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20190423',
#   'staCode': '5190',
#   'gateInComingCnt': '155',
#   'gateOutGoingCnt': '142'},
#  {'trnOpDate': '20190423',
#   'staCode': '5200',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '60'},
#  {'trnOpDate': '20190423',
#   'staCode': '5210',
#   'gateInComingCnt': '424',
#   'gateOutGoingCnt': '456'},
#  {'trnOpDate': '20190423',
#   'staCode': '5220',
#   'gateInComingCnt': '118',
#   'gateOutGoingCnt': '127'},
#  {'trnOpDate': '20190423',
#   'staCode': '5230',
#   'gateInComingCnt': '695',
#   'gateOutGoingCnt': '613'},
#  {'trnOpDate': '20190423',
#   'staCode': '5240',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20190423',
#   'staCode': '6000',
#   'gateInComingCnt': '4295',
#   'gateOutGoingCnt': '3988'},
#  {'trnOpDate': '20190423',
#   'staCode': '6010',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20190423',
#   'staCode': '6020',
#   'gateInComingCnt': '176',
#   'gateOutGoingCnt': '173'},
#  {'trnOpDate': '20190423',
#   'staCode': '6030',
#   'gateInComingCnt': '23',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20190423',
#   'staCode': '6040',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20190423',
#   'staCode': '6050',
#   'gateInComingCnt': '574',
#   'gateOutGoingCnt': '498'},
#  {'trnOpDate': '20190423',
#   'staCode': '6060',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20190423',
#   'staCode': '6070',
#   'gateInComingCnt': '426',
#   'gateOutGoingCnt': '457'},
#  {'trnOpDate': '20190423',
#   'staCode': '6080',
#   'gateInComingCnt': '121',
#   'gateOutGoingCnt': '161'},
#  {'trnOpDate': '20190423',
#   'staCode': '6090',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '21'},
#  {'trnOpDate': '20190423',
#   'staCode': '6100',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20190423',
#   'staCode': '6110',
#   'gateInComingCnt': '1134',
#   'gateOutGoingCnt': '1164'},
#  {'trnOpDate': '20190423',
#   'staCode': '6120',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20190423',
#   'staCode': '6130',
#   'gateInComingCnt': '493',
#   'gateOutGoingCnt': '551'},
#  {'trnOpDate': '20190423',
#   'staCode': '6140',
#   'gateInComingCnt': '33',
#   'gateOutGoingCnt': '40'},
#  {'trnOpDate': '20190423',
#   'staCode': '6150',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '5'},
#  {'trnOpDate': '20190423',
#   'staCode': '6160',
#   'gateInComingCnt': '412',
#   'gateOutGoingCnt': '367'},
#  {'trnOpDate': '20190423',
#   'staCode': '6170',
#   'gateInComingCnt': '31',
#   'gateOutGoingCnt': '43'},
#  {'trnOpDate': '20190423',
#   'staCode': '6180',
#   'gateInComingCnt': '408',
#   'gateOutGoingCnt': '350'},
#  {'trnOpDate': '20190423',
#   'staCode': '6190',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '21'},
#  {'trnOpDate': '20190423',
#   'staCode': '6200',
#   'gateInComingCnt': '113',
#   'gateOutGoingCnt': '95'},
#  {'trnOpDate': '20190423',
#   'staCode': '6210',
#   'gateInComingCnt': '68',
#   'gateOutGoingCnt': '59'},
#  {'trnOpDate': '20190423',
#   'staCode': '6220',
#   'gateInComingCnt': '258',
#   'gateOutGoingCnt': '283'},
#  {'trnOpDate': '20190423',
#   'staCode': '6230',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20190423',
#   'staCode': '6240',
#   'gateInComingCnt': '219',
#   'gateOutGoingCnt': '280'},
#  {'trnOpDate': '20190423',
#   'staCode': '6250',
#   'gateInComingCnt': '512',
#   'gateOutGoingCnt': '405'},
#  {'trnOpDate': '20190423',
#   'staCode': '7000',
#   'gateInComingCnt': '13066',
#   'gateOutGoingCnt': '12695'},
#  {'trnOpDate': '20190423',
#   'staCode': '7010',
#   'gateInComingCnt': '119',
#   'gateOutGoingCnt': '147'},
#  {'trnOpDate': '20190423',
#   'staCode': '7020',
#   'gateInComingCnt': '21',
#   'gateOutGoingCnt': '26'},
#  {'trnOpDate': '20190423',
#   'staCode': '7030',
#   'gateInComingCnt': '3551',
#   'gateOutGoingCnt': '1487'},
#  {'trnOpDate': '20190423',
#   'staCode': '7040',
#   'gateInComingCnt': '41',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20190423',
#   'staCode': '7050',
#   'gateInComingCnt': '49',
#   'gateOutGoingCnt': '88'},
#  {'trnOpDate': '20190423',
#   'staCode': '7060',
#   'gateInComingCnt': '539',
#   'gateOutGoingCnt': '588'},
#  {'trnOpDate': '20190423',
#   'staCode': '7070',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '20'},
#  {'trnOpDate': '20190423',
#   'staCode': '7080',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20190423',
#   'staCode': '7090',
#   'gateInComingCnt': '1036',
#   'gateOutGoingCnt': '1091'},
#  {'trnOpDate': '20190423',
#   'staCode': '7100',
#   'gateInComingCnt': '164',
#   'gateOutGoingCnt': '152'},
#  {'trnOpDate': '20190423',
#   'staCode': '7110',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20190423',
#   'staCode': '7120',
#   'gateInComingCnt': '623',
#   'gateOutGoingCnt': '658'},
#  {'trnOpDate': '20190423',
#   'staCode': '7130',
#   'gateInComingCnt': '990',
#   'gateOutGoingCnt': '4192'},
#  {'trnOpDate': '20190423',
#   'staCode': '7140',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20190423',
#   'staCode': '7150',
#   'gateInComingCnt': '2419',
#   'gateOutGoingCnt': '2460'},
#  {'trnOpDate': '20190423',
#   'staCode': '7160',
#   'gateInComingCnt': '5012',
#   'gateOutGoingCnt': '5106'},
#  {'trnOpDate': '20190423',
#   'staCode': '7170',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '52'},
#  {'trnOpDate': '20190423',
#   'staCode': '7180',
#   'gateInComingCnt': '123',
#   'gateOutGoingCnt': '131'},
#  {'trnOpDate': '20190423',
#   'staCode': '7190',
#   'gateInComingCnt': '4168',
#   'gateOutGoingCnt': '4215'},
#  {'trnOpDate': '20190423',
#   'staCode': '7200',
#   'gateInComingCnt': '125',
#   'gateOutGoingCnt': '128'},
#  {'trnOpDate': '20190423',
#   'staCode': '7210',
#   'gateInComingCnt': '1374',
#   'gateOutGoingCnt': '1425'},
#  {'trnOpDate': '20190423',
#   'staCode': '7220',
#   'gateInComingCnt': '101',
#   'gateOutGoingCnt': '104'},
#  {'trnOpDate': '20190423',
#   'staCode': '7230',
#   'gateInComingCnt': '1176',
#   'gateOutGoingCnt': '1082'},
#  {'trnOpDate': '20190423',
#   'staCode': '7240',
#   'gateInComingCnt': '43',
#   'gateOutGoingCnt': '63'},
#  {'trnOpDate': '20190423',
#   'staCode': '7250',
#   'gateInComingCnt': '59',
#   'gateOutGoingCnt': '78'},
#  {'trnOpDate': '20190423',
#   'staCode': '7260',
#   'gateInComingCnt': '163',
#   'gateOutGoingCnt': '205'},
#  {'trnOpDate': '20190423',
#   'staCode': '7270',
#   'gateInComingCnt': '133',
#   'gateOutGoingCnt': '92'},
#  {'trnOpDate': '20190423',
#   'staCode': '7280',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20190423',
#   'staCode': '7290',
#   'gateInComingCnt': '883',
#   'gateOutGoingCnt': '948'},
#  {'trnOpDate': '20190423',
#   'staCode': '7300',
#   'gateInComingCnt': '170',
#   'gateOutGoingCnt': '189'},
#  {'trnOpDate': '20190423',
#   'staCode': '7310',
#   'gateInComingCnt': '688',
#   'gateOutGoingCnt': '731'},
#  {'trnOpDate': '20190423',
#   'staCode': '7320',
#   'gateInComingCnt': '91',
#   'gateOutGoingCnt': '114'},
#  {'trnOpDate': '20190423',
#   'staCode': '7330',
#   'gateInComingCnt': '59',
#   'gateOutGoingCnt': '62'},
#  {'trnOpDate': '20190423',
#   'staCode': '7331',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20190423',
#   'staCode': '7332',
#   'gateInComingCnt': '1166',
#   'gateOutGoingCnt': '1278'},
#  {'trnOpDate': '20190423',
#   'staCode': '7333',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20190423',
#   'staCode': '7334',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '24'},
#  {'trnOpDate': '20190423',
#   'staCode': '7335',
#   'gateInComingCnt': '176',
#   'gateOutGoingCnt': '227'},
#  {'trnOpDate': '20190423',
#   'staCode': '7336',
#   'gateInComingCnt': '352',
#   'gateOutGoingCnt': '226'},
#  {'trnOpDate': '20190423',
#   'staCode': '7350',
#   'gateInComingCnt': '464',
#   'gateOutGoingCnt': '488'},
#  {'trnOpDate': '20190423',
#   'staCode': '7360',
#   'gateInComingCnt': '5062',
#   'gateOutGoingCnt': '5495'},
#  {'trnOpDate': '20190423',
#   'staCode': '7361',
#   'gateInComingCnt': '72',
#   'gateOutGoingCnt': '52'},
#  {'trnOpDate': '20190423',
#   'staCode': '7362',
#   'gateInComingCnt': '120',
#   'gateOutGoingCnt': '181'},
#  {'trnOpDate': '20190423',
#   'staCode': '7380',
#   'gateInComingCnt': '614',
#   'gateOutGoingCnt': '610'},
#  {'trnOpDate': '20190423',
#   'staCode': '7390',
#   'gateInComingCnt': '425',
#   'gateOutGoingCnt': '436'},
#  {'trnOpDate': '20190427',
#   'staCode': '0900',
#   'gateInComingCnt': '8164',
#   'gateOutGoingCnt': '8032'},
#  {'trnOpDate': '20190427',
#   'staCode': '0910',
#   'gateInComingCnt': '1201',
#   'gateOutGoingCnt': '1267'},
#  {'trnOpDate': '20190427',
#   'staCode': '0920',
#   'gateInComingCnt': '1999',
#   'gateOutGoingCnt': '1994'},
#  {'trnOpDate': '20190427',
#   'staCode': '0930',
#   'gateInComingCnt': '4616',
#   'gateOutGoingCnt': '4632'},
#  {'trnOpDate': '20190427',
#   'staCode': '0940',
#   'gateInComingCnt': '2282',
#   'gateOutGoingCnt': '2191'},
#  {'trnOpDate': '20190427',
#   'staCode': '0950',
#   'gateInComingCnt': '1600',
#   'gateOutGoingCnt': '1387'},
#  {'trnOpDate': '20190427',
#   'staCode': '0960',
#   'gateInComingCnt': '9674',
#   'gateOutGoingCnt': '9338'},
#  {'trnOpDate': '20190427',
#   'staCode': '0970',
#   'gateInComingCnt': '6224',
#   'gateOutGoingCnt': '6127'},
#  {'trnOpDate': '20190427',
#   'staCode': '0980',
#   'gateInComingCnt': '9007',
#   'gateOutGoingCnt': '9443'},
#  {'trnOpDate': '20190427',
#   'staCode': '0990',
#   'gateInComingCnt': '15480',
#   'gateOutGoingCnt': '14402'},
#  {'trnOpDate': '20190427',
#   'staCode': '1000',
#   'gateInComingCnt': '70922',
#   'gateOutGoingCnt': '66146'},
#  {'trnOpDate': '20190427',
#   'staCode': '1010',
#   'gateInComingCnt': '4315',
#   'gateOutGoingCnt': '4203'},
#  {'trnOpDate': '20190427',
#   'staCode': '1020',
#   'gateInComingCnt': '23948',
#   'gateOutGoingCnt': '23382'},
#  {'trnOpDate': '20190427',
#   'staCode': '1030',
#   'gateInComingCnt': '3155',
#   'gateOutGoingCnt': '2805'},
#  {'trnOpDate': '20190427',
#   'staCode': '1040',
#   'gateInComingCnt': '15415',
#   'gateOutGoingCnt': '15015'},
#  {'trnOpDate': '20190427',
#   'staCode': '1050',
#   'gateInComingCnt': '1147',
#   'gateOutGoingCnt': '1083'},
#  {'trnOpDate': '20190427',
#   'staCode': '1060',
#   'gateInComingCnt': '1522',
#   'gateOutGoingCnt': '1493'},
#  {'trnOpDate': '20190427',
#   'staCode': '1070',
#   'gateInComingCnt': '8815',
#   'gateOutGoingCnt': '8889'},
#  {'trnOpDate': '20190427',
#   'staCode': '1080',
#   'gateInComingCnt': '30519',
#   'gateOutGoingCnt': '31662'},
#  {'trnOpDate': '20190427',
#   'staCode': '1090',
#   'gateInComingCnt': '9723',
#   'gateOutGoingCnt': '9343'},
#  {'trnOpDate': '20190427',
#   'staCode': '1100',
#   'gateInComingCnt': '31855',
#   'gateOutGoingCnt': '31394'},
#  {'trnOpDate': '20190427',
#   'staCode': '1110',
#   'gateInComingCnt': '5815',
#   'gateOutGoingCnt': '5404'},
#  {'trnOpDate': '20190427',
#   'staCode': '1120',
#   'gateInComingCnt': '5102',
#   'gateOutGoingCnt': '5148'},
#  {'trnOpDate': '20190427',
#   'staCode': '1130',
#   'gateInComingCnt': '1822',
#   'gateOutGoingCnt': '1867'},
#  {'trnOpDate': '20190427',
#   'staCode': '1140',
#   'gateInComingCnt': '98',
#   'gateOutGoingCnt': '98'},
#  {'trnOpDate': '20190427',
#   'staCode': '1150',
#   'gateInComingCnt': '755',
#   'gateOutGoingCnt': '736'},
#  {'trnOpDate': '20190427',
#   'staCode': '1160',
#   'gateInComingCnt': '4145',
#   'gateOutGoingCnt': '4180'},
#  {'trnOpDate': '20190427',
#   'staCode': '1170',
#   'gateInComingCnt': '5939',
#   'gateOutGoingCnt': '5397'},
#  {'trnOpDate': '20190427',
#   'staCode': '1180',
#   'gateInComingCnt': '5537',
#   'gateOutGoingCnt': '5349'},
#  {'trnOpDate': '20190427',
#   'staCode': '1190',
#   'gateInComingCnt': '1985',
#   'gateOutGoingCnt': '2083'},
#  {'trnOpDate': '20190427',
#   'staCode': '1191',
#   'gateInComingCnt': '442',
#   'gateOutGoingCnt': '326'},
#  {'trnOpDate': '20190427',
#   'staCode': '1192',
#   'gateInComingCnt': '2114',
#   'gateOutGoingCnt': '1732'},
#  {'trnOpDate': '20190427',
#   'staCode': '1193',
#   'gateInComingCnt': '997',
#   'gateOutGoingCnt': '865'},
#  {'trnOpDate': '20190427',
#   'staCode': '1194',
#   'gateInComingCnt': '3069',
#   'gateOutGoingCnt': '3078'},
#  {'trnOpDate': '20190427',
#   'staCode': '1201',
#   'gateInComingCnt': '85',
#   'gateOutGoingCnt': '87'},
#  {'trnOpDate': '20190427',
#   'staCode': '1202',
#   'gateInComingCnt': '198',
#   'gateOutGoingCnt': '153'},
#  {'trnOpDate': '20190427',
#   'staCode': '1203',
#   'gateInComingCnt': '937',
#   'gateOutGoingCnt': '710'},
#  {'trnOpDate': '20190427',
#   'staCode': '1204',
#   'gateInComingCnt': '120',
#   'gateOutGoingCnt': '133'},
#  {'trnOpDate': '20190427',
#   'staCode': '1205',
#   'gateInComingCnt': '66',
#   'gateOutGoingCnt': '82'},
#  {'trnOpDate': '20190427',
#   'staCode': '1206',
#   'gateInComingCnt': '181',
#   'gateOutGoingCnt': '206'},
#  {'trnOpDate': '20190427',
#   'staCode': '1207',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '50'},
#  {'trnOpDate': '20190427',
#   'staCode': '1208',
#   'gateInComingCnt': '1349',
#   'gateOutGoingCnt': '1503'},
#  {'trnOpDate': '20190427',
#   'staCode': '1210',
#   'gateInComingCnt': '25605',
#   'gateOutGoingCnt': '25555'},
#  {'trnOpDate': '20190427',
#   'staCode': '1220',
#   'gateInComingCnt': '1096',
#   'gateOutGoingCnt': '924'},
#  {'trnOpDate': '20190427',
#   'staCode': '1230',
#   'gateInComingCnt': '513',
#   'gateOutGoingCnt': '562'},
#  {'trnOpDate': '20190427',
#   'staCode': '1240',
#   'gateInComingCnt': '242',
#   'gateOutGoingCnt': '302'},
#  {'trnOpDate': '20190427',
#   'staCode': '1250',
#   'gateInComingCnt': '8805',
#   'gateOutGoingCnt': '9003'},
#  {'trnOpDate': '20190427',
#   'staCode': '2110',
#   'gateInComingCnt': '35',
#   'gateOutGoingCnt': '49'},
#  {'trnOpDate': '20190427',
#   'staCode': '2120',
#   'gateInComingCnt': '124',
#   'gateOutGoingCnt': '113'},
#  {'trnOpDate': '20190427',
#   'staCode': '2130',
#   'gateInComingCnt': '998',
#   'gateOutGoingCnt': '1034'},
#  {'trnOpDate': '20190427',
#   'staCode': '2140',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20190427',
#   'staCode': '2150',
#   'gateInComingCnt': '1762',
#   'gateOutGoingCnt': '2182'},
#  {'trnOpDate': '20190427',
#   'staCode': '2160',
#   'gateInComingCnt': '90',
#   'gateOutGoingCnt': '103'},
#  {'trnOpDate': '20190427',
#   'staCode': '2170',
#   'gateInComingCnt': '1028',
#   'gateOutGoingCnt': '1321'},
#  {'trnOpDate': '20190427',
#   'staCode': '2180',
#   'gateInComingCnt': '1712',
#   'gateOutGoingCnt': '1952'},
#  {'trnOpDate': '20190427',
#   'staCode': '2190',
#   'gateInComingCnt': '317',
#   'gateOutGoingCnt': '339'},
#  {'trnOpDate': '20190427',
#   'staCode': '2200',
#   'gateInComingCnt': '4627',
#   'gateOutGoingCnt': '4764'},
#  {'trnOpDate': '20190427',
#   'staCode': '2210',
#   'gateInComingCnt': '71',
#   'gateOutGoingCnt': '78'},
#  {'trnOpDate': '20190427',
#   'staCode': '2220',
#   'gateInComingCnt': '1356',
#   'gateOutGoingCnt': '1460'},
#  {'trnOpDate': '20190427',
#   'staCode': '2230',
#   'gateInComingCnt': '3441',
#   'gateOutGoingCnt': '3071'},
#  {'trnOpDate': '20190427',
#   'staCode': '2240',
#   'gateInComingCnt': '497',
#   'gateOutGoingCnt': '511'},
#  {'trnOpDate': '20190427',
#   'staCode': '2250',
#   'gateInComingCnt': '833',
#   'gateOutGoingCnt': '743'},
#  {'trnOpDate': '20190427',
#   'staCode': '2260',
#   'gateInComingCnt': '2090',
#   'gateOutGoingCnt': '333'},
#  {'trnOpDate': '20190427',
#   'staCode': '3140',
#   'gateInComingCnt': '282',
#   'gateOutGoingCnt': '359'},
#  {'trnOpDate': '20190427',
#   'staCode': '3150',
#   'gateInComingCnt': '907',
#   'gateOutGoingCnt': '914'},
#  {'trnOpDate': '20190427',
#   'staCode': '3160',
#   'gateInComingCnt': '6195',
#   'gateOutGoingCnt': '6595'},
#  {'trnOpDate': '20190427',
#   'staCode': '3170',
#   'gateInComingCnt': '92',
#   'gateOutGoingCnt': '126'},
#  {'trnOpDate': '20190427',
#   'staCode': '3180',
#   'gateInComingCnt': '1111',
#   'gateOutGoingCnt': '1163'},
#  {'trnOpDate': '20190427',
#   'staCode': '3190',
#   'gateInComingCnt': '1117',
#   'gateOutGoingCnt': '1368'},
#  {'trnOpDate': '20190427',
#   'staCode': '3210',
#   'gateInComingCnt': '625',
#   'gateOutGoingCnt': '772'},
#  {'trnOpDate': '20190427',
#   'staCode': '3220',
#   'gateInComingCnt': '4254',
#   'gateOutGoingCnt': '4449'},
#  {'trnOpDate': '20190427',
#   'staCode': '3230',
#   'gateInComingCnt': '10289',
#   'gateOutGoingCnt': '10822'},
#  {'trnOpDate': '20190427',
#   'staCode': '3240',
#   'gateInComingCnt': '646',
#   'gateOutGoingCnt': '621'},
#  {'trnOpDate': '20190427',
#   'staCode': '3250',
#   'gateInComingCnt': '3280',
#   'gateOutGoingCnt': '3062'},
#  {'trnOpDate': '20190427',
#   'staCode': '3260',
#   'gateInComingCnt': '596',
#   'gateOutGoingCnt': '585'},
#  {'trnOpDate': '20190427',
#   'staCode': '3270',
#   'gateInComingCnt': '1302',
#   'gateOutGoingCnt': '1292'},
#  {'trnOpDate': '20190427',
#   'staCode': '3280',
#   'gateInComingCnt': '3807',
#   'gateOutGoingCnt': '3635'},
#  {'trnOpDate': '20190427',
#   'staCode': '3290',
#   'gateInComingCnt': '1301',
#   'gateOutGoingCnt': '1161'},
#  {'trnOpDate': '20190427',
#   'staCode': '3300',
#   'gateInComingCnt': '34265',
#   'gateOutGoingCnt': '33995'},
#  {'trnOpDate': '20190427',
#   'staCode': '3310',
#   'gateInComingCnt': '1571',
#   'gateOutGoingCnt': '1488'},
#  {'trnOpDate': '20190427',
#   'staCode': '3320',
#   'gateInComingCnt': '3245',
#   'gateOutGoingCnt': '2995'},
#  {'trnOpDate': '20190427',
#   'staCode': '3330',
#   'gateInComingCnt': '1035',
#   'gateOutGoingCnt': '1035'},
#  {'trnOpDate': '20190427',
#   'staCode': '3340',
#   'gateInComingCnt': '10807',
#   'gateOutGoingCnt': '8879'},
#  {'trnOpDate': '20190427',
#   'staCode': '3350',
#   'gateInComingCnt': '738',
#   'gateOutGoingCnt': '2406'},
#  {'trnOpDate': '20190427',
#   'staCode': '3360',
#   'gateInComingCnt': '18493',
#   'gateOutGoingCnt': '18727'},
#  {'trnOpDate': '20190427',
#   'staCode': '3370',
#   'gateInComingCnt': '1373',
#   'gateOutGoingCnt': '1505'},
#  {'trnOpDate': '20190427',
#   'staCode': '3380',
#   'gateInComingCnt': '1112',
#   'gateOutGoingCnt': '1104'},
#  {'trnOpDate': '20190427',
#   'staCode': '3390',
#   'gateInComingCnt': '9570',
#   'gateOutGoingCnt': '10045'},
#  {'trnOpDate': '20190427',
#   'staCode': '3400',
#   'gateInComingCnt': '525',
#   'gateOutGoingCnt': '686'},
#  {'trnOpDate': '20190427',
#   'staCode': '3410',
#   'gateInComingCnt': '1244',
#   'gateOutGoingCnt': '1436'},
#  {'trnOpDate': '20190427',
#   'staCode': '3420',
#   'gateInComingCnt': '2905',
#   'gateOutGoingCnt': '3249'},
#  {'trnOpDate': '20190427',
#   'staCode': '3430',
#   'gateInComingCnt': '1226',
#   'gateOutGoingCnt': '1334'},
#  {'trnOpDate': '20190427',
#   'staCode': '3431',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '20'},
#  {'trnOpDate': '20190427',
#   'staCode': '3432',
#   'gateInComingCnt': '143',
#   'gateOutGoingCnt': '133'},
#  {'trnOpDate': '20190427',
#   'staCode': '3433',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '24'},
#  {'trnOpDate': '20190427',
#   'staCode': '3434',
#   'gateInComingCnt': '747',
#   'gateOutGoingCnt': '501'},
#  {'trnOpDate': '20190427',
#   'staCode': '3435',
#   'gateInComingCnt': '203',
#   'gateOutGoingCnt': '338'},
#  {'trnOpDate': '20190427',
#   'staCode': '3436',
#   'gateInComingCnt': '691',
#   'gateOutGoingCnt': '886'},
#  {'trnOpDate': '20190427',
#   'staCode': '3450',
#   'gateInComingCnt': '892',
#   'gateOutGoingCnt': '995'},
#  {'trnOpDate': '20190427',
#   'staCode': '3460',
#   'gateInComingCnt': '221',
#   'gateOutGoingCnt': '291'},
#  {'trnOpDate': '20190427',
#   'staCode': '3470',
#   'gateInComingCnt': '7626',
#   'gateOutGoingCnt': '7661'},
#  {'trnOpDate': '20190427',
#   'staCode': '3480',
#   'gateInComingCnt': '2301',
#   'gateOutGoingCnt': '2512'},
#  {'trnOpDate': '20190427',
#   'staCode': '3490',
#   'gateInComingCnt': '138',
#   'gateOutGoingCnt': '181'},
#  {'trnOpDate': '20190427',
#   'staCode': '4050',
#   'gateInComingCnt': '1931',
#   'gateOutGoingCnt': '1635'},
#  {'trnOpDate': '20190427',
#   'staCode': '4060',
#   'gateInComingCnt': '2726',
#   'gateOutGoingCnt': '2775'},
#  {'trnOpDate': '20190427',
#   'staCode': '4070',
#   'gateInComingCnt': '777',
#   'gateOutGoingCnt': '836'},
#  {'trnOpDate': '20190427',
#   'staCode': '4080',
#   'gateInComingCnt': '12343',
#   'gateOutGoingCnt': '13576'},
#  {'trnOpDate': '20190427',
#   'staCode': '4090',
#   'gateInComingCnt': '746',
#   'gateOutGoingCnt': '818'},
#  {'trnOpDate': '20190427',
#   'staCode': '4100',
#   'gateInComingCnt': '162',
#   'gateOutGoingCnt': '212'},
#  {'trnOpDate': '20190427',
#   'staCode': '4110',
#   'gateInComingCnt': '588',
#   'gateOutGoingCnt': '606'},
#  {'trnOpDate': '20190427',
#   'staCode': '4120',
#   'gateInComingCnt': '5401',
#   'gateOutGoingCnt': '5809'},
#  {'trnOpDate': '20190427',
#   'staCode': '4130',
#   'gateInComingCnt': '579',
#   'gateOutGoingCnt': '637'},
#  {'trnOpDate': '20190427',
#   'staCode': '4140',
#   'gateInComingCnt': '575',
#   'gateOutGoingCnt': '646'},
#  {'trnOpDate': '20190427',
#   'staCode': '4150',
#   'gateInComingCnt': '1491',
#   'gateOutGoingCnt': '1258'},
#  {'trnOpDate': '20190427',
#   'staCode': '4160',
#   'gateInComingCnt': '135',
#   'gateOutGoingCnt': '159'},
#  {'trnOpDate': '20190427',
#   'staCode': '4170',
#   'gateInComingCnt': '3492',
#   'gateOutGoingCnt': '3325'},
#  {'trnOpDate': '20190427',
#   'staCode': '4180',
#   'gateInComingCnt': '931',
#   'gateOutGoingCnt': '785'},
#  {'trnOpDate': '20190427',
#   'staCode': '4190',
#   'gateInComingCnt': '2715',
#   'gateOutGoingCnt': '2261'},
#  {'trnOpDate': '20190427',
#   'staCode': '4200',
#   'gateInComingCnt': '3438',
#   'gateOutGoingCnt': '3140'},
#  {'trnOpDate': '20190427',
#   'staCode': '4210',
#   'gateInComingCnt': '3643',
#   'gateOutGoingCnt': '3217'},
#  {'trnOpDate': '20190427',
#   'staCode': '4220',
#   'gateInComingCnt': '30962',
#   'gateOutGoingCnt': '32144'},
#  {'trnOpDate': '20190427',
#   'staCode': '4250',
#   'gateInComingCnt': '1728',
#   'gateOutGoingCnt': '1542'},
#  {'trnOpDate': '20190427',
#   'staCode': '4260',
#   'gateInComingCnt': '1017',
#   'gateOutGoingCnt': '986'},
#  {'trnOpDate': '20190427',
#   'staCode': '4270',
#   'gateInComingCnt': '524',
#   'gateOutGoingCnt': '433'},
#  {'trnOpDate': '20190427',
#   'staCode': '4271',
#   'gateInComingCnt': '968',
#   'gateOutGoingCnt': '797'},
#  {'trnOpDate': '20190427',
#   'staCode': '4272',
#   'gateInComingCnt': '2966',
#   'gateOutGoingCnt': '2314'},
#  {'trnOpDate': '20190427',
#   'staCode': '4290',
#   'gateInComingCnt': '1401',
#   'gateOutGoingCnt': '1355'},
#  {'trnOpDate': '20190427',
#   'staCode': '4300',
#   'gateInComingCnt': '1907',
#   'gateOutGoingCnt': '1822'},
#  {'trnOpDate': '20190427',
#   'staCode': '4310',
#   'gateInComingCnt': '4012',
#   'gateOutGoingCnt': '3864'},
#  {'trnOpDate': '20190427',
#   'staCode': '4320',
#   'gateInComingCnt': '1788',
#   'gateOutGoingCnt': '2003'},
#  {'trnOpDate': '20190427',
#   'staCode': '4330',
#   'gateInComingCnt': '2759',
#   'gateOutGoingCnt': '2417'},
#  {'trnOpDate': '20190427',
#   'staCode': '4340',
#   'gateInComingCnt': '12504',
#   'gateOutGoingCnt': '11857'},
#  {'trnOpDate': '20190427',
#   'staCode': '4350',
#   'gateInComingCnt': '765',
#   'gateOutGoingCnt': '811'},
#  {'trnOpDate': '20190427',
#   'staCode': '4360',
#   'gateInComingCnt': '673',
#   'gateOutGoingCnt': '704'},
#  {'trnOpDate': '20190427',
#   'staCode': '4370',
#   'gateInComingCnt': '819',
#   'gateOutGoingCnt': '814'},
#  {'trnOpDate': '20190427',
#   'staCode': '4380',
#   'gateInComingCnt': '247',
#   'gateOutGoingCnt': '246'},
#  {'trnOpDate': '20190427',
#   'staCode': '4390',
#   'gateInComingCnt': '366',
#   'gateOutGoingCnt': '356'},
#  {'trnOpDate': '20190427',
#   'staCode': '4400',
#   'gateInComingCnt': '21038',
#   'gateOutGoingCnt': '20284'},
#  {'trnOpDate': '20190427',
#   'staCode': '4410',
#   'gateInComingCnt': '510',
#   'gateOutGoingCnt': '473'},
#  {'trnOpDate': '20190427',
#   'staCode': '4420',
#   'gateInComingCnt': '932',
#   'gateOutGoingCnt': '927'},
#  {'trnOpDate': '20190427',
#   'staCode': '4430',
#   'gateInComingCnt': '981',
#   'gateOutGoingCnt': '998'},
#  {'trnOpDate': '20190427',
#   'staCode': '4440',
#   'gateInComingCnt': '5632',
#   'gateOutGoingCnt': '5219'},
#  {'trnOpDate': '20190427',
#   'staCode': '4450',
#   'gateInComingCnt': '796',
#   'gateOutGoingCnt': '727'},
#  {'trnOpDate': '20190427',
#   'staCode': '4460',
#   'gateInComingCnt': '1276',
#   'gateOutGoingCnt': '1269'},
#  {'trnOpDate': '20190427',
#   'staCode': '4470',
#   'gateInComingCnt': '109',
#   'gateOutGoingCnt': '134'},
#  {'trnOpDate': '20190427',
#   'staCode': '5000',
#   'gateInComingCnt': '11339',
#   'gateOutGoingCnt': '12446'},
#  {'trnOpDate': '20190427',
#   'staCode': '5010',
#   'gateInComingCnt': '236',
#   'gateOutGoingCnt': '235'},
#  {'trnOpDate': '20190427',
#   'staCode': '5020',
#   'gateInComingCnt': '149',
#   'gateOutGoingCnt': '187'},
#  {'trnOpDate': '20190427',
#   'staCode': '5030',
#   'gateInComingCnt': '592',
#   'gateOutGoingCnt': '607'},
#  {'trnOpDate': '20190427',
#   'staCode': '5040',
#   'gateInComingCnt': '354',
#   'gateOutGoingCnt': '397'},
#  {'trnOpDate': '20190427',
#   'staCode': '5050',
#   'gateInComingCnt': '4107',
#   'gateOutGoingCnt': '4401'},
#  {'trnOpDate': '20190427',
#   'staCode': '5060',
#   'gateInComingCnt': '43',
#   'gateOutGoingCnt': '75'},
#  {'trnOpDate': '20190427',
#   'staCode': '5070',
#   'gateInComingCnt': '334',
#   'gateOutGoingCnt': '344'},
#  {'trnOpDate': '20190427',
#   'staCode': '5080',
#   'gateInComingCnt': '16',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20190427',
#   'staCode': '5090',
#   'gateInComingCnt': '331',
#   'gateOutGoingCnt': '443'},
#  {'trnOpDate': '20190427',
#   'staCode': '5100',
#   'gateInComingCnt': '84',
#   'gateOutGoingCnt': '71'},
#  {'trnOpDate': '20190427',
#   'staCode': '5110',
#   'gateInComingCnt': '33',
#   'gateOutGoingCnt': '44'},
#  {'trnOpDate': '20190427',
#   'staCode': '5120',
#   'gateInComingCnt': '917',
#   'gateOutGoingCnt': '1050'},
#  {'trnOpDate': '20190427',
#   'staCode': '5130',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '0'},
#  {'trnOpDate': '20190427',
#   'staCode': '5140',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '0'},
#  {'trnOpDate': '20190427',
#   'staCode': '5160',
#   'gateInComingCnt': '0',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20190427',
#   'staCode': '5190',
#   'gateInComingCnt': '128',
#   'gateOutGoingCnt': '114'},
#  {'trnOpDate': '20190427',
#   'staCode': '5200',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20190427',
#   'staCode': '5210',
#   'gateInComingCnt': '473',
#   'gateOutGoingCnt': '521'},
#  {'trnOpDate': '20190427',
#   'staCode': '5220',
#   'gateInComingCnt': '164',
#   'gateOutGoingCnt': '132'},
#  {'trnOpDate': '20190427',
#   'staCode': '5230',
#   'gateInComingCnt': '782',
#   'gateOutGoingCnt': '661'},
#  {'trnOpDate': '20190427',
#   'staCode': '5240',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20190427',
#   'staCode': '6000',
#   'gateInComingCnt': '4808',
#   'gateOutGoingCnt': '6677'},
#  {'trnOpDate': '20190427',
#   'staCode': '6010',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20190427',
#   'staCode': '6020',
#   'gateInComingCnt': '126',
#   'gateOutGoingCnt': '135'},
#  {'trnOpDate': '20190427',
#   'staCode': '6030',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '26'},
#  {'trnOpDate': '20190427',
#   'staCode': '6040',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20190427',
#   'staCode': '6050',
#   'gateInComingCnt': '462',
#   'gateOutGoingCnt': '767'},
#  {'trnOpDate': '20190427',
#   'staCode': '6060',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20190427',
#   'staCode': '6070',
#   'gateInComingCnt': '457',
#   'gateOutGoingCnt': '567'},
#  {'trnOpDate': '20190427',
#   'staCode': '6080',
#   'gateInComingCnt': '153',
#   'gateOutGoingCnt': '185'},
#  {'trnOpDate': '20190427',
#   'staCode': '6090',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20190427',
#   'staCode': '6100',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20190427',
#   'staCode': '6110',
#   'gateInComingCnt': '1330',
#   'gateOutGoingCnt': '1511'},
#  {'trnOpDate': '20190427',
#   'staCode': '6120',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20190427',
#   'staCode': '6130',
#   'gateInComingCnt': '574',
#   'gateOutGoingCnt': '794'},
#  {'trnOpDate': '20190427',
#   'staCode': '6140',
#   'gateInComingCnt': '60',
#   'gateOutGoingCnt': '60'},
#  {'trnOpDate': '20190427',
#   'staCode': '6150',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20190427',
#   'staCode': '6160',
#   'gateInComingCnt': '488',
#   'gateOutGoingCnt': '484'},
#  {'trnOpDate': '20190427',
#   'staCode': '6170',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '41'},
#  {'trnOpDate': '20190427',
#   'staCode': '6180',
#   'gateInComingCnt': '301',
#   'gateOutGoingCnt': '318'},
#  {'trnOpDate': '20190427',
#   'staCode': '6190',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '22'},
#  {'trnOpDate': '20190427',
#   'staCode': '6200',
#   'gateInComingCnt': '26',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20190427',
#   'staCode': '6210',
#   'gateInComingCnt': '43',
#   'gateOutGoingCnt': '50'},
#  {'trnOpDate': '20190427',
#   'staCode': '6220',
#   'gateInComingCnt': '258',
#   'gateOutGoingCnt': '338'},
#  {'trnOpDate': '20190427',
#   'staCode': '6230',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20190427',
#   'staCode': '6240',
#   'gateInComingCnt': '445',
#   'gateOutGoingCnt': '290'},
#  {'trnOpDate': '20190427',
#   'staCode': '6250',
#   'gateInComingCnt': '415',
#   'gateOutGoingCnt': '377'},
#  {'trnOpDate': '20190427',
#   'staCode': '7000',
#   'gateInComingCnt': '17229',
#   'gateOutGoingCnt': '18502'},
#  {'trnOpDate': '20190427',
#   'staCode': '7010',
#   'gateInComingCnt': '154',
#   'gateOutGoingCnt': '200'},
#  {'trnOpDate': '20190427',
#   'staCode': '7020',
#   'gateInComingCnt': '16',
#   'gateOutGoingCnt': '33'},
#  {'trnOpDate': '20190427',
#   'staCode': '7030',
#   'gateInComingCnt': '3485',
#   'gateOutGoingCnt': '1843'},
#  {'trnOpDate': '20190427',
#   'staCode': '7040',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20190427',
#   'staCode': '7050',
#   'gateInComingCnt': '37',
#   'gateOutGoingCnt': '44'},
#  {'trnOpDate': '20190427',
#   'staCode': '7060',
#   'gateInComingCnt': '393',
#   'gateOutGoingCnt': '483'},
#  {'trnOpDate': '20190427',
#   'staCode': '7070',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20190427',
#   'staCode': '7080',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20190427',
#   'staCode': '7090',
#   'gateInComingCnt': '778',
#   'gateOutGoingCnt': '906'},
#  {'trnOpDate': '20190427',
#   'staCode': '7100',
#   'gateInComingCnt': '219',
#   'gateOutGoingCnt': '287'},
#  {'trnOpDate': '20190427',
#   'staCode': '7110',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20190427',
#   'staCode': '7120',
#   'gateInComingCnt': '482',
#   'gateOutGoingCnt': '568'},
#  {'trnOpDate': '20190427',
#   'staCode': '7130',
#   'gateInComingCnt': '1408',
#   'gateOutGoingCnt': '4320'},
#  {'trnOpDate': '20190427',
#   'staCode': '7140',
#   'gateInComingCnt': '17',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20190427',
#   'staCode': '7150',
#   'gateInComingCnt': '954',
#   'gateOutGoingCnt': '954'},
#  {'trnOpDate': '20190427',
#   'staCode': '7160',
#   'gateInComingCnt': '6293',
#   'gateOutGoingCnt': '6493'},
#  {'trnOpDate': '20190427',
#   'staCode': '7170',
#   'gateInComingCnt': '39',
#   'gateOutGoingCnt': '45'},
#  {'trnOpDate': '20190427',
#   'staCode': '7180',
#   'gateInComingCnt': '122',
#   'gateOutGoingCnt': '138'},
#  {'trnOpDate': '20190427',
#   'staCode': '7190',
#   'gateInComingCnt': '5229',
#   'gateOutGoingCnt': '5223'},
#  {'trnOpDate': '20190427',
#   'staCode': '7200',
#   'gateInComingCnt': '118',
#   'gateOutGoingCnt': '116'},
#  {'trnOpDate': '20190427',
#   'staCode': '7210',
#   'gateInComingCnt': '1806',
#   'gateOutGoingCnt': '2000'},
#  {'trnOpDate': '20190427',
#   'staCode': '7220',
#   'gateInComingCnt': '108',
#   'gateOutGoingCnt': '136'},
# ...
#  {'trnOpDate': '20190430',
#   'staCode': '4350',
#   'gateInComingCnt': '908',
#   'gateOutGoingCnt': '826'},
#  {'trnOpDate': '20190430',
#   'staCode': '4360',
#   'gateInComingCnt': '592',
#   'gateOutGoingCnt': '591'},
#  {'trnOpDate': '20190430',
#   'staCode': '4370',
#   'gateInComingCnt': '804',
#   'gateOutGoingCnt': '682'},
#  {'trnOpDate': '20190430',
#   'staCode': '4380',
#   'gateInComingCnt': '155',
#   'gateOutGoingCnt': '141'},
#  {'trnOpDate': '20190430',
#   'staCode': '4390',
#   'gateInComingCnt': '364',
#   'gateOutGoingCnt': '402'},
#  {'trnOpDate': '20190430',
#   'staCode': '4400',
#   'gateInComingCnt': '13587',
#   'gateOutGoingCnt': '13687'},
#  {'trnOpDate': '20190430',
#   'staCode': '4410',
#   'gateInComingCnt': '505',
#   'gateOutGoingCnt': '494'},
#  {'trnOpDate': '20190430',
#   'staCode': '4420',
#   'gateInComingCnt': '685',
#   'gateOutGoingCnt': '776'},
#  {'trnOpDate': '20190430',
#   'staCode': '4430',
#   'gateInComingCnt': '811',
#   'gateOutGoingCnt': '780'},
#  {'trnOpDate': '20190430',
#   'staCode': '4440',
#   'gateInComingCnt': '4294',
#   'gateOutGoingCnt': '4247'},
#  {'trnOpDate': '20190430',
#   'staCode': '4450',
#   'gateInComingCnt': '556',
#   'gateOutGoingCnt': '600'},
#  {'trnOpDate': '20190430',
#   'staCode': '4460',
#   'gateInComingCnt': '934',
#   'gateOutGoingCnt': '1028'},
#  {'trnOpDate': '20190430',
#   'staCode': '4470',
#   'gateInComingCnt': '158',
#   'gateOutGoingCnt': '138'},
#  {'trnOpDate': '20190430',
#   'staCode': '5000',
#   'gateInComingCnt': '8405',
#   'gateOutGoingCnt': '8697'},
#  {'trnOpDate': '20190430',
#   'staCode': '5010',
#   'gateInComingCnt': '205',
#   'gateOutGoingCnt': '203'},
#  {'trnOpDate': '20190430',
#   'staCode': '5020',
#   'gateInComingCnt': '138',
#   'gateOutGoingCnt': '153'},
#  {'trnOpDate': '20190430',
#   'staCode': '5030',
#   'gateInComingCnt': '503',
#   'gateOutGoingCnt': '505'},
#  {'trnOpDate': '20190430',
#   'staCode': '5040',
#   'gateInComingCnt': '280',
#   'gateOutGoingCnt': '260'},
#  {'trnOpDate': '20190430',
#   'staCode': '5050',
#   'gateInComingCnt': '3000',
#   'gateOutGoingCnt': '3011'},
#  {'trnOpDate': '20190430',
#   'staCode': '5060',
#   'gateInComingCnt': '114',
#   'gateOutGoingCnt': '165'},
#  {'trnOpDate': '20190430',
#   'staCode': '5070',
#   'gateInComingCnt': '383',
#   'gateOutGoingCnt': '336'},
#  {'trnOpDate': '20190430',
#   'staCode': '5080',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20190430',
#   'staCode': '5090',
#   'gateInComingCnt': '290',
#   'gateOutGoingCnt': '200'},
#  {'trnOpDate': '20190430',
#   'staCode': '5100',
#   'gateInComingCnt': '82',
#   'gateOutGoingCnt': '80'},
#  {'trnOpDate': '20190430',
#   'staCode': '5110',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '40'},
#  {'trnOpDate': '20190430',
#   'staCode': '5120',
#   'gateInComingCnt': '830',
#   'gateOutGoingCnt': '663'},
#  {'trnOpDate': '20190430',
#   'staCode': '5130',
#   'gateInComingCnt': '23',
#   'gateOutGoingCnt': '0'},
#  {'trnOpDate': '20190430',
#   'staCode': '5140',
#   'gateInComingCnt': '1',
#   'gateOutGoingCnt': '1'},
#  {'trnOpDate': '20190430',
#   'staCode': '5190',
#   'gateInComingCnt': '170',
#   'gateOutGoingCnt': '166'},
#  {'trnOpDate': '20190430',
#   'staCode': '5200',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20190430',
#   'staCode': '5210',
#   'gateInComingCnt': '425',
#   'gateOutGoingCnt': '390'},
#  {'trnOpDate': '20190430',
#   'staCode': '5220',
#   'gateInComingCnt': '143',
#   'gateOutGoingCnt': '105'},
#  {'trnOpDate': '20190430',
#   'staCode': '5230',
#   'gateInComingCnt': '515',
#   'gateOutGoingCnt': '552'},
#  {'trnOpDate': '20190430',
#   'staCode': '5240',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20190430',
#   'staCode': '6000',
#   'gateInComingCnt': '4765',
#   'gateOutGoingCnt': '4599'},
#  {'trnOpDate': '20190430',
#   'staCode': '6010',
#   'gateInComingCnt': '1',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20190430',
#   'staCode': '6020',
#   'gateInComingCnt': '313',
#   'gateOutGoingCnt': '157'},
#  {'trnOpDate': '20190430',
#   'staCode': '6030',
#   'gateInComingCnt': '46',
#   'gateOutGoingCnt': '33'},
#  {'trnOpDate': '20190430',
#   'staCode': '6040',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20190430',
#   'staCode': '6050',
#   'gateInComingCnt': '705',
#   'gateOutGoingCnt': '554'},
#  {'trnOpDate': '20190430',
#   'staCode': '6060',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20190430',
#   'staCode': '6070',
#   'gateInComingCnt': '577',
#   'gateOutGoingCnt': '489'},
#  {'trnOpDate': '20190430',
#   'staCode': '6080',
#   'gateInComingCnt': '150',
#   'gateOutGoingCnt': '152'},
#  {'trnOpDate': '20190430',
#   'staCode': '6090',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20190430',
#   'staCode': '6100',
#   'gateInComingCnt': '31',
#   'gateOutGoingCnt': '24'},
#  {'trnOpDate': '20190430',
#   'staCode': '6110',
#   'gateInComingCnt': '1218',
#   'gateOutGoingCnt': '1135'},
#  {'trnOpDate': '20190430',
#   'staCode': '6120',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20190430',
#   'staCode': '6130',
#   'gateInComingCnt': '639',
#   'gateOutGoingCnt': '467'},
#  {'trnOpDate': '20190430',
#   'staCode': '6140',
#   'gateInComingCnt': '41',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20190430',
#   'staCode': '6150',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '4'},
#  {'trnOpDate': '20190430',
#   'staCode': '6160',
#   'gateInComingCnt': '358',
#   'gateOutGoingCnt': '360'},
#  {'trnOpDate': '20190430',
#   'staCode': '6170',
#   'gateInComingCnt': '44',
#   'gateOutGoingCnt': '44'},
#  {'trnOpDate': '20190430',
#   'staCode': '6180',
#   'gateInComingCnt': '329',
#   'gateOutGoingCnt': '294'},
#  {'trnOpDate': '20190430',
#   'staCode': '6190',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20190430',
#   'staCode': '6200',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20190430',
#   'staCode': '6210',
#   'gateInComingCnt': '58',
#   'gateOutGoingCnt': '62'},
#  {'trnOpDate': '20190430',
#   'staCode': '6220',
#   'gateInComingCnt': '244',
#   'gateOutGoingCnt': '263'},
#  {'trnOpDate': '20190430',
#   'staCode': '6230',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20190430',
#   'staCode': '6240',
#   'gateInComingCnt': '206',
#   'gateOutGoingCnt': '281'},
#  {'trnOpDate': '20190430',
#   'staCode': '6250',
#   'gateInComingCnt': '384',
#   'gateOutGoingCnt': '416'},
#  {'trnOpDate': '20190430',
#   'staCode': '7000',
#   'gateInComingCnt': '13827',
#   'gateOutGoingCnt': '12605'},
#  {'trnOpDate': '20190430',
#   'staCode': '7010',
#   'gateInComingCnt': '140',
#   'gateOutGoingCnt': '144'},
#  {'trnOpDate': '20190430',
#   'staCode': '7020',
#   'gateInComingCnt': '23',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20190430',
#   'staCode': '7030',
#   'gateInComingCnt': '3680',
#   'gateOutGoingCnt': '1346'},
#  {'trnOpDate': '20190430',
#   'staCode': '7040',
#   'gateInComingCnt': '36',
#   'gateOutGoingCnt': '47'},
#  {'trnOpDate': '20190430',
#   'staCode': '7050',
#   'gateInComingCnt': '72',
#   'gateOutGoingCnt': '94'},
#  {'trnOpDate': '20190430',
#   'staCode': '7060',
#   'gateInComingCnt': '917',
#   'gateOutGoingCnt': '722'},
#  {'trnOpDate': '20190430',
#   'staCode': '7070',
#   'gateInComingCnt': '25',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20190430',
#   'staCode': '7080',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20190430',
#   'staCode': '7090',
#   'gateInComingCnt': '999',
#   'gateOutGoingCnt': '1000'},
#  {'trnOpDate': '20190430',
#   'staCode': '7100',
#   'gateInComingCnt': '156',
#   'gateOutGoingCnt': '242'},
#  {'trnOpDate': '20190430',
#   'staCode': '7110',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '4'},
#  {'trnOpDate': '20190430',
#   'staCode': '7120',
#   'gateInComingCnt': '554',
#   'gateOutGoingCnt': '574'},
#  {'trnOpDate': '20190430',
#   'staCode': '7130',
#   'gateInComingCnt': '896',
#   'gateOutGoingCnt': '4324'},
#  {'trnOpDate': '20190430',
#   'staCode': '7140',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20190430',
#   'staCode': '7150',
#   'gateInComingCnt': '1156',
#   'gateOutGoingCnt': '1158'},
#  {'trnOpDate': '20190430',
#   'staCode': '7160',
#   'gateInComingCnt': '4625',
#   'gateOutGoingCnt': '4707'},
#  {'trnOpDate': '20190430',
#   'staCode': '7170',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '55'},
#  {'trnOpDate': '20190430',
#   'staCode': '7180',
#   'gateInComingCnt': '149',
#   'gateOutGoingCnt': '143'},
#  {'trnOpDate': '20190430',
#   'staCode': '7190',
#   'gateInComingCnt': '4082',
#   'gateOutGoingCnt': '4977'},
#  {'trnOpDate': '20190430',
#   'staCode': '7200',
#   'gateInComingCnt': '128',
#   'gateOutGoingCnt': '129'},
#  {'trnOpDate': '20190430',
#   'staCode': '7210',
#   'gateInComingCnt': '1421',
#   'gateOutGoingCnt': '1413'},
#  {'trnOpDate': '20190430',
#   'staCode': '7220',
#   'gateInComingCnt': '83',
#   'gateOutGoingCnt': '160'},
#  {'trnOpDate': '20190430',
#   'staCode': '7230',
#   'gateInComingCnt': '1155',
#   'gateOutGoingCnt': '1058'},
#  {'trnOpDate': '20190430',
#   'staCode': '7240',
#   'gateInComingCnt': '73',
#   'gateOutGoingCnt': '90'},
#  {'trnOpDate': '20190430',
#   'staCode': '7250',
#   'gateInComingCnt': '103',
#   'gateOutGoingCnt': '90'},
#  {'trnOpDate': '20190430',
#   'staCode': '7260',
#   'gateInComingCnt': '171',
#   'gateOutGoingCnt': '181'},
#  {'trnOpDate': '20190430',
#   'staCode': '7270',
#   'gateInComingCnt': '189',
#   'gateOutGoingCnt': '104'},
#  {'trnOpDate': '20190430',
#   'staCode': '7280',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '23'},
#  {'trnOpDate': '20190430',
#   'staCode': '7290',
#   'gateInComingCnt': '843',
#   'gateOutGoingCnt': '897'},
#  {'trnOpDate': '20190430',
#   'staCode': '7300',
#   'gateInComingCnt': '193',
#   'gateOutGoingCnt': '179'},
#  {'trnOpDate': '20190430',
#   'staCode': '7310',
#   'gateInComingCnt': '685',
#   'gateOutGoingCnt': '759'},
#  {'trnOpDate': '20190430',
#   'staCode': '7320',
#   'gateInComingCnt': '115',
#   'gateOutGoingCnt': '116'},
#  {'trnOpDate': '20190430',
#   'staCode': '7330',
#   'gateInComingCnt': '91',
#   'gateOutGoingCnt': '107'},
#  {'trnOpDate': '20190430',
#   'staCode': '7331',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20190430',
#   'staCode': '7332',
#   'gateInComingCnt': '1992',
#   'gateOutGoingCnt': '2116'},
#  {'trnOpDate': '20190430',
#   'staCode': '7333',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20190430',
#   'staCode': '7334',
#   'gateInComingCnt': '22',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20190430',
#   'staCode': '7335',
#   'gateInComingCnt': '188',
#   'gateOutGoingCnt': '202'},
#  {'trnOpDate': '20190430',
#   'staCode': '7336',
#   'gateInComingCnt': '921',
#   'gateOutGoingCnt': '864'},
#  {'trnOpDate': '20190430',
#   'staCode': '7350',
#   'gateInComingCnt': '748',
#   'gateOutGoingCnt': '734'},
#  {'trnOpDate': '20190430',
#   'staCode': '7360',
#   'gateInComingCnt': '6954',
#   'gateOutGoingCnt': '8063'},
#  {'trnOpDate': '20190430',
#   'staCode': '7361',
#   'gateInComingCnt': '113',
#   'gateOutGoingCnt': '145'},
#  {'trnOpDate': '20190430',
#   'staCode': '7362',
#   'gateInComingCnt': '678',
#   'gateOutGoingCnt': '702'},
#  {'trnOpDate': '20190430',
#   'staCode': '7380',
#   'gateInComingCnt': '608',
#   'gateOutGoingCnt': '551'},
#  {'trnOpDate': '20190430',
#   'staCode': '7390',
#   'gateInComingCnt': '383',
#   'gateOutGoingCnt': '412'},
#  {'trnOpDate': '20190501',
#   'staCode': '0900',
#   'gateInComingCnt': '7557',
#   'gateOutGoingCnt': '7389'},
#  {'trnOpDate': '20190501',
#   'staCode': '0910',
#   'gateInComingCnt': '1047',
#   'gateOutGoingCnt': '1073'},
#  {'trnOpDate': '20190501',
#   'staCode': '0920',
#   'gateInComingCnt': '2041',
#   'gateOutGoingCnt': '1856'},
#  {'trnOpDate': '20190501',
#   'staCode': '0930',
#   'gateInComingCnt': '4962',
#   'gateOutGoingCnt': '5067'},
#  {'trnOpDate': '20190501',
#   'staCode': '0940',
#   'gateInComingCnt': '2134',
#   'gateOutGoingCnt': '2150'},
#  {'trnOpDate': '20190501',
#   'staCode': '0950',
#   'gateInComingCnt': '1502',
#   'gateOutGoingCnt': '1384'},
#  {'trnOpDate': '20190501',
#   'staCode': '0960',
#   'gateInComingCnt': '8512',
#   'gateOutGoingCnt': '8775'},
#  {'trnOpDate': '20190501',
#   'staCode': '0970',
#   'gateInComingCnt': '5109',
#   'gateOutGoingCnt': '5272'},
#  {'trnOpDate': '20190501',
#   'staCode': '0980',
#   'gateInComingCnt': '8331',
#   'gateOutGoingCnt': '8625'},
#  {'trnOpDate': '20190501',
#   'staCode': '0990',
#   'gateInComingCnt': '11247',
#   'gateOutGoingCnt': '11395'},
#  {'trnOpDate': '20190501',
#   'staCode': '1000',
#   'gateInComingCnt': '48533',
#   'gateOutGoingCnt': '47212'},
#  {'trnOpDate': '20190501',
#   'staCode': '1010',
#   'gateInComingCnt': '3414',
#   'gateOutGoingCnt': '3353'},
#  {'trnOpDate': '20190501',
#   'staCode': '1020',
#   'gateInComingCnt': '17204',
#   'gateOutGoingCnt': '17046'},
#  {'trnOpDate': '20190501',
#   'staCode': '1030',
#   'gateInComingCnt': '2637',
#   'gateOutGoingCnt': '2567'},
#  {'trnOpDate': '20190501',
#   'staCode': '1040',
#   'gateInComingCnt': '12412',
#   'gateOutGoingCnt': '12774'},
#  {'trnOpDate': '20190501',
#   'staCode': '1050',
#   'gateInComingCnt': '823',
#   'gateOutGoingCnt': '851'},
#  {'trnOpDate': '20190501',
#   'staCode': '1060',
#   'gateInComingCnt': '1207',
#   'gateOutGoingCnt': '1251'},
#  {'trnOpDate': '20190501',
#   'staCode': '1070',
#   'gateInComingCnt': '6748',
#   'gateOutGoingCnt': '6931'},
#  {'trnOpDate': '20190501',
#   'staCode': '1080',
#   'gateInComingCnt': '21185',
#   'gateOutGoingCnt': '21958'},
#  {'trnOpDate': '20190501',
#   'staCode': '1090',
#   'gateInComingCnt': '7216',
#   'gateOutGoingCnt': '7121'},
#  {'trnOpDate': '20190501',
#   'staCode': '1100',
#   'gateInComingCnt': '20136',
#   'gateOutGoingCnt': '20387'},
#  {'trnOpDate': '20190501',
#   'staCode': '1110',
#   'gateInComingCnt': '5165',
#   'gateOutGoingCnt': '4567'},
#  {'trnOpDate': '20190501',
#   'staCode': '1120',
#   'gateInComingCnt': '4161',
#   'gateOutGoingCnt': '3954'},
#  {'trnOpDate': '20190501',
#   'staCode': '1130',
#   'gateInComingCnt': '1374',
#   'gateOutGoingCnt': '1409'},
#  {'trnOpDate': '20190501',
#   'staCode': '1140',
#   'gateInComingCnt': '48',
#   'gateOutGoingCnt': '70'},
#  {'trnOpDate': '20190501',
#   'staCode': '1150',
#   'gateInComingCnt': '849',
#   'gateOutGoingCnt': '784'},
#  {'trnOpDate': '20190501',
#   'staCode': '1160',
#   'gateInComingCnt': '2793',
#   'gateOutGoingCnt': '2983'},
#  {'trnOpDate': '20190501',
#   'staCode': '1170',
#   'gateInComingCnt': '4511',
#   'gateOutGoingCnt': '4501'},
#  {'trnOpDate': '20190501',
#   'staCode': '1180',
#   'gateInComingCnt': '3764',
#   'gateOutGoingCnt': '3733'},
#  {'trnOpDate': '20190501',
#   'staCode': '1190',
#   'gateInComingCnt': '1682',
#   'gateOutGoingCnt': '1776'},
#  {'trnOpDate': '20190501',
#   'staCode': '1191',
#   'gateInComingCnt': '267',
#   'gateOutGoingCnt': '299'},
#  {'trnOpDate': '20190501',
#   'staCode': '1192',
#   'gateInComingCnt': '1312',
#   'gateOutGoingCnt': '1416'},
#  {'trnOpDate': '20190501',
#   'staCode': '1193',
#   'gateInComingCnt': '514',
#   'gateOutGoingCnt': '531'},
#  {'trnOpDate': '20190501',
#   'staCode': '1194',
#   'gateInComingCnt': '1979',
#   'gateOutGoingCnt': '1851'},
#  {'trnOpDate': '20190501',
#   'staCode': '1201',
#   'gateInComingCnt': '30',
#   'gateOutGoingCnt': '44'},
#  {'trnOpDate': '20190501',
#   'staCode': '1202',
#   'gateInComingCnt': '102',
#   'gateOutGoingCnt': '97'},
#  {'trnOpDate': '20190501',
#   'staCode': '1203',
#   'gateInComingCnt': '408',
#   'gateOutGoingCnt': '336'},
#  {'trnOpDate': '20190501',
#   'staCode': '1204',
#   'gateInComingCnt': '59',
#   'gateOutGoingCnt': '54'},
#  {'trnOpDate': '20190501',
#   'staCode': '1205',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20190501',
#   'staCode': '1206',
#   'gateInComingCnt': '58',
#   'gateOutGoingCnt': '141'},
#  {'trnOpDate': '20190501',
#   'staCode': '1207',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20190501',
#   'staCode': '1208',
#   'gateInComingCnt': '351',
#   'gateOutGoingCnt': '306'},
#  {'trnOpDate': '20190501',
#   'staCode': '1210',
#   'gateInComingCnt': '16024',
#   'gateOutGoingCnt': '15673'},
#  {'trnOpDate': '20190501',
#   'staCode': '1220',
#   'gateInComingCnt': '1024',
#   'gateOutGoingCnt': '917'},
#  {'trnOpDate': '20190501',
#   'staCode': '1230',
#   'gateInComingCnt': '410',
#   'gateOutGoingCnt': '423'},
#  {'trnOpDate': '20190501',
#   'staCode': '1240',
#   'gateInComingCnt': '163',
#   'gateOutGoingCnt': '197'},
#  ...]

# %%
#將list物件轉換為DataFrame
frame = pd.DataFrame(jsObject)

#取得的資料只有火車站的code,沒有站名,必需再下載火車站名的資料
frame
# Out:
#       trnOpDate staCode gateInComingCnt gateOutGoingCnt
# 0      20190423    0900            8437            7739
# 1      20190423    0910            1393            1347
# 2      20190423    0920            2756            2416
# 3      20190423    0930            6086            6306
# 4      20190423    0940            2677            2723
# ...         ...     ...             ...             ...
# 88852  20200429    7360            3131            3209
# 88853  20200429    7361              19              23
# 88854  20200429    7362              85              94
# 88855  20200429    7380             608             592
# 88856  20200429    7390             403             452
#
# [88857 rows x 4 columns]

# %%
#下載火車站資料
staCode_url = 'http://ods.railway.gov.tw/tra-ods-web/ods/download/dataResource/0518b833e8964d53bfea3f7691aea0ee'
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
r = http.request('GET', staCode_url)
staCode_jsObject = json.loads(r.data)
staCode_jsObject

#下載的火車站資料,過濾資料,只要取出火車站code,火車站名,火車站的地址
staCode_frame = pd.DataFrame(staCode_jsObject,columns=['stationCode', 'stationName','stationAddrTw'])
staCode_frame
# Out:
#     stationCode stationName                      stationAddrTw
# 0          0900          基隆              基隆市中山區民治里1鄰中山一路16之 1號
# 1          0910          三坑                 基隆市仁愛區德厚里龍安街 206 號
# 2          0920          八堵                 基隆市暖暖區八南里八堵路 142 號
# 3          0930          七堵                   基隆市七堵區長興里東新街 2 號
# 4          0940          百福              基隆市七堵區堵南里明德三路 1 之 1 號
# ..          ...         ...                                ...
# 236        7360          瑞芳                新北市瑞芳區龍潭里明燈路三段 82 號
# 237        7361         海科館                          基隆市中正區長潭里
# 238        7362         八斗子  基隆市中正區砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)
# 239        7380         四腳亭                  新北市瑞芳區吉慶里中央路 65 號
# 240        7390          暖暖                  基隆市暖暖區暖暖里暖暖街 51 號
#
# [241 rows x 3 columns]

# %%
#僅取出火車站地址內的縣市資料
#利用DataFrame的apply()方法,取出每一個series
#利用索引名程取出地址,取出前3字
#由於其中有一筆資料是空的，split()時會raise exception, 使用try except來排除錯誤

def county(x):
    try:
        x['stationAddrTw'] = x['stationAddrTw'][:3]
        return x;
    except:
        pass;    

staCode_frame = staCode_frame.apply(county,axis=1)
staCode_frame.dropna(inplace=True)
staCode_frame.head(20)
# Out:
#    stationCode stationName stationAddrTw
# 0         0900          基隆           基隆市
# 1         0910          三坑           基隆市
# 2         0920          八堵           基隆市
# 3         0930          七堵           基隆市
# 4         0940          百福           基隆市
# 5         0950          五堵           新北市
# 6         0960          汐止           新北市
# 7         0970          汐科           新北市
# 8         0980          南港           臺北市
# 9         0990          松山           臺北市
# 10        1000          臺北           臺北市
# 12        1010          萬華           臺北市
# 13        1020          板橋           新北市
# 14        1030          浮洲           新北市
# 15        1040          樹林           新北市
# 16        1050         南樹林           新北市
# 17        1060          山佳           新北市
# 18        1070          鶯歌           新北市
# 19        1080          桃園           桃園市
# 20        1090          內壢           桃園市

# %%
#使用pd.merge()方法將frame和staCode_frame做left_join
mergeFrame = pd.merge(frame,staCode_frame,left_on='staCode',right_on='stationCode',how='left')
mergeFrame
# Out:
#       trnOpDate staCode gateInComingCnt gateOutGoingCnt stationCode  \
# 0      20190423    0900            8437            7739        0900
# 1      20190423    0910            1393            1347        0910
# 2      20190423    0920            2756            2416        0920
# 3      20190423    0930            6086            6306        0930
# 4      20190423    0940            2677            2723        0940
# ...         ...     ...             ...             ...         ...
# 88852  20200429    7360            3131            3209        7360
# 88853  20200429    7361              19              23        7361
# 88854  20200429    7362              85              94        7362
# 88855  20200429    7380             608             592        7380
# 88856  20200429    7390             403             452        7390
#
#       stationName stationAddrTw
# 0              基隆           基隆市
# 1              三坑           基隆市
# 2              八堵           基隆市
# 3              七堵           基隆市
# 4              百福           基隆市
# ...           ...           ...
# 88852          瑞芳           新北市
# 88853         海科館           基隆市
# 88854         八斗子           基隆市
# 88855         四腳亭           新北市
# 88856          暖暖           基隆市
#
# [88857 rows x 7 columns]

# %%
#將日期欄位資料類型改為datetime
mergeFrame['trnOpDate'] = mergeFrame['trnOpDate'].map(lambda x:datetime.strptime(x,'%Y%m%d'))

# %%
#檢查類型是否有改變
mergeFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88857 entries, 0 to 88856
# Data columns (total 7 columns):
# trnOpDate          88857 non-null datetime64[ns]
# staCode            88857 non-null object
# gateInComingCnt    88857 non-null object
# gateOutGoingCnt    88857 non-null object
# stationCode        88857 non-null object
# stationName        88857 non-null object
# stationAddrTw      88857 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 5.4+ MB

# %%
#將進入人數改為int類型
mergeFrame['gateInComingCnt'] = mergeFrame['gateInComingCnt'].map(lambda x:int(x))

# %%
#使用astype改為int類型
mergeFrame['gateOutGoingCnt'] = mergeFrame['gateOutGoingCnt'].map(lambda x:int(x))
mergeFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88857 entries, 0 to 88856
# Data columns (total 7 columns):
# trnOpDate          88857 non-null datetime64[ns]
# staCode            88857 non-null object
# gateInComingCnt    88857 non-null int64
# gateOutGoingCnt    88857 non-null int64
# stationCode        88857 non-null object
# stationName        88857 non-null object
# stationAddrTw      88857 non-null object
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 5.4+ MB

# %%
#使用reindex取出想要的欄位
mergeFrame = mergeFrame.reindex(columns=['trnOpDate','stationName','stationAddrTw', 'gateInComingCnt','gateOutGoingCnt'])
mergeFrame
# Out:
#        trnOpDate stationName stationAddrTw  gateInComingCnt  gateOutGoingCnt
# 0     2019-04-23          基隆           基隆市             8437             7739
# 1     2019-04-23          三坑           基隆市             1393             1347
# 2     2019-04-23          八堵           基隆市             2756             2416
# 3     2019-04-23          七堵           基隆市             6086             6306
# 4     2019-04-23          百福           基隆市             2677             2723
# ...          ...         ...           ...              ...              ...
# 88852 2020-04-29          瑞芳           新北市             3131             3209
# 88853 2020-04-29         海科館           基隆市               19               23
# 88854 2020-04-29         八斗子           基隆市               85               94
# 88855 2020-04-29         四腳亭           新北市              608              592
# 88856 2020-04-29          暖暖           基隆市              403              452
#
# [88857 rows x 5 columns]

# %%
mergeFrame.columns = ['日期','站名', '縣市','進站數量','出站數量']
mergeFrame
# Out:
#               日期   站名   縣市  進站數量  出站數量
# 0     2019-04-23   基隆  基隆市  8437  7739
# 1     2019-04-23   三坑  基隆市  1393  1347
# 2     2019-04-23   八堵  基隆市  2756  2416
# 3     2019-04-23   七堵  基隆市  6086  6306
# 4     2019-04-23   百福  基隆市  2677  2723
# ...          ...  ...  ...   ...   ...
# 88852 2020-04-29   瑞芳  新北市  3131  3209
# 88853 2020-04-29  海科館  基隆市    19    23
# 88854 2020-04-29  八斗子  基隆市    85    94
# 88855 2020-04-29  四腳亭  新北市   608   592
# 88856 2020-04-29   暖暖  基隆市   403   452
#
# [88857 rows x 5 columns]

# %%
sumFrame=mergeFrame.groupby(['縣市','站名']).sum()
sumFrame
# Out:
#             進站數量     出站數量
# 縣市  站名
# 南投縣 水里     65038    66689
#     濁水     49671    45301
#     車埕    160316   198661
#     集集    167122   135009
#     龍泉      5889     6913
# ...          ...      ...
# 高雄市 美術館   316942   306607
#     路竹    621865   640558
#     高雄   5868789  5872208
#     鳳山   1859198  1814101
#     鼓山     72847    75532
#
# [239 rows x 2 columns]

# %%
#使用concat結合進站數量>=5000000 boolean的series,和出站數量>=5000000 boolean的series
conditions = pd.concat([sumFrame['進站數量'] >= 5000000, sumFrame['出站數量'] >= 5000000],axis=1)

#使用dataFrame的boolean方法all()或 any()取得seriese boolean
andCondition = conditions.all(axis=1)
andCondition
# Out:
# 縣市   站名
# 南投縣  水里     False
#      濁水     False
#      車埕     False
#      集集     False
#      龍泉     False
#             ...
# 高雄市  美術館    False
#      路竹     False
#      高雄      True
#      鳳山     False
#      鼓山     False
# Length: 239, dtype: bool

# %%
result = sumFrame[andCondition]
result
# Out:
#             進站數量      出站數量
# 縣市  站名
# 彰化縣 彰化   5179445   5319155
# 新北市 板橋   7832880   7841910
#     樹林   5358838   5340391
# 新竹市 新竹   7162593   7223557
# 桃園市 中壢   9552066   9663534
#     桃園  10005609  10305894
# 臺中市 臺中   9250612   9144348
# 臺北市 松山   5954293   5886167
#     臺北  22140557  21933334
# 臺南市 臺南   9342167   9495844
# 花蓮縣 花蓮   5428749   5214244
# 高雄市 高雄   5868789   5872208

# %%
figure1, ax1 = plt.subplots() #使用pyplot的subplots()建立單獨figure和AxesSubplot
result.plot(ax = ax1, kind='bar')
ax1.legend(prop=font)
ax1.set_title('進站人數和出站數量都超過500萬的車站',fontproperties=font)
ax1.set_xticklabels(result.index,fontproperties=font,rotation=30)
ax1.set_yticklabels(['0','200萬','400萬', '600萬', '800萬','1000萬', '1200萬', '1400萬', '1600萬'],fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(0, 0, '0'),
#  Text(0, 0, '200萬'),
#  Text(0, 0, '400萬'),
#  Text(0, 0, '600萬'),
#  Text(0, 0, '800萬'),
#  Text(0, 0, '1000萬')]
