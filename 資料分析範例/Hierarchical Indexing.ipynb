# %% [markdown]
# ## 中文在matplotlib上的使用

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


populations = [33871648, 37253956,
               18976457, 19378102,
               20851820, 25145561]

pop = pd.Series(populations, index=[['台北','台北','台中','台中','台南','台南'],
                                    [2019, 2020,2019,2020,2019,2020]
                                   ])
pop
# Out:
# 縣市  年
# 台北  2019    33871648
#     2020    37253956
# 台中  2019    18976457
#     2020    19378102
# 台南  2019    20851820
#     2020    25145561
# dtype: int64

# %%
pop[:, 2019]
# Out:
# 縣市
# 台北    33871648
# 台中    18976457
# 台南    20851820
# dtype: int64

# %%
pop
# Out:
# 縣市  年
# 台北  2019    33871648
#     2020    37253956
# 台中  2019    18976457
#     2020    19378102
# 台南  2019    20851820
#     2020    25145561
# dtype: int64

# %%
pop_df = pop.unstack()
pop_df
# Out:
# 年       2019      2020
# 縣市
# 台中  18976457  19378102
# 台北  33871648  37253956
# 台南  20851820  25145561

# %%
#import FontProperties
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

figure, ax1 = plt.subplots(1,1)
pop_df.plot(ax=ax1,kind='bar',color=['r', 'g'])
ax1.set_xticklabels(pop_df.index,fontproperties=font)
ax1.legend(prop=font)
ax1.set_title('2019,2020城市人口',fontproperties=font)
ax1.set_xlabel('縣市',fontproperties=font)
ax1.set_yticklabels(['0','5佰萬','1仟萬','1仟5佰萬','2仟萬','2仟5佰萬','3仟萬','3仟5佰萬'],fontproperties=font)
for p in ax1.patches:
    width, height = p.get_width(), p.get_height()
    print('width',width)
    print('height',height)
    x, y = p.get_xy()
    print('x',x)
    print('y',y)
    print('x+width/2',x+width/2)
    print('y+height', x+height)
    ax1.annotate('{:}'.format(height), (x+width/2-width/2, y+height+height/100), fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# width 0.25
# height 18976457
# x -0.25
# y 0
# x+width/2 -0.125
# y+height 18976456.75
# width 0.25
# height 33871648
# x 0.75
# y 0
# x+width/2 0.875
# y+height 33871648.75
# width 0.25
# height 20851820
# x 1.75
# y 0
# x+width/2 1.875
# y+height 20851821.75
# width 0.25
# height 19378102
# x 0.0
# y 0
# x+width/2 0.125
# y+height 19378102.0
# width 0.25
# height 37253956
# x 1.0
# y 0
# x+width/2 1.125
# y+height 37253957.0
# width 0.25
# height 25145561
# x 2.0
# y 0
# x+width/2 2.125
# y+height 25145563.0

# %%
figure = plt.figure()
ax1 = figure.add_subplot(2,1,1)
ax2 = figure.add_subplot(2,1,2)
pop_df.plot(ax = ax1,kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pop_df.T.plot(ax = ax2,kind='bar')

# %%
pop_df
# Out:
# 年       2019      2020
# 縣市
# 台中  18976457  19378102
# 台北  33871648  37253956
# 台南  20851820  25145561

# %%
pop_df.stack()
# Out:
# 縣市  年
# 台中  2019    18976457
#     2020    19378102
# 台北  2019    33871648
#     2020    37253956
# 台南  2019    20851820
#     2020    25145561
# dtype: int64

# %% [markdown]
# <a id='abc'></a>

# %%
pop_df = pd.DataFrame({'total':pop,
                       'under18':[9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})
pop_df
# Out:
#             total  under18
# 縣市 年
# 台北 2019  33871648  9267089
#    2020  37253956  9284094
# 台中 2019  18976457  4687374
#    2020  19378102  4318033
# 台南 2019  20851820  5906301
#    2020  25145561  6879014

# %%
figure, ax1 = plt.subplots(1,1)
pop_df.plot(ax=ax1, kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="640">
