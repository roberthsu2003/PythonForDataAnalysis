# %%
#及時空氣品質指標下載
import requests
import pandas as pd
aqi_url = 'https://data.epa.gov.tw/api/v1/aqx_p_432?limit=1000&api_key=9be7b239-557b-4c10-9775-78cadfc555e9&format=csv'
response = requests.get(aqi_url,stream=True)
if response.status_code == 200:    
    content_raw=response.raw
    with open('空氣品質指標.csv','wb') as file:
        for chunk in response.iter_content(chunk_size=128):
            file.write(chunk)
    print("下載成功")        
else:
    print("下載失敗")
# Out:
# 下載成功

# %%
import pandas as pd
AQIDataFrame=pd.read_csv('空氣品質指標.csv')
AQIDataFrame
# Out:
#    SiteName County  AQI Pollutant Status  SO2    CO CO_8hr    O3  O3_8hr  ...  \
# 0        基隆    基隆市   51     細懸浮微粒     普通  1.1  0.42    0.3  13.2    36.0  ...
# 1        汐止    新北市   55      二氧化氮     普通  5.7  0.41    0.3   8.5    29.0  ...
# 2        萬里    新北市   42       NaN     良好  0.7  0.22    0.2  32.4    45.0  ...
# 3        新店    新北市   37       NaN     良好  1.5  0.44    0.3  25.0    36.0  ...
# 4        土城    新北市   39       NaN     良好  1.6   0.4    0.3  34.2    39.0  ...
# ..      ...    ...  ...       ...    ...  ...   ...    ...   ...     ...  ...
# 79   臺南(麻豆)    臺南市   54     細懸浮微粒     普通  2.5  0.35    0.2  27.8    42.0  ...
# 80   屏東(琉球)    屏東縣   79     細懸浮微粒     普通  2.3  0.39    0.4  35.1    62.0  ...
# 81   新北(樹林)    新北市   55     細懸浮微粒     普通  0.7  0.51    0.5  25.2    24.0  ...
# 82   臺南(學甲)    臺南市   70      懸浮微粒     普通  2.2  0.32    0.2  26.4    36.0  ...
# 83   屏東(枋寮)    屏東縣   75     細懸浮微粒     普通  1.3  0.33    0.3  28.7    52.0  ...
#
# ...

# %%
AQIDataFrame = AQIDataFrame.reindex(columns=['SiteName','County','AQI','PM2.5_AVG'])
AQIDataFrame
# Out:
#    SiteName County  AQI  PM2.5_AVG
# 0        基隆    基隆市   51         15
# 1        汐止    新北市   55         14
# 2        萬里    新北市   42         11
# 3        新店    新北市   37         11
# 4        土城    新北市   39         12
# ..      ...    ...  ...        ...
# 79   臺南(麻豆)    臺南市   54         16
# 80   屏東(琉球)    屏東縣   79         26
# 81   新北(樹林)    新北市   55         17
# 82   臺南(學甲)    臺南市   70         21
# 83   屏東(枋寮)    屏東縣   75         25
#
# [84 rows x 4 columns]

# %%
#排序AQI
AQIDataFrame.sort_values(by='AQI',inplace=True)
AQIDataFrame
# Out:
#    SiteName County  AQI  PM2.5_AVG
# 74       關山    臺東縣   32          9
# 60       臺東    臺東縣   33          9
# 61       花蓮    花蓮縣   33         10
# 27       豐原    臺中市   33         10
# 3        新店    新北市   37         11
# ..      ...    ...  ...        ...
# 36       斗六    雲林縣   77         26
# 76      富貴角    新北市   77          7
# 80   屏東(琉球)    屏東縣   79         26
# 51       林園    高雄市   79         26
# 58       潮州    屏東縣   84         27
#
# [84 rows x 4 columns]

# %%
good_avg = AQIDataFrame['PM2.5_AVG'] < 15
goodAQI = AQIDataFrame[good_avg]
# Out:
#    SiteName County  AQI  PM2.5_AVG
# 74       關山    臺東縣   32          9
# 60       臺東    臺東縣   33          9
# 61       花蓮    花蓮縣   33         10
# 27       豐原    臺中市   33         10
# 3        新店    新北市   37         11
# 26       三義    苗栗縣   38         11
# 4        土城    新北市   39         12
# 64       冬山    宜蘭縣   40          8
# 9        淡水    新北市   41         12
# 22       竹東    新竹縣   41         12
# 2        萬里    新北市   42         11
# 8        林口    新北市   42         12
# 59       恆春    屏東縣   43          8
# 13       古亭    臺北市   44         13
# 20       龍潭    桃園市   44         13
# 10       士林    臺北市   45         12
# 28       沙鹿    臺中市   47         14
# 33       線西    彰化縣   47         14
# 68       永和    新北市   48         14
# 72       金門    金門縣   49         12
# 62       陽明    臺北市   50          9
# 40       臺西    雲林縣   50         13
# 17       大園    桃園市   50         13
# 7        菜寮    新北市   51         14
# 77       大城    彰化縣   51         13
# 1        汐止    新北市   55         14
# ...

# %%
bad_avg = AQIDataFrame['PM2.5_AVG'] >= 16
badAQI = AQIDataFrame[bad_avg]
badAQI
# Out:
#    SiteName County  AQI  PM2.5_AVG
# 31       西屯    臺中市   52         16
# 35       南投    南投縣   53         16
# 25       苗栗    苗栗縣   53         16
# 19       平鎮    桃園市   53         16
# 79   臺南(麻豆)    臺南市   54         16
# 52       楠梓    高雄市   54         16
# 21       湖口    新竹縣   55         17
# 42       新營    臺南市   55         17
# 81   新北(樹林)    新北市   55         17
# 75       麥寮    雲林縣   55         17
# 43       善化    臺南市   56         17
# 16       桃園    桃園市   56         17
# 45       臺南    臺南市   58         18
# 44       安南    臺南市   59         17
# 41       嘉義    嘉義市   60         19
# 34       二林    彰化縣   60         16
# 55       前鎮    高雄市   62         19
# 15       大同    臺北市   62         16
# 48       仁武    高雄市   62         20
# 69       復興    高雄市   62         20
# 57       屏東    屏東縣   62         20
# 53       左營    高雄市   63         20
# 54       前金    高雄市   64         20
# 39       朴子    嘉義縣   64         20
# 47       橋頭    高雄市   65         21
# 56       小港    高雄市   65         21
# ...

# %%
AQIDataFrame['品質'] = AQIDataFrame['PM2.5_AVG'].map(lambda x: '好' if x<15 else '差')
AQIDataFrame
# Out:
#    SiteName County  AQI  PM2.5_AVG 品質
# 74       關山    臺東縣   32          9  好
# 60       臺東    臺東縣   33          9  好
# 61       花蓮    花蓮縣   33         10  好
# 27       豐原    臺中市   33         10  好
# 3        新店    新北市   37         11  好
# ..      ...    ...  ...        ... ..
# 36       斗六    雲林縣   77         26  差
# 76      富貴角    新北市   77          7  好
# 80   屏東(琉球)    屏東縣   79         26  差
# 51       林園    高雄市   79         26  差
# 58       潮州    屏東縣   84         27  差
#
# [84 rows x 5 columns]
