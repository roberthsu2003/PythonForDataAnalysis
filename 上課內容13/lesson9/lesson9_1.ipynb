# %%
import matplotlib.pyplot as plt

# %%
data = [-1, -4.3, 15, 21, 31]
plt.figure(num=3,figsize=(6,3))
plt.plot(data)
plt.show()

# %%
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [97, 68, 75, 62, 99]
y2 = [99, 78, 82, 74, 90]

plt.figure(4,figsize=(8,5))
plt.plot(x,y1,x,y2)
plt.show()

# %%
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [97, 68, 75, 62, 99]
y2 = [99, 78, 82, 74, 90]

plt.figure(6,figsize=(8,5))
plt.plot(x,y1,'r-o', x, y2, 'g--')
plt.grid()
plt.show()

# %%
plt.figure(7,figsize=(8,5))
plt.title('My First Plot')
plt.axis([0,5,0,20])
plt.plot([1, 2, 3, 4],[1,4,9,16],'ro')
plt.show()

# %%
plt.figure(8,figsize=(8,5))
days = range(0, 22,3)
celsius = [25.6, 23.2, 18.5, 28.3, 26.5, 30.5, 32.6, 33.1]
plt.title('My First Plot')
plt.xlabel('Day')
plt.ylabel('Celsius')
plt.plot(days,celsius,'ro')
plt.show()

# %%
plt.figure(9,figsize=(8,5))
index = ['apple', 'banana', 'orange', 'tomato', 'guava']
values = [5, 7, 3, 4, 6]
plt.bar(index,values)
plt.show()

# %%
index = range(5)
value1 = [5000, 7000, 3000, 4000, 6000]
plt.figure(10,figsize=(8,5))
plt.axis([-1,5,0,9000])
plt.bar(index,value1)
plt.xticks(index,['apple', 'banana', 'orange', 'tomato', 'guava'])
plt.show()

# %%
index = range(5)
value1 = [5000, 7000, 3000, 4000, 6000]
plt.figure(10,figsize=(8,5))
plt.axis([-1,5,0,8000])
plt.bar(index,value1)
plt.xticks(index,['apple', 'banana', 'orange', 'tomato', 'guava'])
for i in index:
    plt.text(i-0.2,value1[i]+200,value1[i])
plt.show()

# %%
plt.figure(11,figsize=(8,5))
labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [10, 30, 45, 15]
colors = ['yellow', 'green', 'red', 'blue']
explode= [0.3, 0, 0, 0]
plt.pie(values, labels = labels, colors= colors, explode=explode, startangle=360,shadow=True,autopct='%1.1f%%')
plt.show()
