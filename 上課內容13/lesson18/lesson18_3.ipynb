# %%
# 請處理(新北市公共自行車租賃系統.json)
# google搜尋online json viewer
#api接口:https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000

import requests
import numpy as np
import pandas as pd

url = 'https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000'
response = requests.get(url)
if response.status_code == 200:
    python_json = response.json()    

df = pd.DataFrame(python_json)
df
# Out:
#       sno           sna tot sbi sarea            mday        lat         lng  \
# 0    1001          大鵬華城  28  10   新店區  20211124211422   24.99116   121.53398
# 1    1002         汐止火車站  44   9   汐止區  20211124211423  25.068914  121.662748
# 2    1003         汐止區公所  46   6   汐止區  20211124211418  25.064162  121.658301
# 3    1004        國泰綜合醫院  48   4   汐止區  20211124211437   25.07315  121.662555
# 4    1005          裕隆公園  32  20   新店區  20211124211419  24.979649  121.546319
# ..    ...           ...  ..  ..   ...             ...        ...         ...
# 664  1759  學士學府路口(大苑社區)  34   0   土城區  20211105115147  24.976690  121.445270
# 665  1760         龍米停車場  36  20   八里區  20211124211432  25.156780  121.436040
# 666  1761          雙和醫院  30   7   中和區  20211124211434  24.993670  121.494110
# 667  1762      寶高智慧產業園區  60  20   新店區  20211124211417  24.977500  121.551330
# 668  1763   捷運三重站(1號出口)  40  22   三重區  20211124211424  25.054640  121.483220
#
#                                   ar         sareaen  \
# 0                    新北市新店區中正路700巷3號   Xindian Dist.
# 1                     南昌街/新昌路口(西側廣場)     Xizhi Dist.
# 2    新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)     Xizhi Dist.
# 3                        建成路78號對面停車場     Xizhi Dist.
# 4                      寶中路/品牌路口(東南側)   Xindian Dist.
# ..                               ...             ...
# 664                 學士路/學府路(西北側建案基地)   Tucheng Dist.
# 665                     龍米路二段150號(旁)      Bali Dist.
# 666                    中正路281號(公車亭旁)   Zhonghe Dist.
# 667                        寶高路10號(旁)   Xindian Dist.
# 668                        捷運路36號(旁)  Sanchong Dist.
#
#                                   snaen  \
# 0                      Dapeng Community
# 1                 Xizhi Railway Station
# 2                    Xizhi Dist. Office
# 3               Cathay General Hospital
# 4                            Yulon Park
# ..                                  ...
# 664       Xueshi & Xuefu Intersection
# 665                  Longmi Parking Lot
# 666                  Shuang Ho Hospital
# 667  Baogao Intelligent Industrial Park
# 668       MRT Sanchong Station (Exit.1)
#
#                                                   aren bemp act
# 0    No. 3, Lane 700 Chung Cheng Road, Xindian Dist...   17   1
# 1                            Nanchang St./Xinchang Rd.   31   1
# 2                    Sec. 1, Xintai 5th Rd./Ren’ai Rd.   34   1
# 3                                   No78, Jiancheng Rd   42   1
# 4                                        Baozhong Rd./   12   1
# ..                                                 ...  ...  ..
# 664                      Xueshi & Xuefu Intersection      0   1
# 665                        No. 150, Sec. 2, Longmi Rd.   15   1
# 666                            No. 281, Zhongzheng Rd.   23   1
# 667                                 No. 10, Baogao Rd.   36   1
# 668                          No. 36, Jieyun Rd. (Side)   17   1
#
# [669 rows x 14 columns]
