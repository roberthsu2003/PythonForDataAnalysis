# %%
import csv
with open('youbike.csv','r',encoding='big5') as file:
    rows = csv.reader(file)
    for row in rows:
        print(row)
# Out:
# ['場站編號', '站名', '土木施工費用']
# ['500101002', '復興南路二段273號前', '9,574']
# ['500101003', '國北教大實小東側門', '5,456']
# ['500101004', '和平公園東側', '6,037']
# ['500101005', '辛亥復興路口西北側', '4,858']
# ['500101006', '復興南路二段280號前', '4,858']
# ['500101007', '復興南路二段340巷口', '8,993']
# ['500101008', '新生南路三段52號前', '5,078']
# ['500101012', '辛亥路一段30號前', '8,396']
# ['500101010', '新生南路三段82號前', '5,456']
# ['500101011', '羅斯福路三段333巷9號旁', '6,934']
# ['500101014', '羅斯福路三段311號前', '5,456']
# ['500101016', '羅斯福路三段245號前', '6,934']
# ['500101024', '臺灣科技大學正門', '6,917']
# ['500101026', '公館公園', '6,037']
# ['500101028', '臺大醫學院附設癌醫中心', '6,037']
# ['500101030', '臺大永齡生醫工程館', '5,456']
# ['500101032', '臺大男一舍前', '6,917']
# ['500101033', '臺大男六舍前', '4,858']
# ['500101036', '臺大萬才館前', '5,456']
# ['500101038', '臺大社科院圖書館前', '63,645']
# ['500101039', '臺大法人語言訓練中心前', '5,456']
# ['500101042', '基隆長興路口東側', '4,717']
# ['500101013', '和平復興路口西北側', '4,717']
# ['500101015', '大安運動中心停車場', '4,717']
# ['500101017', '羅斯福路三段269巷5號前', '6,934']
# ...
