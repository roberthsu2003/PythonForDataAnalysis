# %%
import numpy as np
import pandas as pd
result = pd.read_csv('各鄉鎮市區人口密度-2.csv')
result.columns = result.loc[0]
result1 = result.drop(0)
result1
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# 5    106                                             新北市新莊區  416524  19.7383
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 1    23835
# 2    23747
# ...

# %%
result2=result1.dropna()
result2
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    145
# 368  106  連江縣東引鄉    1352      3.8    250
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
result3 = result2.drop([369,370])
result3
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 364  106  金門縣烏坵鄉     685      1.2    571
# 365  106  連江縣南竿鄉    7544     10.4    725
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    145
# 368  106  連江縣東引鄉    1352      3.8    250
#
# [368 rows x 5 columns]

# %%
result3.dtypes
# Out:
# 0
# 統計年      object
# 區域別      object
# 年底人口數    object
# 土地面積     object
# 人口密度     object
# dtype: object

# %%
result4=result3.astype({'統計年':int,'年底人口數':int,'土地面積':float,'人口密度':int})
result4.dtypes
# Out:
# 0
# 統計年        int64
# 區域別       object
# 年底人口數      int64
# 土地面積     float64
# 人口密度       int64
# dtype: object

# %%
def getState(x):
    return x[:3]

result4['縣市'] = result4['區域別'].map(getState)
result4
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度   縣市
# 1    106  新北市板橋區  551480  23.1373  23835  新北市
# 2    106  新北市三重區  387484  16.3170  23747  新北市
# 3    106  新北市中和區  413590  20.1440  20532  新北市
# 4    106  新北市永和區  222585   5.7138  38956  新北市
# 5    106  新北市新莊區  416524  19.7383  21102  新北市
# ..   ...     ...     ...      ...    ...  ...
# 364  106  金門縣烏坵鄉     685   1.2000    571  金門縣
# 365  106  連江縣南竿鄉    7544  10.4000    725  連江縣
# 366  106  連江縣北竿鄉    2360   9.9000    238  連江縣
# 367  106  連江縣莒光鄉    1624   4.7000    145  連江縣
# 368  106  連江縣東引鄉    1352   3.8000    250  連江縣
#
# [368 rows x 6 columns]

# %%
result4['區域別'] = result4['區域別'].map(lambda x:x[3:])
result4
# Out:
# 0    統計年  區域別   年底人口數     土地面積   人口密度   縣市
# 1    106  板橋區  551480  23.1373  23835  新北市
# 2    106  三重區  387484  16.3170  23747  新北市
# 3    106  中和區  413590  20.1440  20532  新北市
# 4    106  永和區  222585   5.7138  38956  新北市
# 5    106  新莊區  416524  19.7383  21102  新北市
# ..   ...  ...     ...      ...    ...  ...
# 364  106  烏坵鄉     685   1.2000    571  金門縣
# 365  106  南竿鄉    7544  10.4000    725  連江縣
# 366  106  北竿鄉    2360   9.9000    238  連江縣
# 367  106  莒光鄉    1624   4.7000    145  連江縣
# 368  106  東引鄉    1352   3.8000    250  連江縣
#
# [368 rows x 6 columns]

# %%
result5=result4.set_index(['縣市','區域別'])
result5
# Out:
# 0        統計年   年底人口數     土地面積   人口密度
# 縣市  區域別
# 新北市 板橋區  106  551480  23.1373  23835
#     三重區  106  387484  16.3170  23747
#     中和區  106  413590  20.1440  20532
#     永和區  106  222585   5.7138  38956
#     新莊區  106  416524  19.7383  21102
# ...      ...     ...      ...    ...
# 金門縣 烏坵鄉  106     685   1.2000    571
# 連江縣 南竿鄉  106    7544  10.4000    725
#     北竿鄉  106    2360   9.9000    238
#     莒光鄉  106    1624   4.7000    145
#     東引鄉  106    1352   3.8000    250
#
# [368 rows x 4 columns]

# %%
result6=result5.reindex(columns=['年底人口數','土地面積','人口密度'])
result6
# Out:
# 0         年底人口數     土地面積   人口密度
# 縣市  區域別
# 新北市 板橋區  551480  23.1373  23835
#     三重區  387484  16.3170  23747
#     中和區  413590  20.1440  20532
#     永和區  222585   5.7138  38956
#     新莊區  416524  19.7383  21102
# ...         ...      ...    ...
# 金門縣 烏坵鄉     685   1.2000    571
# 連江縣 南竿鄉    7544  10.4000    725
#     北竿鄉    2360   9.9000    238
#     莒光鄉    1624   4.7000    145
#     東引鄉    1352   3.8000    250
#
# [368 rows x 3 columns]

# %%
result7 = result6.groupby(level='縣市').sum()
result7
# Out:
# 0      年底人口數       土地面積    人口密度
# 縣市
# 南投縣   501051  4106.4360    4403
# 嘉義市   269398    60.0256    8980
# 嘉義縣   511182  1903.6367    6906
# 基隆市   371458   132.7589   32227
# 宜蘭縣   456607  2143.6251   13505
# 屏東縣   829939  2775.6003   18733
# 彰化縣  1282458  1074.3960   33626
# 新北市  3986689  2052.5667  194233
# 新竹市   441132   104.1526   17329
# 新竹縣   552169  1427.5369   10195
# 桃園市  2188017  1220.9540   39652
# 澎湖縣   104073   126.8641    4135
# 臺中市  2787070  2214.8968  144916
# 臺北市  2683257   271.7997  184532
# 臺南市  1886522  2191.6531   74254
# 臺東縣   219540  3515.2526    2134
# 花蓮縣   329237  4628.5714    6067
# 苗栗縣   553807  1820.3149   10282
# 連江縣    12880    28.8000    1358
# 金門縣   137456   151.6560    5596
# 雲林縣   690373  1290.8326   11201
# 高雄市  2776912  2951.8524  194410

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes=figure.add_subplot(1,1,1)
mean=result7['年底人口數'].mean()
std = result7['年底人口數'].std()
normalize = (result7['年底人口數'] - mean) / std
normalize.plot(ax=axes)
# Out:
# <AxesSubplot:xlabel='縣市'>
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25237 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
mean=result7.mean()
std = result7.std()
normalize = (result7 - mean) / std

fig=plt.figure()
axes = fig.add_subplot(1,1,1)
normalize.plot(ax=axes)
# Out:
# <AxesSubplot:xlabel='縣市'>
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25237 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
result7.plot()
# Out:
# <AxesSubplot:xlabel='縣市'>
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21335 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25237 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/roberthsu2003/Documents/virtualenv01/venv04/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23631 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
