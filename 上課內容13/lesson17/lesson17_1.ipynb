# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                      [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1    0.436002
#    2    0.684595
#    3   -0.851408
# b  1    1.260487
#    2    0.140614
# c  3    0.555565
#    1    1.759245
# d  2   -1.512330
#    3   -1.555899
# dtype: float64

# %%
data['b']
# Out:
# 1    1.260487
# 2    0.140614
# dtype: float64

# %%
data['b':'c']
# Out:
# b  1    1.260487
#    2    0.140614
# c  3    0.555565
#    1    1.759245
# dtype: float64

# %%
data.unstack()
# Out:
#           1         2         3
# a  0.436002  0.684595 -0.851408
# b  1.260487  0.140614       NaN
# c  1.759245       NaN  0.555565
# d       NaN -1.512330 -1.555899

# %%
data.unstack().stack()
# Out:
# a  1    0.436002
#    2    0.684595
#    3   -0.851408
# b  1    1.260487
#    2    0.140614
# c  1    1.759245
#    3    0.555565
# d  2   -1.512330
#    3   -1.555899
# dtype: float64

# %%
#DataFrame使用階層索引
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                    index=[['a','a','b','b'],[1, 2, 1, 2]],
                    columns=[['台北','台北','台中'],['Green','Red','Green']])
frame
# Out:
#        台北        台中
#     Green Red Green
# a 1     0   1     2
#   2     3   4     5
# b 1     6   7     8
#   2     9  10    11

# %%
frame.stack()
# Out:
#              台中  台北
# a 1 Green   2.0   0
#     Red     NaN   1
#   2 Green   5.0   3
#     Red     NaN   4
# b 1 Green   8.0   6
#     Red     NaN   7
#   2 Green  11.0   9
#     Red     NaN  10

# %%
frame.index.names = ['key1','key2']
frame.columns.names = ['縣市','顏色']
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
frame['台北']
# Out:
# 顏色         Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
#swaplevel()階層對掉
frame.swaplevel('key1','key2')
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key2 key1
# 1    a        0   1     2
# 2    a        3   4     5
# 1    b        6   7     8
# 2    b        9  10    11

# %%
#sort_index() 排序階層式索引
frame.sort_index(level='key2')
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
# b    1        6   7     8
# a    2        3   4     5
# b    2        9  10    11

# %%
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
#群組索引groupby
frame.groupby(level='key1').sum()
# Out:
# 縣市      台北        台中
# 顏色   Green Red Green
# key1
# a        3   5     7
# b       15  17    19

# %%
frame.groupby(level='顏色',axis=1).sum()
# Out:
# 顏色         Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %%
#將欄位變索引,或索引變欄位
#set_index()
#reset_index()

frame = pd.DataFrame({'a':range(7), 'b':range(7, 0, -1),
                     'c':['one', 'one', 'one', 'two', 'two', 'two', 'two'],
                     'd':[0, 1, 2, 0, 1, 2, 3]})
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame.set_index('c')
# Out:
#      a  b  d
# c
# one  0  7  0
# one  1  6  1
# one  2  5  2
# two  3  4  0
# two  4  3  1
# two  5  2  2
# two  6  1  3

# %%
frame.set_index(['c','d']).unstack()
# Out:
#        a                   b
# d      0    1    2    3    0    1    2    3
# c
# one  0.0  1.0  2.0  NaN  7.0  6.0  5.0  NaN
# two  3.0  4.0  5.0  6.0  4.0  3.0  2.0  1.0

# %%
frame1=frame.set_index(['c','d'])
frame1
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
frame1.reset_index()
# Out:
#      c  d  a  b
# 0  one  0  0  7
# 1  one  1  1  6
# 2  one  2  2  5
# 3  two  0  3  4
# 4  two  1  4  3
# 5  two  2  5  2
# 6  two  3  6  1
