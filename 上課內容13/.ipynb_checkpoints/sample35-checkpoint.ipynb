# %%
#空氣品質指標(AQI)
import csv
import pandas as pd
import urllib3
import certifi

CSV_URL = "https://opendata.epa.gov.tw/api/v1/AQI?%24skip=0&%24top=1000&%24format=csv"
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
r = http.request('GET', CSV_URL)
if r.status == 200:
    with open('output.csv','wb') as f:
        f.write(r.data)
        f.close()
else:
    print('下載錯誤')
    
df = pd.read_csv('output.csv', sep=',')
df.head(20)
# Out:
#      SiteName County  AQI Pollutant Status  SO2    CO  CO_8hr  O3  O3_8hr  \
# 0   桃園(觀音工業區)    桃園市   40       NaN     良好  4.4   0.3     0.2  19    17.0
# 1      臺南(北門)    臺南市   19       NaN     良好  0.1  0.12     0.1  22    20.0
# 2      屏東(琉球)    屏東縣   22       NaN     良好  0.3  0.13     0.1  28    24.0
# 3      新北(樹林)    新北市   52     細懸浮微粒     普通  1.6  0.19     0.3  42    31.0
# 4      彰化(大城)    彰化縣   30       NaN     良好  5.5  0.31     0.3  23    20.0
# 5      臺南(麻豆)    臺南市   22       NaN     良好  1.3  0.44     0.5  31    24.0
# 6         富貴角    新北市   34       NaN     良好  0.2  0.09     0.1  29    26.0
# 7          麥寮    雲林縣   25       NaN     良好  1.5  0.13     0.1  24    21.0
# 8          關山    臺東縣   18       NaN     良好  1.1     -     NaN  31    19.0
# 9          馬公    澎湖縣   26       NaN     良好  1.7  0.13     0.1  31    28.0
# 10         金門    金門縣   65     細懸浮微粒     普通  3.4  0.22     0.2  58    33.0
# 11         馬祖    連江縣   73     細懸浮微粒     普通  1.9  0.21     0.3  46    32.0
# 12         埔里    南投縣   57     細懸浮微粒     普通  1.8  0.23     0.3  53    36.0
# 13         復興    高雄市   22       NaN     良好  1.6  0.18     0.2  27    21.0
# 14         永和    新北市   55     細懸浮微粒     普通  1.8  0.53     0.7  38    31.0
# 15         竹山    南投縣   44       NaN     良好  2.4  0.12     0.2  39    30.0
# 16         中壢    桃園市   43       NaN     良好  2.1  0.72     0.9  25    18.0
# 17         三重    新北市   67     細懸浮微粒     普通  2.6  0.89     1.0   -     NaN
# 18         冬山    宜蘭縣   52     細懸浮微粒     普通  3.5  0.23     0.3  44    38.0
# 19         宜蘭    宜蘭縣   45       NaN     良好  2.3   0.2     0.3  47    41.0
#
#     ...    NO  WindSpeed  WindDirec       PublishTime  PM2.5_AVG  PM10_AVG  \
# 0   ...   4.3        4.9      228.0  2020-05-03 14:00         12      27.0
# 1   ...   NaN        4.3      254.0  2020-05-03 14:00          5      12.0
# 2   ...   1.7        3.4      318.0  2020-05-03 14:00          5       8.0
# 3   ...   0.4        1.6       64.0  2020-05-03 14:00         16      34.0
# 4   ...   2.9        5.8      252.0  2020-05-03 14:00          6      32.0
# 5   ...   0.9        2.2      251.0  2020-05-03 14:00          5      16.0
# 6   ...   0.6        5.1      253.0  2020-05-03 14:00         10      21.0
# 7   ...   1.5        4.9      245.0  2020-05-03 14:00          8      18.0
# 8   ...  -0.1        2.0      219.0  2020-05-03 14:00          5       7.0
# 9   ...   1.1        2.3      214.0  2020-05-03 14:00          7       NaN
# 10  ...   2.0        7.7      174.0  2020-05-03 14:00         21      38.0
# 11  ...   0.0        1.7       30.0  2020-05-03 14:00         25      39.0
# 12  ...   0.8        2.4      296.0  2020-05-03 14:00         18      25.0
# 13  ...   3.2        1.7      235.0  2020-05-03 14:00          7      14.0
# 14  ...   6.3        2.1      282.0  2020-05-03 14:00         17      28.0
# 15  ...   1.1        2.8      264.0  2020-05-03 14:00         14      27.0
# 16  ...  25.0        2.3      169.0  2020-05-03 14:00         13      28.0
# 17  ...  38.0        NaN        NaN  2020-05-03 14:00         22      34.0
# 18  ...   2.3        2.3       51.0  2020-05-03 14:00         16      26.0
# 19  ...   NaN        2.2       23.0  2020-05-03 14:00         14      24.0
#
#     SO2_AVG   Longitude   Latitude  SiteId
# 0       3.0  121.128044  25.063039     312
# 1       1.0  120.124444  23.264722     310
# 2       1.0  120.377222  22.352222     204
# 3       2.0  121.383528  24.949028     203
# 4       3.0  120.273117  23.843139     202
# 5       2.0  120.245831  23.179047     201
# 6       1.0  121.536763  25.298562      84
# 7       2.0  120.251825  23.753506      83
# 8       1.0  121.161933  23.045083      80
# 9       1.0  119.566158  23.569031      78
# 10      3.0  118.312256  24.432133      77
# 11      4.0  119.949875  26.160469      75
# 12      2.0  120.967903  23.968842      72
# 13      2.0  120.312017  22.608711      71
# 14      3.0  121.516306  25.017000      70
# 15      2.0  120.677306  23.756389      69
# 16      3.0  121.221667  24.953278      68
# 17      3.0  121.493806  25.072611      67
# 18      2.0  121.792928  24.632203      66
# 19      2.0  121.746394  24.747917      65
#
# [20 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 24 columns):
# SiteName       83 non-null object
# County         83 non-null object
# AQI            83 non-null int64
# Pollutant      26 non-null object
# Status         83 non-null object
# SO2            81 non-null float64
# CO             83 non-null object
# CO_8hr         82 non-null float64
# O3             83 non-null object
# O3_8hr         81 non-null float64
# PM10           82 non-null float64
# PM2.5          83 non-null int64
# NO2            81 non-null float64
# NOx            81 non-null float64
# NO             81 non-null float64
# WindSpeed      79 non-null float64
# WindDirec      79 non-null float64
# PublishTime    83 non-null object
# PM2.5_AVG      83 non-null int64
# PM10_AVG       82 non-null float64
# SO2_AVG        82 non-null float64
# Longitude      83 non-null float64
# Latitude       83 non-null float64
# SiteId         83 non-null int64
# dtypes: float64(13), int64(4), object(7)
# memory usage: 15.7+ KB

# %%
final_df = df.loc[:,['County', 'SiteName', 'AQI', 'PublishTime', 'PM2.5_AVG']]
final_df.columns = ['縣市', '位置', '空氣品質', '發佈時間', 'PM2.5']
final_df
# Out:
#      縣市         位置  空氣品質              發佈時間  PM2.5
# 0   桃園市  桃園(觀音工業區)    40  2020-05-03 14:00     12
# 1   臺南市     臺南(北門)    19  2020-05-03 14:00      5
# 2   屏東縣     屏東(琉球)    22  2020-05-03 14:00      5
# 3   新北市     新北(樹林)    52  2020-05-03 14:00     16
# 4   彰化縣     彰化(大城)    30  2020-05-03 14:00      6
# ..  ...        ...   ...               ...    ...
# 78  新北市         土城    62  2020-05-03 14:00     20
# 79  新北市         新店    52  2020-05-03 14:00     16
# 80  新北市         萬里    58  2020-05-03 14:00     18
# 81  新北市         汐止    58  2020-05-03 14:00     19
# 82  基隆市         基隆    64  2020-05-03 14:00     21
#
# [83 rows x 5 columns]

# %%
def f(x):
    if x <= 50:
        return '良好'
    elif x <=100:
        return '普通'
    elif x <= 150:
        return '對敏感族群不健康'
    elif x <= 200:
        return '對所有族群不健康'
    elif x <= 300:
        return '非常不健康'
    else: 
        return '危害'
        
final_df['空氣狀況'] = final_df['空氣品質'].map(f)
final_df.head(20)
# Out:
#      縣市         位置  空氣品質              發佈時間  PM2.5 空氣狀況
# 0   桃園市  桃園(觀音工業區)    40  2020-05-03 14:00     12   良好
# 1   臺南市     臺南(北門)    19  2020-05-03 14:00      5   良好
# 2   屏東縣     屏東(琉球)    22  2020-05-03 14:00      5   良好
# 3   新北市     新北(樹林)    52  2020-05-03 14:00     16   普通
# 4   彰化縣     彰化(大城)    30  2020-05-03 14:00      6   良好
# 5   臺南市     臺南(麻豆)    22  2020-05-03 14:00      5   良好
# 6   新北市        富貴角    34  2020-05-03 14:00     10   良好
# 7   雲林縣         麥寮    25  2020-05-03 14:00      8   良好
# 8   臺東縣         關山    18  2020-05-03 14:00      5   良好
# 9   澎湖縣         馬公    26  2020-05-03 14:00      7   良好
# 10  金門縣         金門    65  2020-05-03 14:00     21   普通
# 11  連江縣         馬祖    73  2020-05-03 14:00     25   普通
# 12  南投縣         埔里    57  2020-05-03 14:00     18   普通
# 13  高雄市         復興    22  2020-05-03 14:00      7   良好
# 14  新北市         永和    55  2020-05-03 14:00     17   普通
# 15  南投縣         竹山    44  2020-05-03 14:00     14   良好
# 16  桃園市         中壢    43  2020-05-03 14:00     13   良好
# 17  新北市         三重    67  2020-05-03 14:00     22   普通
# 18  宜蘭縣         冬山    52  2020-05-03 14:00     16   普通
# 19  宜蘭縣         宜蘭    45  2020-05-03 14:00     14   良好

# %%
final_df.index = final_df['縣市'] + final_df['位置']
final_df
# Out:
#                縣市         位置  空氣品質              發佈時間  PM2.5 空氣狀況
# 桃園市桃園(觀音工業區)  桃園市  桃園(觀音工業區)    40  2020-05-03 14:00     12   良好
# 臺南市臺南(北門)     臺南市     臺南(北門)    19  2020-05-03 14:00      5   良好
# 屏東縣屏東(琉球)     屏東縣     屏東(琉球)    22  2020-05-03 14:00      5   良好
# 新北市新北(樹林)     新北市     新北(樹林)    52  2020-05-03 14:00     16   普通
# 彰化縣彰化(大城)     彰化縣     彰化(大城)    30  2020-05-03 14:00      6   良好
# ...           ...        ...   ...               ...    ...  ...
# 新北市土城         新北市         土城    62  2020-05-03 14:00     20   普通
# 新北市新店         新北市         新店    52  2020-05-03 14:00     16   普通
# 新北市萬里         新北市         萬里    58  2020-05-03 14:00     18   普通
# 新北市汐止         新北市         汐止    58  2020-05-03 14:00     19   普通
# 基隆市基隆         基隆市         基隆    64  2020-05-03 14:00     21   普通
#
# [83 rows x 6 columns]

# %%
df1=final_df.drop(['縣市', '位置'],axis=1)
df1
# Out:
#               空氣品質              發佈時間  PM2.5 空氣狀況
# 桃園市桃園(觀音工業區)    40  2020-05-03 14:00     12   良好
# 臺南市臺南(北門)       19  2020-05-03 14:00      5   良好
# 屏東縣屏東(琉球)       22  2020-05-03 14:00      5   良好
# 新北市新北(樹林)       52  2020-05-03 14:00     16   普通
# 彰化縣彰化(大城)       30  2020-05-03 14:00      6   良好
# ...            ...               ...    ...  ...
# 新北市土城           62  2020-05-03 14:00     20   普通
# 新北市新店           52  2020-05-03 14:00     16   普通
# 新北市萬里           58  2020-05-03 14:00     18   普通
# 新北市汐止           58  2020-05-03 14:00     19   普通
# 基隆市基隆           64  2020-05-03 14:00     21   普通
#
# [83 rows x 4 columns]

# %%
stateFrame = df1.groupby('空氣狀況').size()
stateFrame
# Out:
# 空氣狀況
# 普通    26
# 良好    57
# dtype: int64

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
font1=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=14)

figure, ax1 = plt.subplots()
stateFrame.plot(ax=ax1,kind='bar',color=['r','g','orange', 'blue'])
#ax1.legend(prop=font)
ax1.set_title('空氣狀況',fontproperties=font)
ax1.set_xticklabels(stateFrame.index, fontproperties=font,rotation=0)
ax1.set_xlabel('狀況', fontproperties=font)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, '狀況')

# %%
for p in ax1.patches:
    width, height = p.get_width(), p.get_height()
    #print('width',width)
    #print('height',height)
    x, y = p.get_xy()
    #print('x',x)
    #print('y',y)
    #print('x+width/2',x+width/2)
    #print('y+height', x+height)
    ax1.annotate('{:}'.format(height), (x+width/2, y+height + height/50), fontproperties=font)
