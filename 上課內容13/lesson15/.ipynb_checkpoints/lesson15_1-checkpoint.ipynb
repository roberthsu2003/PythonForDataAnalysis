# %%
jsonString = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
                  {"name": "Katie", "age": 38,
                   "pets": ["Sixes", "Stache", "Cisco"]}]
}

"""

import json
pythonStruct = json.loads(jsonString)
print(pythonStruct.__class__)
print(pythonStruct["name"])
print(pythonStruct['siblings'][1]["pets"])
# Out:
# <class 'dict'>
# Wes
# ['Sixes', 'Stache', 'Cisco']

# %%
#線上申請api key 的網址 https://opendata.cwb.gov.tw/devManual/insrtuction

import requests
import json

downloadUrlPath = "https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
urlPathApi = "https://opendata.cwb.gov.tw/api/v1/rest/datastore/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"

response = requests.get(urlPathApi)
if response.status_code == 200:
    print("下載成功")
    pyStruct=json.loads(response.text)
    print(pyStruct)
else:
    print("下載失敗")
# Out:
# 下載成功
# {'success': 'true', 'result': {'resource_id': 'O-A0001-001', 'fields': [{'id': 'lat', 'type': 'Double'}, {'id': 'lon', 'type': 'Double'}, {'id': 'locationName', 'type': 'String'}, {'id': 'stationId', 'type': 'String'}, {'id': 'obsTime', 'type': 'Timestamp'}, {'id': 'elementName', 'type': 'String'}, {'id': 'elementValue', 'type': 'String'}, {'id': 'parameterName', 'type': 'String'}, {'id': 'parameterValue', 'type': 'String'}]}, 'records': {'location': [{'lat': '24.778333', 'lon': '121.494583', 'locationName': '福山', 'stationId': 'C0A560', 'time': {'obsTime': '2021-11-15 19:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '405.0'}, {'elementName': 'WDIR', 'elementValue': '161'}, {'elementName': 'WDSD', 'elementValue': '0.4'}, {'elementName': 'TEMP', 'elementValue': '15.7'}, {'elementName': 'HUMD', 'elementValue': '1'}, {'elementName': 'PRES', 'elementValue': '972.1'}, {'elementName': 'H_24R', 'elementValue': '0.0'}, {'elementName': 'H_FX', 'elementValue': '-99'}, {'elementName': 'H_XD', 'elementValue': '-99'}, {'elementName': 'H_FXT', 'elementValue': '-99'}, {'elementName': 'D_TX', 'elementValue': '17.30'}, {'elementName': 'D_TXT', 'elementValue': '2021-11-15T15:30:00+08:00'}, {'elementName': 'D_TN', 'elementValue': '14.10'}, {'elementName': 'D_TNT', 'elementValue': '2021-11-15T00:50:00+08:00'}], 'parameter': [{'parameterName': 'CITY', 'parameterValue': '新北市'}, {'parameterName': 'CITY_SN', 'parameterValue': '06'}, {'parameterName': 'TOWN', 'parameterValue': '烏來區'}, {'parameterName': 'TOWN_SN', 'parameterValue': '061'}]}, {'lat': '22.994972', 'lon': '120.144111', 'locationName': '安平', 'stationId': 'C0X190', 'time': {'obsTime': '2021-11-15 19:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '10.0'}, {'elementName': 'WDIR', 'elementValue': '1'}, {'elementName': 'WDSD', 'elementValue': '1.9'}, {'elementName': 'TEMP', 'elementValue': '23.6'}, {'elementName': 'HUMD', 'elementValue': '0.76'}, {'elementName': 'PRES', 'elementValue': '1013.4'}, {'elementName': 'H_24R', 'elementValue': '0.0'}, {'elementName': 'H_FX', 'elementValue': '-99'}, {'elementName': 'H_XD', 'elementValue': '-99'}, {'elementName': 'H_FXT', 'elementValue': '-99'}, {'elementName': 'D_TX', 'elementValue': '26.80'}, {'elementName': 'D_TXT', 'elementValue': '2021-11-15T13:50:00+08:00'}, {'elementName': 'D_TN', 'elementValue': '18.80'}, {'elementName': 'D_TNT', 'elementValue': '2021-11-15T04:40:00+08:00'}], 'parameter': [{'parameterName': 'CITY', 'parameterValue': '臺南市'}, {'parameterName': 'CITY_SN', 'parameterValue': '04'}, {'parameterName': 'TOWN', 'parameterValue': '安平區'}, {'parameterName': 'TOWN_SN', 'parameterValue': '276'}]}, {'lat': '22.956258', 'lon': '121.221844', 'locationName': '七塊厝', 'stationId': 'C0S950', 'time': {'obsTime': '2021-11-15 19:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '415.0'}, {'elementName': 'WDIR', 'elementValue': '215'}, {'elementName': 'WDSD', 'elementValue': '1.6'}, {'elementName': 'TEMP', 'elementValue': '19.3'}, {'elementName': 'HUMD', 'elementValue': '0.9'}, {'elementName': 'PRES', 'elementValue': '969.9'}, {'elementName': 'H_24R', 'elementValue': '0.0'}, {'elementName': 'H_FX', 'elementValue': '-99'}, {'elementName': 'H_XD', 'elementValue': '-99'}, {'elementName': 'H_FXT', 'elementValue': '-99'}, {'elementName': 'D_TX', 'elementValue': '23.50'}, {'elementName': 'D_TXT', 'elementValue': '2021-11-15T13:00:00+08:00'}, {'elementName': 'D_TN', 'elementValue': '16.60'}, {'elementName': 'D_TNT', 'elementValue': '2021-11-15T04:30:00+08:00'}], 'parameter': [{'parameterName': 'CITY', 'parameterValue': '臺東縣'}, {'parameterName': 'CITY_SN', 'parameterValue': '22'}, {'parameterName': 'TOWN', 'parameterValue': '東河鄉'}, {'parameterName': 'TOWN_SN', 'parameterValue': '264'}]}, {'lat': '25.019167', 'lon': '121.934167', 'locationName': '福隆', 'stationId': 'C0A880', 'time': {'obsTime': '2021-11-15 19:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '6.0'}, {'elementName': 'WDIR ...

# %%
#有檢查發生錯誤

import requests
#import requests.exceptions
from requests.exceptions import *


downloadUrlPath = "https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
urlPathApi = "https://opendata.cwb.gov.tw/api/v1/rest/datastore/O-A0001-001?Authorization=rdec-key-123-45678-011121314&format=JSON"
try:
    response = requests.get(urlPathApi)
    response.raise_for_status()
    
except ConnectionError:
    print("連線錯誤")
except  HTTPError as e:
    print("HTTPError")
    print(e)
except:
    print("發生錯誤")    
else:
    print("沒有發生任何錯誤")
    print(response.json())
# Out:
# 沒有發生任何錯誤
# {'success': 'true', 'result': {'resource_id': 'O-A0001-001', 'fields': [{'id': 'lat', 'type': 'Double'}, {'id': 'lon', 'type': 'Double'}, {'id': 'locationName', 'type': 'String'}, {'id': 'stationId', 'type': 'String'}, {'id': 'obsTime', 'type': 'Timestamp'}, {'id': 'elementName', 'type': 'String'}, {'id': 'elementValue', 'type': 'String'}, {'id': 'parameterName', 'type': 'String'}, {'id': 'parameterValue', 'type': 'String'}]}, 'records': {'location': [{'lat': '24.778333', 'lon': '121.494583', 'locationName': '福山', 'stationId': 'C0A560', 'time': {'obsTime': '2021-11-15 20:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '405.0'}, {'elementName': 'WDIR', 'elementValue': '0'}, {'elementName': 'WDSD', 'elementValue': '0.0'}, {'elementName': 'TEMP', 'elementValue': '15.7'}, {'elementName': 'HUMD', 'elementValue': '1'}, {'elementName': 'PRES', 'elementValue': '972.7'}, {'elementName': 'H_24R', 'elementValue': '0.0'}, {'elementName': 'H_FX', 'elementValue': '-99'}, {'elementName': 'H_XD', 'elementValue': '-99'}, {'elementName': 'H_FXT', 'elementValue': '-99'}, {'elementName': 'D_TX', 'elementValue': '17.30'}, {'elementName': 'D_TXT', 'elementValue': '2021-11-15T15:30:00+08:00'}, {'elementName': 'D_TN', 'elementValue': '14.10'}, {'elementName': 'D_TNT', 'elementValue': '2021-11-15T00:50:00+08:00'}], 'parameter': [{'parameterName': 'CITY', 'parameterValue': '新北市'}, {'parameterName': 'CITY_SN', 'parameterValue': '06'}, {'parameterName': 'TOWN', 'parameterValue': '烏來區'}, {'parameterName': 'TOWN_SN', 'parameterValue': '061'}]}, {'lat': '22.994972', 'lon': '120.144111', 'locationName': '安平', 'stationId': 'C0X190', 'time': {'obsTime': '2021-11-15 20:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '10.0'}, {'elementName': 'WDIR', 'elementValue': '25'}, {'elementName': 'WDSD', 'elementValue': '2.1'}, {'elementName': 'TEMP', 'elementValue': '23.2'}, {'elementName': 'HUMD', 'elementValue': '0.79'}, {'elementName': 'PRES', 'elementValue': '1013.9'}, {'elementName': 'H_24R', 'elementValue': '0.0'}, {'elementName': 'H_FX', 'elementValue': '-99'}, {'elementName': 'H_XD', 'elementValue': '-99'}, {'elementName': 'H_FXT', 'elementValue': '-99'}, {'elementName': 'D_TX', 'elementValue': '26.80'}, {'elementName': 'D_TXT', 'elementValue': '2021-11-15T13:50:00+08:00'}, {'elementName': 'D_TN', 'elementValue': '18.80'}, {'elementName': 'D_TNT', 'elementValue': '2021-11-15T04:40:00+08:00'}], 'parameter': [{'parameterName': 'CITY', 'parameterValue': '臺南市'}, {'parameterName': 'CITY_SN', 'parameterValue': '04'}, {'parameterName': 'TOWN', 'parameterValue': '安平區'}, {'parameterName': 'TOWN_SN', 'parameterValue': '276'}]}, {'lat': '22.956258', 'lon': '121.221844', 'locationName': '七塊厝', 'stationId': 'C0S950', 'time': {'obsTime': '2021-11-15 20:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '415.0'}, {'elementName': 'WDIR', 'elementValue': '228'}, {'elementName': 'WDSD', 'elementValue': '1.7'}, {'elementName': 'TEMP', 'elementValue': '19.1'}, {'elementName': 'HUMD', 'elementValue': '0.89'}, {'elementName': 'PRES', 'elementValue': '970.3'}, {'elementName': 'H_24R', 'elementValue': '0.0'}, {'elementName': 'H_FX', 'elementValue': '-99'}, {'elementName': 'H_XD', 'elementValue': '-99'}, {'elementName': 'H_FXT', 'elementValue': '-99'}, {'elementName': 'D_TX', 'elementValue': '23.50'}, {'elementName': 'D_TXT', 'elementValue': '2021-11-15T13:00:00+08:00'}, {'elementName': 'D_TN', 'elementValue': '16.60'}, {'elementName': 'D_TNT', 'elementValue': '2021-11-15T04:30:00+08:00'}], 'parameter': [{'parameterName': 'CITY', 'parameterValue': '臺東縣'}, {'parameterName': 'CITY_SN', 'parameterValue': '22'}, {'parameterName': 'TOWN', 'parameterValue': '東河鄉'}, {'parameterName': 'TOWN_SN', 'parameterValue': '264'}]}, {'lat': '25.019167', 'lon': '121.934167', 'locationName': '福隆', 'stationId': 'C0A880', 'time': {'obsTime': '2021-11-15 20:00:00'}, 'weatherElement': [{'elementName': 'ELEV', 'elementValue': '6.0'}, {'elementName': 'WDIR ...
