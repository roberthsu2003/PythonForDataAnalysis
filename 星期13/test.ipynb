# %%
import matplotlib.pyplot as plt
data = [-1, -4.3, 15, 21, 31]
figure = plt.figure(num=3, figsize=(8,5))

print(plt.plot(data))
plt.show()

# %%
x = ['chinese', 'english', 'math', 'history', 'discover']
y1 = [1, 2, 5, 6, 7]
y2 = [4, 5, 6, 7, 8]
plt.plot(x,y1, x, y2)

# %%
x = [1,2,3,4,5]
y1 = [1,2,5,6,7]
y2 = [4,5,6,7,8]
plt.plot(x, y1, "r-o", x,y2, "g--")
plt.axis([1.0, 5.0,1.0, 10.0])
plt.grid()
