# %%
import numpy as np
import pandas as pd

tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
tips.columns = ['總票價', '小費', '吸煙者', '日期', '時間', '大小']
tips
# Out:
#        總票價    小費  吸煙者    日期      時間  大小
# 0    16.99  1.01   No   Sun  Dinner   2
# 1    10.34  1.66   No   Sun  Dinner   3
# 2    21.01  3.50   No   Sun  Dinner   3
# 3    23.68  3.31   No   Sun  Dinner   2
# 4    24.59  3.61   No   Sun  Dinner   4
# ..     ...   ...  ...   ...     ...  ..
# 239  29.03  5.92   No   Sat  Dinner   3
# 240  27.18  2.00  Yes   Sat  Dinner   2
# 241  22.67  2.00  Yes   Sat  Dinner   2
# 242  17.82  1.75   No   Sat  Dinner   2
# 243  18.78  3.00   No  Thur  Dinner   2
#
# [244 rows x 6 columns]

# %%
tips['小費比例'] = tips['小費']/tips['總票價']

# %%
tips
# Out:
#        總票價    小費  吸煙者    日期      時間  大小      小費比例
# 0    16.99  1.01   No   Sun  Dinner   2  0.059447
# 1    10.34  1.66   No   Sun  Dinner   3  0.160542
# 2    21.01  3.50   No   Sun  Dinner   3  0.166587
# 3    23.68  3.31   No   Sun  Dinner   2  0.139780
# 4    24.59  3.61   No   Sun  Dinner   4  0.146808
# ..     ...   ...  ...   ...     ...  ..       ...
# 239  29.03  5.92   No   Sat  Dinner   3  0.203927
# 240  27.18  2.00  Yes   Sat  Dinner   2  0.073584
# 241  22.67  2.00  Yes   Sat  Dinner   2  0.088222
# 242  17.82  1.75   No   Sat  Dinner   2  0.098204
# 243  18.78  3.00   No  Thur  Dinner   2  0.159744
#
# [244 rows x 7 columns]

# %%
grouped = tips.groupby(['日期','吸煙者'])
grouped_pct = tips.groupby(['日期','吸煙者'])['小費']
grouped_pct.mean()
# Out:
# 日期    吸煙者
# Fri   No     2.812500
#       Yes    2.714000
# Sat   No     3.102889
#       Yes    2.875476
# Sun   No     3.167895
#       Yes    3.516842
# Thur  No     2.673778
#       Yes    3.030000
# Name: 小費, dtype: float64

# %%
grouped_pct.agg(['mean','std'])
# Out:
#               mean       std
# 日期   吸煙者
# Fri  No   2.812500  0.898494
#      Yes  2.714000  1.077668
# Sat  No   3.102889  1.642088
#      Yes  2.875476  1.630580
# Sun  No   3.167895  1.224785
#      Yes  3.516842  1.261151
# Thur No   2.673778  1.282964
#      Yes  3.030000  1.113491

# %%
s1 = pd.Series([0, 5, 9, 14])
s1.mean()
s1.std()
# Out:
# 5.94418483337567

# %%
s2 = pd.Series([5, 6, 8, 9])
s2.mean()
s2.std()
# Out:
# 1.8257418583505538

# %%
#grouped_pct是SerialGroupby,沒有欄位
grouped_pct.agg([('小費平均','mean'),('小費標準差','std')])
# Out:
#               小費平均     小費標準差
# 日期   吸煙者
# Fri  No   2.812500  0.898494
#      Yes  2.714000  1.077668
# Sat  No   3.102889  1.642088
#      Yes  2.875476  1.630580
# Sun  No   3.167895  1.224785
#      Yes  3.516842  1.261151
# Thur No   2.673778  1.282964
#      Yes  3.030000  1.113491

# %%
grouped_pct.agg(['mean','std'])
# Out:
#               mean       std
# 日期   吸煙者
# Fri  No   2.812500  0.898494
#      Yes  2.714000  1.077668
# Sat  No   3.102889  1.642088
#      Yes  2.875476  1.630580
# Sun  No   3.167895  1.224785
#      Yes  3.516842  1.261151
# Thur No   2.673778  1.282964
#      Yes  3.030000  1.113491

# %%
resultDf=grouped[['總票價','小費']].agg([('平均','mean'),('筆數','count'),('最大','max')])
resultDf
# Out:
#                 總票價                   小費
#                  平均  筆數     最大        平均  筆數     最大
# 日期   吸煙者
# Fri  No   18.420000   4  22.75  2.812500   4   3.50
#      Yes  16.813333  15  40.17  2.714000  15   4.73
# Sat  No   19.661778  45  48.33  3.102889  45   9.00
#      Yes  21.276667  42  50.81  2.875476  42  10.00
# Sun  No   20.506667  57  48.17  3.167895  57   6.00
#      Yes  24.120000  19  45.35  3.516842  19   6.50
# Thur No   17.113111  45  41.19  2.673778  45   6.70
#      Yes  19.190588  17  43.11  3.030000  17   5.00

# %%
resultDf['總票價']
# Out:
#                  平均  筆數     最大
# 日期   吸煙者
# Fri  No   18.420000   4  22.75
#      Yes  16.813333  15  40.17
# Sat  No   19.661778  45  48.33
#      Yes  21.276667  42  50.81
# Sun  No   20.506667  57  48.17
#      Yes  24.120000  19  45.35
# Thur No   17.113111  45  41.19
#      Yes  19.190588  17  43.11

# %%
resultDf['總票價','筆數']
# Out:
# 日期    吸煙者
# Fri   No      4
#       Yes    15
# Sat   No     45
#       Yes    42
# Sun   No     57
#       Yes    19
# Thur  No     45
#       Yes    17
# Name: (總票價, 筆數), dtype: int64

# %%
resultDf.loc['Fri']
# Out:
#            總票價                 小費
#             平均  筆數     最大      平均  筆數    最大
# 吸煙者
# No   18.420000   4  22.75  2.8125   4  3.50
# Yes  16.813333  15  40.17  2.7140  15  4.73
