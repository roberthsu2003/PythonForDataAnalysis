# %%
import requests
import re
#https://data.gov.tw/dataset/89029
CSV_URL = "https://data.epa.gov.tw/api/v1/aqx_p_432?limit=1000&api_key=9be7b239-557b-4c10-9775-78cadfc555e9&format=csv"
response = requests.get(CSV_URL)

d = response.headers['content-disposition']
fname = re.findall("filename=(.+)", d)[0]
print(fname)
filename = '空氣品質指標.csv'
if response.status_code == 200:
    print("下載成功")
    with open(filename,'wb') as file:
        for chunk in response.iter_content(chunk_size=128,decode_unicode=False):
            file.write(chunk)
    print("存檔成功")
# Out:
# "aqx_p_432_20220406115622.csv"
# 下載成功
# 存檔成功

# %%
import pandas as pd
dataFrame = pd.read_csv(filename)
dataFrame
# Out:
#    SiteName County  AQI Pollutant Status  SO2    CO CO_8hr    O3  O3_8hr  ...  \
# 0        基隆    基隆市   43       NaN     良好  0.4  0.41    0.2  25.1    40.0  ...
# 1        汐止    新北市   35       NaN     良好  0.5  0.21    0.1   NaN     NaN  ...
# 2        萬里    新北市   42       NaN     良好  0.2   0.2    0.1  39.5    45.0  ...
# 3        新店    新北市   42       NaN     良好  0.7  0.28    0.2  35.4    37.0  ...
# 4        土城    新北市   44       NaN     良好  0.9  0.37    0.2  33.9    39.0  ...
# ..      ...    ...  ...       ...    ...  ...   ...    ...   ...     ...  ...
# 80   屏東(琉球)    屏東縣   80     臭氧八小時     普通  1.7   0.2    0.2  63.0    64.0  ...
# 81   桃園(蘆竹)    桃園市   51     細懸浮微粒     普通  2.1  0.47    0.3  16.1    18.0  ...
# 82   新北(樹林)    新北市   37       NaN     良好  0.4  0.43    0.3  18.9    23.0  ...
# 83   臺南(學甲)    臺南市   75     細懸浮微粒     普通  1.1  0.36    0.3  33.4    41.0  ...
# 84   屏東(枋寮)    屏東縣   49       NaN     良好  0.6  0.15    0.2  40.2    53.0  ...
#
#      NO  WIND_SPEED  WIND_DIREC          PublishTime  PM2.5_AVG PM10_AVG  \
# 0   1.3         0.4         247  2022/04/06 19:00:00         13       22
# 1   1.0         1.2          33  2022/04/06 19:00:00         10       21
# 2   0.7         2.1         208  2022/04/06 19:00:00         12       35
# 3   1.5         1.3          75  2022/04/06 19:00:00         12       19
# 4   0.4         1.5         339  2022/04/06 19:00:00         13       24
# ..  ...         ...         ...                  ...        ...      ...
# 80  0.9           1         308  2022/04/06 19:00:00         21       35
# 81  3.5         0.4         241  2022/04/06 19:00:00         15       28
# 82  6.4         0.3         167  2022/04/06 19:00:00         11       23
# 83  5.2         1.7          21  2022/04/06 19:00:00         25       68
# 84  0.1         0.1          69  2022/04/06 19:00:00         13       30
#
#    SO2_AVG   Longitude   Latitude  SiteId
# 0      0.0  121.760056  25.129167       1
# 1      0.0  121.642300  25.067131       2
# 2      0.0  121.689881  25.179667       3
# 3      0.0  121.537778  24.977222       4
# 4      0.0  121.451861  24.982528       5
# ..     ...         ...        ...     ...
# 80     1.0  120.377220  22.352220     204
# 81     3.0  121.317950  25.001308     310
# 82     0.0  121.383528  24.949028     311
# 83     0.0  120.183397  23.236881     312
# 84     0.0  120.590369  22.384742     313
#
# [85 rows x 24 columns]
