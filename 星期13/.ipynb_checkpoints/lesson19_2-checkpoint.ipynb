# %%
import requests
jsonUrl = 'http://ods.railway.gov.tw/tra-ods-web/ods/download/dataResource/8ae4cabf6973990e0169947ed32454b9'
response = requests.get(jsonUrl)
jsObject = response.json()
jsObject
# Out:
# [{'trnOpDate': '20220101',
#   'staCode': '0900',
#   'gateInComingCnt': '8645',
#   'gateOutGoingCnt': '8526'},
#  {'trnOpDate': '20220101',
#   'staCode': '0910',
#   'gateInComingCnt': '996',
#   'gateOutGoingCnt': '1243'},
#  {'trnOpDate': '20220101',
#   'staCode': '0920',
#   'gateInComingCnt': '1369',
#   'gateOutGoingCnt': '1711'},
#  {'trnOpDate': '20220101',
#   'staCode': '0930',
#   'gateInComingCnt': '3663',
#   'gateOutGoingCnt': '4535'},
#  {'trnOpDate': '20220101',
#   'staCode': '0940',
#   'gateInComingCnt': '1532',
#   'gateOutGoingCnt': '1845'},
#  {'trnOpDate': '20220101',
#   'staCode': '0950',
#   'gateInComingCnt': '1319',
#   'gateOutGoingCnt': '1343'},
#  {'trnOpDate': '20220101',
#   'staCode': '0960',
#   'gateInComingCnt': '7138',
#   'gateOutGoingCnt': '8228'},
#  {'trnOpDate': '20220101',
#   'staCode': '0970',
#   'gateInComingCnt': '4616',
#   'gateOutGoingCnt': '5277'},
#  {'trnOpDate': '20220101',
#   'staCode': '0980',
#   'gateInComingCnt': '9418',
#   'gateOutGoingCnt': '8806'},
#  {'trnOpDate': '20220101',
#   'staCode': '0990',
#   'gateInComingCnt': '12266',
#   'gateOutGoingCnt': '10553'},
#  {'trnOpDate': '20220101',
#   'staCode': '1000',
#   'gateInComingCnt': '66454',
#   'gateOutGoingCnt': '48827'},
#  {'trnOpDate': '20220101',
#   'staCode': '1010',
#   'gateInComingCnt': '3443',
#   'gateOutGoingCnt': '3330'},
#  {'trnOpDate': '20220101',
#   'staCode': '1020',
#   'gateInComingCnt': '26366',
#   'gateOutGoingCnt': '23999'},
#  {'trnOpDate': '20220101',
#   'staCode': '1030',
#   'gateInComingCnt': '1958',
#   'gateOutGoingCnt': '2059'},
#  {'trnOpDate': '20220101',
#   'staCode': '1040',
#   'gateInComingCnt': '12337',
#   'gateOutGoingCnt': '14532'},
#  {'trnOpDate': '20220101',
#   'staCode': '1050',
#   'gateInComingCnt': '1038',
#   'gateOutGoingCnt': '1170'},
#  {'trnOpDate': '20220101',
#   'staCode': '1060',
#   'gateInComingCnt': '1405',
#   'gateOutGoingCnt': '1679'},
#  {'trnOpDate': '20220101',
#   'staCode': '1070',
#   'gateInComingCnt': '7345',
#   'gateOutGoingCnt': '8169'},
#  {'trnOpDate': '20220101',
#   'staCode': '1080',
#   'gateInComingCnt': '24991',
#   'gateOutGoingCnt': '31095'},
#  {'trnOpDate': '20220101',
#   'staCode': '1090',
#   'gateInComingCnt': '6704',
#   'gateOutGoingCnt': '8271'},
#  {'trnOpDate': '20220101',
#   'staCode': '1100',
#   'gateInComingCnt': '24577',
#   'gateOutGoingCnt': '28729'},
#  {'trnOpDate': '20220101',
#   'staCode': '1110',
#   'gateInComingCnt': '4329',
#   'gateOutGoingCnt': '5086'},
#  {'trnOpDate': '20220101',
#   'staCode': '1120',
#   'gateInComingCnt': '3601',
#   'gateOutGoingCnt': '4256'},
#  {'trnOpDate': '20220101',
#   'staCode': '1130',
#   'gateInComingCnt': '1513',
#   'gateOutGoingCnt': '1870'},
#  {'trnOpDate': '20220101',
#   'staCode': '1140',
#   'gateInComingCnt': '67',
#   'gateOutGoingCnt': '173'},
#  {'trnOpDate': '20220101',
#   'staCode': '1150',
#   'gateInComingCnt': '465',
#   'gateOutGoingCnt': '548'},
#  {'trnOpDate': '20220101',
#   'staCode': '1160',
#   'gateInComingCnt': '2946',
#   'gateOutGoingCnt': '3188'},
#  {'trnOpDate': '20220101',
#   'staCode': '1170',
#   'gateInComingCnt': '5107',
#   'gateOutGoingCnt': '6152'},
#  {'trnOpDate': '20220101',
#   'staCode': '1180',
#   'gateInComingCnt': '3733',
#   'gateOutGoingCnt': '4032'},
#  {'trnOpDate': '20220101',
#   'staCode': '1190',
#   'gateInComingCnt': '1341',
#   'gateOutGoingCnt': '1552'},
#  {'trnOpDate': '20220101',
#   'staCode': '1191',
#   'gateInComingCnt': '263',
#   'gateOutGoingCnt': '278'},
#  {'trnOpDate': '20220101',
#   'staCode': '1192',
#   'gateInComingCnt': '1295',
#   'gateOutGoingCnt': '1431'},
#  {'trnOpDate': '20220101',
#   'staCode': '1193',
#   'gateInComingCnt': '704',
#   'gateOutGoingCnt': '819'},
#  {'trnOpDate': '20220101',
#   'staCode': '1194',
#   'gateInComingCnt': '3093',
#   'gateOutGoingCnt': '2345'},
#  {'trnOpDate': '20220101',
#   'staCode': '1201',
#   'gateInComingCnt': '62',
#   'gateOutGoingCnt': '84'},
#  {'trnOpDate': '20220101',
#   'staCode': '1202',
#   'gateInComingCnt': '147',
#   'gateOutGoingCnt': '125'},
#  {'trnOpDate': '20220101',
#   'staCode': '1203',
#   'gateInComingCnt': '777',
#   'gateOutGoingCnt': '755'},
#  {'trnOpDate': '20220101',
#   'staCode': '1204',
#   'gateInComingCnt': '97',
#   'gateOutGoingCnt': '96'},
#  {'trnOpDate': '20220101',
#   'staCode': '1205',
#   'gateInComingCnt': '40',
#   'gateOutGoingCnt': '56'},
#  {'trnOpDate': '20220101',
#   'staCode': '1206',
#   'gateInComingCnt': '299',
#   'gateOutGoingCnt': '448'},
#  {'trnOpDate': '20220101',
#   'staCode': '1207',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '110'},
#  {'trnOpDate': '20220101',
#   'staCode': '1208',
#   'gateInComingCnt': '1761',
#   'gateOutGoingCnt': '1554'},
#  {'trnOpDate': '20220101',
#   'staCode': '1210',
#   'gateInComingCnt': '20655',
#   'gateOutGoingCnt': '22460'},
#  {'trnOpDate': '20220101',
#   'staCode': '1220',
#   'gateInComingCnt': '755',
#   'gateOutGoingCnt': '797'},
#  {'trnOpDate': '20220101',
#   'staCode': '1230',
#   'gateInComingCnt': '527',
#   'gateOutGoingCnt': '559'},
#  {'trnOpDate': '20220101',
#   'staCode': '1240',
#   'gateInComingCnt': '266',
#   'gateOutGoingCnt': '311'},
#  {'trnOpDate': '20220101',
#   'staCode': '1250',
#   'gateInComingCnt': '6768',
#   'gateOutGoingCnt': '7866'},
#  {'trnOpDate': '20220101',
#   'staCode': '2110',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '64'},
#  {'trnOpDate': '20220101',
#   'staCode': '2120',
#   'gateInComingCnt': '71',
#   'gateOutGoingCnt': '78'},
#  {'trnOpDate': '20220101',
#   'staCode': '2130',
#   'gateInComingCnt': '683',
#   'gateOutGoingCnt': '890'},
#  {'trnOpDate': '20220101',
#   'staCode': '2140',
#   'gateInComingCnt': '25',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20220101',
#   'staCode': '2150',
#   'gateInComingCnt': '904',
#   'gateOutGoingCnt': '851'},
#  {'trnOpDate': '20220101',
#   'staCode': '2160',
#   'gateInComingCnt': '84',
#   'gateOutGoingCnt': '73'},
#  {'trnOpDate': '20220101',
#   'staCode': '2170',
#   'gateInComingCnt': '761',
#   'gateOutGoingCnt': '863'},
#  {'trnOpDate': '20220101',
#   'staCode': '2180',
#   'gateInComingCnt': '1316',
#   'gateOutGoingCnt': '1532'},
#  {'trnOpDate': '20220101',
#   'staCode': '2190',
#   'gateInComingCnt': '253',
#   'gateOutGoingCnt': '267'},
#  {'trnOpDate': '20220101',
#   'staCode': '2200',
#   'gateInComingCnt': '3391',
#   'gateOutGoingCnt': '3461'},
#  {'trnOpDate': '20220101',
#   'staCode': '2210',
#   'gateInComingCnt': '68',
#   'gateOutGoingCnt': '97'},
#  {'trnOpDate': '20220101',
#   'staCode': '2220',
#   'gateInComingCnt': '1057',
#   'gateOutGoingCnt': '1157'},
#  {'trnOpDate': '20220101',
#   'staCode': '2230',
#   'gateInComingCnt': '2697',
#   'gateOutGoingCnt': '2847'},
#  {'trnOpDate': '20220101',
#   'staCode': '2240',
#   'gateInComingCnt': '425',
#   'gateOutGoingCnt': '461'},
#  {'trnOpDate': '20220101',
#   'staCode': '2250',
#   'gateInComingCnt': '549',
#   'gateOutGoingCnt': '527'},
#  {'trnOpDate': '20220101',
#   'staCode': '2260',
#   'gateInComingCnt': '4325',
#   'gateOutGoingCnt': '479'},
#  {'trnOpDate': '20220101',
#   'staCode': '3140',
#   'gateInComingCnt': '224',
#   'gateOutGoingCnt': '259'},
#  {'trnOpDate': '20220101',
#   'staCode': '3150',
#   'gateInComingCnt': '892',
#   'gateOutGoingCnt': '843'},
#  {'trnOpDate': '20220101',
#   'staCode': '3160',
#   'gateInComingCnt': '4339',
#   'gateOutGoingCnt': '4871'},
#  {'trnOpDate': '20220101',
#   'staCode': '3170',
#   'gateInComingCnt': '84',
#   'gateOutGoingCnt': '102'},
#  {'trnOpDate': '20220101',
#   'staCode': '3180',
#   'gateInComingCnt': '948',
#   'gateOutGoingCnt': '1137'},
#  {'trnOpDate': '20220101',
#   'staCode': '3190',
#   'gateInComingCnt': '784',
#   'gateOutGoingCnt': '944'},
#  {'trnOpDate': '20220101',
#   'staCode': '3210',
#   'gateInComingCnt': '929',
#   'gateOutGoingCnt': '1011'},
#  {'trnOpDate': '20220101',
#   'staCode': '3220',
#   'gateInComingCnt': '2859',
#   'gateOutGoingCnt': '2732'},
#  {'trnOpDate': '20220101',
#   'staCode': '3230',
#   'gateInComingCnt': '8560',
#   'gateOutGoingCnt': '9231'},
#  {'trnOpDate': '20220101',
#   'staCode': '3240',
#   'gateInComingCnt': '805',
#   'gateOutGoingCnt': '806'},
#  {'trnOpDate': '20220101',
#   'staCode': '3250',
#   'gateInComingCnt': '2800',
#   'gateOutGoingCnt': '2772'},
#  {'trnOpDate': '20220101',
#   'staCode': '3260',
#   'gateInComingCnt': '556',
#   'gateOutGoingCnt': '507'},
#  {'trnOpDate': '20220101',
#   'staCode': '3270',
#   'gateInComingCnt': '2299',
#   'gateOutGoingCnt': '1792'},
#  {'trnOpDate': '20220101',
#   'staCode': '3280',
#   'gateInComingCnt': '2364',
#   'gateOutGoingCnt': '2259'},
#  {'trnOpDate': '20220101',
#   'staCode': '3290',
#   'gateInComingCnt': '1293',
#   'gateOutGoingCnt': '1299'},
#  {'trnOpDate': '20220101',
#   'staCode': '3300',
#   'gateInComingCnt': '34398',
#   'gateOutGoingCnt': '32633'},
#  {'trnOpDate': '20220101',
#   'staCode': '3310',
#   'gateInComingCnt': '1498',
#   'gateOutGoingCnt': '1251'},
#  {'trnOpDate': '20220101',
#   'staCode': '3320',
#   'gateInComingCnt': '2750',
#   'gateOutGoingCnt': '2366'},
#  {'trnOpDate': '20220101',
#   'staCode': '3330',
#   'gateInComingCnt': '911',
#   'gateOutGoingCnt': '923'},
#  {'trnOpDate': '20220101',
#   'staCode': '3340',
#   'gateInComingCnt': '7769',
#   'gateOutGoingCnt': '6468'},
#  {'trnOpDate': '20220101',
#   'staCode': '3350',
#   'gateInComingCnt': '782',
#   'gateOutGoingCnt': '4639'},
#  {'trnOpDate': '20220101',
#   'staCode': '3360',
#   'gateInComingCnt': '14502',
#   'gateOutGoingCnt': '16641'},
#  {'trnOpDate': '20220101',
#   'staCode': '3370',
#   'gateInComingCnt': '1160',
#   'gateOutGoingCnt': '1363'},
#  {'trnOpDate': '20220101',
#   'staCode': '3380',
#   'gateInComingCnt': '839',
#   'gateOutGoingCnt': '962'},
#  {'trnOpDate': '20220101',
#   'staCode': '3390',
#   'gateInComingCnt': '6758',
#   'gateOutGoingCnt': '7089'},
#  {'trnOpDate': '20220101',
#   'staCode': '3400',
#   'gateInComingCnt': '398',
#   'gateOutGoingCnt': '464'},
#  {'trnOpDate': '20220101',
#   'staCode': '3410',
#   'gateInComingCnt': '875',
#   'gateOutGoingCnt': '1048'},
#  {'trnOpDate': '20220101',
#   'staCode': '3420',
#   'gateInComingCnt': '2012',
#   'gateOutGoingCnt': '2476'},
#  {'trnOpDate': '20220101',
#   'staCode': '3430',
#   'gateInComingCnt': '982',
#   'gateOutGoingCnt': '1122'},
#  {'trnOpDate': '20220101',
#   'staCode': '3431',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '26'},
#  {'trnOpDate': '20220101',
#   'staCode': '3432',
#   'gateInComingCnt': '138',
#   'gateOutGoingCnt': '176'},
#  {'trnOpDate': '20220101',
#   'staCode': '3433',
#   'gateInComingCnt': '16',
#   'gateOutGoingCnt': '31'},
#  {'trnOpDate': '20220101',
#   'staCode': '3434',
#   'gateInComingCnt': '635',
#   'gateOutGoingCnt': '531'},
#  {'trnOpDate': '20220101',
#   'staCode': '3435',
#   'gateInComingCnt': '88',
#   'gateOutGoingCnt': '95'},
#  {'trnOpDate': '20220101',
#   'staCode': '3436',
#   'gateInComingCnt': '294',
#   'gateOutGoingCnt': '339'},
#  {'trnOpDate': '20220101',
#   'staCode': '3450',
#   'gateInComingCnt': '712',
#   'gateOutGoingCnt': '755'},
#  {'trnOpDate': '20220101',
#   'staCode': '3460',
#   'gateInComingCnt': '154',
#   'gateOutGoingCnt': '208'},
#  {'trnOpDate': '20220101',
#   'staCode': '3470',
#   'gateInComingCnt': '5535',
#   'gateOutGoingCnt': '6045'},
#  {'trnOpDate': '20220101',
#   'staCode': '3480',
#   'gateInComingCnt': '1887',
#   'gateOutGoingCnt': '2113'},
#  {'trnOpDate': '20220101',
#   'staCode': '3490',
#   'gateInComingCnt': '109',
#   'gateOutGoingCnt': '134'},
#  {'trnOpDate': '20220101',
#   'staCode': '4050',
#   'gateInComingCnt': '1288',
#   'gateOutGoingCnt': '1313'},
#  {'trnOpDate': '20220101',
#   'staCode': '4060',
#   'gateInComingCnt': '1683',
#   'gateOutGoingCnt': '1786'},
#  {'trnOpDate': '20220101',
#   'staCode': '4070',
#   'gateInComingCnt': '518',
#   'gateOutGoingCnt': '519'},
#  {'trnOpDate': '20220101',
#   'staCode': '4080',
#   'gateInComingCnt': '11563',
#   'gateOutGoingCnt': '12288'},
#  {'trnOpDate': '20220101',
#   'staCode': '4090',
#   'gateInComingCnt': '631',
#   'gateOutGoingCnt': '668'},
#  {'trnOpDate': '20220101',
#   'staCode': '4100',
#   'gateInComingCnt': '152',
#   'gateOutGoingCnt': '193'},
#  {'trnOpDate': '20220101',
#   'staCode': '4110',
#   'gateInComingCnt': '499',
#   'gateOutGoingCnt': '567'},
#  {'trnOpDate': '20220101',
#   'staCode': '4120',
#   'gateInComingCnt': '4160',
#   'gateOutGoingCnt': '4683'},
#  {'trnOpDate': '20220101',
#   'staCode': '4130',
#   'gateInComingCnt': '410',
#   'gateOutGoingCnt': '402'},
#  {'trnOpDate': '20220101',
#   'staCode': '4140',
#   'gateInComingCnt': '465',
#   'gateOutGoingCnt': '556'},
#  {'trnOpDate': '20220101',
#   'staCode': '4150',
#   'gateInComingCnt': '997',
#   'gateOutGoingCnt': '1167'},
#  {'trnOpDate': '20220101',
#   'staCode': '4160',
#   'gateInComingCnt': '121',
#   'gateOutGoingCnt': '136'},
#  {'trnOpDate': '20220101',
#   'staCode': '4170',
#   'gateInComingCnt': '2550',
#   'gateOutGoingCnt': '2747'},
#  {'trnOpDate': '20220101',
#   'staCode': '4180',
#   'gateInComingCnt': '670',
#   'gateOutGoingCnt': '680'},
#  {'trnOpDate': '20220101',
#   'staCode': '4190',
#   'gateInComingCnt': '2030',
#   'gateOutGoingCnt': '2063'},
#  {'trnOpDate': '20220101',
#   'staCode': '4200',
#   'gateInComingCnt': '6477',
#   'gateOutGoingCnt': '3839'},
#  {'trnOpDate': '20220101',
#   'staCode': '4210',
#   'gateInComingCnt': '2226',
#   'gateOutGoingCnt': '2071'},
#  {'trnOpDate': '20220101',
#   'staCode': '4220',
#   'gateInComingCnt': '28307',
#   'gateOutGoingCnt': '27727'},
#  {'trnOpDate': '20220101',
#   'staCode': '4250',
#   'gateInComingCnt': '2596',
#   'gateOutGoingCnt': '5097'},
#  {'trnOpDate': '20220101',
#   'staCode': '4260',
#   'gateInComingCnt': '887',
#   'gateOutGoingCnt': '821'},
#  {'trnOpDate': '20220101',
#   'staCode': '4270',
#   'gateInComingCnt': '372',
#   'gateOutGoingCnt': '386'},
#  {'trnOpDate': '20220101',
#   'staCode': '4271',
#   'gateInComingCnt': '304',
#   'gateOutGoingCnt': '295'},
#  {'trnOpDate': '20220101',
#   'staCode': '4272',
#   'gateInComingCnt': '2170',
#   'gateOutGoingCnt': '2219'},
#  {'trnOpDate': '20220101',
#   'staCode': '4290',
#   'gateInComingCnt': '853',
#   'gateOutGoingCnt': '984'},
#  {'trnOpDate': '20220101',
#   'staCode': '4300',
#   'gateInComingCnt': '1420',
#   'gateOutGoingCnt': '1613'},
#  {'trnOpDate': '20220101',
#   'staCode': '4310',
#   'gateInComingCnt': '2497',
#   'gateOutGoingCnt': '2592'},
#  {'trnOpDate': '20220101',
#   'staCode': '4320',
#   'gateInComingCnt': '1817',
#   'gateOutGoingCnt': '1732'},
#  {'trnOpDate': '20220101',
#   'staCode': '4330',
#   'gateInComingCnt': '2312',
#   'gateOutGoingCnt': '2195'},
#  {'trnOpDate': '20220101',
#   'staCode': '4340',
#   'gateInComingCnt': '13583',
#   'gateOutGoingCnt': '12917'},
#  {'trnOpDate': '20220101',
#   'staCode': '4350',
#   'gateInComingCnt': '747',
#   'gateOutGoingCnt': '805'},
#  {'trnOpDate': '20220101',
#   'staCode': '4360',
#   'gateInComingCnt': '742',
#   'gateOutGoingCnt': '722'},
#  {'trnOpDate': '20220101',
#   'staCode': '4370',
#   'gateInComingCnt': '1643',
#   'gateOutGoingCnt': '1601'},
#  {'trnOpDate': '20220101',
#   'staCode': '4380',
#   'gateInComingCnt': '550',
#   'gateOutGoingCnt': '392'},
#  {'trnOpDate': '20220101',
#   'staCode': '4390',
#   'gateInComingCnt': '645',
#   'gateOutGoingCnt': '559'},
#  {'trnOpDate': '20220101',
#   'staCode': '4400',
#   'gateInComingCnt': '17468',
#   'gateOutGoingCnt': '15816'},
#  {'trnOpDate': '20220101',
#   'staCode': '4410',
#   'gateInComingCnt': '642',
#   'gateOutGoingCnt': '615'},
#  {'trnOpDate': '20220101',
#   'staCode': '4420',
#   'gateInComingCnt': '1169',
#   'gateOutGoingCnt': '1114'},
#  {'trnOpDate': '20220101',
#   'staCode': '4430',
#   'gateInComingCnt': '1012',
#   'gateOutGoingCnt': '976'},
#  {'trnOpDate': '20220101',
#   'staCode': '4440',
#   'gateInComingCnt': '4563',
#   'gateOutGoingCnt': '4734'},
#  {'trnOpDate': '20220101',
#   'staCode': '4450',
#   'gateInComingCnt': '620',
#   'gateOutGoingCnt': '554'},
#  {'trnOpDate': '20220101',
#   'staCode': '4460',
#   'gateInComingCnt': '1097',
#   'gateOutGoingCnt': '1196'},
#  {'trnOpDate': '20220101',
#   'staCode': '4470',
#   'gateInComingCnt': '92',
#   'gateOutGoingCnt': '98'},
#  {'trnOpDate': '20220101',
#   'staCode': '5000',
#   'gateInComingCnt': '10587',
#   'gateOutGoingCnt': '11233'},
#  {'trnOpDate': '20220101',
#   'staCode': '5010',
#   'gateInComingCnt': '161',
#   'gateOutGoingCnt': '231'},
#  {'trnOpDate': '20220101',
#   'staCode': '5020',
#   'gateInComingCnt': '182',
#   'gateOutGoingCnt': '217'},
#  {'trnOpDate': '20220101',
#   'staCode': '5030',
#   'gateInComingCnt': '657',
#   'gateOutGoingCnt': '734'},
#  {'trnOpDate': '20220101',
#   'staCode': '5040',
#   'gateInComingCnt': '272',
#   'gateOutGoingCnt': '363'},
#  {'trnOpDate': '20220101',
#   'staCode': '5050',
#   'gateInComingCnt': '3554',
#   'gateOutGoingCnt': '3940'},
#  {'trnOpDate': '20220101',
#   'staCode': '5060',
#   'gateInComingCnt': '36',
#   'gateOutGoingCnt': '49'},
#  {'trnOpDate': '20220101',
#   'staCode': '5070',
#   'gateInComingCnt': '358',
#   'gateOutGoingCnt': '407'},
#  {'trnOpDate': '20220101',
#   'staCode': '5080',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '38'},
#  {'trnOpDate': '20220101',
#   'staCode': '5090',
#   'gateInComingCnt': '538',
#   'gateOutGoingCnt': '473'},
#  {'trnOpDate': '20220101',
#   'staCode': '5100',
#   'gateInComingCnt': '126',
#   'gateOutGoingCnt': '121'},
#  {'trnOpDate': '20220101',
#   'staCode': '5110',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '333'},
#  {'trnOpDate': '20220101',
#   'staCode': '5120',
#   'gateInComingCnt': '1140',
#   'gateOutGoingCnt': '1306'},
#  {'trnOpDate': '20220101',
#   'staCode': '5130',
#   'gateInComingCnt': '356',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20220101',
#   'staCode': '5140',
#   'gateInComingCnt': '1',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20220101',
#   'staCode': '5160',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '27'},
#  {'trnOpDate': '20220101',
#   'staCode': '5190',
#   'gateInComingCnt': '213',
#   'gateOutGoingCnt': '237'},
#  {'trnOpDate': '20220101',
#   'staCode': '5200',
#   'gateInComingCnt': '34',
#   'gateOutGoingCnt': '22'},
#  {'trnOpDate': '20220101',
#   'staCode': '5210',
#   'gateInComingCnt': '954',
#   'gateOutGoingCnt': '860'},
#  {'trnOpDate': '20220101',
#   'staCode': '5220',
#   'gateInComingCnt': '436',
#   'gateOutGoingCnt': '281'},
#  {'trnOpDate': '20220101',
#   'staCode': '5230',
#   'gateInComingCnt': '755',
#   'gateOutGoingCnt': '704'},
#  {'trnOpDate': '20220101',
#   'staCode': '5240',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220101',
#   'staCode': '6000',
#   'gateInComingCnt': '6178',
#   'gateOutGoingCnt': '4507'},
#  {'trnOpDate': '20220101',
#   'staCode': '6010',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '67'},
#  {'trnOpDate': '20220101',
#   'staCode': '6020',
#   'gateInComingCnt': '201',
#   'gateOutGoingCnt': '159'},
#  {'trnOpDate': '20220101',
#   'staCode': '6030',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '30'},
#  {'trnOpDate': '20220101',
#   'staCode': '6040',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20220101',
#   'staCode': '6050',
#   'gateInComingCnt': '411',
#   'gateOutGoingCnt': '412'},
#  {'trnOpDate': '20220101',
#   'staCode': '6060',
#   'gateInComingCnt': '0',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20220101',
#   'staCode': '6070',
#   'gateInComingCnt': '865',
#   'gateOutGoingCnt': '746'},
#  {'trnOpDate': '20220101',
#   'staCode': '6080',
#   'gateInComingCnt': '106',
#   'gateOutGoingCnt': '121'},
#  {'trnOpDate': '20220101',
#   'staCode': '6090',
#   'gateInComingCnt': '6',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20220101',
#   'staCode': '6100',
#   'gateInComingCnt': '25',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20220101',
#   'staCode': '6110',
#   'gateInComingCnt': '1129',
#   'gateOutGoingCnt': '1214'},
#  {'trnOpDate': '20220101',
#   'staCode': '6120',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220101',
#   'staCode': '6130',
#   'gateInComingCnt': '554',
#   'gateOutGoingCnt': '702'},
#  {'trnOpDate': '20220101',
#   'staCode': '6140',
#   'gateInComingCnt': '34',
#   'gateOutGoingCnt': '43'},
#  {'trnOpDate': '20220101',
#   'staCode': '6150',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20220101',
#   'staCode': '6160',
#   'gateInComingCnt': '365',
#   'gateOutGoingCnt': '348'},
#  {'trnOpDate': '20220101',
#   'staCode': '6170',
#   'gateInComingCnt': '30',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20220101',
#   'staCode': '6180',
#   'gateInComingCnt': '279',
#   'gateOutGoingCnt': '279'},
#  {'trnOpDate': '20220101',
#   'staCode': '6190',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20220101',
#   'staCode': '6200',
#   'gateInComingCnt': '57',
#   'gateOutGoingCnt': '59'},
#  {'trnOpDate': '20220101',
#   'staCode': '6210',
#   'gateInComingCnt': '35',
#   'gateOutGoingCnt': '34'},
#  {'trnOpDate': '20220101',
#   'staCode': '6220',
#   'gateInComingCnt': '235',
#   'gateOutGoingCnt': '253'},
#  {'trnOpDate': '20220101',
#   'staCode': '6230',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20220101',
#   'staCode': '6240',
#   'gateInComingCnt': '310',
#   'gateOutGoingCnt': '332'},
#  {'trnOpDate': '20220101',
#   'staCode': '6250',
#   'gateInComingCnt': '413',
#   'gateOutGoingCnt': '288'},
#  {'trnOpDate': '20220101',
#   'staCode': '7000',
#   'gateInComingCnt': '11814',
#   'gateOutGoingCnt': '8418'},
#  {'trnOpDate': '20220101',
#   'staCode': '7010',
#   'gateInComingCnt': '60',
#   'gateOutGoingCnt': '42'},
#  {'trnOpDate': '20220101',
#   'staCode': '7020',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20220101',
#   'staCode': '7030',
#   'gateInComingCnt': '414',
#   'gateOutGoingCnt': '301'},
#  {'trnOpDate': '20220101',
#   'staCode': '7040',
#   'gateInComingCnt': '15',
#   'gateOutGoingCnt': '21'},
#  {'trnOpDate': '20220101',
#   'staCode': '7050',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20220101',
#   'staCode': '7060',
#   'gateInComingCnt': '134',
#   'gateOutGoingCnt': '187'},
#  {'trnOpDate': '20220101',
#   'staCode': '7070',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20220101',
#   'staCode': '7080',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20220101',
#   'staCode': '7090',
#   'gateInComingCnt': '525',
#   'gateOutGoingCnt': '601'},
#  {'trnOpDate': '20220101',
#   'staCode': '7100',
#   'gateInComingCnt': '196',
#   'gateOutGoingCnt': '135'},
#  {'trnOpDate': '20220101',
#   'staCode': '7110',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '79'},
#  {'trnOpDate': '20220101',
#   'staCode': '7120',
#   'gateInComingCnt': '419',
#   'gateOutGoingCnt': '508'},
#  {'trnOpDate': '20220101',
#   'staCode': '7130',
#   'gateInComingCnt': '428',
#   'gateOutGoingCnt': '540'},
#  {'trnOpDate': '20220101',
#   'staCode': '7140',
#   'gateInComingCnt': '31',
#   'gateOutGoingCnt': '42'},
#  {'trnOpDate': '20220101',
#   'staCode': '7150',
#   'gateInComingCnt': '712',
#   'gateOutGoingCnt': '727'},
#  {'trnOpDate': '20220101',
#   'staCode': '7160',
#   'gateInComingCnt': '6483',
#   'gateOutGoingCnt': '6256'},
#  {'trnOpDate': '20220101',
#   'staCode': '7170',
#   'gateInComingCnt': '56',
#   'gateOutGoingCnt': '69'},
#  {'trnOpDate': '20220101',
#   'staCode': '7180',
#   'gateInComingCnt': '98',
#   'gateOutGoingCnt': '113'},
#  {'trnOpDate': '20220101',
#   'staCode': '7190',
#   'gateInComingCnt': '5163',
#   'gateOutGoingCnt': '4726'},
#  {'trnOpDate': '20220101',
#   'staCode': '7200',
#   'gateInComingCnt': '118',
#   'gateOutGoingCnt': '106'},
#  {'trnOpDate': '20220101',
#   'staCode': '7210',
#   'gateInComingCnt': '3654',
#   'gateOutGoingCnt': '3544'},
#  {'trnOpDate': '20220101',
#   'staCode': '7220',
#   'gateInComingCnt': '70',
#   'gateOutGoingCnt': '91'},
#  {'trnOpDate': '20220101',
#   'staCode': '7230',
#   'gateInComingCnt': '1205',
#   'gateOutGoingCnt': '1092'},
#  {'trnOpDate': '20220101',
#   'staCode': '7240',
#   'gateInComingCnt': '259',
#   'gateOutGoingCnt': '222'},
#  {'trnOpDate': '20220101',
#   'staCode': '7250',
#   'gateInComingCnt': '110',
#   'gateOutGoingCnt': '97'},
#  {'trnOpDate': '20220101',
#   'staCode': '7260',
#   'gateInComingCnt': '220',
#   'gateOutGoingCnt': '257'},
#  {'trnOpDate': '20220101',
#   'staCode': '7270',
#   'gateInComingCnt': '545',
#   'gateOutGoingCnt': '179'},
#  {'trnOpDate': '20220101',
#   'staCode': '7280',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '48'},
#  {'trnOpDate': '20220101',
#   'staCode': '7290',
#   'gateInComingCnt': '781',
#   'gateOutGoingCnt': '953'},
#  {'trnOpDate': '20220101',
#   'staCode': '7300',
#   'gateInComingCnt': '136',
#   'gateOutGoingCnt': '185'},
#  {'trnOpDate': '20220101',
#   'staCode': '7310',
#   'gateInComingCnt': '638',
#   'gateOutGoingCnt': '685'},
#  {'trnOpDate': '20220101',
#   'staCode': '7320',
#   'gateInComingCnt': '148',
#   'gateOutGoingCnt': '183'},
#  {'trnOpDate': '20220101',
#   'staCode': '7330',
#   'gateInComingCnt': '147',
#   'gateOutGoingCnt': '216'},
#  {'trnOpDate': '20220101',
#   'staCode': '7331',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220101',
#   'staCode': '7332',
#   'gateInComingCnt': '1559',
#   'gateOutGoingCnt': '1372'},
#  {'trnOpDate': '20220101',
#   'staCode': '7333',
#   'gateInComingCnt': '34',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20220101',
#   'staCode': '7334',
#   'gateInComingCnt': '81',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20220101',
#   'staCode': '7335',
#   'gateInComingCnt': '924',
#   'gateOutGoingCnt': '968'},
#  {'trnOpDate': '20220101',
#   'staCode': '7336',
#   'gateInComingCnt': '722',
#   'gateOutGoingCnt': '707'},
#  {'trnOpDate': '20220101',
#   'staCode': '7350',
#   'gateInComingCnt': '1229',
#   'gateOutGoingCnt': '1219'},
#  {'trnOpDate': '20220101',
#   'staCode': '7360',
#   'gateInComingCnt': '4449',
#   'gateOutGoingCnt': '4874'},
#  {'trnOpDate': '20220101',
#   'staCode': '7361',
#   'gateInComingCnt': '101',
#   'gateOutGoingCnt': '104'},
#  {'trnOpDate': '20220101',
#   'staCode': '7362',
#   'gateInComingCnt': '367',
#   'gateOutGoingCnt': '468'},
#  {'trnOpDate': '20220101',
#   'staCode': '7380',
#   'gateInComingCnt': '442',
#   'gateOutGoingCnt': '482'},
#  {'trnOpDate': '20220101',
#   'staCode': '7390',
#   'gateInComingCnt': '278',
#   'gateOutGoingCnt': '357'},
#  {'trnOpDate': '20220102',
#   'staCode': '0900',
#   'gateInComingCnt': '6744',
#   'gateOutGoingCnt': '6897'},
#  {'trnOpDate': '20220102',
#   'staCode': '0910',
#   'gateInComingCnt': '1011',
#   'gateOutGoingCnt': '1007'},
#  {'trnOpDate': '20220102',
#   'staCode': '0920',
#   'gateInComingCnt': '1494',
#   'gateOutGoingCnt': '1421'},
#  {'trnOpDate': '20220102',
#   'staCode': '0930',
#   'gateInComingCnt': '3691',
#   'gateOutGoingCnt': '3773'},
#  {'trnOpDate': '20220102',
#   'staCode': '0940',
#   'gateInComingCnt': '1526',
#   'gateOutGoingCnt': '1480'},
#  {'trnOpDate': '20220102',
#   'staCode': '0950',
#   'gateInComingCnt': '1134',
#   'gateOutGoingCnt': '1019'},
#  {'trnOpDate': '20220102',
#   'staCode': '0960',
#   'gateInComingCnt': '6320',
#   'gateOutGoingCnt': '6305'},
#  {'trnOpDate': '20220102',
#   'staCode': '0970',
#   'gateInComingCnt': '4123',
#   'gateOutGoingCnt': '4282'},
#  {'trnOpDate': '20220102',
#   'staCode': '0980',
#   'gateInComingCnt': '8348',
#   'gateOutGoingCnt': '8205'},
#  {'trnOpDate': '20220102',
#   'staCode': '0990',
#   'gateInComingCnt': '9334',
#   'gateOutGoingCnt': '11122'},
#  {'trnOpDate': '20220102',
#   'staCode': '1000',
#   'gateInComingCnt': '47299',
#   'gateOutGoingCnt': '60070'},
#  {'trnOpDate': '20220102',
#   'staCode': '1010',
#   'gateInComingCnt': '2886',
#   'gateOutGoingCnt': '2771'},
#  {'trnOpDate': '20220102',
#   'staCode': '1020',
#   'gateInComingCnt': '21477',
#   'gateOutGoingCnt': '24127'},
#  {'trnOpDate': '20220102',
#   'staCode': '1030',
#   'gateInComingCnt': '1812',
#   'gateOutGoingCnt': '1991'},
#  {'trnOpDate': '20220102',
#   'staCode': '1040',
#   'gateInComingCnt': '11987',
#   'gateOutGoingCnt': '12953'},
#  {'trnOpDate': '20220102',
#   'staCode': '1050',
#   'gateInComingCnt': '816',
#   'gateOutGoingCnt': '940'},
#  {'trnOpDate': '20220102',
#   'staCode': '1060',
#   'gateInComingCnt': '1378',
#   'gateOutGoingCnt': '1414'},
#  {'trnOpDate': '20220102',
#   'staCode': '1070',
#   'gateInComingCnt': '6509',
#   'gateOutGoingCnt': '6258'},
#  {'trnOpDate': '20220102',
#   'staCode': '1080',
#   'gateInComingCnt': '25728',
#   'gateOutGoingCnt': '25389'},
#  {'trnOpDate': '20220102',
#   'staCode': '1090',
#   'gateInComingCnt': '6703',
#   'gateOutGoingCnt': '7430'},
#  {'trnOpDate': '20220102',
#   'staCode': '1100',
#   'gateInComingCnt': '25927',
#   'gateOutGoingCnt': '27533'},
#  {'trnOpDate': '20220102',
#   'staCode': '1110',
#   'gateInComingCnt': '4402',
#   'gateOutGoingCnt': '4069'},
#  {'trnOpDate': '20220102',
#   'staCode': '1120',
#   'gateInComingCnt': '4264',
#   'gateOutGoingCnt': '4144'},
#  {'trnOpDate': '20220102',
#   'staCode': '1130',
#   'gateInComingCnt': '1642',
#   'gateOutGoingCnt': '1480'},
#  {'trnOpDate': '20220102',
#   'staCode': '1140',
#   'gateInComingCnt': '51',
#   'gateOutGoingCnt': '69'},
#  {'trnOpDate': '20220102',
#   'staCode': '1150',
#   'gateInComingCnt': '466',
#   'gateOutGoingCnt': '565'},
#  {'trnOpDate': '20220102',
#   'staCode': '1160',
#   'gateInComingCnt': '3158',
#   'gateOutGoingCnt': '2846'},
#  {'trnOpDate': '20220102',
#   'staCode': '1170',
#   'gateInComingCnt': '5796',
#   'gateOutGoingCnt': '6439'},
#  {'trnOpDate': '20220102',
#   'staCode': '1180',
#   'gateInComingCnt': '4229',
#   'gateOutGoingCnt': '4113'},
#  {'trnOpDate': '20220102',
#   'staCode': '1190',
#   'gateInComingCnt': '1261',
#   'gateOutGoingCnt': '1637'},
#  {'trnOpDate': '20220102',
#   'staCode': '1191',
#   'gateInComingCnt': '280',
#   'gateOutGoingCnt': '366'},
#  {'trnOpDate': '20220102',
#   'staCode': '1192',
#   'gateInComingCnt': '1093',
#   'gateOutGoingCnt': '2672'},
#  {'trnOpDate': '20220102',
#   'staCode': '1193',
#   'gateInComingCnt': '535',
#   'gateOutGoingCnt': '982'},
#  {'trnOpDate': '20220102',
#   'staCode': '1194',
#   'gateInComingCnt': '4581',
#   'gateOutGoingCnt': '2218'},
#  {'trnOpDate': '20220102',
#   'staCode': '1201',
#   'gateInComingCnt': '85',
#   'gateOutGoingCnt': '91'},
#  {'trnOpDate': '20220102',
#   'staCode': '1202',
#   'gateInComingCnt': '117',
#   'gateOutGoingCnt': '117'},
#  {'trnOpDate': '20220102',
#   'staCode': '1203',
#   'gateInComingCnt': '576',
#   'gateOutGoingCnt': '478'},
#  {'trnOpDate': '20220102',
#   'staCode': '1204',
#   'gateInComingCnt': '94',
#   'gateOutGoingCnt': '125'},
#  {'trnOpDate': '20220102',
#   'staCode': '1205',
#   'gateInComingCnt': '70',
#   'gateOutGoingCnt': '84'},
#  {'trnOpDate': '20220102',
#   'staCode': '1206',
#   'gateInComingCnt': '208',
#   'gateOutGoingCnt': '261'},
#  {'trnOpDate': '20220102',
#   'staCode': '1207',
#   'gateInComingCnt': '20',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20220102',
#   'staCode': '1208',
#   'gateInComingCnt': '1143',
#   'gateOutGoingCnt': '980'},
#  {'trnOpDate': '20220102',
#   'staCode': '1210',
#   'gateInComingCnt': '21176',
#   'gateOutGoingCnt': '23222'},
#  {'trnOpDate': '20220102',
#   'staCode': '1220',
#   'gateInComingCnt': '835',
#   'gateOutGoingCnt': '1096'},
#  {'trnOpDate': '20220102',
#   'staCode': '1230',
#   'gateInComingCnt': '552',
#   'gateOutGoingCnt': '436'},
#  {'trnOpDate': '20220102',
#   'staCode': '1240',
#   'gateInComingCnt': '230',
#   'gateOutGoingCnt': '265'},
#  {'trnOpDate': '20220102',
#   'staCode': '1250',
#   'gateInComingCnt': '8816',
#   'gateOutGoingCnt': '7933'},
#  {'trnOpDate': '20220102',
#   'staCode': '2110',
#   'gateInComingCnt': '35',
#   'gateOutGoingCnt': '45'},
#  {'trnOpDate': '20220102',
#   'staCode': '2120',
#   'gateInComingCnt': '93',
#   'gateOutGoingCnt': '76'},
#  {'trnOpDate': '20220102',
#   'staCode': '2130',
#   'gateInComingCnt': '821',
#   'gateOutGoingCnt': '1776'},
#  {'trnOpDate': '20220102',
#   'staCode': '2140',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '27'},
#  {'trnOpDate': '20220102',
#   'staCode': '2150',
#   'gateInComingCnt': '636',
#   'gateOutGoingCnt': '524'},
#  {'trnOpDate': '20220102',
#   'staCode': '2160',
#   'gateInComingCnt': '74',
#   'gateOutGoingCnt': '58'},
#  {'trnOpDate': '20220102',
#   'staCode': '2170',
#   'gateInComingCnt': '1087',
#   'gateOutGoingCnt': '645'},
#  {'trnOpDate': '20220102',
#   'staCode': '2180',
#   'gateInComingCnt': '1877',
#   'gateOutGoingCnt': '1345'},
#  {'trnOpDate': '20220102',
#   'staCode': '2190',
#   'gateInComingCnt': '341',
#   'gateOutGoingCnt': '304'},
#  {'trnOpDate': '20220102',
#   'staCode': '2200',
#   'gateInComingCnt': '3972',
#   'gateOutGoingCnt': '2973'},
#  {'trnOpDate': '20220102',
#   'staCode': '2210',
#   'gateInComingCnt': '96',
#   'gateOutGoingCnt': '44'},
#  {'trnOpDate': '20220102',
#   'staCode': '2220',
#   'gateInComingCnt': '1806',
#   'gateOutGoingCnt': '1165'},
#  {'trnOpDate': '20220102',
#   'staCode': '2230',
#   'gateInComingCnt': '3938',
#   'gateOutGoingCnt': '4685'},
#  {'trnOpDate': '20220102',
#   'staCode': '2240',
#   'gateInComingCnt': '464',
#   'gateOutGoingCnt': '384'},
#  {'trnOpDate': '20220102',
#   'staCode': '2250',
#   'gateInComingCnt': '745',
#   'gateOutGoingCnt': '550'},
#  {'trnOpDate': '20220102',
#   'staCode': '2260',
#   'gateInComingCnt': '758',
#   'gateOutGoingCnt': '300'},
#  {'trnOpDate': '20220102',
#   'staCode': '3140',
#   'gateInComingCnt': '278',
#   'gateOutGoingCnt': '237'},
#  {'trnOpDate': '20220102',
#   'staCode': '3150',
#   'gateInComingCnt': '1235',
#   'gateOutGoingCnt': '899'},
#  {'trnOpDate': '20220102',
#   'staCode': '3160',
#   'gateInComingCnt': '5510',
#   'gateOutGoingCnt': '5437'},
#  {'trnOpDate': '20220102',
#   'staCode': '3170',
#   'gateInComingCnt': '110',
#   'gateOutGoingCnt': '165'},
#  {'trnOpDate': '20220102',
#   'staCode': '3180',
#   'gateInComingCnt': '1309',
#   'gateOutGoingCnt': '861'},
#  {'trnOpDate': '20220102',
#   'staCode': '3190',
#   'gateInComingCnt': '975',
#   'gateOutGoingCnt': '725'},
#  {'trnOpDate': '20220102',
#   'staCode': '3210',
#   'gateInComingCnt': '767',
#   'gateOutGoingCnt': '609'},
#  {'trnOpDate': '20220102',
#   'staCode': '3220',
#   'gateInComingCnt': '2692',
#   'gateOutGoingCnt': '2775'},
#  {'trnOpDate': '20220102',
#   'staCode': '3230',
#   'gateInComingCnt': '10590',
#   'gateOutGoingCnt': '8900'},
#  {'trnOpDate': '20220102',
#   'staCode': '3240',
#   'gateInComingCnt': '782',
#   'gateOutGoingCnt': '722'},
#  {'trnOpDate': '20220102',
#   'staCode': '3250',
#   'gateInComingCnt': '2923',
#   'gateOutGoingCnt': '2769'},
#  {'trnOpDate': '20220102',
#   'staCode': '3260',
#   'gateInComingCnt': '574',
#   'gateOutGoingCnt': '522'},
#  {'trnOpDate': '20220102',
#   'staCode': '3270',
#   'gateInComingCnt': '2073',
#   'gateOutGoingCnt': '1906'},
#  {'trnOpDate': '20220102',
#   'staCode': '3280',
#   'gateInComingCnt': '2521',
#   'gateOutGoingCnt': '2435'},
#  {'trnOpDate': '20220102',
#   'staCode': '3290',
#   'gateInComingCnt': '1450',
#   'gateOutGoingCnt': '1659'},
#  {'trnOpDate': '20220102',
#   'staCode': '3300',
#   'gateInComingCnt': '33114',
#   'gateOutGoingCnt': '37087'},
#  {'trnOpDate': '20220102',
#   'staCode': '3310',
#   'gateInComingCnt': '1330',
#   'gateOutGoingCnt': '1693'},
#  {'trnOpDate': '20220102',
#   'staCode': '3320',
#   'gateInComingCnt': '2130',
#   'gateOutGoingCnt': '2634'},
#  {'trnOpDate': '20220102',
#   'staCode': '3330',
#   'gateInComingCnt': '958',
#   'gateOutGoingCnt': '962'},
#  {'trnOpDate': '20220102',
#   'staCode': '3340',
#   'gateInComingCnt': '9000',
#   'gateOutGoingCnt': '10095'},
#  {'trnOpDate': '20220102',
#   'staCode': '3350',
#   'gateInComingCnt': '591',
#   'gateOutGoingCnt': '1378'},
#  {'trnOpDate': '20220102',
#   'staCode': '3360',
#   'gateInComingCnt': '18150',
#   'gateOutGoingCnt': '16656'},
#  {'trnOpDate': '20220102',
#   'staCode': '3370',
#   'gateInComingCnt': '1424',
#   'gateOutGoingCnt': '1126'},
#  {'trnOpDate': '20220102',
#   'staCode': '3380',
#   'gateInComingCnt': '1043',
#   'gateOutGoingCnt': '986'},
#  {'trnOpDate': '20220102',
#   'staCode': '3390',
#   'gateInComingCnt': '9653',
#   'gateOutGoingCnt': '7374'},
#  {'trnOpDate': '20220102',
#   'staCode': '3400',
#   'gateInComingCnt': '619',
#   'gateOutGoingCnt': '413'},
#  {'trnOpDate': '20220102',
#   'staCode': '3410',
#   'gateInComingCnt': '1129',
#   'gateOutGoingCnt': '659'},
#  {'trnOpDate': '20220102',
#   'staCode': '3420',
#   'gateInComingCnt': '3536',
#   'gateOutGoingCnt': '2003'},
#  {'trnOpDate': '20220102',
#   'staCode': '3430',
#   'gateInComingCnt': '1327',
#   'gateOutGoingCnt': '899'},
#  {'trnOpDate': '20220102',
#   'staCode': '3431',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '27'},
#  {'trnOpDate': '20220102',
#   'staCode': '3432',
#   'gateInComingCnt': '172',
#   'gateOutGoingCnt': '165'},
#  {'trnOpDate': '20220102',
#   'staCode': '3433',
#   'gateInComingCnt': '17',
#   'gateOutGoingCnt': '31'},
#  {'trnOpDate': '20220102',
#   'staCode': '3434',
#   'gateInComingCnt': '597',
#   'gateOutGoingCnt': '402'},
#  {'trnOpDate': '20220102',
#   'staCode': '3435',
#   'gateInComingCnt': '149',
#   'gateOutGoingCnt': '98'},
#  {'trnOpDate': '20220102',
#   'staCode': '3436',
#   'gateInComingCnt': '213',
#   'gateOutGoingCnt': '239'},
#  {'trnOpDate': '20220102',
#   'staCode': '3450',
#   'gateInComingCnt': '1210',
#   'gateOutGoingCnt': '657'},
#  {'trnOpDate': '20220102',
#   'staCode': '3460',
#   'gateInComingCnt': '270',
#   'gateOutGoingCnt': '226'},
#  {'trnOpDate': '20220102',
#   'staCode': '3470',
#   'gateInComingCnt': '7909',
#   'gateOutGoingCnt': '7749'},
#  {'trnOpDate': '20220102',
#   'staCode': '3480',
#   'gateInComingCnt': '3303',
#   'gateOutGoingCnt': '2509'},
#  {'trnOpDate': '20220102',
#   'staCode': '3490',
#   'gateInComingCnt': '188',
#   'gateOutGoingCnt': '143'},
#  {'trnOpDate': '20220102',
#   'staCode': '4050',
#   'gateInComingCnt': '1510',
#   'gateOutGoingCnt': '2013'},
#  {'trnOpDate': '20220102',
#   'staCode': '4060',
#   'gateInComingCnt': '2122',
#   'gateOutGoingCnt': '3326'},
#  {'trnOpDate': '20220102',
#   'staCode': '4070',
#   'gateInComingCnt': '690',
#   'gateOutGoingCnt': '593'},
#  {'trnOpDate': '20220102',
#   'staCode': '4080',
#   'gateInComingCnt': '14608',
#   'gateOutGoingCnt': '12165'},
#  {'trnOpDate': '20220102',
#   'staCode': '4090',
#   'gateInComingCnt': '913',
#   'gateOutGoingCnt': '722'},
#  {'trnOpDate': '20220102',
#   'staCode': '4100',
#   'gateInComingCnt': '337',
#   'gateOutGoingCnt': '147'},
#  {'trnOpDate': '20220102',
#   'staCode': '4110',
#   'gateInComingCnt': '658',
#   'gateOutGoingCnt': '438'},
#  {'trnOpDate': '20220102',
#   'staCode': '4120',
#   'gateInComingCnt': '5659',
#   'gateOutGoingCnt': '4234'},
#  {'trnOpDate': '20220102',
#   'staCode': '4130',
#   'gateInComingCnt': '390',
#   'gateOutGoingCnt': '1048'},
#  {'trnOpDate': '20220102',
#   'staCode': '4140',
#   'gateInComingCnt': '568',
#   'gateOutGoingCnt': '389'},
#  {'trnOpDate': '20220102',
#   'staCode': '4150',
#   'gateInComingCnt': '1263',
#   'gateOutGoingCnt': '1325'},
#  {'trnOpDate': '20220102',
#   'staCode': '4160',
#   'gateInComingCnt': '133',
#   'gateOutGoingCnt': '127'},
#  {'trnOpDate': '20220102',
#   'staCode': '4170',
#   'gateInComingCnt': '3031',
#   'gateOutGoingCnt': '3247'},
#  {'trnOpDate': '20220102',
#   'staCode': '4180',
#   'gateInComingCnt': '699',
#   'gateOutGoingCnt': '1166'},
#  {'trnOpDate': '20220102',
#   'staCode': '4190',
#   'gateInComingCnt': '2081',
#   'gateOutGoingCnt': '2713'},
#  {'trnOpDate': '20220102',
#   'staCode': '4200',
#   'gateInComingCnt': '3847',
#   'gateOutGoingCnt': '4252'},
#  {'trnOpDate': '20220102',
#   'staCode': '4210',
#   'gateInComingCnt': '2039',
#   'gateOutGoingCnt': '3933'},
#  {'trnOpDate': '20220102',
#   'staCode': '4220',
#   'gateInComingCnt': '29091',
#   'gateOutGoingCnt': '30538'},
#  {'trnOpDate': '20220102',
#   'staCode': '4250',
#   'gateInComingCnt': '1512',
#   'gateOutGoingCnt': '3277'},
#  {'trnOpDate': '20220102',
#   'staCode': '4260',
#   'gateInComingCnt': '929',
#   'gateOutGoingCnt': '1104'},
#  {'trnOpDate': '20220102',
#   'staCode': '4270',
#   'gateInComingCnt': '348',
#   'gateOutGoingCnt': '464'},
#  {'trnOpDate': '20220102',
#   'staCode': '4271',
#   'gateInComingCnt': '279',
#   'gateOutGoingCnt': '1102'},
#  {'trnOpDate': '20220102',
#   'staCode': '4272',
#   'gateInComingCnt': '4861',
#   'gateOutGoingCnt': '4201'},
#  {'trnOpDate': '20220102',
#   'staCode': '4290',
#   'gateInComingCnt': '919',
#   'gateOutGoingCnt': '1860'},
#  {'trnOpDate': '20220102',
#   'staCode': '4300',
#   'gateInComingCnt': '1372',
#   'gateOutGoingCnt': '1556'},
#  {'trnOpDate': '20220102',
#   'staCode': '4310',
#   'gateInComingCnt': '2884',
#   'gateOutGoingCnt': '3275'},
#  {'trnOpDate': '20220102',
#   'staCode': '4320',
#   'gateInComingCnt': '1360',
#   'gateOutGoingCnt': '1579'},
#  {'trnOpDate': '20220102',
#   'staCode': '4330',
#   'gateInComingCnt': '2278',
#   'gateOutGoingCnt': '2954'},
#  {'trnOpDate': '20220102',
#   'staCode': '4340',
#   'gateInComingCnt': '16073',
#   'gateOutGoingCnt': '16483'},
#  {'trnOpDate': '20220102',
#   'staCode': '4350',
#   'gateInComingCnt': '630',
#   'gateOutGoingCnt': '637'},
#  {'trnOpDate': '20220102',
#   'staCode': '4360',
#   'gateInComingCnt': '667',
#   'gateOutGoingCnt': '629'},
#  {'trnOpDate': '20220102',
#   'staCode': '4370',
#   'gateInComingCnt': '1280',
#   'gateOutGoingCnt': '1162'},
#  {'trnOpDate': '20220102',
#   'staCode': '4380',
#   'gateInComingCnt': '411',
#   'gateOutGoingCnt': '414'},
#  {'trnOpDate': '20220102',
#   'staCode': '4390',
#   'gateInComingCnt': '495',
#   'gateOutGoingCnt': '496'},
#  {'trnOpDate': '20220102',
#   'staCode': '4400',
#   'gateInComingCnt': '16778',
#   'gateOutGoingCnt': '15997'},
#  {'trnOpDate': '20220102',
#   'staCode': '4410',
#   'gateInComingCnt': '639',
#   'gateOutGoingCnt': '603'},
#  {'trnOpDate': '20220102',
#   'staCode': '4420',
#   'gateInComingCnt': '1036',
#   'gateOutGoingCnt': '1234'},
#  {'trnOpDate': '20220102',
#   'staCode': '4430',
#   'gateInComingCnt': '970',
#   'gateOutGoingCnt': '935'},
#  {'trnOpDate': '20220102',
#   'staCode': '4440',
#   'gateInComingCnt': '5789',
#   'gateOutGoingCnt': '6187'},
#  {'trnOpDate': '20220102',
#   'staCode': '4450',
#   'gateInComingCnt': '616',
#   'gateOutGoingCnt': '580'},
#  {'trnOpDate': '20220102',
#   'staCode': '4460',
#   'gateInComingCnt': '1087',
#   'gateOutGoingCnt': '1028'},
#  {'trnOpDate': '20220102',
#   'staCode': '4470',
#   'gateInComingCnt': '104',
#   'gateOutGoingCnt': '107'},
#  {'trnOpDate': '20220102',
#   'staCode': '5000',
#   'gateInComingCnt': '12181',
#   'gateOutGoingCnt': '12061'},
#  {'trnOpDate': '20220102',
#   'staCode': '5010',
#   'gateInComingCnt': '184',
#   'gateOutGoingCnt': '219'},
#  {'trnOpDate': '20220102',
#   'staCode': '5020',
#   'gateInComingCnt': '196',
#   'gateOutGoingCnt': '170'},
#  {'trnOpDate': '20220102',
#   'staCode': '5030',
#   'gateInComingCnt': '784',
#   'gateOutGoingCnt': '662'},
#  {'trnOpDate': '20220102',
#   'staCode': '5040',
#   'gateInComingCnt': '323',
#   'gateOutGoingCnt': '282'},
#  {'trnOpDate': '20220102',
#   'staCode': '5050',
#   'gateInComingCnt': '4850',
#   'gateOutGoingCnt': '3352'},
#  {'trnOpDate': '20220102',
#   'staCode': '5060',
#   'gateInComingCnt': '45',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20220102',
#   'staCode': '5070',
#   'gateInComingCnt': '517',
#   'gateOutGoingCnt': '700'},
#  {'trnOpDate': '20220102',
#   'staCode': '5080',
#   'gateInComingCnt': '28',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20220102',
#   'staCode': '5090',
#   'gateInComingCnt': '633',
#   'gateOutGoingCnt': '335'},
#  {'trnOpDate': '20220102',
#   'staCode': '5100',
#   'gateInComingCnt': '192',
#   'gateOutGoingCnt': '88'},
#  {'trnOpDate': '20220102',
#   'staCode': '5110',
#   'gateInComingCnt': '74',
#   'gateOutGoingCnt': '77'},
#  {'trnOpDate': '20220102',
#   'staCode': '5120',
#   'gateInComingCnt': '1747',
#   'gateOutGoingCnt': '1059'},
#  {'trnOpDate': '20220102',
#   'staCode': '5130',
#   'gateInComingCnt': '17',
#   'gateOutGoingCnt': '0'},
#  {'trnOpDate': '20220102',
#   'staCode': '5160',
#   'gateInComingCnt': '0',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20220102',
#   'staCode': '5190',
#   'gateInComingCnt': '341',
#   'gateOutGoingCnt': '212'},
#  {'trnOpDate': '20220102',
#   'staCode': '5200',
#   'gateInComingCnt': '60',
#   'gateOutGoingCnt': '16'},
#  {'trnOpDate': '20220102',
#   'staCode': '5210',
#   'gateInComingCnt': '682',
#   'gateOutGoingCnt': '408'},
#  {'trnOpDate': '20220102',
#   'staCode': '5220',
#   'gateInComingCnt': '389',
#   'gateOutGoingCnt': '192'},
#  {'trnOpDate': '20220102',
#   'staCode': '5230',
#   'gateInComingCnt': '1018',
#   'gateOutGoingCnt': '1547'},
#  {'trnOpDate': '20220102',
#   'staCode': '5240',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20220102',
#   'staCode': '6000',
#   'gateInComingCnt': '13642',
#   'gateOutGoingCnt': '7969'},
#  {'trnOpDate': '20220102',
#   'staCode': '6010',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20220102',
#   'staCode': '6020',
#   'gateInComingCnt': '345',
#   'gateOutGoingCnt': '154'},
#  {'trnOpDate': '20220102',
#   'staCode': '6030',
#   'gateInComingCnt': '30',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20220102',
#   'staCode': '6040',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '4'},
#  {'trnOpDate': '20220102',
#   'staCode': '6050',
#   'gateInComingCnt': '842',
#   'gateOutGoingCnt': '445'},
#  {'trnOpDate': '20220102',
#   'staCode': '6060',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '1'},
#  {'trnOpDate': '20220102',
#   'staCode': '6070',
#   'gateInComingCnt': '1009',
#   'gateOutGoingCnt': '469'},
#  {'trnOpDate': '20220102',
#   'staCode': '6080',
#   'gateInComingCnt': '258',
#   'gateOutGoingCnt': '125'},
#  {'trnOpDate': '20220102',
#   'staCode': '6090',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20220102',
#   'staCode': '6100',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20220102',
#   'staCode': '6110',
#   'gateInComingCnt': '2118',
#   'gateOutGoingCnt': '1399'},
#  {'trnOpDate': '20220102',
#   'staCode': '6120',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '17'},
#  {'trnOpDate': '20220102',
#   'staCode': '6130',
#   'gateInComingCnt': '902',
#   'gateOutGoingCnt': '528'},
#  {'trnOpDate': '20220102',
#   'staCode': '6140',
#   'gateInComingCnt': '62',
#   'gateOutGoingCnt': '24'},
#  {'trnOpDate': '20220102',
#   'staCode': '6150',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20220102',
#   'staCode': '6160',
#   'gateInComingCnt': '663',
#   'gateOutGoingCnt': '330'},
#  {'trnOpDate': '20220102',
#   'staCode': '6170',
#   'gateInComingCnt': '44',
#   'gateOutGoingCnt': '32'},
#  {'trnOpDate': '20220102',
#   'staCode': '6180',
#   'gateInComingCnt': '482',
#   'gateOutGoingCnt': '353'},
#  {'trnOpDate': '20220102',
#   'staCode': '6190',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20220102',
#   'staCode': '6200',
#   'gateInComingCnt': '40',
#   'gateOutGoingCnt': '33'},
#  {'trnOpDate': '20220102',
#   'staCode': '6210',
#   'gateInComingCnt': '50',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20220102',
#   'staCode': '6220',
#   'gateInComingCnt': '365',
#   'gateOutGoingCnt': '306'},
#  {'trnOpDate': '20220102',
#   'staCode': '6230',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20220102',
#   'staCode': '6240',
#   'gateInComingCnt': '325',
#   'gateOutGoingCnt': '1438'},
#  {'trnOpDate': '20220102',
#   'staCode': '6250',
#   'gateInComingCnt': '477',
#   'gateOutGoingCnt': '458'},
#  {'trnOpDate': '20220102',
#   'staCode': '7000',
#   'gateInComingCnt': '22736',
#   'gateOutGoingCnt': '15275'},
#  {'trnOpDate': '20220102',
#   'staCode': '7010',
#   'gateInComingCnt': '69',
#   'gateOutGoingCnt': '69'},
#  {'trnOpDate': '20220102',
#   'staCode': '7020',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20220102',
#   'staCode': '7030',
#   'gateInComingCnt': '521',
#   'gateOutGoingCnt': '257'},
#  {'trnOpDate': '20220102',
#   'staCode': '7040',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '18'},
#  {'trnOpDate': '20220102',
#   'staCode': '7050',
#   'gateInComingCnt': '17',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20220102',
#   'staCode': '7060',
#   'gateInComingCnt': '213',
#   'gateOutGoingCnt': '197'},
#  {'trnOpDate': '20220102',
#   'staCode': '7070',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20220102',
#   'staCode': '7080',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20220102',
#   'staCode': '7090',
#   'gateInComingCnt': '624',
#   'gateOutGoingCnt': '399'},
#  {'trnOpDate': '20220102',
#   'staCode': '7100',
#   'gateInComingCnt': '152',
#   'gateOutGoingCnt': '85'},
#  {'trnOpDate': '20220102',
#   'staCode': '7110',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20220102',
#   'staCode': '7120',
#   'gateInComingCnt': '397',
#   'gateOutGoingCnt': '321'},
#  {'trnOpDate': '20220102',
#   'staCode': '7130',
#   'gateInComingCnt': '473',
#   'gateOutGoingCnt': '374'},
#  {'trnOpDate': '20220102',
#   'staCode': '7140',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '14'},
#  {'trnOpDate': '20220102',
#   'staCode': '7150',
#   'gateInComingCnt': '375',
#   'gateOutGoingCnt': '306'},
#  {'trnOpDate': '20220102',
#   'staCode': '7160',
#   'gateInComingCnt': '6306',
#   'gateOutGoingCnt': '5089'},
#  {'trnOpDate': '20220102',
#   'staCode': '7170',
#   'gateInComingCnt': '27',
#   'gateOutGoingCnt': '25'},
#  {'trnOpDate': '20220102',
#   'staCode': '7180',
#   'gateInComingCnt': '110',
#   'gateOutGoingCnt': '81'},
#  {'trnOpDate': '20220102',
#   'staCode': '7190',
#   'gateInComingCnt': '5280',
#   'gateOutGoingCnt': '4781'},
#  {'trnOpDate': '20220102',
#   'staCode': '7200',
#   'gateInComingCnt': '89',
#   'gateOutGoingCnt': '67'},
#  {'trnOpDate': '20220102',
#   'staCode': '7210',
#   'gateInComingCnt': '2449',
#   'gateOutGoingCnt': '1891'},
#  {'trnOpDate': '20220102',
#   'staCode': '7220',
#   'gateInComingCnt': '53',
#   'gateOutGoingCnt': '46'},
#  {'trnOpDate': '20220102',
#   'staCode': '7230',
#   'gateInComingCnt': '902',
#   'gateOutGoingCnt': '607'},
# ...
#   'gateOutGoingCnt': '1117'},
#  {'trnOpDate': '20220104',
#   'staCode': '4380',
#   'gateInComingCnt': '242',
#   'gateOutGoingCnt': '263'},
#  {'trnOpDate': '20220104',
#   'staCode': '4390',
#   'gateInComingCnt': '552',
#   'gateOutGoingCnt': '592'},
#  {'trnOpDate': '20220104',
#   'staCode': '4400',
#   'gateInComingCnt': '8953',
#   'gateOutGoingCnt': '8673'},
#  {'trnOpDate': '20220104',
#   'staCode': '4410',
#   'gateInComingCnt': '695',
#   'gateOutGoingCnt': '715'},
#  {'trnOpDate': '20220104',
#   'staCode': '4420',
#   'gateInComingCnt': '1158',
#   'gateOutGoingCnt': '1058'},
#  {'trnOpDate': '20220104',
#   'staCode': '4430',
#   'gateInComingCnt': '999',
#   'gateOutGoingCnt': '981'},
#  {'trnOpDate': '20220104',
#   'staCode': '4440',
#   'gateInComingCnt': '3965',
#   'gateOutGoingCnt': '3689'},
#  {'trnOpDate': '20220104',
#   'staCode': '4450',
#   'gateInComingCnt': '567',
#   'gateOutGoingCnt': '553'},
#  {'trnOpDate': '20220104',
#   'staCode': '4460',
#   'gateInComingCnt': '906',
#   'gateOutGoingCnt': '970'},
#  {'trnOpDate': '20220104',
#   'staCode': '4470',
#   'gateInComingCnt': '137',
#   'gateOutGoingCnt': '143'},
#  {'trnOpDate': '20220104',
#   'staCode': '5000',
#   'gateInComingCnt': '7152',
#   'gateOutGoingCnt': '7223'},
#  {'trnOpDate': '20220104',
#   'staCode': '5010',
#   'gateInComingCnt': '228',
#   'gateOutGoingCnt': '251'},
#  {'trnOpDate': '20220104',
#   'staCode': '5020',
#   'gateInComingCnt': '130',
#   'gateOutGoingCnt': '136'},
#  {'trnOpDate': '20220104',
#   'staCode': '5030',
#   'gateInComingCnt': '686',
#   'gateOutGoingCnt': '656'},
#  {'trnOpDate': '20220104',
#   'staCode': '5040',
#   'gateInComingCnt': '210',
#   'gateOutGoingCnt': '213'},
#  {'trnOpDate': '20220104',
#   'staCode': '5050',
#   'gateInComingCnt': '2738',
#   'gateOutGoingCnt': '2575'},
#  {'trnOpDate': '20220104',
#   'staCode': '5060',
#   'gateInComingCnt': '176',
#   'gateOutGoingCnt': '179'},
#  {'trnOpDate': '20220104',
#   'staCode': '5070',
#   'gateInComingCnt': '466',
#   'gateOutGoingCnt': '428'},
#  {'trnOpDate': '20220104',
#   'staCode': '5080',
#   'gateInComingCnt': '21',
#   'gateOutGoingCnt': '20'},
#  {'trnOpDate': '20220104',
#   'staCode': '5090',
#   'gateInComingCnt': '362',
#   'gateOutGoingCnt': '364'},
#  {'trnOpDate': '20220104',
#   'staCode': '5100',
#   'gateInComingCnt': '115',
#   'gateOutGoingCnt': '103'},
#  {'trnOpDate': '20220104',
#   'staCode': '5110',
#   'gateInComingCnt': '63',
#   'gateOutGoingCnt': '62'},
#  {'trnOpDate': '20220104',
#   'staCode': '5120',
#   'gateInComingCnt': '646',
#   'gateOutGoingCnt': '698'},
#  {'trnOpDate': '20220104',
#   'staCode': '5160',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20220104',
#   'staCode': '5190',
#   'gateInComingCnt': '102',
#   'gateOutGoingCnt': '101'},
#  {'trnOpDate': '20220104',
#   'staCode': '5200',
#   'gateInComingCnt': '9',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220104',
#   'staCode': '5210',
#   'gateInComingCnt': '498',
#   'gateOutGoingCnt': '489'},
#  {'trnOpDate': '20220104',
#   'staCode': '5220',
#   'gateInComingCnt': '109',
#   'gateOutGoingCnt': '104'},
#  {'trnOpDate': '20220104',
#   'staCode': '5230',
#   'gateInComingCnt': '446',
#   'gateOutGoingCnt': '510'},
#  {'trnOpDate': '20220104',
#   'staCode': '5240',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20220104',
#   'staCode': '6000',
#   'gateInComingCnt': '2733',
#   'gateOutGoingCnt': '2757'},
#  {'trnOpDate': '20220104',
#   'staCode': '6010',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '8'},
#  {'trnOpDate': '20220104',
#   'staCode': '6020',
#   'gateInComingCnt': '137',
#   'gateOutGoingCnt': '143'},
#  {'trnOpDate': '20220104',
#   'staCode': '6030',
#   'gateInComingCnt': '42',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20220104',
#   'staCode': '6040',
#   'gateInComingCnt': '4',
#   'gateOutGoingCnt': '5'},
#  {'trnOpDate': '20220104',
#   'staCode': '6050',
#   'gateInComingCnt': '381',
#   'gateOutGoingCnt': '381'},
#  {'trnOpDate': '20220104',
#   'staCode': '6060',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '3'},
#  {'trnOpDate': '20220104',
#   'staCode': '6070',
#   'gateInComingCnt': '318',
#   'gateOutGoingCnt': '308'},
#  {'trnOpDate': '20220104',
#   'staCode': '6080',
#   'gateInComingCnt': '94',
#   'gateOutGoingCnt': '100'},
#  {'trnOpDate': '20220104',
#   'staCode': '6090',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '7'},
#  {'trnOpDate': '20220104',
#   'staCode': '6100',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220104',
#   'staCode': '6110',
#   'gateInComingCnt': '827',
#   'gateOutGoingCnt': '811'},
#  {'trnOpDate': '20220104',
#   'staCode': '6120',
#   'gateInComingCnt': '5',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220104',
#   'staCode': '6130',
#   'gateInComingCnt': '429',
#   'gateOutGoingCnt': '428'},
#  {'trnOpDate': '20220104',
#   'staCode': '6140',
#   'gateInComingCnt': '38',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20220104',
#   'staCode': '6150',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '1'},
#  {'trnOpDate': '20220104',
#   'staCode': '6160',
#   'gateInComingCnt': '334',
#   'gateOutGoingCnt': '308'},
#  {'trnOpDate': '20220104',
#   'staCode': '6170',
#   'gateInComingCnt': '47',
#   'gateOutGoingCnt': '43'},
#  {'trnOpDate': '20220104',
#   'staCode': '6180',
#   'gateInComingCnt': '313',
#   'gateOutGoingCnt': '270'},
#  {'trnOpDate': '20220104',
#   'staCode': '6190',
#   'gateInComingCnt': '23',
#   'gateOutGoingCnt': '20'},
#  {'trnOpDate': '20220104',
#   'staCode': '6200',
#   'gateInComingCnt': '12',
#   'gateOutGoingCnt': '10'},
#  {'trnOpDate': '20220104',
#   'staCode': '6210',
#   'gateInComingCnt': '90',
#   'gateOutGoingCnt': '95'},
#  {'trnOpDate': '20220104',
#   'staCode': '6220',
#   'gateInComingCnt': '251',
#   'gateOutGoingCnt': '353'},
#  {'trnOpDate': '20220104',
#   'staCode': '6230',
#   'gateInComingCnt': '7',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220104',
#   'staCode': '6240',
#   'gateInComingCnt': '238',
#   'gateOutGoingCnt': '313'},
#  {'trnOpDate': '20220104',
#   'staCode': '6250',
#   'gateInComingCnt': '384',
#   'gateOutGoingCnt': '361'},
#  {'trnOpDate': '20220104',
#   'staCode': '7000',
#   'gateInComingCnt': '6474',
#   'gateOutGoingCnt': '5993'},
#  {'trnOpDate': '20220104',
#   'staCode': '7010',
#   'gateInComingCnt': '121',
#   'gateOutGoingCnt': '119'},
#  {'trnOpDate': '20220104',
#   'staCode': '7020',
#   'gateInComingCnt': '17',
#   'gateOutGoingCnt': '22'},
#  {'trnOpDate': '20220104',
#   'staCode': '7030',
#   'gateInComingCnt': '290',
#   'gateOutGoingCnt': '271'},
#  {'trnOpDate': '20220104',
#   'staCode': '7040',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '24'},
#  {'trnOpDate': '20220104',
#   'staCode': '7050',
#   'gateInComingCnt': '50',
#   'gateOutGoingCnt': '57'},
#  {'trnOpDate': '20220104',
#   'staCode': '7060',
#   'gateInComingCnt': '805',
#   'gateOutGoingCnt': '802'},
#  {'trnOpDate': '20220104',
#   'staCode': '7070',
#   'gateInComingCnt': '2',
#   'gateOutGoingCnt': '2'},
#  {'trnOpDate': '20220104',
#   'staCode': '7080',
#   'gateInComingCnt': '10',
#   'gateOutGoingCnt': '15'},
#  {'trnOpDate': '20220104',
#   'staCode': '7090',
#   'gateInComingCnt': '782',
#   'gateOutGoingCnt': '790'},
#  {'trnOpDate': '20220104',
#   'staCode': '7100',
#   'gateInComingCnt': '276',
#   'gateOutGoingCnt': '158'},
#  {'trnOpDate': '20220104',
#   'staCode': '7110',
#   'gateInComingCnt': '13',
#   'gateOutGoingCnt': '95'},
#  {'trnOpDate': '20220104',
#   'staCode': '7120',
#   'gateInComingCnt': '436',
#   'gateOutGoingCnt': '544'},
#  {'trnOpDate': '20220104',
#   'staCode': '7130',
#   'gateInComingCnt': '538',
#   'gateOutGoingCnt': '1185'},
#  {'trnOpDate': '20220104',
#   'staCode': '7140',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20220104',
#   'staCode': '7150',
#   'gateInComingCnt': '474',
#   'gateOutGoingCnt': '445'},
#  {'trnOpDate': '20220104',
#   'staCode': '7160',
#   'gateInComingCnt': '3380',
#   'gateOutGoingCnt': '3096'},
#  {'trnOpDate': '20220104',
#   'staCode': '7170',
#   'gateInComingCnt': '18',
#   'gateOutGoingCnt': '21'},
#  {'trnOpDate': '20220104',
#   'staCode': '7180',
#   'gateInComingCnt': '127',
#   'gateOutGoingCnt': '134'},
#  {'trnOpDate': '20220104',
#   'staCode': '7190',
#   'gateInComingCnt': '2910',
#   'gateOutGoingCnt': '2786'},
#  {'trnOpDate': '20220104',
#   'staCode': '7200',
#   'gateInComingCnt': '122',
#   'gateOutGoingCnt': '131'},
#  {'trnOpDate': '20220104',
#   'staCode': '7210',
#   'gateInComingCnt': '1048',
#   'gateOutGoingCnt': '1080'},
#  {'trnOpDate': '20220104',
#   'staCode': '7220',
#   'gateInComingCnt': '92',
#   'gateOutGoingCnt': '104'},
#  {'trnOpDate': '20220104',
#   'staCode': '7230',
#   'gateInComingCnt': '968',
#   'gateOutGoingCnt': '956'},
#  {'trnOpDate': '20220104',
#   'staCode': '7240',
#   'gateInComingCnt': '28',
#   'gateOutGoingCnt': '29'},
#  {'trnOpDate': '20220104',
#   'staCode': '7250',
#   'gateInComingCnt': '46',
#   'gateOutGoingCnt': '63'},
#  {'trnOpDate': '20220104',
#   'staCode': '7260',
#   'gateInComingCnt': '163',
#   'gateOutGoingCnt': '171'},
#  {'trnOpDate': '20220104',
#   'staCode': '7270',
#   'gateInComingCnt': '60',
#   'gateOutGoingCnt': '57'},
#  {'trnOpDate': '20220104',
#   'staCode': '7280',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '13'},
#  {'trnOpDate': '20220104',
#   'staCode': '7290',
#   'gateInComingCnt': '333',
#   'gateOutGoingCnt': '380'},
#  {'trnOpDate': '20220104',
#   'staCode': '7300',
#   'gateInComingCnt': '131',
#   'gateOutGoingCnt': '139'},
#  {'trnOpDate': '20220104',
#   'staCode': '7310',
#   'gateInComingCnt': '636',
#   'gateOutGoingCnt': '621'},
#  {'trnOpDate': '20220104',
#   'staCode': '7320',
#   'gateInComingCnt': '144',
#   'gateOutGoingCnt': '152'},
#  {'trnOpDate': '20220104',
#   'staCode': '7330',
#   'gateInComingCnt': '29',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20220104',
#   'staCode': '7331',
#   'gateInComingCnt': '11',
#   'gateOutGoingCnt': '9'},
#  {'trnOpDate': '20220104',
#   'staCode': '7332',
#   'gateInComingCnt': '124',
#   'gateOutGoingCnt': '130'},
#  {'trnOpDate': '20220104',
#   'staCode': '7333',
#   'gateInComingCnt': '14',
#   'gateOutGoingCnt': '11'},
#  {'trnOpDate': '20220104',
#   'staCode': '7334',
#   'gateInComingCnt': '19',
#   'gateOutGoingCnt': '19'},
#  {'trnOpDate': '20220104',
#   'staCode': '7335',
#   'gateInComingCnt': '63',
#   'gateOutGoingCnt': '69'},
#  {'trnOpDate': '20220104',
#   'staCode': '7336',
#   'gateInComingCnt': '54',
#   'gateOutGoingCnt': '55'},
#  {'trnOpDate': '20220104',
#   'staCode': '7350',
#   'gateInComingCnt': '127',
#   'gateOutGoingCnt': '125'},
#  {'trnOpDate': '20220104',
#   'staCode': '7360',
#   'gateInComingCnt': '2799',
#   'gateOutGoingCnt': '2848'},
#  {'trnOpDate': '20220104',
#   'staCode': '7361',
#   'gateInComingCnt': '8',
#   'gateOutGoingCnt': '12'},
#  {'trnOpDate': '20220104',
#   'staCode': '7362',
#   'gateInComingCnt': '24',
#   'gateOutGoingCnt': '35'},
#  {'trnOpDate': '20220104',
#   'staCode': '7380',
#   'gateInComingCnt': '620',
#   'gateOutGoingCnt': '616'},
#  {'trnOpDate': '20220104',
#   'staCode': '7390',
#   'gateInComingCnt': '446',
#   'gateOutGoingCnt': '464'},
#  {'trnOpDate': '20220105',
#   'staCode': '0900',
#   'gateInComingCnt': '6772',
#   'gateOutGoingCnt': '6249'},
#  {'trnOpDate': '20220105',
#   'staCode': '0910',
#   'gateInComingCnt': '1375',
#   'gateOutGoingCnt': '1521'},
#  {'trnOpDate': '20220105',
#   'staCode': '0920',
#   'gateInComingCnt': '2260',
#   'gateOutGoingCnt': '2032'},
#  {'trnOpDate': '20220105',
#   'staCode': '0930',
#   'gateInComingCnt': '5958',
#   'gateOutGoingCnt': '5960'},
#  {'trnOpDate': '20220105',
#   'staCode': '0940',
#   'gateInComingCnt': '2510',
#   'gateOutGoingCnt': '2536'},
#  {'trnOpDate': '20220105',
#   'staCode': '0950',
#   'gateInComingCnt': '2193',
#   'gateOutGoingCnt': '1834'},
#  {'trnOpDate': '20220105',
#   'staCode': '0960',
#   'gateInComingCnt': '9910',
#   'gateOutGoingCnt': '10369'},
#  {'trnOpDate': '20220105',
#   'staCode': '0970',
#   'gateInComingCnt': '11773',
#   'gateOutGoingCnt': '11777'},
#  {'trnOpDate': '20220105',
#   'staCode': '0980',
#   'gateInComingCnt': '10928',
#   'gateOutGoingCnt': '11305'},
#  {'trnOpDate': '20220105',
#   'staCode': '0990',
#   'gateInComingCnt': '15466',
#   'gateOutGoingCnt': '15662'},
#  {'trnOpDate': '20220105',
#   'staCode': '1000',
#   'gateInComingCnt': '44998',
#   'gateOutGoingCnt': '44416'},
#  {'trnOpDate': '20220105',
#   'staCode': '1010',
#   'gateInComingCnt': '4140',
#   'gateOutGoingCnt': '3971'},
#  {'trnOpDate': '20220105',
#   'staCode': '1020',
#   'gateInComingCnt': '17746',
#   'gateOutGoingCnt': '17416'},
#  {'trnOpDate': '20220105',
#   'staCode': '1030',
#   'gateInComingCnt': '3013',
#   'gateOutGoingCnt': '2915'},
#  {'trnOpDate': '20220105',
#   'staCode': '1040',
#   'gateInComingCnt': '12219',
#   'gateOutGoingCnt': '12448'},
#  {'trnOpDate': '20220105',
#   'staCode': '1050',
#   'gateInComingCnt': '1134',
#   'gateOutGoingCnt': '1070'},
#  {'trnOpDate': '20220105',
#   'staCode': '1060',
#   'gateInComingCnt': '1600',
#   'gateOutGoingCnt': '1590'},
#  {'trnOpDate': '20220105',
#   'staCode': '1070',
#   'gateInComingCnt': '7763',
#   'gateOutGoingCnt': '7979'},
#  {'trnOpDate': '20220105',
#   'staCode': '1080',
#   'gateInComingCnt': '21336',
#   'gateOutGoingCnt': '22202'},
#  {'trnOpDate': '20220105',
#   'staCode': '1090',
#   'gateInComingCnt': '8227',
#   'gateOutGoingCnt': '8057'},
#  {'trnOpDate': '20220105',
#   'staCode': '1100',
#   'gateInComingCnt': '18341',
#   'gateOutGoingCnt': '18784'},
#  {'trnOpDate': '20220105',
#   'staCode': '1110',
#   'gateInComingCnt': '5829',
#   'gateOutGoingCnt': '5333'},
#  {'trnOpDate': '20220105',
#   'staCode': '1120',
#   'gateInComingCnt': '4335',
#   'gateOutGoingCnt': '4151'},
#  {'trnOpDate': '20220105',
#   'staCode': '1130',
#   'gateInComingCnt': '1473',
#   'gateOutGoingCnt': '1436'},
#  {'trnOpDate': '20220105',
#   'staCode': '1140',
#   'gateInComingCnt': '76',
#   'gateOutGoingCnt': '87'},
#  {'trnOpDate': '20220105',
#   'staCode': '1150',
#   'gateInComingCnt': '828',
#   'gateOutGoingCnt': '788'},
#  {'trnOpDate': '20220105',
#   'staCode': '1160',
#   'gateInComingCnt': '3021',
#   'gateOutGoingCnt': '3085'},
#  {'trnOpDate': '20220105',
#   'staCode': '1170',
#   'gateInComingCnt': '4557',
#   'gateOutGoingCnt': '4707'},
#  {'trnOpDate': '20220105',
#   'staCode': '1180',
#   'gateInComingCnt': '4694',
#   'gateOutGoingCnt': '4490'},
#  {'trnOpDate': '20220105',
#   'staCode': '1190',
#   'gateInComingCnt': '2315',
#   'gateOutGoingCnt': '2330'},
#  {'trnOpDate': '20220105',
#   'staCode': '1191',
#   'gateInComingCnt': '254',
#   'gateOutGoingCnt': '249'},
#  {'trnOpDate': '20220105',
#   'staCode': '1192',
#   'gateInComingCnt': '1298',
#   'gateOutGoingCnt': '1343'},
#  {'trnOpDate': '20220105',
#   'staCode': '1193',
#   'gateInComingCnt': '462',
#   'gateOutGoingCnt': '462'},
#  {'trnOpDate': '20220105',
#   'staCode': '1194',
#   'gateInComingCnt': '2073',
#   'gateOutGoingCnt': '2099'},
#  {'trnOpDate': '20220105',
#   'staCode': '1201',
#   'gateInComingCnt': '52',
#   'gateOutGoingCnt': '56'},
#  {'trnOpDate': '20220105',
#   'staCode': '1202',
#   'gateInComingCnt': '119',
#   'gateOutGoingCnt': '107'},
#  {'trnOpDate': '20220105',
#   'staCode': '1203',
#   'gateInComingCnt': '337',
#   'gateOutGoingCnt': '310'},
#  {'trnOpDate': '20220105',
#   'staCode': '1204',
#   'gateInComingCnt': '70',
#   'gateOutGoingCnt': '70'},
#  {'trnOpDate': '20220105',
#   'staCode': '1205',
#   'gateInComingCnt': '37',
#   'gateOutGoingCnt': '59'},
#  {'trnOpDate': '20220105',
#   'staCode': '1206',
#   'gateInComingCnt': '26',
#   'gateOutGoingCnt': '22'},
#  {'trnOpDate': '20220105',
#   'staCode': '1207',
#   'gateInComingCnt': '3',
#   'gateOutGoingCnt': '6'},
#  {'trnOpDate': '20220105',
#   'staCode': '1208',
#   'gateInComingCnt': '152',
#   'gateOutGoingCnt': '132'},
#  {'trnOpDate': '20220105',
#   'staCode': '1210',
#   'gateInComingCnt': '13245',
#   'gateOutGoingCnt': '13185'},
#  {'trnOpDate': '20220105',
#   'staCode': '1220',
#   'gateInComingCnt': '1150',
#   'gateOutGoingCnt': '1013'},
#  {'trnOpDate': '20220105',
#   'staCode': '1230',
#   'gateInComingCnt': '559',
#   'gateOutGoingCnt': '552'},
#  {'trnOpDate': '20220105',
#   'staCode': '1240',
#   'gateInComingCnt': '188',
#   'gateOutGoingCnt': '200'},
#  {'trnOpDate': '20220105',
#   'staCode': '1250',
#   'gateInComingCnt': '6540',
#   'gateOutGoingCnt': '6681'},
#  {'trnOpDate': '20220105',
#   'staCode': '2110',
#   'gateInComingCnt': '32',
#   'gateOutGoingCnt': '28'},
#  {'trnOpDate': '20220105',
#   'staCode': '2120',
#   'gateInComingCnt': '87',
#   'gateOutGoingCnt': '91'},
#  {'trnOpDate': '20220105',
#   'staCode': '2130',
#   'gateInComingCnt': '1260',
#   'gateOutGoingCnt': '1163'},
#  ...]

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(jsObject)
df
# Out:
#       trnOpDate staCode gateInComingCnt gateOutGoingCnt
# 0      20220101    0900            8645            8526
# 1      20220101    0910             996            1243
# 2      20220101    0920            1369            1711
# 3      20220101    0930            3663            4535
# 4      20220101    0940            1532            1845
# ...         ...     ...             ...             ...
# 21630  20220401    7335               1               1
# 21631  20220401    7350               6               6
# 21632  20220401    7360             380             403
# 21633  20220401    7380              44              43
# 21634  20220401    7390              28              27
#
# [21635 rows x 4 columns]
