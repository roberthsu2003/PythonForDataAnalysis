# %%
import numpy as np
import pandas as pd

array = np.random.randn(10).cumsum()
print(array)

series = pd.Series(array,index=np.arange(0,100,10))
series
# Out:
# [-1.6453713  -1.30511847  0.22920058  0.05267191  0.29832001 -1.35557997
#  -0.26750902 -0.56113197 -0.33121907 -0.50616444]
# 0    -1.645371
# 10   -1.305118
# 20    0.229201
# 30    0.052672
# 40    0.298320
# 50   -1.355580
# 60   -0.267509
# 70   -0.561132
# 80   -0.331219
# 90   -0.506164
# dtype: float64

# %%
series.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
ax1 = figure.add_subplot(1,1,1)
ax1.plot(series)

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),
                 index=np.arange(0,100,10),
                 columns = ['A','B','C','D']
                 )
figure = plt.figure()
ax1 = figure.add_subplot(1,1,1)
ax1.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x121682350>,
#  <matplotlib.lines.Line2D at 0x1216823b0>,
#  <matplotlib.lines.Line2D at 0x1216824d0>,
#  <matplotlib.lines.Line2D at 0x1216825f0>]

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                   index=['one', 'two', 'three', 'four', 'five', 'six'],
                   columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.092175  0.145128  0.784015  0.748282
# two    0.982101  0.188539  0.675177  0.508384
# three  0.756271  0.061538  0.059692  0.255008
# four   0.176793  0.881086  0.372427  0.953139
# five   0.123407  0.993671  0.135132  0.033873
# six    0.584385  0.756412  0.461415  0.593831

# %%
figure = plt.figure()
ax1 = figure.add_subplot(1,1,1)
ax1.bar(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <module>
#       1 figure = plt.figure()
#       2 ax1 = figure.add_subplot(1,1,1)
# ----> 3 ax1.bar(df)
#
# File ~/Documents/virtualEnv/venv05/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# TypeError: Axes.bar() missing 1 required positional argument: 'height'

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>
