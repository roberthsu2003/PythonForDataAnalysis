# %%
#pd.read_csv()
import pandas as pd
dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             106                                             新北市板橋區
# 2             106                                             新北市三重區
# 3             106                                             新北市中和區
# 4             106                                             新北市永和區
# ..            ...                                                ...
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         551480  23.1373              23835
# ...

# %%
dataFrame.dtypes
# Out:
# statistic_yyy         object
# site_id               object
# people_total          object
# area                  object
# population_density    object
# dtype: object

# %%
dataFrame.iloc[:10]
# Out:
#   statistic_yyy site_id people_total      area population_density
# 0           統計年     區域別        年底人口數      土地面積               人口密度
# 1           106  新北市板橋區       551480   23.1373              23835
# 2           106  新北市三重區       387484    16.317              23747
# 3           106  新北市中和區       413590    20.144              20532
# 4           106  新北市永和區       222585    5.7138              38956
# 5           106  新北市新莊區       416524   19.7383              21102
# 6           106  新北市新店區       302089  120.2255               2513
# 7           106  新北市樹林區       184149   33.1288               5559
# 8           106  新北市鶯歌區        86593   21.1248               4099
# 9           106  新北市三峽區       114926  191.4508                600

# %%
dataFrame.iloc[-10:]
# Out:
#     statistic_yyy                                            site_id  \
# 366           106                                             連江縣北竿鄉
# 367           106                                             連江縣莒光鄉
# 368           106                                             連江縣東引鄉
# 369           106                                               東沙群島
# 370           106                                               南沙群島
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total    area population_density
# 366         2360     9.9                238
# 367         1624     4.7                346
# 368         1352     3.8                356
# ...

# %%
dataFrame.shape
# Out:
# (376, 5)

# %%
dataFrame.columns = ['統計年份','區域','人口數','土地面積','人口密度']

# %%
dataFrame.drop(labels=0,inplace=True)

# %%
dataFrame.iloc[-10:]
# Out:
#     統計年份                                                 區域   人口數    土地面積 人口密度
# 366  106                                             連江縣北竿鄉  2360     9.9  238
# 367  106                                             連江縣莒光鄉  1624     4.7  346
# 368  106                                             連江縣東引鄉  1352     3.8  356
# 369  106                                               東沙群島    …     2.38   …
# 370  106                                               南沙群島    …   0.5045   …
# 371  NaN                                                NaN   NaN     NaN  NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。   NaN     NaN  NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)   NaN     NaN  NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。   NaN     NaN  NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。   NaN     NaN  NaN

# %%
dataFrame.drop(labels=[371,372,373,374,375],inplace=True)
dataFrame
# Out:
#     統計年份      區域     人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
needsDataFrame = dataFrame[['區域','人口數','土地面積']]

# %%
import openpyxl
needsDataFrame.to_excel('needsDataFrame.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [23], in <module>
# ----> 1 needsDataFrame.to_excel('needsDataFrame.xlsx')
#
# File ~/Documents/virtualEnv/venv05/lib/python3.10/site-packages/pandas/core/generic.py:2357, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2344 from pandas.io.formats.excel import ExcelFormatter
#    2346 formatter = ExcelFormatter(
#    2347     df,
#    2348     na_rep=na_rep,
#    (...)
#    2355     inf_rep=inf_rep,
#    2356 )
# -> 2357 formatter.write(
#    2358     excel_writer,
#    2359     sheet_name=sheet_name,
#    2360     startrow=startrow,
#    2361     startcol=startcol,
#    2362     freeze_panes=freeze_panes,
#    2363     engine=engine,
# ...
