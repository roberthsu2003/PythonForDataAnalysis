# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-3,3,num=50)
y1 = 2*x + 1
y2 = x ** 2

plt.figure()
plt.plot(x,y1,color='red',linewidth=1.0, linestyle='--')
plt.plot(x,y2,'b-')
plt.title('numpy test')
plt.xlabel('Day')
plt.ylabel('Celsius')
plt.show()

# %%
import math

x = np.arange(0, 2.5, 0.1)
y1 = np.sin(math.pi * x)
y2 = np.sin(math.pi * x + math.pi / 2)
y3 = np.sin(math.pi * x - math.pi / 2)

plt.figure()
plt.plot(x,y1,'b*', x, y2, 'g^', x, y3, 'ys')
plt.legend(['First line', 'Second line','third line'],loc='upper right')

# %%
x = np.arange(0, 2.5, 0.1)
y1 = np.sin(math.pi * x)
y2 = np.sin(math.pi * x + math.pi / 2)

plt.figure(figsize=(10,16))
plt.subplot(2,1,1)
plt.plot(x,y1,'b*')
plt.legend(['line1'])
plt.subplot(2,1,2)
plt.plot(x,y2,'g^')
plt.show()

# %%
x = np.arange(0, 2.5, 0.1)
y1 = np.sin(math.pi * x)
y2 = np.sin(math.pi * x + math.pi / 2)
y3 = np.sin(math.pi * x - math.pi / 2)

plt.figure(figsize=(10,16))
plt.subplot(3,1,1)
plt.plot(x,y1,'b*')


plt.subplot(3,1,2)
plt.plot(x,y2,'g^')

plt.subplot(3,1,3)
plt.plot(x,y3,'ys')
plt.show()
