# %%
#homework
#讀取ex6.csv
#將key欄位設定成為row的index
import numpy as np
import pandas as pd
result = pd.read_csv('ex6.csv')
result.index.name='編號' #改變row索引名稱

'''
           one       two     three      four key
編號                                              
0     0.467976 -0.038649 -0.295344 -1.824726   L
1    -0.358893  1.404453  0.704965 -0.200638   B
2    -0.501840  0.659254 -0.421691 -0.057688   G
3     0.204886  1.074134  1.388361 -0.982404   R
4     0.354628 -0.133116  0.283763 -0.837063   Q
...        ...       ...       ...       ...  ..
9995  2.311896 -0.417070 -1.409599 -0.515821   L
9996 -0.479893 -0.650419  0.745152 -0.646038   E
9997  0.523331  0.787112  0.486066  1.093156   K
9998 -0.362559  0.598894 -1.843201  0.887292   G
9999 -0.096376 -1.012999 -0.657431 -0.573315   0

[10000 rows x 5 columns]

'''


#保留原來的索引,建立row的階層式索引
newResult = result.reset_index().set_index(['key', '編號']) 
newResult
'''
               one       two     three      four
key 編號                                          
L   0     0.467976 -0.038649 -0.295344 -1.824726
B   1    -0.358893  1.404453  0.704965 -0.200638
G   2    -0.501840  0.659254 -0.421691 -0.057688
R   3     0.204886  1.074134  1.388361 -0.982404
Q   4     0.354628 -0.133116  0.283763 -0.837063
...            ...       ...       ...       ...
L   9995  2.311896 -0.417070 -1.409599 -0.515821
E   9996 -0.479893 -0.650419  0.745152 -0.646038
K   9997  0.523331  0.787112  0.486066  1.093156
G   9998 -0.362559  0.598894 -1.843201  0.887292
0   9999 -0.096376 -1.012999 -0.657431 -0.573315

[10000 rows x 4 columns]

'''


#取出欄位one
newSerial = newResult['one']
newSerial
'''
Out[5]: 
key  編號  
L    0       0.467976
B    1      -0.358893
G    2      -0.501840
R    3       0.204886
Q    4       0.354628
               ...   
L    9995    2.311896
E    9996   -0.479893
K    9997    0.523331
G    9998   -0.362559
0    9999   -0.096376
Name: one, Length: 10000, dtype: float64
'''


#排序索引key
newSerial.sort_index(level='key',inplace=True)
newSerial.index
'''
MultiIndex([('0',  101),
            ('0',  142),
            ('0',  168),
            ('0',  197),
            ('0',  429),
            ('0',  453),
            ('0',  654),
            ('0',  776),
            ('0',  784),
            ('0', 1094),
            ...
            ('Z', 9554),
            ('Z', 9558),
            ('Z', 9584),
            ('Z', 9634),
            ('Z', 9697),
            ('Z', 9774),
            ('Z', 9878),
            ('Z', 9901),
            ('Z', 9942),
            ('Z', 9972)],
           names=['key', '編號'], length=10000)
'''

#建立樞紐分析表
newSerial.unstack()
'''
Out[7]: 
編號       0         1        2     ...      9997      9998      9999
key                               ...                              
0         NaN       NaN      NaN  ...       NaN       NaN -0.096376
1         NaN       NaN      NaN  ...       NaN       NaN       NaN
2         NaN       NaN      NaN  ...       NaN       NaN       NaN
3         NaN       NaN      NaN  ...       NaN       NaN       NaN
4         NaN       NaN      NaN  ...       NaN       NaN       NaN
5         NaN       NaN      NaN  ...       NaN       NaN       NaN
6         NaN       NaN      NaN  ...       NaN       NaN       NaN
7         NaN       NaN      NaN  ...       NaN       NaN       NaN
8         NaN       NaN      NaN  ...       NaN       NaN       NaN
9         NaN       NaN      NaN  ...       NaN       NaN       NaN
A         NaN       NaN      NaN  ...       NaN       NaN       NaN
B         NaN -0.358893      NaN  ...       NaN       NaN       NaN
C         NaN       NaN      NaN  ...       NaN       NaN       NaN
D         NaN       NaN      NaN  ...       NaN       NaN       NaN
E         NaN       NaN      NaN  ...       NaN       NaN       NaN
F         NaN       NaN      NaN  ...       NaN       NaN       NaN
G         NaN       NaN -0.50184  ...       NaN -0.362559       NaN
H         NaN       NaN      NaN  ...       NaN       NaN       NaN
I         NaN       NaN      NaN  ...       NaN       NaN       NaN
J         NaN       NaN      NaN  ...       NaN       NaN       NaN
K         NaN       NaN      NaN  ...  0.523331       NaN       NaN
