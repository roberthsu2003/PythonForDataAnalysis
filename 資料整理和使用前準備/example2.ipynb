# %%
import numpy as np
import pandas as pd

dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame[-20:]
# Out:
#     statistic_yyy                                            site_id  \
# 356           106                                             新竹市香山區
# 357           106                                              嘉義市東區
# 358           106                                              嘉義市西區
# 359           106                                             金門縣金城鎮
# 360           106                                             金門縣金湖鎮
# 361           106                                             金門縣金沙鎮
# 362           106                                             金門縣金寧鄉
# 363           106                                             金門縣烈嶼鄉
# 364           106                                             金門縣烏坵鄉
# 365           106                                             連江縣南竿鄉
# 366           106                                             連江縣北竿鄉
# 367           106                                             連江縣莒光鄉
# 368           106                                             連江縣東引鄉
# ...

# %%
dataFrame.dropna(thresh=4,inplace=True)
dataFrame
# Out:
#     statistic_yyy site_id people_total     area population_density
# 0             統計年     區域別        年底人口數     土地面積               人口密度
# 1             106  新北市板橋區       551480  23.1373              23835
# 2             106  新北市三重區       387484   16.317              23747
# 3             106  新北市中和區       413590   20.144              20532
# 4             106  新北市永和區       222585   5.7138              38956
# ..            ...     ...          ...      ...                ...
# 366           106  連江縣北竿鄉         2360      9.9                238
# 367           106  連江縣莒光鄉         1624      4.7                NaN
# 368           106  連江縣東引鄉         1352      3.8                NaN
# 369           106    東沙群島           …      2.38                 …
# 370           106    南沙群島           …    0.5045                 …
#
# [371 rows x 5 columns]

# %%
def transforming(x):
    if x == '… ' or None:
        return 0
    else:
        return x

dataFrame['people_total']=dataFrame['people_total'].map(transforming) #Serial使用map()
dataFrame
# Out:
#     statistic_yyy site_id people_total     area population_density
# 0             統計年     區域別        年底人口數     土地面積               人口密度
# 1             106  新北市板橋區       551480  23.1373              23835
# 2             106  新北市三重區       387484   16.317              23747
# 3             106  新北市中和區       413590   20.144              20532
# 4             106  新北市永和區       222585   5.7138              38956
# ..            ...     ...          ...      ...                ...
# 366           106  連江縣北竿鄉         2360      9.9                238
# 367           106  連江縣莒光鄉         1624      4.7                NaN
# 368           106  連江縣東引鄉         1352      3.8                NaN
# 369           106    東沙群島            0     2.38                 …
# 370           106    南沙群島            0   0.5045                 …
#
# [371 rows x 5 columns]

# %%
def transforming(x):
    if x == '… ' or x is np.nan:  #要使用is
        return 0
    else:
        return x

dataFrame.applymap(transforming)
# Out:
#     statistic_yyy site_id people_total     area population_density
# 0             統計年     區域別        年底人口數     土地面積               人口密度
# 1             106  新北市板橋區       551480  23.1373              23835
# 2             106  新北市三重區       387484   16.317              23747
# 3             106  新北市中和區       413590   20.144              20532
# 4             106  新北市永和區       222585   5.7138              38956
# ..            ...     ...          ...      ...                ...
# 366           106  連江縣北竿鄉         2360      9.9                238
# 367           106  連江縣莒光鄉         1624      4.7                  0
# 368           106  連江縣東引鄉         1352      3.8                  0
# 369           106    東沙群島            0     2.38                  0
# 370           106    南沙群島            0   0.5045                  0
#
# [371 rows x 5 columns]
