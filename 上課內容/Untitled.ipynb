# %%
# %matplotlib notebook
import math
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 2.5, 0.1)
y1 = np.sin(math.pi * t)
y2 = np.sin(math.pi * t + math.pi/2)
y3 = np.sin(math.pi * t - math.pi/2)
plt.plot(t,y1,'b*', t,y2,'g^', t, y3, 'ys')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7fba50de53d0>,
#  <matplotlib.lines.Line2D at 0x7fba5105db10>,
#  <matplotlib.lines.Line2D at 0x7fba3095a8d0>]
