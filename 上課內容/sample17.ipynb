# %%
#建立一個檔案物件
#stander 方法print()
text = '''python與中文
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
'''

f = open('data.txt','w',encoding='utf-8')
print(text,file=f)
f.close()

# %%
scores = dict();
no = 1
while True:
    score = int(input('請輸入第' + str(no) + "號的成績:(-1結束)"))
    if score == -1:
        break;
    
    scores[no] = score
    no += 1
print(scores)
strDict = str(scores)
file = open('score.txt','w',encoding='utf-8')
file.write(strDict)
file.close()
# Out:
# 請輸入第1號的成績:(-1結束)60
# 請輸入第2號的成績:(-1結束)70
# 請輸入第3號的成績:(-1結束)80
# 請輸入第4號的成績:(-1結束)-1
# {1: 60, 2: 70, 3: 80}

# %%
import csv 

f = open('ex1.csv','r',encoding='utf-8')
rows = csv.reader(f)
list1 = list(rows)
print(list1)
print(list1[0][:4])
f.close()
# Out:
# [['a', 'b', 'c', 'd', 'message'], ['1', '2', '3', '4', 'hello'], ['5', '6', '7', '8', 'world'], ['9', '10', '11', '12', 'foo']]
# ['a', 'b', 'c', 'd']

# %%
import csv
poplist = list()
f = open('各鄉鎮市區人口密度.csv','r',encoding='utf-8')
csvReader = csv.reader(f)
allDataList = list(csvReader)
for row in allDataList:
    if '臺中市' in row[1]:        
        poplist.append(row)

f.close()
print(poplist)
# Out:
# [['106', '臺中市中區', '18450', '0.8803', '20959'], ['106', '臺中市東區', '75811', '9.2855', '8164'], ['106', '臺中市南區', '125067', '6.8101', '18365'], ['106', '臺中市西區', '115627', '5.7042', '20271'], ['106', '臺中市北區', '147653', '6.9376', '21283'], ['106', '臺中市西屯區', '227043', '39.8467', '5698'], ['106', '臺中市南屯區', '168760', '31.2578', '5399'], ['106', '臺中市北屯區', '274819', '62.7034', '4383'], ['106', '臺中市豐原區', '166879', '41.1845', '4052'], ['106', '臺中市東勢區', '50714', '117.4065', '432'], ['106', '臺中市大甲區', '77761', '58.5192', '1329'], ['106', '臺中市清水區', '86420', '64.1709', '1347'], ['106', '臺中市沙鹿區', '92645', '40.4604', '2290'], ['106', '臺中市梧棲區', '57993', '16.6049', '3493'], ['106', '臺中市后里區', '54482', '58.9439', '924'], ['106', '臺中市神岡區', '65553', '35.0445', '1871'], ['106', '臺中市潭子區', '108288', '25.8497', '4189'], ['106', '臺中市大雅區', '95203', '32.4109', '2937'], ['106', '臺中市新社區', '24754', '68.8874', '359'], ['106', '臺中市石岡區', '15066', '18.2105', '827'], ['106', '臺中市外埔區', '32185', '42.4099', '759'], ['106', '臺中市大安區', '19303', '27.4045', '704'], ['106', '臺中市烏日區', '74554', '43.4032', '1718'], ['106', '臺中市大肚區', '57322', '37.0024', '1549'], ['106', '臺中市龍井區', '77818', '38.0377', '2046'], ['106', '臺中市霧峰區', '65393', '98.0779', '667'], ['106', '臺中市太平區', '189066', '120.7473', '1566'], ['106', '臺中市大里區', '211492', '28.8758', '7324'], ['106', '臺中市和平區', '10949', '1037.8192', '11']]

# %%
import csv
poplist = list()
f = open('各鄉鎮市區人口密度.csv','r',encoding='utf-8')
next(f)
dictReader = csv.DictReader(f)
allDataList=[{'統計年':row['統計年'],'區域別':row['區域別'],'年底人口數':row['年底人口數'],'土地面積':row['土地面積'],'人口密度':row['人口密度']} for row in dictReader]
for item in allDataList:
    if '新北市' in item['區域別']
# Out:
# [{'統計年': '106',
#   '區域別': '新北市板橋區',
#   '年底人口數': '551480',
#   '土地面積': '23.1373',
#   '人口密度': '23835'},
#  {'統計年': '106',
#   '區域別': '新北市三重區',
#   '年底人口數': '387484',
#   '土地面積': '16.317',
#   '人口密度': '23747'},
#  {'統計年': '106',
#   '區域別': '新北市中和區',
#   '年底人口數': '413590',
#   '土地面積': '20.144',
#   '人口密度': '20532'},
#  {'統計年': '106',
#   '區域別': '新北市永和區',
#   '年底人口數': '222585',
#   '土地面積': '5.7138',
#   '人口密度': '38956'},
#  {'統計年': '106',
#   '區域別': '新北市新莊區',
#   '年底人口數': '416524',
#   '土地面積': '19.7383',
#   '人口密度': '21102'},
#  {'統計年': '106',
#   '區域別': '新北市新店區',
#   '年底人口數': '302089',
#   '土地面積': '120.2255',
#   '人口密度': '2513'},
#  {'統計年': '106',
#   '區域別': '新北市樹林區',
#   '年底人口數': '184149',
#   '土地面積': '33.1288',
#   '人口密度': '5559'},
#  {'統計年': '106',
#   '區域別': '新北市鶯歌區',
#   '年底人口數': '86593',
#   '土地面積': '21.1248',
#   '人口密度': '4099'},
#  {'統計年': '106',
#   '區域別': '新北市三峽區',
#   '年底人口數': '114926',
#   '土地面積': '191.4508',
#   '人口密度': '600'},
#  {'統計年': '106',
#   '區域別': '新北市淡水區',
#   '年底人口數': '169597',
#   '土地面積': '70.6565',
#   '人口密度': '2400'},
#  {'統計年': '106',
#   '區域別': '新北市汐止區',
#   '年底人口數': '199321',
#   '土地面積': '71.2354',
#   '人口密度': '2798'},
#  {'統計年': '106',
#   '區域別': '新北市瑞芳區',
#   '年底人口數': '40353',
#   '土地面積': '70.7336',
#   '人口密度': '570'},
#  {'統計年': '106',
#   '區域別': '新北市土城區',
#   '年底人口數': '238067',
#   '土地面積': '29.5578',
#   '人口密度': '8054'},
#  {'統計年': '106',
#   '區域別': '新北市蘆洲區',
#   '年底人口數': '201309',
#   '土地面積': '7.4351',
#   '人口密度': '27075'},
#  {'統計年': '106',
#   '區域別': '新北市五股區',
#   '年底人口數': '84919',
#   '土地面積': '34.8632',
#   '人口密度': '2436'},
#  {'統計年': '106',
#   '區域別': '新北市泰山區',
#   '年底人口數': '78911',
#   '土地面積': '19.1603',
#   '人口密度': '4118'},
#  {'統計年': '106',
#   '區域別': '新北市林口區',
#   '年底人口數': '106101',
#   '土地面積': '54.1519',
#   '人口密度': '1959'},
#  {'統計年': '106',
#   '區域別': '新北市深坑區',
#   '年底人口數': '23660',
#   '土地面積': '20.5787',
#   '人口密度': '1150'},
#  {'統計年': '106',
#   '區域別': '新北市石碇區',
#   '年底人口數': '7683',
#   '土地面積': '144.3498',
#   '人口密度': '53'},
#  {'統計年': '106',
#   '區域別': '新北市坪林區',
#   '年底人口數': '6528',
#   '土地面積': '170.835',
#   '人口密度': '38'},
#  {'統計年': '106',
#   '區域別': '新北市三芝區',
#   '年底人口數': '23200',
#   '土地面積': '65.9909',
#   '人口密度': '352'},
#  {'統計年': '106',
#   '區域別': '新北市石門區',
#   '年底人口數': '12286',
#   '土地面積': '51.2645',
#   '人口密度': '240'},
#  {'統計年': '106',
#   '區域別': '新北市八里區',
#   '年底人口數': '38493',
#   '土地面積': '39.4933',
#   '人口密度': '975'},
#  {'統計年': '106',
#   '區域別': '新北市平溪區',
#   '年底人口數': '4719',
#   '土地面積': '71.3382',
#   '人口密度': '66'},
#  {'統計年': '106',
#   '區域別': '新北市雙溪區',
#   '年底人口數': '8939',
#   '土地面積': '146.2484',
#   '人口密度': '61'},
#  {'統計年': '106',
#   '區域別': '新北市貢寮區',
#   '年底人口數': '12552',
#   '土地面積': '99.9734',
#   '人口密度': '126'},
#  {'統計年': '106',
#   '區域別': '新北市金山區',
#   '年底人口數': '22015',
#   '土地面積': '49.2132',
#   '人口密度': '447'},
#  {'統計年': '106',
#   '區域別': '新北市萬里區',
#   '年底人口數': '22296',
#   '土地面積': '63.3766',
#   '人口密度': '352'},
#  {'統計年': '106',
#   '區域別': '新北市烏來區',
#   '年底人口數': '6320',
#   '土地面積': '321.1306',
#   '人口密度': '20'},
#  {'統計年': '106',
#   '區域別': '臺北市松山區',
#   '年底人口數': '206988',
#   '土地面積': '9.2878',
#   '人口密度': '22286'},
#  {'統計年': '106',
#   '區域別': '臺北市信義區',
#   '年底人口數': '225753',
#   '土地面積': '11.2077',
#   '人口密度': '20143'},
#  {'統計年': '106',
#   '區域別': '臺北市大安區',
#   '年底人口數': '309969',
#   '土地面積': '11.3614',
#   '人口密度': '27283'},
#  {'統計年': '106',
#   '區域別': '臺北市中山區',
#   '年底人口數': '230710',
#   '土地面積': '13.6821',
#   '人口密度': '16862'},
#  {'統計年': '106',
#   '區域別': '臺北市中正區',
#   '年底人口數': '159608',
#   '土地面積': '7.6071',
#   '人口密度': '20981'},
#  {'統計年': '106',
#   '區域別': '臺北市大同區',
#   '年底人口數': '129278',
#   '土地面積': '5.6815',
#   '人口密度': '22754'},
#  {'統計年': '106',
#   '區域別': '臺北市萬華區',
#   '年底人口數': '191850',
#   '土地面積': '8.8522',
#   '人口密度': '21673'},
#  {'統計年': '106',
#   '區域別': '臺北市文山區',
#   '年底人口數': '274424',
#   '土地面積': '31.509',
#   '人口密度': '8709'},
#  {'統計年': '106',
#   '區域別': '臺北市南港區',
#   '年底人口數': '122155',
#   '土地面積': '21.8424',
#   '人口密度': '5593'},
#  {'統計年': '106',
#   '區域別': '臺北市內湖區',
#   '年底人口數': '287771',
#   '土地面積': '31.5787',
#   '人口密度': '9113'},
#  {'統計年': '106',
#   '區域別': '臺北市士林區',
#   '年底人口數': '288295',
#   '土地面積': '62.3682',
#   '人口密度': '4622'},
#  {'統計年': '106',
#   '區域別': '臺北市北投區',
#   '年底人口數': '256456',
#   '土地面積': '56.8216',
#   '人口密度': '4513'},
#  {'統計年': '106',
#   '區域別': '桃園市桃園區',
#   '年底人口數': '440840',
#   '土地面積': '34.8046',
#   '人口密度': '12666'},
#  {'統計年': '106',
#   '區域別': '桃園市中壢區',
#   '年底人口數': '405216',
#   '土地面積': '76.52',
#   '人口密度': '5296'},
#  {'統計年': '106',
#   '區域別': '桃園市大溪區',
#   '年底人口數': '94451',
#   '土地面積': '105.1206',
#   '人口密度': '899'},
#  {'統計年': '106',
#   '區域別': '桃園市楊梅區',
#   '年底人口數': '167639',
#   '土地面積': '89.1229',
#   '人口密度': '1881'},
#  {'統計年': '106',
#   '區域別': '桃園市蘆竹區',
#   '年底人口數': '161912',
#   '土地面積': '75.5025',
#   '人口密度': '2144'},
#  {'統計年': '106',
#   '區域別': '桃園市大園區',
#   '年底人口數': '89281',
#   '土地面積': '87.3925',
#   '人口密度': '1022'},
#  {'統計年': '106',
#   '區域別': '桃園市龜山區',
#   '年底人口數': '157633',
#   '土地面積': '72.0177',
#   '人口密度': '2189'},
#  {'統計年': '106',
#   '區域別': '桃園市八德區',
#   '年底人口數': '198074',
#   '土地面積': '33.7111',
#   '人口密度': '5876'},
#  {'統計年': '106',
#   '區域別': '桃園市龍潭區',
#   '年底人口數': '121822',
#   '土地面積': '75.2341',
#   '人口密度': '1619'},
#  {'統計年': '106',
#   '區域別': '桃園市平鎮區',
#   '年底人口數': '224219',
#   '土地面積': '47.7532',
#   '人口密度': '4695'},
#  {'統計年': '106',
#   '區域別': '桃園市新屋區',
#   '年底人口數': '48953',
#   '土地面積': '85.0166',
#   '人口密度': '576'},
#  {'統計年': '106',
#   '區域別': '桃園市觀音區',
#   '年底人口數': '66472',
#   '土地面積': '87.9807',
#   '人口密度': '756'},
#  {'統計年': '106',
#   '區域別': '桃園市復興區',
#   '年底人口數': '11505',
#   '土地面積': '350.7775',
#   '人口密度': '33'},
#  {'統計年': '106',
#   '區域別': '臺中市中區',
#   '年底人口數': '18450',
#   '土地面積': '0.8803',
#   '人口密度': '20959'},
#  {'統計年': '106',
#   '區域別': '臺中市東區',
#   '年底人口數': '75811',
#   '土地面積': '9.2855',
#   '人口密度': '8164'},
#  {'統計年': '106',
#   '區域別': '臺中市南區',
#   '年底人口數': '125067',
#   '土地面積': '6.8101',
#   '人口密度': '18365'},
#  {'統計年': '106',
#   '區域別': '臺中市西區',
#   '年底人口數': '115627',
#   '土地面積': '5.7042',
#   '人口密度': '20271'},
#  {'統計年': '106',
#   '區域別': '臺中市北區',
#   '年底人口數': '147653',
#   '土地面積': '6.9376',
#   '人口密度': '21283'},
#  {'統計年': '106',
#   '區域別': '臺中市西屯區',
#   '年底人口數': '227043',
#   '土地面積': '39.8467',
#   '人口密度': '5698'},
#  {'統計年': '106',
#   '區域別': '臺中市南屯區',
#   '年底人口數': '168760',
#   '土地面積': '31.2578',
#   '人口密度': '5399'},
#  {'統計年': '106',
#   '區域別': '臺中市北屯區',
#   '年底人口數': '274819',
#   '土地面積': '62.7034',
#   '人口密度': '4383'},
#  {'統計年': '106',
#   '區域別': '臺中市豐原區',
#   '年底人口數': '166879',
#   '土地面積': '41.1845',
#   '人口密度': '4052'},
#  {'統計年': '106',
#   '區域別': '臺中市東勢區',
#   '年底人口數': '50714',
#   '土地面積': '117.4065',
#   '人口密度': '432'},
#  {'統計年': '106',
#   '區域別': '臺中市大甲區',
#   '年底人口數': '77761',
#   '土地面積': '58.5192',
#   '人口密度': '1329'},
#  {'統計年': '106',
#   '區域別': '臺中市清水區',
#   '年底人口數': '86420',
#   '土地面積': '64.1709',
#   '人口密度': '1347'},
#  {'統計年': '106',
#   '區域別': '臺中市沙鹿區',
#   '年底人口數': '92645',
#   '土地面積': '40.4604',
#   '人口密度': '2290'},
#  {'統計年': '106',
#   '區域別': '臺中市梧棲區',
#   '年底人口數': '57993',
#   '土地面積': '16.6049',
#   '人口密度': '3493'},
#  {'統計年': '106',
#   '區域別': '臺中市后里區',
#   '年底人口數': '54482',
#   '土地面積': '58.9439',
#   '人口密度': '924'},
#  {'統計年': '106',
#   '區域別': '臺中市神岡區',
#   '年底人口數': '65553',
#   '土地面積': '35.0445',
#   '人口密度': '1871'},
#  {'統計年': '106',
#   '區域別': '臺中市潭子區',
#   '年底人口數': '108288',
#   '土地面積': '25.8497',
#   '人口密度': '4189'},
#  {'統計年': '106',
#   '區域別': '臺中市大雅區',
#   '年底人口數': '95203',
#   '土地面積': '32.4109',
#   '人口密度': '2937'},
#  {'統計年': '106',
#   '區域別': '臺中市新社區',
#   '年底人口數': '24754',
#   '土地面積': '68.8874',
#   '人口密度': '359'},
#  {'統計年': '106',
#   '區域別': '臺中市石岡區',
#   '年底人口數': '15066',
#   '土地面積': '18.2105',
#   '人口密度': '827'},
#  {'統計年': '106',
#   '區域別': '臺中市外埔區',
#   '年底人口數': '32185',
#   '土地面積': '42.4099',
#   '人口密度': '759'},
#  {'統計年': '106',
#   '區域別': '臺中市大安區',
#   '年底人口數': '19303',
#   '土地面積': '27.4045',
#   '人口密度': '704'},
#  {'統計年': '106',
#   '區域別': '臺中市烏日區',
#   '年底人口數': '74554',
#   '土地面積': '43.4032',
#   '人口密度': '1718'},
#  {'統計年': '106',
#   '區域別': '臺中市大肚區',
#   '年底人口數': '57322',
#   '土地面積': '37.0024',
#   '人口密度': '1549'},
#  {'統計年': '106',
#   '區域別': '臺中市龍井區',
#   '年底人口數': '77818',
#   '土地面積': '38.0377',
#   '人口密度': '2046'},
#  {'統計年': '106',
#   '區域別': '臺中市霧峰區',
#   '年底人口數': '65393',
#   '土地面積': '98.0779',
#   '人口密度': '667'},
#  {'統計年': '106',
#   '區域別': '臺中市太平區',
#   '年底人口數': '189066',
#   '土地面積': '120.7473',
#   '人口密度': '1566'},
#  {'統計年': '106',
#   '區域別': '臺中市大里區',
#   '年底人口數': '211492',
#   '土地面積': '28.8758',
#   '人口密度': '7324'},
#  {'統計年': '106',
#   '區域別': '臺中市和平區',
#   '年底人口數': '10949',
#   '土地面積': '1037.8192',
#   '人口密度': '11'},
#  {'統計年': '106',
#   '區域別': '臺南市新營區',
#   '年底人口數': '77966',
#   '土地面積': '38.5386',
#   '人口密度': '2023'},
#  {'統計年': '106',
#   '區域別': '臺南市鹽水區',
#   '年底人口數': '25583',
#   '土地面積': '52.2455',
#   '人口密度': '490'},
#  {'統計年': '106',
#   '區域別': '臺南市白河區',
#   '年底人口數': '28520',
#   '土地面積': '126.4046',
#   '人口密度': '226'},
#  {'統計年': '106',
#   '區域別': '臺南市柳營區',
#   '年底人口數': '21365',
#   '土地面積': '61.2929',
#   '人口密度': '349'},
#  {'統計年': '106',
#   '區域別': '臺南市後壁區',
#   '年底人口數': '23718',
#   '土地面積': '72.2189',
#   '人口密度': '328'},
#  {'統計年': '106',
#   '區域別': '臺南市東山區',
#   '年底人口數': '21049',
#   '土地面積': '124.9178',
#   '人口密度': '169'},
#  {'統計年': '106',
#   '區域別': '臺南市麻豆區',
#   '年底人口數': '44603',
#   '土地面積': '53.9744',
#   '人口密度': '826'},
#  {'統計年': '106',
#   '區域別': '臺南市下營區',
#   '年底人口數': '24239',
#   '土地面積': '33.5291',
#   '人口密度': '723'},
#  {'統計年': '106',
#   '區域別': '臺南市六甲區',
#   '年底人口數': '22275',
#   '土地面積': '67.5471',
#   '人口密度': '330'},
#  {'統計年': '106',
#   '區域別': '臺南市官田區',
#   '年底人口數': '21448',
#   '土地面積': '70.7953',
#   '人口密度': '303'},
#  {'統計年': '106',
#   '區域別': '臺南市大內區',
#   '年底人口數': '9761',
#   '土地面積': '70.3125',
#   '人口密度': '139'},
#  {'統計年': '106',
#   '區域別': '臺南市佳里區',
#   '年底人口數': '59380',
#   '土地面積': '38.9422',
#   '人口密度': '1525'},
#  {'統計年': '106',
#   '區域別': '臺南市學甲區',
#   '年底人口數': '26078',
#   '土地面積': '53.9919',
#   '人口密度': '483'},
#  {'統計年': '106',
#   '區域別': '臺南市西港區',
#   '年底人口數': '24758',
#   '土地面積': '33.7666',
#   '人口密度': '733'},
#  {'統計年': '106',
#   '區域別': '臺南市七股區',
#   '年底人口數': '22974',
#   '土地面積': '110.1492',
#   '人口密度': '209'},
#  {'統計年': '106',
#   '區域別': '臺南市將軍區',
#   '年底人口數': '19849',
#   '土地面積': '41.9796',
#   '人口密度': '473'},
#  {'統計年': '106',
#   '區域別': '臺南市北門區',
#   '年底人口數': '11188',
#   '土地面積': '44.1003',
#   '人口密度': '254'},
#  {'統計年': '106',
#   '區域別': '臺南市新化區',
#   '年底人口數': '43630',
#   '土地面積': '62.0579',
#   '人口密度': '703'},
#  {'統計年': '106',
#   '區域別': '臺南市善化區',
#   '年底人口數': '48386',
#   '土地面積': '55.3097',
#   '人口密度': '875'},
#  {'統計年': '106',
#   '區域別': '臺南市新市區',
#   '年底人口數': '36574',
#   '土地面積': '47.8096',
#   '人口密度': '765'},
#  {'統計年': '106',
#   '區域別': '臺南市安定區',
#   '年底人口數': '30564',
#   '土地面積': '31.27',
#   '人口密度': '977'},
#  {'統計年': '106',
#   '區域別': '臺南市山上區',
#   '年底人口數': '7314',
#   '土地面積': '27.878',
#   '人口密度': '262'},
#  {'統計年': '106',
#   '區域別': '臺南市玉井區',
#   '年底人口數': '14151',
#   '土地面積': '76.3662',
#   '人口密度': '185'},
#  {'統計年': '106',
#   '區域別': '臺南市楠西區',
#   '年底人口數': '9717',
#   '土地面積': '109.6316',
#   '人口密度': '89'},
#  {'統計年': '106',
#   '區域別': '臺南市南化區',
#   '年底人口數': '8787',
#   '土地面積': '171.5198',
#   '人口密度': '51'},
#  {'統計年': '106',
#   '區域別': '臺南市左鎮區',
#   '年底人口數': '4876',
#   '土地面積': '74.9025',
#   '人口密度': '65'},
#  {'統計年': '106',
#   '區域別': '臺南市仁德區',
#   '年底人口數': '75518',
#   '土地面積': '50.7664',
#   '人口密度': '1488'},
#  {'統計年': '106',
#   '區域別': '臺南市歸仁區',
#   '年底人口數': '68424',
#   '土地面積': '55.7913',
#   '人口密度': '1226'},
#  {'統計年': '106',
#   '區域別': '臺南市關廟區',
#   '年底人口數': '34433',
#   '土地面積': '53.6413',
#   '人口密度': '642'},
#  {'統計年': '106',
#   '區域別': '臺南市龍崎區',
#   '年底人口數': '4038',
#   '土地面積': '64.0814',
#   '人口密度': '63'},
#  {'統計年': '106',
#   '區域別': '臺南市永康區',
#   '年底人口數': '233905',
#   '土地面積': '40.2753',
#   '人口密度': '5808'},
#  {'統計年': '106',
#   '區域別': '臺南市東區',
#   '年底人口數': '186841',
#   '土地面積': '13.4156',
#   '人口密度': '13927'},
#  {'統計年': '106',
#   '區域別': '臺南市南區',
#   '年底人口數': '125394',
#   '土地面積': '27.2681',
#   '人口密度': '4599'},
#  {'統計年': '106',
#   '區域別': '臺南市北區',
#   '年底人口數': '132726',
#   '土地面積': '10.434',
#   '人口密度': '12721'},
#  {'統計年': '106',
#   '區域別': '臺南市安南區',
#   '年底人口數': '192224',
#   '土地面積': '107.2016',
#   '人口密度': '1793'},
#  {'統計年': '106',
#   '區域別': '臺南市安平區',
#   '年底人口數': '66496',
#   '土地面積': '11.0663',
#   '人口密度': '6009'},
#  {'統計年': '106',
#   '區域別': '臺南市中西區',
#   '年底人口數': '77770',
#   '土地面積': '6.26',
#   '人口密度': '12423'},
#  {'統計年': '106',
#   '區域別': '高雄市鹽埕區',
#   '年底人口數': '24219',
#   '土地面積': '1.4161',
#   '人口密度': '17103'},
#  {'統計年': '106',
#   '區域別': '高雄市鼓山區',
#   '年底人口數': '139259',
#   '土地面積': '14.7523',
#   '人口密度': '9440'},
#  {'統計年': '106',
#   '區域別': '高雄市左營區',
#   '年底人口數': '197072',
#   '土地面積': '19.3823',
#   '人口密度': '10168'},
#  {'統計年': '106',
#   '區域別': '高雄市楠梓區',
#   '年底人口數': '183751',
#   '土地面積': '25.8276',
#   '人口密度': '7115'},
#  {'統計年': '106',
#   '區域別': '高雄市三民區',
#   '年底人口數': '343243',
#   '土地面積': '19.7866',
#   '人口密度': '17347'},
#  {'統計年': '106',
#   '區域別': '高雄市新興區',
#   '年底人口數': '51153',
#   '土地面積': '1.9764',
#   '人口密度': '25882'},
#  {'統計年': '106',
#   '區域別': '高雄市前金區',
#   '年底人口數': '26991',
#   '土地面積': '1.8573',
#   '人口密度': '14532'},
#  {'統計年': '106',
#   '區域別': '高雄市苓雅區',
#   '年底人口數': '171033',
#   '土地面積': '8.1522',
#   '人口密度': '20980'},
#  {'統計年': '106',
#   '區域別': '高雄市前鎮區',
#   '年底人口數': '189839',
#   '土地面積': '19.1207',
#   '人口密度': '9928'},
#  {'統計年': '106',
#   '區域別': '高雄市旗津區',
#   '年底人口數': '28763',
#   '土地面積': '1.4639',
#   '人口密度': '19648'},
#  {'統計年': '106',
#   '區域別': '高雄市小港區',
#   '年底人口數': '157475',
#   '土地面積': '45.4426',
#   '人口密度': '3465'},
#  {'統計年': '106',
#   '區域別': '高雄市鳳山區',
#   '年底人口數': '359120',
#   '土地面積': '26.759',
#   '人口密度': '13421'},
#  {'統計年': '106',
#   '區域別': '高雄市林園區',
#   '年底人口數': '69990',
#   '土地面積': '32.286',
#   '人口密度': '2168'},
#  {'統計年': '106',
#   '區域別': '高雄市大寮區',
#   '年底人口數': '112397',
#   '土地面積': '71.04',
#   '人口密度': '1582'},
#  {'統計年': '106',
#   '區域別': '高雄市大樹區',
#   '年底人口數': '42757',
#   '土地面積': '66.9811',
#   '人口密度': '638'},
#  {'統計年': '106',
#   '區域別': '高雄市大社區',
#   '年底人口數': '34577',
#   '土地面積': '26.5848',
#   '人口密度': '1301'},
#  {'統計年': '106',
#   '區域別': '高雄市仁武區',
#   '年底人口數': '85894',
#   '土地面積': '36.0808',
#   '人口密度': '2381'},
#  {'統計年': '106',
#   '區域別': '高雄市鳥松區',
#   '年底人口數': '44291',
#   '土地面積': '24.5927',
#   '人口密度': '1801'},
#  {'統計年': '106',
#   '區域別': '高雄市岡山區',
#   '年底人口數': '97329',
#   '土地面積': '47.9421',
#   '人口密度': '2030'},
#  {'統計年': '106',
#   '區域別': '高雄市橋頭區',
#   '年底人口數': '37579',
#   '土地面積': '25.9379',
#   '人口密度': '1449'},
#  {'統計年': '106',
#   '區域別': '高雄市燕巢區',
#   '年底人口數': '29922',
#   '土地面積': '65.395',
#   '人口密度': '458'},
#  {'統計年': '106',
#   '區域別': '高雄市田寮區',
#   '年底人口數': '7245',
#   '土地面積': '92.6802',
#   '人口密度': '78'},
#  {'統計年': '106',
#   '區域別': '高雄市阿蓮區',
#   '年底人口數': '28844',
#   '土地面積': '34.6164',
#   '人口密度': '833'},
#  {'統計年': '106',
#   '區域別': '高雄市路竹區',
#   '年底人口數': '52761',
#   '土地面積': '48.4348',
#   '人口密度': '1089'},
#  {'統計年': '106',
#   '區域別': '高雄市湖內區',
#   '年底人口數': '29803',
#   '土地面積': '20.1615',
#   '人口密度': '1478'},
#  {'統計年': '106',
#   '區域別': '高雄市茄萣區',
#   '年底人口數': '30217',
#   '土地面積': '15.7624',
#   '人口密度': '1917'},
#  {'統計年': '106',
#   '區域別': '高雄市永安區',
#   '年底人口數': '13980',
#   '土地面積': '22.6141',
#   '人口密度': '618'},
#  {'統計年': '106',
#   '區域別': '高雄市彌陀區',
#   '年底人口數': '19383',
#   '土地面積': '14.7772',
#   '人口密度': '1312'},
#  {'統計年': '106',
#   '區域別': '高雄市梓官區',
#   '年底人口數': '36116',
#   '土地面積': '11.5967',
#   '人口密度': '3114'},
#  {'統計年': '106',
#   '區域別': '高雄市旗山區',
#   '年底人口數': '36940',
#   '土地面積': '94.6122',
#   '人口密度': '390'},
#  {'統計年': '106',
#   '區域別': '高雄市美濃區',
#   '年底人口數': '39973',
#   '土地面積': '120.0316',
#   '人口密度': '333'},
#  {'統計年': '106',
#   '區域別': '高雄市六龜區',
#   '年底人口數': '13016',
#   '土地面積': '194.1584',
#   '人口密度': '67'},
#  {'統計年': '106',
#   '區域別': '高雄市甲仙區',
#   '年底人口數': '6107',
#   '土地面積': '124.034',
#   '人口密度': '49'},
#  {'統計年': '106',
#   '區域別': '高雄市杉林區',
#   '年底人口數': '12038',
#   '土地面積': '104.0036',
#   '人口密度': '116'},
#  {'統計年': '106',
#   '區域別': '高雄市內門區',
#   '年底人口數': '14540',
#   '土地面積': '95.6224',
#   '人口密度': '152'},
#  {'統計年': '106', '區域別': '高雄市茂林區', '年底人口數': '1924', '土地面積': '194', '人口密度': '10'},
#  {'統計年': '106',
#   '區域別': '高雄市桃源區',
#   '年底人口數': '4246',
#   '土地面積': '928.98',
#   '人口密度': '5'},
#  {'統計年': '106',
#   '區域別': '高雄市那瑪夏區',
#   '年底人口數': '3125',
#   '土地面積': '252.9895',
#   '人口密度': '12'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣宜蘭市',
#   '年底人口數': '95918',
#   '土地面積': '29.408',
#   '人口密度': '3262'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣羅東鎮',
#   '年底人口數': '72319',
#   '土地面積': '11.3448',
#   '人口密度': '6375'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣蘇澳鎮',
#   '年底人口數': '40056',
#   '土地面積': '89.0196',
#   '人口密度': '450'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣頭城鎮',
#   '年底人口數': '29398',
#   '土地面積': '100.893',
#   '人口密度': '291'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣礁溪鄉',
#   '年底人口數': '35777',
#   '土地面積': '101.4278',
#   '人口密度': '353'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣壯圍鄉',
#   '年底人口數': '24250',
#   '土地面積': '38.4769',
#   '人口密度': '630'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣員山鄉',
#   '年底人口數': '32458',
#   '土地面積': '111.9106',
#   '人口密度': '290'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣冬山鄉',
#   '年底人口數': '53289',
#   '土地面積': '79.8573',
#   '人口密度': '667'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣五結鄉',
#   '年底人口數': '39673',
#   '土地面積': '38.8671',
#   '人口密度': '1021'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣三星鄉',
#   '年底人口數': '21467',
#   '土地面積': '144.2238',
#   '人口密度': '149'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣大同鄉',
#   '年底人口數': '6102',
#   '土地面積': '657.5442',
#   '人口密度': '9'},
#  {'統計年': '106',
#   '區域別': '宜蘭縣南澳鄉',
#   '年底人口數': '5900',
#   '土地面積': '740.652',
#   '人口密度': '8'},
#  {'統計年': '106',
#   '區域別': '新竹縣竹北市',
#   '年底人口數': '181955',
#   '土地面積': '46.8341',
#   '人口密度': '3885'},
#  {'統計年': '106',
#   '區域別': '新竹縣關西鎮',
#   '年底人口數': '28896',
#   '土地面積': '125.5193',
#   '人口密度': '230'},
#  {'統計年': '106',
#   '區域別': '新竹縣新埔鎮',
#   '年底人口數': '33415',
#   '土地面積': '72.1911',
#   '人口密度': '463'},
#  {'統計年': '106',
#   '區域別': '新竹縣竹東鎮',
#   '年底人口數': '96918',
#   '土地面積': '53.5133',
#   '人口密度': '1811'},
#  {'統計年': '106',
#   '區域別': '新竹縣湖口鄉',
#   '年底人口數': '77444',
#   '土地面積': '58.4303',
#   '人口密度': '1325'},
#  {'統計年': '106',
#   '區域別': '新竹縣橫山鄉',
#   '年底人口數': '13064',
#   '土地面積': '66.3502',
#   '人口密度': '197'},
#  {'統計年': '106',
#   '區域別': '新竹縣新豐鄉',
#   '年底人口數': '56836',
#   '土地面積': '46.3496',
#   '人口密度': '1226'},
#  {'統計年': '106',
#   '區域別': '新竹縣芎林鄉',
#   '年底人口數': '20061',
#   '土地面積': '40.7858',
#   '人口密度': '492'},
#  {'統計年': '106',
#   '區域別': '新竹縣寶山鄉',
#   '年底人口數': '14550',
#   '土地面積': '64.7871',
#   '人口密度': '225'},
#  {'統計年': '106',
#   '區域別': '新竹縣北埔鄉',
#   '年底人口數': '9390',
#   '土地面積': '50.6676',
#   '人口密度': '185'},
#  {'統計年': '106',
#   '區域別': '新竹縣峨眉鄉',
#   '年底人口數': '5538',
#   '土地面積': '46.801',
#   '人口密度': '118'},
#  {'統計年': '106',
#   '區域別': '新竹縣尖石鄉',
#   '年底人口數': '9543',
#   '土地面積': '527.5795',
#   '人口密度': '18'},
#  {'統計年': '106',
#   '區域別': '新竹縣五峰鄉',
#   '年底人口數': '4559',
#   '土地面積': '227.728',
#   '人口密度': '20'},
#  {'統計年': '106',
#   '區域別': '苗栗縣苗栗市',
#   '年底人口數': '89165',
#   '土地面積': '37.8878',
#   '人口密度': '2353'},
#  {'統計年': '106',
#   '區域別': '苗栗縣頭份市',
#   '年底人口數': '103147',
#   '土地面積': '53.3205',
#   '人口密度': '1934'},
#  {'統計年': '106',
#   '區域別': '苗栗縣苑裡鎮',
#   '年底人口數': '45976',
#   '土地面積': '68.2473',
#   '人口密度': '674'},
#  {'統計年': '106',
#   '區域別': '苗栗縣通霄鎮',
#   '年底人口數': '34691',
#   '土地面積': '107.8486',
#   '人口密度': '322'},
#  {'統計年': '106',
#   '區域別': '苗栗縣竹南鎮',
#   '年底人口數': '85587',
#   '土地面積': '37.5592',
#   '人口密度': '2279'},
#  {'統計年': '106',
#   '區域別': '苗栗縣後龍鎮',
#   '年底人口數': '36750',
#   '土地面積': '75.8079',
#   '人口密度': '485'},
#  {'統計年': '106',
#   '區域別': '苗栗縣卓蘭鎮',
#   '年底人口數': '17134',
#   '土地面積': '76.3153',
#   '人口密度': '225'},
#  {'統計年': '106',
#   '區域別': '苗栗縣大湖鄉',
#   '年底人口數': '14738',
#   '土地面積': '90.8396',
#   '人口密度': '162'},
#  {'統計年': '106',
#   '區域別': '苗栗縣公館鄉',
#   '年底人口數': '33773',
#   '土地面積': '71.4523',
#   '人口密度': '473'},
#  {'統計年': '106',
#   '區域別': '苗栗縣銅鑼鄉',
#   '年底人口數': '18138',
#   '土地面積': '78.3805',
#   '人口密度': '231'},
#  {'統計年': '106',
#   '區域別': '苗栗縣南庄鄉',
#   '年底人口數': '10176',
#   '土地面積': '165.4938',
#   '人口密度': '61'},
#  {'統計年': '106',
#   '區域別': '苗栗縣頭屋鄉',
#   '年底人口數': '10840',
#   '土地面積': '52.5046',
#   '人口密度': '206'},
#  {'統計年': '106',
#   '區域別': '苗栗縣三義鄉',
#   '年底人口數': '16530',
#   '土地面積': '69.3424',
#   '人口密度': '238'},
#  {'統計年': '106',
#   '區域別': '苗栗縣西湖鄉',
#   '年底人口數': '7154',
#   '土地面積': '41.0758',
#   '人口密度': '174'},
#  {'統計年': '106',
#   '區域別': '苗栗縣造橋鄉',
#   '年底人口數': '12952',
#   '土地面積': '47.9978',
#   '人口密度': '270'},
#  {'統計年': '106',
#   '區域別': '苗栗縣三灣鄉',
#   '年底人口數': '6756',
#   '土地面積': '52.2964',
#   '人口密度': '129'},
#  {'統計年': '106',
#   '區域別': '苗栗縣獅潭鄉',
#   '年底人口數': '4417',
#   '土地面積': '79.4324',
#   '人口密度': '56'},
#  {'統計年': '106',
#   '區域別': '苗栗縣泰安鄉',
#   '年底人口數': '5883',
#   '土地面積': '614.5127',
#   '人口密度': '10'},
#  {'統計年': '106',
#   '區域別': '彰化縣彰化市',
#   '年底人口數': '233613',
#   '土地面積': '65.6947',
#   '人口密度': '3556'},
#  {'統計年': '106',
#   '區域別': '彰化縣員林市',
#   '年底人口數': '124632',
#   '土地面積': '40.038',
#   '人口密度': '3113'},
#  {'統計年': '106',
#   '區域別': '彰化縣鹿港鎮',
#   '年底人口數': '86799',
#   '土地面積': '39.4625',
#   '人口密度': '2200'},
#  {'統計年': '106',
#   '區域別': '彰化縣和美鎮',
#   '年底人口數': '90986',
#   '土地面積': '39.9345',
#   '人口密度': '2278'},
#  {'統計年': '106',
#   '區域別': '彰化縣北斗鎮',
#   '年底人口數': '33355',
#   '土地面積': '19.2547',
#   '人口密度': '1732'},
#  {'統計年': '106',
#   '區域別': '彰化縣溪湖鎮',
#   '年底人口數': '55686',
#   '土地面積': '32.0592',
#   '人口密度': '1737'},
#  {'統計年': '106',
#   '區域別': '彰化縣田中鎮',
#   '年底人口數': '41890',
#   '土地面積': '34.6056',
#   '人口密度': '1210'},
#  {'統計年': '106',
#   '區域別': '彰化縣二林鎮',
#   '年底人口數': '50980',
#   '土地面積': '92.8478',
#   '人口密度': '549'},
#  {'統計年': '106',
#   '區域別': '彰化縣線西鄉',
#   '年底人口數': '16928',
#   '土地面積': '18.0856',
#   '人口密度': '936'},
#  {'統計年': '106',
#   '區域別': '彰化縣伸港鄉',
#   '年底人口數': '36957',
#   '土地面積': '22.3268',
#   '人口密度': '1655'},
#  {'統計年': '106',
#   '區域別': '彰化縣福興鄉',
#   '年底人口數': '47332',
#   '土地面積': '49.8934',
#   '人口密度': '949'},
#  {'統計年': '106',
#   '區域別': '彰化縣秀水鄉',
#   '年底人口數': '39357',
#   '土地面積': '29.3447',
#   '人口密度': '1341'},
#  {'統計年': '106',
#   '區域別': '彰化縣花壇鄉',
#   '年底人口數': '45924',
#   '土地面積': '36.3469',
#   '人口密度': '1263'},
#  {'統計年': '106',
#   '區域別': '彰化縣芬園鄉',
#   '年底人口數': '23755',
#   '土地面積': '38.0204',
#   '人口密度': '625'},
#  {'統計年': '106',
#   '區域別': '彰化縣大村鄉',
#   '年底人口數': '36870',
#   '土地面積': '30.7837',
#   '人口密度': '1198'},
#  {'統計年': '106',
#   '區域別': '彰化縣埔鹽鄉',
#   '年底人口數': '32587',
#   '土地面積': '38.6081',
#   '人口密度': '844'},
#  {'統計年': '106',
#   '區域別': '彰化縣埔心鄉',
#   '年底人口數': '34836',
#   '土地面積': '20.9526',
#   '人口密度': '1663'},
#  {'統計年': '106',
#   '區域別': '彰化縣永靖鄉',
#   '年底人口數': '37334',
#   '土地面積': '20.6382',
#   '人口密度': '1809'},
#  {'統計年': '106',
#   '區域別': '彰化縣社頭鄉',
#   '年底人口數': '43144',
#   '土地面積': '36.1449',
#   '人口密度': '1194'},
#  {'統計年': '106',
#   '區域別': '彰化縣二水鄉',
#   '年底人口數': '15325',
#   '土地面積': '29.4449',
#   '人口密度': '520'},
#  {'統計年': '106',
#   '區域別': '彰化縣田尾鄉',
#   '年底人口數': '27462',
#   '土地面積': '24.0375',
#   '人口密度': '1142'},
#  {'統計年': '106',
#   '區域別': '彰化縣埤頭鄉',
#   '年底人口數': '30642',
#   '土地面積': '42.7508',
#   '人口密度': '717'},
#  {'統計年': '106',
#   '區域別': '彰化縣芳苑鄉',
#   '年底人口數': '33714',
#   '土地面積': '91.3827',
#   '人口密度': '369'},
#  {'統計年': '106',
#   '區域別': '彰化縣大城鄉',
#   '年底人口數': '16987',
#   '土地面積': '63.7406',
#   '人口密度': '267'},
#  {'統計年': '106',
#   '區域別': '彰化縣竹塘鄉',
#   '年底人口數': '15303',
#   '土地面積': '42.1662',
#   '人口密度': '363'},
#  {'統計年': '106',
#   '區域別': '彰化縣溪州鄉',
#   '年底人口數': '30060',
#   '土地面積': '75.831',
#   '人口密度': '396'},
#  {'統計年': '106',
#   '區域別': '南投縣南投市',
#   '年底人口數': '100180',
#   '土地面積': '71.6021',
#   '人口密度': '1399'},
#  {'統計年': '106',
#   '區域別': '南投縣埔里鎮',
#   '年底人口數': '81033',
#   '土地面積': '162.2227',
#   '人口密度': '500'},
#  {'統計年': '106',
#   '區域別': '南投縣草屯鎮',
#   '年底人口數': '97875',
#   '土地面積': '104.0327',
#   '人口密度': '941'},
#  {'統計年': '106',
#   '區域別': '南投縣竹山鎮',
#   '年底人口數': '55060',
#   '土地面積': '247.3339',
#   '人口密度': '223'},
#  {'統計年': '106',
#   '區域別': '南投縣集集鎮',
#   '年底人口數': '10904',
#   '土地面積': '49.7268',
#   '人口密度': '219'},
#  {'統計年': '106',
#   '區域別': '南投縣名間鄉',
#   '年底人口數': '38796',
#   '土地面積': '83.0955',
#   '人口密度': '467'},
#  {'統計年': '106',
#   '區域別': '南投縣鹿谷鄉',
#   '年底人口數': '17808',
#   '土地面積': '141.8981',
#   '人口密度': '125'},
#  {'統計年': '106',
#   '區域別': '南投縣中寮鄉',
#   '年底人口數': '14842',
#   '土地面積': '146.6541',
#   '人口密度': '101'},
#  {'統計年': '106',
#   '區域別': '南投縣魚池鄉',
#   '年底人口數': '15946',
#   '土地面積': '121.3735',
#   '人口密度': '131'},
#  {'統計年': '106',
#   '區域別': '南投縣國姓鄉',
#   '年底人口數': '18803',
#   '土地面積': '175.7042',
#   '人口密度': '107'},
#  {'統計年': '106',
#   '區域別': '南投縣水里鄉',
#   '年底人口數': '17803',
#   '土地面積': '106.8424',
#   '人口密度': '167'},
#  {'統計年': '106',
#   '區域別': '南投縣信義鄉',
#   '年底人口數': '16253',
#   '土地面積': '1422.4188',
#   '人口密度': '11'},
#  {'統計年': '106',
#   '區域別': '南投縣仁愛鄉',
#   '年底人口數': '15748',
#   '土地面積': '1273.5312',
#   '人口密度': '12'},
#  {'統計年': '106',
#   '區域別': '雲林縣斗六市',
#   '年底人口數': '108567',
#   '土地面積': '93.7151',
#   '人口密度': '1158'},
#  {'統計年': '106',
#   '區域別': '雲林縣斗南鎮',
#   '年底人口數': '44941',
#   '土地面積': '48.1505',
#   '人口密度': '933'},
#  {'統計年': '106',
#   '區域別': '雲林縣虎尾鎮',
#   '年底人口數': '70892',
#   '土地面積': '68.742',
#   '人口密度': '1031'},
#  {'統計年': '106',
#   '區域別': '雲林縣西螺鎮',
#   '年底人口數': '46244',
#   '土地面積': '49.7985',
#   '人口密度': '929'},
#  {'統計年': '106',
#   '區域別': '雲林縣土庫鎮',
#   '年底人口數': '28932',
#   '土地面積': '49.0212',
#   '人口密度': '590'},
#  {'統計年': '106',
#   '區域別': '雲林縣北港鎮',
#   '年底人口數': '40278',
#   '土地面積': '41.4999',
#   '人口密度': '971'},
#  {'統計年': '106',
#   '區域別': '雲林縣古坑鄉',
#   '年底人口數': '31708',
#   '土地面積': '166.6059',
#   '人口密度': '190'},
#  {'統計年': '106',
#   '區域別': '雲林縣大埤鄉',
#   '年底人口數': '19263',
#   '土地面積': '44.9973',
#   '人口密度': '428'},
#  {'統計年': '106',
#   '區域別': '雲林縣莿桐鄉',
#   '年底人口數': '28939',
#   '土地面積': '50.8502',
#   '人口密度': '569'},
#  {'統計年': '106',
#   '區域別': '雲林縣林內鄉',
#   '年底人口數': '18230',
#   '土地面積': '37.6035',
#   '人口密度': '485'},
#  {'統計年': '106',
#   '區域別': '雲林縣二崙鄉',
#   '年底人口數': '27255',
#   '土地面積': '59.5625',
#   '人口密度': '458'},
#  {'統計年': '106',
#   '區域別': '雲林縣崙背鄉',
#   '年底人口數': '24678',
#   '土地面積': '58.484',
#   '人口密度': '422'},
#  {'統計年': '106',
#   '區域別': '雲林縣麥寮鄉',
#   '年底人口數': '45665',
#   '土地面積': '80.1668',
#   '人口密度': '570'},
#  {'統計年': '106',
#   '區域別': '雲林縣東勢鄉',
#   '年底人口數': '14893',
#   '土地面積': '48.3562',
#   '人口密度': '308'},
#  {'統計年': '106',
#   '區域別': '雲林縣褒忠鄉',
#   '年底人口數': '13010',
#   '土地面積': '37.0552',
#   '人口密度': '351'},
#  {'統計年': '106',
#   '區域別': '雲林縣臺西鄉',
#   '年底人口數': '23954',
#   '土地面積': '54.0983',
#   '人口密度': '443'},
#  {'統計年': '106',
#   '區域別': '雲林縣元長鄉',
#   '年底人口數': '25980',
#   '土地面積': '71.5872',
#   '人口密度': '363'},
#  {'統計年': '106',
#   '區域別': '雲林縣四湖鄉',
#   '年底人口數': '23667',
#   '土地面積': '77.1189',
#   '人口密度': '307'},
#  {'統計年': '106',
#   '區域別': '雲林縣口湖鄉',
#   '年底人口數': '27653',
#   '土地面積': '80.4612',
#   '人口密度': '344'},
#  {'統計年': '106',
#   '區域別': '雲林縣水林鄉',
#   '年底人口數': '25624',
#   '土地面積': '72.9582',
#   '人口密度': '351'},
#  {'統計年': '106',
#   '區域別': '嘉義縣太保市',
#   '年底人口數': '37781',
#   '土地面積': '66.8964',
#   '人口密度': '565'},
#  {'統計年': '106',
#   '區域別': '嘉義縣朴子市',
#   '年底人口數': '42382',
#   '土地面積': '49.5737',
#   '人口密度': '855'},
#  {'統計年': '106',
#   '區域別': '嘉義縣布袋鎮',
#   '年底人口數': '27143',
#   '土地面積': '61.7307',
#   '人口密度': '440'},
#  {'統計年': '106',
#   '區域別': '嘉義縣大林鎮',
#   '年底人口數': '31198',
#   '土地面積': '64.1663',
#   '人口密度': '486'},
#  {'統計年': '106',
#   '區域別': '嘉義縣民雄鄉',
#   '年底人口數': '71693',
#   '土地面積': '85.4969',
#   '人口密度': '839'},
#  {'統計年': '106',
#   '區域別': '嘉義縣溪口鄉',
#   '年底人口數': '14751',
#   '土地面積': '33.0463',
#   '人口密度': '446'},
#  {'統計年': '106',
#   '區域別': '嘉義縣新港鄉',
#   '年底人口數': '31935',
#   '土地面積': '66.0495',
#   '人口密度': '484'},
#  {'統計年': '106',
#   '區域別': '嘉義縣六腳鄉',
#   '年底人口數': '23318',
#   '土地面積': '62.2619',
#   '人口密度': '375'},
#  {'統計年': '106',
#   '區域別': '嘉義縣東石鄉',
#   '年底人口數': '24969',
#   '土地面積': '81.5821',
#   '人口密度': '306'},
#  {'統計年': '106',
#   '區域別': '嘉義縣義竹鄉',
#   '年底人口數': '18486',
#   '土地面積': '79.2925',
#   '人口密度': '233'},
#  {'統計年': '106',
#   '區域別': '嘉義縣鹿草鄉',
#   '年底人口數': '15577',
#   '土地面積': '54.3151',
#   '人口密度': '287'},
#  {'統計年': '106',
#   '區域別': '嘉義縣水上鄉',
#   '年底人口數': '49744',
#   '土地面積': '69.1198',
#   '人口密度': '720'},
#  {'統計年': '106',
#   '區域別': '嘉義縣中埔鄉',
#   '年底人口數': '44974',
#   '土地面積': '129.5016',
#   '人口密度': '347'},
#  {'統計年': '106',
#   '區域別': '嘉義縣竹崎鄉',
#   '年底人口數': '35962',
#   '土地面積': '162.2256',
#   '人口密度': '222'},
#  {'統計年': '106',
#   '區域別': '嘉義縣梅山鄉',
#   '年底人口數': '19475',
#   '土地面積': '119.7571',
#   '人口密度': '163'},
#  {'統計年': '106',
#   '區域別': '嘉義縣番路鄉',
#   '年底人口數': '11599',
#   '土地面積': '117.5269',
#   '人口密度': '99'},
#  {'統計年': '106',
#   '區域別': '嘉義縣大埔鄉',
#   '年底人口數': '4564',
#   '土地面積': '173.2472',
#   '人口密度': '26'},
#  {'統計年': '106',
#   '區域別': '嘉義縣阿里山鄉',
#   '年底人口數': '5631',
#   '土地面積': '427.8471',
#   '人口密度': '13'},
#  {'統計年': '106',
#   '區域別': '屏東縣屏東市',
#   '年底人口數': '200452',
#   '土地面積': '65.067',
#   '人口密度': '3081'},
#  {'統計年': '106',
#   '區域別': '屏東縣潮州鎮',
#   '年底人口數': '54377',
#   '土地面積': '42.4331',
#   '人口密度': '1281'},
#  {'統計年': '106',
#   '區域別': '屏東縣東港鎮',
#   '年底人口數': '47866',
#   '土地面積': '29.4635',
#   '人口密度': '1625'},
#  {'統計年': '106',
#   '區域別': '屏東縣恆春鎮',
#   '年底人口數': '30726',
#   '土地面積': '136.763',
#   '人口密度': '225'},
#  {'統計年': '106',
#   '區域別': '屏東縣萬丹鄉',
#   '年底人口數': '50935',
#   '土地面積': '57.4679',
#   '人口密度': '886'},
#  {'統計年': '106',
#   '區域別': '屏東縣長治鄉',
#   '年底人口數': '30008',
#   '土地面積': '39.8861',
#   '人口密度': '752'},
#  {'統計年': '106',
#   '區域別': '屏東縣麟洛鄉',
#   '年底人口數': '11076',
#   '土地面積': '16.26',
#   '人口密度': '681'},
#  {'統計年': '106',
#   '區域別': '屏東縣九如鄉',
#   '年底人口數': '22110',
#   '土地面積': '42.0187',
#   '人口密度': '526'},
#  {'統計年': '106',
#   '區域別': '屏東縣里港鄉',
#   '年底人口數': '26459',
#   '土地面積': '68.9208',
#   '人口密度': '384'},
#  {'統計年': '106',
#   '區域別': '屏東縣鹽埔鄉',
#   '年底人口數': '25997',
#   '土地面積': '64.3493',
#   '人口密度': '404'},
#  {'統計年': '106',
#   '區域別': '屏東縣高樹鄉',
#   '年底人口數': '24622',
#   '土地面積': '90.1522',
#   '人口密度': '273'},
#  {'統計年': '106',
#   '區域別': '屏東縣萬巒鄉',
#   '年底人口數': '20556',
#   '土地面積': '60.7315',
#   '人口密度': '338'},
#  {'統計年': '106',
#   '區域別': '屏東縣內埔鄉',
#   '年底人口數': '54707',
#   '土地面積': '81.8554',
#   '人口密度': '668'},
#  {'統計年': '106',
#   '區域別': '屏東縣竹田鄉',
#   '年底人口數': '17158',
#   '土地面積': '29.0732',
#   '人口密度': '590'},
#  {'統計年': '106',
#   '區域別': '屏東縣新埤鄉',
#   '年底人口數': '9936',
#   '土地面積': '59.0102',
#   '人口密度': '168'},
#  {'統計年': '106',
#   '區域別': '屏東縣枋寮鄉',
#   '年底人口數': '24571',
#   '土地面積': '57.7347',
#   '人口密度': '426'},
#  {'統計年': '106',
#   '區域別': '屏東縣新園鄉',
#   '年底人口數': '35321',
#   '土地面積': '38.3109',
#   '人口密度': '922'},
#  {'統計年': '106',
#   '區域別': '屏東縣崁頂鄉',
#   '年底人口數': '15720',
#   '土地面積': '31.2659',
#   '人口密度': '503'},
#  {'統計年': '106',
#   '區域別': '屏東縣林邊鄉',
#   '年底人口數': '18080',
#   '土地面積': '15.6233',
#   '人口密度': '1157'},
#  {'統計年': '106',
#   '區域別': '屏東縣南州鄉',
#   '年底人口數': '10670',
#   '土地面積': '18.97',
#   '人口密度': '562'},
#  {'統計年': '106',
#   '區域別': '屏東縣佳冬鄉',
#   '年底人口數': '19380',
#   '土地面積': '30.9842',
#   '人口密度': '625'},
#  {'統計年': '106',
#   '區域別': '屏東縣琉球鄉',
#   '年底人口數': '12337',
#   '土地面積': '6.8018',
#   '人口密度': '1814'},
#  {'統計年': '106',
#   '區域別': '屏東縣車城鄉',
#   '年底人口數': '8586',
#   '土地面積': '49.8517',
#   '人口密度': '172'},
#  {'統計年': '106',
#   '區域別': '屏東縣滿州鄉',
#   '年底人口數': '7840',
#   '土地面積': '142.2013',
#   '人口密度': '55'},
#  {'統計年': '106',
#   '區域別': '屏東縣枋山鄉',
#   '年底人口數': '5478',
#   '土地面積': '17.2697',
#   '人口密度': '317'},
#  {'統計年': '106',
#   '區域別': '屏東縣三地門鄉',
#   '年底人口數': '7644',
#   '土地面積': '196.3965',
#   '人口密度': '39'},
#  {'統計年': '106',
#   '區域別': '屏東縣霧臺鄉',
#   '年底人口數': '3246',
#   '土地面積': '278.796',
#   '人口密度': '12'},
#  {'統計年': '106',
#   '區域別': '屏東縣瑪家鄉',
#   '年底人口數': '6746',
#   '土地面積': '78.7008',
#   '人口密度': '86'},
#  {'統計年': '106',
#   '區域別': '屏東縣泰武鄉',
#   '年底人口數': '5271',
#   '土地面積': '118.6266',
#   '人口密度': '44'},
#  {'統計年': '106',
#   '區域別': '屏東縣來義鄉',
#   '年底人口數': '7465',
#   '土地面積': '167.7756',
#   '人口密度': '44'},
#  {'統計年': '106',
#   '區域別': '屏東縣春日鄉',
#   '年底人口數': '4867',
#   '土地面積': '160.001',
#   '人口密度': '30'},
#  {'統計年': '106',
#   '區域別': '屏東縣獅子鄉',
#   '年底人口數': '4806',
#   '土地面積': '301.0018',
#   '人口密度': '16'},
#  {'統計年': '106',
#   '區域別': '屏東縣牡丹鄉',
#   '年底人口數': '4926',
#   '土地面積': '181.8366',
#   '人口密度': '27'},
#  {'統計年': '106',
#   '區域別': '臺東縣臺東市',
#   '年底人口數': '105960',
#   '土地面積': '109.7691',
#   '人口密度': '965'},
#  {'統計年': '106',
#   '區域別': '臺東縣成功鎮',
#   '年底人口數': '14238',
#   '土地面積': '143.9939',
#   '人口密度': '99'},
#  {'統計年': '106',
#   '區域別': '臺東縣關山鎮',
#   '年底人口數': '8742',
#   '土地面積': '58.7351',
#   '人口密度': '149'},
#  {'統計年': '106',
#   '區域別': '臺東縣卑南鄉',
#   '年底人口數': '17399',
#   '土地面積': '412.6871',
#   '人口密度': '42'},
#  {'統計年': '106',
#   '區域別': '臺東縣大武鄉',
#   '年底人口數': '6117',
#   '土地面積': '69.1454',
#   '人口密度': '88'},
#  {'統計年': '106',
#   '區域別': '臺東縣太麻里鄉',
#   '年底人口數': '11163',
#   '土地面積': '96.6523',
#   '人口密度': '115'},
#  {'統計年': '106',
#   '區域別': '臺東縣東河鄉',
#   '年底人口數': '8517',
#   '土地面積': '210.1908',
#   '人口密度': '41'},
#  {'統計年': '106',
#   '區域別': '臺東縣長濱鄉',
#   '年底人口數': '7260',
#   '土地面積': '155.1868',
#   '人口密度': '47'},
#  {'統計年': '106',
#   '區域別': '臺東縣鹿野鄉',
#   '年底人口數': '7951',
#   '土地面積': '89.698',
#   '人口密度': '89'},
#  {'統計年': '106',
#   '區域別': '臺東縣池上鄉',
#   '年底人口數': '8248',
#   '土地面積': '82.6854',
#   '人口密度': '100'},
#  {'統計年': '106',
#   '區域別': '臺東縣綠島鄉',
#   '年底人口數': '3926',
#   '土地面積': '15.0919',
#   '人口密度': '260'},
#  {'統計年': '106',
#   '區域別': '臺東縣延平鄉',
#   '年底人口數': '3551',
#   '土地面積': '455.8805',
#   '人口密度': '8'},
#  {'統計年': '106',
#   '區域別': '臺東縣海端鄉',
#   '年底人口數': '4222',
#   '土地面積': '880.0382',
#   '人口密度': '5'},
#  {'統計年': '106',
#   '區域別': '臺東縣達仁鄉',
#   '年底人口數': '3518',
#   '土地面積': '306.4454',
#   '人口密度': '11'},
#  {'統計年': '106',
#   '區域別': '臺東縣金峰鄉',
#   '年底人口數': '3653',
#   '土地面積': '380.6635',
#   '人口密度': '10'},
#  {'統計年': '106',
#   '區域別': '臺東縣蘭嶼鄉',
#   '年底人口數': '5075',
#   '土地面積': '48.3892',
#   '人口密度': '105'},
#  {'統計年': '106',
#   '區域別': '花蓮縣花蓮市',
#   '年底人口數': '104380',
#   '土地面積': '29.4095',
#   '人口密度': '3549'},
#  {'統計年': '106',
#   '區域別': '花蓮縣鳳林鎮',
#   '年底人口數': '10861',
#   '土地面積': '120.5181',
#   '人口密度': '90'},
#  {'統計年': '106',
#   '區域別': '花蓮縣玉里鎮',
#   '年底人口數': '24345',
#   '土地面積': '252.3719',
#   '人口密度': '96'},
#  {'統計年': '106',
#   '區域別': '花蓮縣新城鄉',
#   '年底人口數': '20185',
#   '土地面積': '29.4095',
#   '人口密度': '686'},
#  {'統計年': '106',
#   '區域別': '花蓮縣吉安鄉',
#   '年底人口數': '83747',
#   '土地面積': '65.2582',
#   '人口密度': '1283'},
#  {'統計年': '106',
#   '區域別': '花蓮縣壽豐鄉',
#   '年底人口數': '18043',
#   '土地面積': '218.4448',
#   '人口密度': '83'},
#  {'統計年': '106',
#   '區域別': '花蓮縣光復鄉',
#   '年底人口數': '12888',
#   '土地面積': '157.11',
#   '人口密度': '82'},
#  {'統計年': '106',
#   '區域別': '花蓮縣豐濱鄉',
#   '年底人口數': '4383',
#   '土地面積': '162.4332',
#   '人口密度': '27'},
#  {'統計年': '106',
#   '區域別': '花蓮縣瑞穗鄉',
#   '年底人口數': '11653',
#   '土地面積': '135.5862',
#   '人口密度': '86'},
#  {'統計年': '106',
#   '區域別': '花蓮縣富里鄉',
#   '年底人口數': '10413',
#   '土地面積': '176.3705',
#   '人口密度': '59'},
#  {'統計年': '106',
#   '區域別': '花蓮縣秀林鄉',
#   '年底人口數': '15889',
#   '土地面積': '1641.8555',
#   '人口密度': '10'},
#  {'統計年': '106',
#   '區域別': '花蓮縣萬榮鄉',
#   '年底人口數': '6384',
#   '土地面積': '618.491',
#   '人口密度': '10'},
#  {'統計年': '106',
#   '區域別': '花蓮縣卓溪鄉',
#   '年底人口數': '6066',
#   '土地面積': '1021.313',
#   '人口密度': '6'},
#  {'統計年': '106',
#   '區域別': '澎湖縣馬公市',
#   '年底人口數': '62308',
#   '土地面積': '33.9918',
#   '人口密度': '1833'},
#  {'統計年': '106',
#   '區域別': '澎湖縣湖西鄉',
#   '年底人口數': '14508',
#   '土地面積': '33.3008',
#   '人口密度': '436'},
#  {'統計年': '106',
#   '區域別': '澎湖縣白沙鄉',
#   '年底人口數': '9817',
#   '土地面積': '20.0875',
#   '人口密度': '489'},
#  {'統計年': '106',
#   '區域別': '澎湖縣西嶼鄉',
#   '年底人口數': '8408',
#   '土地面積': '18.7148',
#   '人口密度': '449'},
#  {'統計年': '106',
#   '區域別': '澎湖縣望安鄉',
#   '年底人口數': '5176',
#   '土地面積': '13.7824',
#   '人口密度': '376'},
#  {'統計年': '106',
#   '區域別': '澎湖縣七美鄉',
#   '年底人口數': '3856',
#   '土地面積': '6.9868',
#   '人口密度': '552'},
#  {'統計年': '106',
#   '區域別': '基隆市中正區',
#   '年底人口數': '52163',
#   '土地面積': '10.2118',
#   '人口密度': '5108'},
#  {'統計年': '106',
#   '區域別': '基隆市七堵區',
#   '年底人口數': '53972',
#   '土地面積': '56.2659',
#   '人口密度': '959'},
#  {'統計年': '106',
#   '區域別': '基隆市暖暖區',
#   '年底人口數': '38708',
#   '土地面積': '22.8283',
#   '人口密度': '1696'},
#  {'統計年': '106',
#   '區域別': '基隆市仁愛區',
#   '年底人口數': '44314',
#   '土地面積': '4.2335',
#   '人口密度': '10467'},
#  {'統計年': '106',
#   '區域別': '基隆市中山區',
#   '年底人口數': '47908',
#   '土地面積': '10.5238',
#   '人口密度': '4552'},
#  {'統計年': '106',
#   '區域別': '基隆市安樂區',
#   '年底人口數': '82358',
#   '土地面積': '18.025',
#   '人口密度': '4569'},
#  {'統計年': '106',
#   '區域別': '基隆市信義區',
#   '年底人口數': '52035',
#   '土地面積': '10.6706',
#   '人口密度': '4876'},
#  {'統計年': '106',
#   '區域別': '新竹市東區',
#   '年底人口數': '212553',
#   '土地面積': '33.5768',
#   '人口密度': '6330'},
#  {'統計年': '106',
#   '區域別': '新竹市北區',
#   '年底人口數': '150636',
#   '土地面積': '15.7267',
#   '人口密度': '9578'},
#  {'統計年': '106',
#   '區域別': '新竹市香山區',
#   '年底人口數': '77943',
#   '土地面積': '54.8491',
#   '人口密度': '1421'},
#  {'統計年': '106',
#   '區域別': '嘉義市東區',
#   '年底人口數': '122103',
#   '土地面積': '30.1556',
#   '人口密度': '4049'},
#  {'統計年': '106',
#   '區域別': '嘉義市西區',
#   '年底人口數': '147295',
#   '土地面積': '29.87',
#   '人口密度': '4931'},
#  {'統計年': '106',
#   '區域別': '金門縣金城鎮',
#   '年底人口數': '43285',
#   '土地面積': '21.713',
#   '人口密度': '1994'},
#  {'統計年': '106',
#   '區域別': '金門縣金湖鎮',
#   '年底人口數': '29413',
#   '土地面積': '41.696',
#   '人口密度': '705'},
#  {'統計年': '106',
#   '區域別': '金門縣金沙鎮',
#   '年底人口數': '20535',
#   '土地面積': '41.19',
#   '人口密度': '499'},
#  {'統計年': '106',
#   '區域別': '金門縣金寧鄉',
#   '年底人口數': '30838',
#   '土地面積': '29.854',
#   '人口密度': '1033'},
#  {'統計年': '106',
#   '區域別': '金門縣烈嶼鄉',
#   '年底人口數': '12700',
#   '土地面積': '16.003',
#   '人口密度': '794'},
#  {'統計年': '106', '區域別': '金門縣烏坵鄉', '年底人口數': '685', '土地面積': '1.2', '人口密度': '571'},
#  {'統計年': '106',
#   '區域別': '連江縣南竿鄉',
#   '年底人口數': '7544',
#   '土地面積': '10.4',
#   '人口密度': '725'},
#  {'統計年': '106',
#   '區域別': '連江縣北竿鄉',
#   '年底人口數': '2360',
#   '土地面積': '9.9',
#   '人口密度': '238'},
#  {'統計年': '106',
#   '區域別': '連江縣莒光鄉',
#   '年底人口數': '1624',
#   '土地面積': '4.7',
#   '人口密度': '346'},
#  {'統計年': '106',
#   '區域別': '連江縣東引鄉',
#   '年底人口數': '1352',
#   '土地面積': '3.8',
#   '人口密度': '356'},
#  {'統計年': '106', '區域別': '東沙群島', '年底人口數': '… ', '土地面積': '2.38', '人口密度': '… '},
#  {'統計年': '106', '區域別': '南沙群島', '年底人口數': '… ', '土地面積': '0.5045', '人口密度': '… '},
#  {'統計年': '', '區域別': '', '年底人口數': '', '土地面積': '', '人口密度': ''},
#  {'統計年': '',
#   '區域別': '說明：1.人口密度係指每單位土地面積內之人口數。',
#   '年底人口數': '',
#   '土地面積': '',
#   '人口密度': ''},
#  {'統計年': '',
#   '區域別': '2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)',
#   '年底人口數': '',
#   '土地面積': '',
#   '人口密度': ''},
#  {'統計年': '',
#   '區域別': '，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。',
#   '年底人口數': '',
#   '土地面積': '',
#   '人口密度': ''},
#  {'統計年': '',
#   '區域別': '3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。',
#   '年底人口數': '',
#   '土地面積': '',
#   '人口密度': ''}]
