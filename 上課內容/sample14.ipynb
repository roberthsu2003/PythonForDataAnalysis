# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

data = [5, -4.3, 15, 21, 50]
plt.figure(num=3, figsize=(8,5))
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.plot([5, 10, 15, 20 ,25],[15, 30, 40, 60, 100])
# Out:
# <img src="data:image/png;base64,..." width="640">
