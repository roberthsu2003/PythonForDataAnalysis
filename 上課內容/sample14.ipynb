# %%
import matplotlib.pyplot as plt
import weather
data = [-1, -4.3, 15, 21, 31]
plt.figure(num=3, figsize=(8,5))
plt.plot(data)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
