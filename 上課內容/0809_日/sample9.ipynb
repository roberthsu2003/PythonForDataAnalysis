# %%
import random

students = list()
for i in range(1,51):
    scores = []
    scores.append('stu'+str(i))
    for _ in range(5):
        r = random.randint(50,100)
        scores.append(r)
    students.append(scores)
    
file=open('students.txt','w',encoding='utf-8')
file.write(str(students))
file.close()

# %%
#open()
#建立txt檔
text = '''python與中文
1. 我們來試試看中文儲存能力。
2. 許這個字會有編碼衝突風險。
3. 犇這個字必須是utf8編碼才有。
'''
file=open('data.txt','w',encoding='utf-8')
file.write(text)
file.close()

# %%
#讀取檔案
file=open('data.txt','r',encoding='utf-8')
content=file.read()
print(content)
file.close()
# Out:
# python與中文
# 1. 我們來試試看中文儲存能力。
# 2. 許這個字會有編碼衝突風險。
# 3. 犇這個字必須是utf8編碼才有。

# %%
#讀取檔案
#一筆一筆的資料不適合存成txt
file=open('students.txt','r',encoding='utf-8')
content=file.read()
content = list(content)
print(content)
file.close()
# Out:
# ['[', '[', "'", 's', 't', 'u', '1', "'", ',', ' ', '7', '8', ',', ' ', '5', '4', ',', ' ', '8', '3', ',', ' ', '5', '3', ',', ' ', '5', '7', ']', ',', ' ', '[', "'", 's', 't', 'u', '2', "'", ',', ' ', '6', '2', ',', ' ', '8', '5', ',', ' ', '8', '8', ',', ' ', '6', '7', ',', ' ', '6', '8', ']', ',', ' ', '[', "'", 's', 't', 'u', '3', "'", ',', ' ', '8', '0', ',', ' ', '9', '0', ',', ' ', '5', '6', ',', ' ', '8', '7', ',', ' ', '6', '4', ']', ',', ' ', '[', "'", 's', 't', 'u', '4', "'", ',', ' ', '5', '9', ',', ' ', '9', '5', ',', ' ', '8', '4', ',', ' ', '5', '4', ',', ' ', '7', '9', ']', ',', ' ', '[', "'", 's', 't', 'u', '5', "'", ',', ' ', '7', '8', ',', ' ', '5', '6', ',', ' ', '9', '3', ',', ' ', '5', '0', ',', ' ', '7', '1', ']', ',', ' ', '[', "'", 's', 't', 'u', '6', "'", ',', ' ', '5', '9', ',', ' ', '5', '6', ',', ' ', '7', '3', ',', ' ', '6', '8', ',', ' ', '7', '1', ']', ',', ' ', '[', "'", 's', 't', 'u', '7', "'", ',', ' ', '7', '5', ',', ' ', '7', '8', ',', ' ', '8', '9', ',', ' ', '7', '3', ',', ' ', '5', '7', ']', ',', ' ', '[', "'", 's', 't', 'u', '8', "'", ',', ' ', '9', '7', ',', ' ', '8', '2', ',', ' ', '6', '8', ',', ' ', '6', '7', ',', ' ', '9', '8', ']', ',', ' ', '[', "'", 's', 't', 'u', '9', "'", ',', ' ', '6', '5', ',', ' ', '7', '9', ',', ' ', '9', '1', ',', ' ', '6', '1', ',', ' ', '8', '5', ']', ',', ' ', '[', "'", 's', 't', 'u', '1', '0', "'", ',', ' ', '6', '4', ',', ' ', '7', '8', ',', ' ', '9', '8', ',', ' ', '8', '8', ',', ' ', '8', '0', ']', ',', ' ', '[', "'", 's', 't', 'u', '1', '1', "'", ',', ' ', '7', '7', ',', ' ', '9', '9', ',', ' ', '6', '7', ',', ' ', '9', '3', ',', ' ', '5', '9', ']',