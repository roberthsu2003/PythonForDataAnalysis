# %%
import urllib3
import certifi
import csv


#CSV_URL = "http://opendata.epa.gov.tw/webapi/Data/REWIQA/?$orderby=SiteName&$skip=0&$top=1000&format=csv"
#下載並存檔
CSV_URL = "http://opendata.epa.gov.tw/webapi/Data/REWIQA/?$orderby=SiteName&$skip=0&$top=1000&format=csv"
http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
r = http.request('GET', CSV_URL)
if r.status == 200:
    with open('空氣品質指標.csv','wb') as f:
        f.write(r.data)
        f.close()
else:
    print('下載錯誤')

# %%
import pandas as pd
aqiDataFrame = pd.read_csv('空氣品質指標.csv')
aqiDataFrame
# Out:
#    SiteName County  AQI Pollutant Status  SO2    CO  CO_8hr   O3  O3_8hr  ...  \
# 0        二林    彰化縣   47       NaN     良好  3.6  0.19     0.2   20    20.0  ...
# 1        三重    新北市   31       NaN     良好  1.0   0.7     0.5    -     NaN  ...
# 2        三義    苗栗縣   21       NaN     良好  1.4  0.15     0.2   20    23.0  ...
# 3        土城    新北市   27       NaN     良好  2.0  0.26     0.2   22    29.0  ...
# 4        士林    臺北市   35       NaN     良好  2.1  0.18     0.1   33    38.0  ...
# ..      ...    ...  ...       ...    ...  ...   ...     ...  ...     ...  ...
# 76       頭份    苗栗縣   22       NaN     良好  1.8  0.24     0.2  5.8    16.0  ...
# 77       龍潭    桃園市   31       NaN     良好  2.3  0.22     0.2   31    34.0  ...
# 78       豐原    臺中市   35       NaN     良好  1.7  0.31     0.2  7.3    12.0  ...
# 79       關山    臺東縣   21       NaN     良好  1.3     -     NaN   20    23.0  ...
# 80       觀音    桃園市   33       NaN     良好  3.0  0.18     0.2   37    36.0  ...
#
#       NO WindSpeed  WindDirec       PublishTime  PM2.5_AVG  PM10_AVG  SO2_AVG  \
# 0    1.1       2.9       45.0  2020-10-11 07:00         11        51        5
# 1   19.0       NaN        NaN  2020-10-11 07:00         10        17        1
# 2    0.4       2.9       21.0  2020-10-11 07:00          4        12        2
# 3    1.8       0.6      141.0  2020-10-11 07:00          6        13        1
# 4    1.1       2.4      118.0  2020-10-11 07:00          4        10        2
# ..   ...       ...        ...               ...        ...       ...      ...
# 76   1.8       0.9      113.0  2020-10-11 07:00          7        15        2
# 77   1.5       4.1       55.0  2020-10-11 07:00          5        13        2
# 78   2.8       1.0       45.0  2020-10-11 07:00         11        15        1
# 79   1.5       1.0       84.0  2020-10-11 07:00          6        16        2
# 80   1.6       5.9       69.0  2020-10-11 07:00          9        29        3
#
#      Longitude   Latitude  SiteId
# 0   120.409653  23.925175      35
# 1   121.493806  25.072611      67
# 2   120.758833  24.382942      27
# 3   121.451861  24.982528       5
# 4   121.515389  25.105417      11
# ..         ...        ...     ...
# 76  120.898572  24.696969      25
# 77  121.216350  24.863869      21
# 78  120.741711  24.256586      28
# 79  121.161933  23.045083      80
# 80  121.082761  25.035503      19
#
# [81 rows x 24 columns]
