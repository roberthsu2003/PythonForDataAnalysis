# %%
# %matplotlib notebook
import numpy as np
import math
import matplotlib.pyplot as plt


t = np.arange(0, 2.5, 0.1)
y1=np.sin(t * math.pi)
y2=np.sin(t * math.pi + math.pi/2)
y3=np.sin(t * math.pi - math.pi/2)
plt.plot(t,y1,'b*',t,y2,'g^',t,y3,'ys')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7ff3a1344160>,
#  <matplotlib.lines.Line2D at 0x7ff3a1344040>,
#  <matplotlib.lines.Line2D at 0x7ff3a1344190>]

# %%
#展示線的樣式
# %matplotlib notebook
plt.plot(t, y1, 'b--', t, y2, 'g', t, y3, 'r-.')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7ff3b0be5190>,
#  <matplotlib.lines.Line2D at 0x7ff3b0be5040>,
#  <matplotlib.lines.Line2D at 0x7ff3b0be51c0>]

# %%
# %matplotlib notebook
plt.plot([1, 2, 4, 2, 1, 0, 1, 2, 1, 4], linewidth=3.0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#subplot()可顯示1個figure 多個Axes
#第一個參數垂直分割
#第二個參數水平分割
#第三個選擇那一個
# %matplotlib notebook
t = np.arange(0, 5, 0.1)
y1 = np.sin(2 * np.pi * t)
y2 = np.sin(2*np.pi*t)

plt.subplot(211)
plt.plot(t, y1, 'b-.')
plt.subplot(212)
plt.plot(t, y2, 'r--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#subplot()可顯示1個figure 多個Axes
#第一個參數垂直分割
#第二個參數水平分割
#第三個選擇那一個
# %matplotlib notebook
t = np.arange(0, 1, 0.01)
y1 = np.sin(2 * np.pi * t)
y2 = np.sin(2*np.pi*t)

plt.subplot(121)
plt.plot(t, y1, 'b-.')
plt.subplot(122)
plt.plot(t, y2, 'r--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#增加元素至圖表內
# title()
# xlabel()
# ylabel()

# %matplotlib notebook
plt.axis([0, 5, 0, 20])
plt.title("My First Plot")
plt.xlabel('Counting')
plt.ylabel('Square values')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#2位學生分數,畫線圖
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
subs = ['chinese','english','math','graphic', 'history']

plt.title('students')
plt.xlabel('subject')
plt.ylabel('score')
students=np.random.randint(50,101,size=(2, 5))
plt.plot(subs,students[0,:],'ro-',subs,students[1,:],'go-')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x7ff3916fc8b0>,
#  <matplotlib.lines.Line2D at 0x7ff3916fc790>]
