# %%
# 請處理(新北市公共自行車租賃系統.json)
# google搜尋online json viewer
#api接口:https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000

import urllib3
import certifi
import json
import pandas as pd

http = urllib3.PoolManager(cert_reqs='CERT_REQUIRED',ca_certs=certifi.where())
r = http.request('GET', 'https://data.ntpc.gov.tw/api/datasets/71CD1490-A2DF-4198-BEF1-318479775E8A/json?page=0&size=1000')
if r.status == 200:
    records = json.loads(r.data.decode('utf-8'))    
else:
    print("下載失敗")

allRecords=pd.DataFrame(records,columns=['sna','tot','sbi', 'sarea', 'ar', 'bemp'])
allRecords=allRecords.rename(columns={'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還'})
# Out:
#              站名  數量  可借   區域                               地址  可還
# 0          大鵬華城  38  14  新店區                  新北市新店區中正路700巷3號  24
# 1         汐止火車站  56  36  汐止區                   南昌街/新昌路口(西側廣場)  20
# 2         汐止區公所  46  25  汐止區  新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)  20
# 3        國泰綜合醫院  56  26  汐止區                      建成路78號對面停車場  30
# 4          裕隆公園  40  19  新店區                    寶中路/品牌路口(東南側)  21
# ..          ...  ..  ..  ...                              ...  ..
# 626      中華城林路口  44  17  土城區                     中華路二段175號(前)  27
# 627      中山八德街口  32   9  樹林區                    中山路二段10號對面人行道  23
# 628     輕軌漁人碼頭站  50   4  淡水區            中正路二段/中正路二段51巷口(輕軌站旁)  46
# 629  凌雲路一段158巷口  30   5  五股區                 凌雲路一段158巷22號(對面)  25
# 630       深坑雲鄉路  16   1  深坑區                  雲鄉路1號(旁橋下汽車停車格)  15
#
# [631 rows x 6 columns]

# %%
allRecords.dtypes
# Out:
# 站名    object
# 數量    object
# 可借    object
# 區域    object
# 地址    object
# 可還    object
# dtype: object

# %%
allRecords[['數量','可借','可還']]=allRecords[['數量','可借','可還']].astype(int)
allRecords.dtypes
# Out:
# 站名    object
# 數量     int64
# 可借     int64
# 區域    object
# 地址    object
# 可還     int64
# dtype: object

# %%
allRecords
# Out:
#              站名  數量  可借   區域                               地址  可還
# 0          大鵬華城  38  14  新店區                  新北市新店區中正路700巷3號  24
# 1         汐止火車站  56  36  汐止區                   南昌街/新昌路口(西側廣場)  20
# 2         汐止區公所  46  25  汐止區  新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)  20
# 3        國泰綜合醫院  56  26  汐止區                      建成路78號對面停車場  30
# 4          裕隆公園  40  19  新店區                    寶中路/品牌路口(東南側)  21
# ..          ...  ..  ..  ...                              ...  ..
# 626      中華城林路口  44  17  土城區                     中華路二段175號(前)  27
# 627      中山八德街口  32   9  樹林區                    中山路二段10號對面人行道  23
# 628     輕軌漁人碼頭站  50   4  淡水區            中正路二段/中正路二段51巷口(輕軌站旁)  46
# 629  凌雲路一段158巷口  30   5  五股區                 凌雲路一段158巷22號(對面)  25
# 630       深坑雲鄉路  16   1  深坑區                  雲鄉路1號(旁橋下汽車停車格)  15
#
# [631 rows x 6 columns]

# %%
allRecords['故障'] = allRecords['數量'] - (allRecords['可借'] + allRecords['可還'])
allRecords['故障率'] = allRecords['故障'] / allRecords['數量']
allRecords
# Out:
#              站名  數量  可借   區域                               地址  可還  故障  \
# 0          大鵬華城  38  14  新店區                  新北市新店區中正路700巷3號  24   0
# 1         汐止火車站  56  36  汐止區                   南昌街/新昌路口(西側廣場)  20   0
# 2         汐止區公所  46  25  汐止區  新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)  20   1
# 3        國泰綜合醫院  56  26  汐止區                      建成路78號對面停車場  30   0
# 4          裕隆公園  40  19  新店區                    寶中路/品牌路口(東南側)  21   0
# ..          ...  ..  ..  ...                              ...  ..  ..
# 626      中華城林路口  44  17  土城區                     中華路二段175號(前)  27   0
# 627      中山八德街口  32   9  樹林區                    中山路二段10號對面人行道  23   0
# 628     輕軌漁人碼頭站  50   4  淡水區            中正路二段/中正路二段51巷口(輕軌站旁)  46   0
# 629  凌雲路一段158巷口  30   5  五股區                 凌雲路一段158巷22號(對面)  25   0
# 630       深坑雲鄉路  16   1  深坑區                  雲鄉路1號(旁橋下汽車停車格)  15   0
#
#           故障率
# 0    0.000000
# 1    0.000000
# 2    0.021739
# 3    0.000000
# 4    0.000000
# ..        ...
# 626  0.000000
# 627  0.000000
# 628  0.000000
# 629  0.000000
# 630  0.000000
#
# [631 rows x 8 columns]

# %%
grouped = allRecords.groupby('區域')
result = grouped[['數量','可還', '可借','故障']].sum()
result
# Out:
#        數量    可還    可借   故障
# 區域
# 三峽區   750   376   365    9
# 三芝區    50    39    11    0
# 三重區  2624  1855   704   65
# 中和區  2176  1092  1035   49
# 五股區   690   435   250    5
# 八里區   224   192    32    0
# 土城區  1490   919   497   74
# 新店區  2020  1028   969   23
# 新莊區  2460  1595   808   57
# 板橋區  4196  2433  1656  107
# 林口區  1206   743   452   11
# 樹林區  1314   926   349   39
# 永和區  1010   582   388   40
# 汐止區  1782   907   860   15
# 泰山區   462   342   117    3
# 淡水區  1254   706   504   44
# 深坑區   134    76    54    4
# 瑞芳區   166   113    52    1
# 石門區    50    39    11    0
# 萬里區    50    27    23    0
# 蘆洲區  1164   797   328   39
# 金山區   102    84    18    0
# 鶯歌區   702   384   262   56
