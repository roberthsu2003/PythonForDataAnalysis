# %%
#練習建立學生成績單
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
scores_pd = pd.DataFrame(scores,columns=['國文', '英文', '數學', '地理', '歷史'],index=range(1,51))
scores_pd.index.name="學號"
scores_pd.columns.name="科目"

# %%
#一直列(整欄)
scores_pd.sum()
# Out:
# 科目
# 國文    3798
# 英文    3772
# 數學    3726
# 地理    3817
# 歷史    3695
# dtype: int64

# %%
#1號學生的總分
scores_pd.loc[1].sum()
# Out:
# 325

# %%
#1號學生的平均
scores_pd.loc[1].mean()
# Out:
# 65.0

# %%
sum_values = scores_pd.sum(axis=1)
avg_values = scores_pd.mean(axis=1)
scores_pd['總分'] = sum_values
scores_pd['平均'] = avg_values
scores_pd
# Out:
# 科目   國文   英文   數學  地理   歷史   總分    平均
# 學號
# 1    67   77   61  68   52  325  65.0
# 2    89   87   57  98   70  401  80.2
# 3    94   75   98  53   52  372  74.4
# 4    62   60   60  64   54  300  60.0
# 5    99   65   89  65   75  393  78.6
# 6    83   50   78  91   81  383  76.6
# 7    53   71   72  83   80  359  71.8
# 8    81   53   70  66   69  339  67.8
# 9    76   74   53  62   81  346  69.2
# 10   52   85   64  93   77  371  74.2
# 11   57   82   90  54   61  344  68.8
# 12   83   72   63  64   78  360  72.0
# 13   50   96   97  66   75  384  76.8
# 14   83  100   56  77   71  387  77.4
# 15   56   52  100  89   78  375  75.0
# 16   92   51   68  98   54  363  72.6
# 17  100   62   85  59   90  396  79.2
# 18   88   98   94  96   90  466  93.2
# 19   56   58   67  88   84  353  70.6
# 20   62   73   83  79   86  383  76.6
# 21   86  100   87  64   64  401  80.2
# 22   65   83   93  58   88  387  77.4
# 23   75   60   85  65   57  342  68.4
# 24   73   92   53  69   59  346  69.2
# 25  100   56   73  71   50  350  70.0
# 26   59   60   74  98  100  391  78.2
# 27   86   73   57  86   88  390  78.0
# 28   57   74   90  89   71  381  76.2
# 29   56   93   87  91   94  421  84.2
# 30   93   95   77  96   64  425  85.0
# 31   97   67   70  74   68  376  75.2
# 32   93   86   64  85   86  414  82.8
# 33   51   50  100  75   84  360  72.0
# 34   66   95   64  82   86  393  78.6
# 35   93   97   80  66   61  397  79.4
# 36   65   80   69  79   96  389  77.8
# 37   91   75   62  53   59  340  68.0
# 38   72   63   72  98   81  386  77.2
# 39   96   88   82  77   99  442  88.4
# 40   67   84   84  84   51  370  74.0
# 41   60   50   60  87   59  316  63.2
# 42   78   93   75  82   93  421  84.2
# 43   70   94   56  60   51  331  66.2
# 44   93   91   53  64   97  398  79.6
# 45   82   67   62  97   53  361  72.2
# 46   85   52   89  77   72  375  75.0
# 47   79   68   59  58   86  350  70.0
# 48   66   80   60  64   75  345  69.0
# 49   92   99   98  77   50  416  83.2
# 50   69   66   86  78   95  394  78.8
