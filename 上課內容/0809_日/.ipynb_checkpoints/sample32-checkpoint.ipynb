# %%
import numpy as np
import pandas as pd
dataFrame=pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame.iloc[:100]
# Out:
#    statistic_yyy site_id people_total      area population_density
# 0            統計年     區域別        年底人口數      土地面積               人口密度
# 1            106  新北市板橋區       551480   23.1373              23835
# 2            106  新北市三重區       387484    16.317              23747
# 3            106  新北市中和區       413590    20.144              20532
# 4            106  新北市永和區       222585    5.7138              38956
# ..           ...     ...          ...       ...                ...
# 95           106  臺南市佳里區        59380   38.9422               1525
# 96           106  臺南市學甲區        26078   53.9919                483
# 97           106  臺南市西港區        24758   33.7666                733
# 98           106  臺南市七股區        22974  110.1492                209
# 99           106  臺南市將軍區        19849   41.9796                473
#
# [100 rows x 5 columns]

# %%
dataFrame.columns = dataFrame.iloc[0]
dataFrame
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 0     人口密度
# 1    23835
# 2    23747
# 3    20532
# 4    38956
# ..     ...
# 371    NaN
# 372    NaN
# 373    NaN
# 374    NaN
# 375    NaN
#
# [376 rows x 5 columns]

# %%
dataFrame = dataFrame.iloc[1:-5]
dataFrame
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
def a1(x):
    if len(x) > 4:
        return x[:3]
    else:
        return x
    
states=dataFrame['區域別'].map(lambda x:x[:3] if len(x)> 4 else x)
dataFrame['縣市'] = states
dataFrame
# Out:
# <ipython-input-64-5b580d92fe38>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataFrame['縣市'] = states
# 0    統計年     區域別   年底人口數     土地面積   人口密度    縣市
# 1    106  新北市板橋區  551480  23.1373  23835   新北市
# 2    106  新北市三重區  387484   16.317  23747   新北市
# 3    106  新北市中和區  413590   20.144  20532   新北市
# 4    106  新北市永和區  222585   5.7138  38956   新北市
# 5    106  新北市新莊區  416524  19.7383  21102   新北市
# ..   ...     ...     ...      ...    ...   ...
# 366  106  連江縣北竿鄉    2360      9.9    238   連江縣
# 367  106  連江縣莒光鄉    1624      4.7    346   連江縣
# 368  106  連江縣東引鄉    1352      3.8    356   連江縣
# 369  106    東沙群島      …      2.38     …   東沙群島
# 370  106    南沙群島      …    0.5045     …   南沙群島
#
# [370 rows x 6 columns]

# %%
dataFrame=dataFrame.reindex(columns=['縣市','年底人口數','土地面積'])
dataFrame
# Out:
# 0      縣市   年底人口數     土地面積
# 1     新北市  551480  23.1373
# 2     新北市  387484   16.317
# 3     新北市  413590   20.144
# 4     新北市  222585   5.7138
# 5     新北市  416524  19.7383
# ..    ...     ...      ...
# 366   連江縣    2360      9.9
# 367   連江縣    1624      4.7
# 368   連江縣    1352      3.8
# 369  東沙群島      …      2.38
# 370  南沙群島      …    0.5045
#
# [370 rows x 3 columns]

# %%
dataFrame.dtypes
# Out:
# 0
# 縣市       object
# 年底人口數    object
# 土地面積     object
# dtype: object

# %%
def toInt(x):
    try:
        return int(x)
    except:
        return 0


dataFrame['年底人口數']=dataFrame['年底人口數'].map(toInt)
dataFrame
# Out:
# 0      縣市   年底人口數     土地面積
# 1     新北市  551480  23.1373
# 2     新北市  387484   16.317
# 3     新北市  413590   20.144
# 4     新北市  222585   5.7138
# 5     新北市  416524  19.7383
# ..    ...     ...      ...
# 366   連江縣    2360      9.9
# 367   連江縣    1624      4.7
# 368   連江縣    1352      3.8
# 369  東沙群島       0     2.38
# 370  南沙群島       0   0.5045
#
# [370 rows x 3 columns]

# %%
dataFrame['土地面積']=dataFrame['土地面積'].map(lambda x:float(x))
dataFrame.dtypes
# Out:
# 0
# 縣市        object
# 年底人口數      int64
# 土地面積     float64
# dtype: object

# %%
allDict=dict(list(dataFrame.groupby('縣市')))
allDict['新北市']
# Out:
# 0    縣市   年底人口數      土地面積
# 1   新北市  551480   23.1373
# 2   新北市  387484   16.3170
# 3   新北市  413590   20.1440
# 4   新北市  222585    5.7138
# 5   新北市  416524   19.7383
# 6   新北市  302089  120.2255
# 7   新北市  184149   33.1288
# 8   新北市   86593   21.1248
# 9   新北市  114926  191.4508
# 10  新北市  169597   70.6565
# 11  新北市  199321   71.2354
# 12  新北市   40353   70.7336
# 13  新北市  238067   29.5578
# 14  新北市  201309    7.4351
# 15  新北市   84919   34.8632
# 16  新北市   78911   19.1603
# 17  新北市  106101   54.1519
# 18  新北市   23660   20.5787
# 19  新北市    7683  144.3498
# 20  新北市    6528  170.8350
# 21  新北市   23200   65.9909
# 22  新北市   12286   51.2645
# 23  新北市   38493   39.4933
# 24  新北市    4719   71.3382
# 25  新北市    8939  146.2484
# 26  新北市   12552   99.9734
# 27  新北市   22015   49.2132
# 28  新北市   22296   63.3766
# 29  新北市    6320  321.1306

# %%
resultData=dataFrame.groupby('縣市').sum()
resultData
# Out:
# 0       年底人口數       土地面積
# 縣市
# 南投縣    501051  4106.4360
# 南沙群島        0     0.5045
# 嘉義市    269398    60.0256
# 嘉義縣    511182  1903.6367
# 基隆市    371458   132.7589
# 宜蘭縣    456607  2143.6251
# 屏東縣    829939  2775.6003
# 彰化縣   1282458  1074.3960
# 新北市   3986689  2052.5667
# 新竹市    441132   104.1526
# 新竹縣    552169  1427.5369
# 東沙群島        0     2.3800
# 桃園市   2188017  1220.9540
# 澎湖縣    104073   126.8641
# 臺中市   2787070  2214.8968
# 臺北市   2683257   271.7997
# 臺南市   1886522  2191.6531
# 臺東縣    219540  3515.2526
# 花蓮縣    329237  4628.5714
# 苗栗縣    553807  1820.3149
# 連江縣     12880    28.8000
# 金門縣    137456   151.6560
# 雲林縣    690373  1290.8326
# 高雄市   2776912  2951.8524

# %%
resultData.sort_values(by='年底人口數',ascending=False)
# Out:
# 0       年底人口數       土地面積
# 縣市
# 新北市   3986689  2052.5667
# 臺中市   2787070  2214.8968
# 高雄市   2776912  2951.8524
# 臺北市   2683257   271.7997
# 桃園市   2188017  1220.9540
# 臺南市   1886522  2191.6531
# 彰化縣   1282458  1074.3960
# 屏東縣    829939  2775.6003
# 雲林縣    690373  1290.8326
# 苗栗縣    553807  1820.3149
# 新竹縣    552169  1427.5369
# 嘉義縣    511182  1903.6367
# 南投縣    501051  4106.4360
# 宜蘭縣    456607  2143.6251
# 新竹市    441132   104.1526
# 基隆市    371458   132.7589
# 花蓮縣    329237  4628.5714
# 嘉義市    269398    60.0256
# 臺東縣    219540  3515.2526
# 金門縣    137456   151.6560
# 澎湖縣    104073   126.8641
# 連江縣     12880    28.8000
# 南沙群島        0     0.5045
# 東沙群島        0     2.3800
