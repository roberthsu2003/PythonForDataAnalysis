# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one -0.987247 -0.334008
# 1    a  two -0.826163  0.891835
# 2    b  one  2.063263  0.587019
# 3    b  two  0.255783 -1.520441
# 4    a  one  1.166981 -0.539635

# %%
grouped = df.groupby('key1')
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    0.768352
# b    1.882515
# Name: data1, dtype: float64

# %%
#agg(function)可以自已做統計
#自訂的apple
#這範例只有傳回一個數值
def peak_to_peak(arr):
    return arr.max() - arr.min()
    
grouped.agg(peak_to_peak)
# Out:
#          data1     data2
# key1
# a     2.154228  1.431469
# b     1.807480  2.107461

# %%
#這是傳回一個Series
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -0.215476  1.199949 -0.987247 -0.906705 -0.826163  0.170409
# b      2.0  1.159523  1.278081  0.255783  0.707653  1.159523  1.611393
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     1.166981   3.0  0.006064  0.773959 -0.539635 -0.436821 -0.334008
# b     2.063263   2.0 -0.466711  1.490200 -1.520441 -0.993576 -0.466711
#
#
#            75%       max
# key1
# a     0.278913  0.891835
# b     0.060154  0.587019
