# %%
import numpy as np
import pandas as pd

dataFrame = pd.read_csv('各鄉鎮市區人口密度.csv')
dataFrame
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             106                                             新北市板橋區
# 2             106                                             新北市三重區
# 3             106                                             新北市中和區
# 4             106                                             新北市永和區
# ..            ...                                                ...
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         551480  23.1373              23835
# ...

# %%
#如果欄位是整數,但傳出的是object,整欄無法全部轉成整數
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   statistic_yyy       371 non-null    object
#  1   site_id             375 non-null    object
#  2   people_total        371 non-null    object
#  3   area                371 non-null    object
#  4   population_density  371 non-null    object
# dtypes: object(5)
# memory usage: 14.8+ KB

# %%
#改變欄位名
dataFrame.columns = dataFrame.iloc[0]
dataFrame
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 0    統計年                                                區域別   年底人口數     土地面積
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 0     人口密度
# 1    23835
# ...

# %%
#清除第一列
dataFrame1 = dataFrame.drop(labels=0)
dataFrame1
# Out:
# 0    統計年                                                區域別   年底人口數     土地面積  \
# 1    106                                             新北市板橋區  551480  23.1373
# 2    106                                             新北市三重區  387484   16.317
# 3    106                                             新北市中和區  413590   20.144
# 4    106                                             新北市永和區  222585   5.7138
# 5    106                                             新北市新莊區  416524  19.7383
# ..   ...                                                ...     ...      ...
# 371  NaN                                                NaN     NaN      NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。     NaN      NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)     NaN      NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。     NaN      NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。     NaN      NaN
#
# 0     人口密度
# 1    23835
# 2    23747
# ...

# %%
dataFrame1.iloc[-10:]
# Out:
# 0    統計年                                                區域別 年底人口數    土地面積 人口密度
# 366  106                                             連江縣北竿鄉  2360     9.9  238
# 367  106                                             連江縣莒光鄉  1624     4.7  346
# 368  106                                             連江縣東引鄉  1352     3.8  356
# 369  106                                               東沙群島    …     2.38   …
# 370  106                                               南沙群島    …   0.5045   …
# 371  NaN                                                NaN   NaN     NaN  NaN
# 372  NaN                           說明：1.人口密度係指每單位土地面積內之人口數。   NaN     NaN  NaN
# 373  NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)   NaN     NaN  NaN
# 374  NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。   NaN     NaN  NaN
# 375  NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。   NaN     NaN  NaN

# %%
#移除後面不要的列
dataFrame2 = dataFrame1.dropna()
dataFrame3=dataFrame2.drop(labels=[369,370])
dataFrame3
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 364  106  金門縣烏坵鄉     685      1.2    571
# 365  106  連江縣南竿鄉    7544     10.4    725
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
#
# [368 rows x 5 columns]

# %%
dataFrame3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 1 to 368
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     368 non-null    object
#  1   區域別     368 non-null    object
#  2   年底人口數   368 non-null    object
#  3   土地面積    368 non-null    object
#  4   人口密度    368 non-null    object
# dtypes: object(5)
# memory usage: 17.2+ KB

# %%
dataFrame4 = dataFrame3.astype(dtype={'年底人口數':np.int32,'土地面積':np.float32,'人口密度':np.int32})
dataFrame4
# Out:
# 0    統計年     區域別   年底人口數       土地面積   人口密度
# 1    106  新北市板橋區  551480  23.137300  23835
# 2    106  新北市三重區  387484  16.316999  23747
# 3    106  新北市中和區  413590  20.143999  20532
# 4    106  新北市永和區  222585   5.713800  38956
# 5    106  新北市新莊區  416524  19.738300  21102
# ..   ...     ...     ...        ...    ...
# 364  106  金門縣烏坵鄉     685   1.200000    571
# 365  106  連江縣南竿鄉    7544  10.400000    725
# 366  106  連江縣北竿鄉    2360   9.900000    238
# 367  106  連江縣莒光鄉    1624   4.700000    346
# 368  106  連江縣東引鄉    1352   3.800000    356
#
# [368 rows x 5 columns]

# %%
dataFrame4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 1 to 368
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統計年     368 non-null    object
#  1   區域別     368 non-null    object
#  2   年底人口數   368 non-null    int32
#  3   土地面積    368 non-null    float32
#  4   人口密度    368 non-null    int32
# dtypes: float32(1), int32(2), object(2)
# memory usage: 12.9+ KB

# %%
#[]搜尋或選取
#搜尋新北市三重區
dataFrame4[dataFrame4['區域別'] == '新北市三重區']
# Out:
# 0  統計年     區域別   年底人口數       土地面積   人口密度
# 2  106  新北市三重區  387484  16.316999  23747

# %%
#如果整欄是字串,可以使用str
dataFrame4[dataFrame4['區域別'].str.contains('臺北市')]
# Out:
# 0   統計年     區域別   年底人口數       土地面積   人口密度
# 30  106  臺北市松山區  206988   9.287800  22286
# 31  106  臺北市信義區  225753  11.207700  20143
# 32  106  臺北市大安區  309969  11.361400  27283
# 33  106  臺北市中山區  230710  13.682100  16862
# 34  106  臺北市中正區  159608   7.607100  20981
# 35  106  臺北市大同區  129278   5.681500  22754
# 36  106  臺北市萬華區  191850   8.852200  21673
# 37  106  臺北市文山區  274424  31.509001   8709
# 38  106  臺北市南港區  122155  21.842400   5593
# 39  106  臺北市內湖區  287771  31.578699   9113
# 40  106  臺北市士林區  288295  62.368198   4622
# 41  106  臺北市北投區  256456  56.821602   4513

# %%
#取出縣市
dataFrame4['縣市'] = dataFrame4['區域別'].str[:3]
dataFrame4
# Out:
# 0    統計年     區域別   年底人口數       土地面積   人口密度   縣市
# 1    106  新北市板橋區  551480  23.137300  23835  新北市
# 2    106  新北市三重區  387484  16.316999  23747  新北市
# 3    106  新北市中和區  413590  20.143999  20532  新北市
# 4    106  新北市永和區  222585   5.713800  38956  新北市
# 5    106  新北市新莊區  416524  19.738300  21102  新北市
# ..   ...     ...     ...        ...    ...  ...
# 364  106  金門縣烏坵鄉     685   1.200000    571  金門縣
# 365  106  連江縣南竿鄉    7544  10.400000    725  連江縣
# 366  106  連江縣北竿鄉    2360   9.900000    238  連江縣
# 367  106  連江縣莒光鄉    1624   4.700000    346  連江縣
# 368  106  連江縣東引鄉    1352   3.800000    356  連江縣
#
# [368 rows x 6 columns]

# %%
dataFrame5 = dataFrame4.groupby('縣市')[['年底人口數','土地面積']].sum()
dataFrame5
# Out:
# 0      年底人口數         土地面積
# 縣市
# 南投縣   501051  4106.436035
# 嘉義市   269398    60.025600
# 嘉義縣   511182  1903.636719
# 基隆市   371458   132.758896
# 宜蘭縣   456607  2143.625000
# 屏東縣   829939  2775.600342
# 彰化縣  1282458  1074.395996
# 新北市  3986689  2052.566650
# 新竹市   441132   104.152603
# 新竹縣   552169  1427.536987
# 桃園市  2188017  1220.953979
# 澎湖縣   104073   126.864098
# 臺中市  2787070  2214.896973
# 臺北市  2683257   271.799683
# 臺南市  1886522  2191.653076
# 臺東縣   219540  3515.252686
# 花蓮縣   329237  4628.571289
# 苗栗縣   553807  1820.314941
# 連江縣    12880    28.799999
# 金門縣   137456   151.655991
# 雲林縣   690373  1290.832642
# 高雄市  2776912  2951.852539

# %%
#重新手動排序index
dataFrame5.reindex(['臺北市','新北市'])
# Out:
# 0      年底人口數         土地面積
# 縣市
# 臺北市  2683257   271.799683
# 新北市  3986689  2052.566650

# %%
dataFrame4.groupby('縣市')[['年底人口數']].sum()
# Out:
# 0      年底人口數
# 縣市
# 南投縣   501051
# 嘉義市   269398
# 嘉義縣   511182
# 基隆市   371458
# 宜蘭縣   456607
# 屏東縣   829939
# 彰化縣  1282458
# 新北市  3986689
# 新竹市   441132
# 新竹縣   552169
# 桃園市  2188017
# 澎湖縣   104073
# 臺中市  2787070
# 臺北市  2683257
# 臺南市  1886522
# 臺東縣   219540
# 花蓮縣   329237
# 苗栗縣   553807
# 連江縣    12880
# 金門縣   137456
# 雲林縣   690373
# 高雄市  2776912

# %%
dataFrame4.groupby('縣市')['年底人口數'].agg(['sum','mean','std'])
# Out:
#          sum           mean            std
# 縣市
# 南投縣   501051   38542.384615   33541.229687
# 嘉義市   269398  134699.000000   17813.434032
# 嘉義縣   511182   28399.000000   16981.404958
# 基隆市   371458   53065.428571   13964.688203
# 宜蘭縣   456607   38050.583333   25924.685072
# 屏東縣   829939   25149.666667   34865.216599
# 彰化縣  1282458   49325.307692   45044.986060
# 新北市  3986689  137472.034483  151458.942714
# 新竹市   441132  147044.000000   67376.849681
# 新竹縣   552169   42474.538462   51024.954340
# 桃園市  2188017  168309.000000  128332.542397
# 澎湖縣   104073   17345.500000   22344.119457
# 臺中市  2787070   96105.862069   68284.317871
# 臺北市  2683257  223604.750000   63279.662246
# 臺南市  1886522   50987.081081   55589.815942
# 臺東縣   219540   13721.250000   24917.031063
# 花蓮縣   329237   25325.923077   31323.160011
# 苗栗縣   553807   30767.055556   31000.023726
# 連江縣    12880    3220.000000    2913.944406
# 金門縣   137456   22909.333333   14994.119950
# 雲林縣   690373   34518.650000   22009.465486
# ...

# %%
dataFrame4.groupby('縣市')[['年底人口數','土地面積']].agg([('加總','sum'),('平均','mean'),('標準差','std')])
# Out:
# 0      年底人口數                                       土地面積              \
#           加總             平均            標準差           加總          平均
# 縣市
# 南投縣   501051   38542.384615   33541.229687  4106.436035  315.879700
# 嘉義市   269398  134699.000000   17813.434032    60.025600   30.012800
# 嘉義縣   511182   28399.000000   16981.404958  1903.636719  105.757599
# 基隆市   371458   53065.428571   13964.688203   132.758896   18.965557
# 宜蘭縣   456607   38050.583333   25924.685072  2143.625000  178.635422
# 屏東縣   829939   25149.666667   34865.216599  2775.600342   84.109100
# 彰化縣  1282458   49325.307692   45044.986060  1074.395996   41.322922
# 新北市  3986689  137472.034483  151458.942714  2052.566650   70.778160
# 新竹市   441132  147044.000000   67376.849681   104.152603   34.717533
# 新竹縣   552169   42474.538462   51024.954340  1427.536987  109.810539
# 桃園市  2188017  168309.000000  128332.542397  1220.953979   93.919540
# 澎湖縣   104073   17345.500000   22344.119457   126.864098   21.144016
# ...

# %%
dataFrame4.groupby('縣市')[['年底人口數','']].agg([('加總','sum'),('平均','mean'),('標準差','std')])
