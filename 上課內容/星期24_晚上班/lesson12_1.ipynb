# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(8.0,5.0))
ax = fig.add_subplot(1,1,1)
ax.plot([0, 1, 2],[3, 4, 5])
plt.show()

# %%
fig = plt.figure(figsize=(8, 5))
ax_1 = fig.add_subplot(1,3,1)
ax_2 = fig.add_subplot(1,3,2)
ax_3 = fig.add_subplot(1,3,3)

ax_1.set_title("title1")
ax_2.set_title("title2")
ax_3.set_title("title3")

plt.show()

# %%
fig_1 = plt.figure(figsize=(8,5))
ax_1 = fig_1.add_subplot(1,1,1)
ax_1.plot([0,1,2],[3,4,1])

fig_2 = plt.figure(figsize=(5,8))
ax_2 = fig_2.add_subplot(1,1,1)
ax_2.plot([2, 3, 6],[2,1,2])
plt.show()

# %%
data = [-1, -4.3, 15, 21, 31]
xticks = ['a', 'b', 'c', 'd', 'e']
fig = plt.figure(figsize=(8,5))
ax_1 = fig.add_subplot(1,1,1)
ax_1.plot(xticks,data)
plt.show()

# %%
student1 = {'chinese':78, 'english':80, 'math':92, 'history':75, 'discover':85}
student2 = {'chinese':92, 'english':60, 'math':85, 'history':62, 'discover':73}
subjects1 = list(student1.keys())
scores1= list(student1.values())
subjects2 = list(student2.keys())
scores2 = list(student2.values())
print(subjects1)
print(scores1)

fig = plt.figure(figsize=(8,5),dpi=250,facecolor='#cccccc')
ax = fig.add_subplot(1,1,1)
ax.plot(subjects1,scores1,subjects2,scores2)
plt.show()
# Out:
# ['chinese', 'english', 'math', 'history', 'discover']
# [78, 80, 92, 75, 85]

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=8)
font1=FontProperties(fname='/Library/Fonts/Arial Unicode.ttf',size=12)
#window font=FontProperties(fname=r'c:\windows\fonts\simsun.ttc',size=8)

subjects3=['國文','英文','數學','歷史','探索']
fig = plt.figure(figsize=(8,5), dpi=250, facecolor="#cccccc")
ax = fig.add_subplot(1,1,1)
ax.set_title("學生1和學生2分數比較表",fontproperties=font)
ax.set_xlabel("科目",fontproperties=font)
ax.set_ylabel("分數",fontproperties=font)
ax.plot(subjects1,scores1,'m-.o')
ax.plot(subjects1,scores2,'c--o')
ax.legend(['學生1','學生2'],prop=font)
ax.set_xticklabels(subjects3,fontproperties=font)
#ax.annotate('98',(0,90),fontproperties=font)
for x in range(len(subjects3)):
    ax.annotate(str(scores1[x]),(x+0.05,scores1[x]))
    ax.annotate(str(scores2[x]),(x+0.05,scores2[x]))
scores1_total = 0
for value in scores1:
    scores1_total += value

scores2_total = 0
for value in scores2:
    scores2_total += value

ax.annotate(f'學生1總分{scores1_total}\n學生2總分{scores2_total}',(2.5,85),fontproperties=font1)
plt.show()
# Out:
# /var/folders/by/68nnsq553f59kbs1v470m4k40000gp/T/ipykernel_1745/3418828627.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(subjects3,fontproperties=font)
