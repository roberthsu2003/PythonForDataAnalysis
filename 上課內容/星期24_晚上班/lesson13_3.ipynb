# %%
import matplotlib.pyplot as plt
import numpy as np

figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot(1,1,1)
x_linespace = np.linspace(-3,3,50)
y = 2 * x_linespace + 1 
axes.plot(x_linespace,y,'r--')
plt.show()
