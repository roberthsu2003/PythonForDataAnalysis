# %%
import numpy as np
import pandas as pd
scores = np.random.randint(50,101,size=(50, 5))
students_dataFrame= pd.DataFrame(scores,
            index=range(1,51),
            columns=['國文','英文','數學','地理','歷史'])
students_dataFrame

# %%
students_dataFrame.loc[1]
# Out:
# 國文    60
# 英文    53
# 數學    64
# 地理    95
# 歷史    64
# Name: 1, dtype: int64

# %%
num1_sum =np.sum(students_dataFrame.loc[1])
num1_sum
# Out:
# 336

# %%
num1_average = num1_sum / 5
num1_average
# Out:
# 67.2

# %%
students_dataFrame.index.name="學號"
students_dataFrame.columns.name = "科目"
students_dataFrame

# %%
sums = students_dataFrame.sum(axis=1)
students_dataFrame['總分'] = sums
students_dataFrame
students_dataFrame['平均'] = sums/5
students_dataFrame
# Out:
# 科目   國文  英文   數學   地理  歷史   總分    平均
# 學號
# 1    60  53   64   95  64  336  67.2
# 2    55  53   63   97  97  365  73.0
# 3    73  56   61  100  86  376  75.2
# 4   100  97   50   69  65  381  76.2
# 5    56  85   80   94  89  404  80.8
# 6    97  96   70   71  95  429  85.8
# 7    74  56   90  100  59  379  75.8
# 8    99  87   73   85  60  404  80.8
# 9    72  95   68   93  65  393  78.6
# 10   56  92   55   71  59  333  66.6
# 11   83  79   63   81  54  360  72.0
# 12   83  53   56   73  77  342  68.4
# 13   61  63   78   67  92  361  72.2
# 14   82  81   80   86  61  390  78.0
# 15   65  62   93   50  72  342  68.4
# 16   91  62   55   66  64  338  67.6
# 17   77  52   85   68  79  361  72.2
# 18   83  59   55   77  86  360  72.0
# 19   77  73   99   53  95  397  79.4
# 20   79  69   50   57  89  344  68.8
# 21   56  61   85   90  70  362  72.4
# 22   99  62   75   55  89  380  76.0
# 23   54  79   85   94  91  403  80.6
# 24   91  81   88   79  82  421  84.2
# ...

# %%
students_dataFrame.to_excel('全班成績.xlsx')
