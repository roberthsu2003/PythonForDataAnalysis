# %%
import numpy as np
import pandas as pd

data = {
    '縣市': ['台北','台北','台北', '新竹', '新竹', '新竹'],
    '年份': [2000, 2001, 2002, 2001, 2002, 2003],
    '人口': [2.2, 2.5, 2.7, 1.1, 1.5, 2.0]
}
frame = pd.DataFrame(data)
frame
# Out:
#    縣市    年份   人口
# 0  台北  2000  2.2
# 1  台北  2001  2.5
# 2  台北  2002  2.7
# 3  新竹  2001  1.1
# 4  新竹  2002  1.5
# 5  新竹  2003  2.0

# %%
data = {
    '縣市': ['台北','台北','台北', '新竹', '新竹', '新竹'],
    '年份': [2000, 2001, 2002, 2001, 2002, 2003],
    '人口': [2.2, 2.5, 2.7, 1.1, 1.5, 2.0]
}

frame = pd.DataFrame(data, columns=['縣市', '人口', '年份'])
frame
# Out:
#    縣市   人口    年份
# 0  台北  2.2  2000
# 1  台北  2.5  2001
# 2  台北  2.7  2002
# 3  新竹  1.1  2001
# 4  新竹  1.5  2002
# 5  新竹  2.0  2003

# %%
#自定row index
data = {
    '縣市': ['台北','台北','台北', '新竹', '新竹', '新竹'],
    '年份': [2000, 2001, 2002, 2001, 2002, 2003],
    '人口': [2.2, 2.5, 2.7, 1.1, 1.5, 2.0]
}
frame = pd.DataFrame(data,
                     columns = ['縣市', '人口', '年份'],
                     index=['one', 'two', 'three', 'four', 'five', 'six'])
frame
# Out:
#        縣市   人口    年份
# one    台北  2.2  2000
# two    台北  2.5  2001
# three  台北  2.7  2002
# four   新竹  1.1  2001
# five   新竹  1.5  2002
# six    新竹  2.0  2003

# %%
frame.columns
# Out:
# Index(['縣市', '人口', '年份'], dtype='object')

# %%
frame.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
frame['縣市']
# Out:
# one      台北
# two      台北
# three    台北
# four     新竹
# five     新竹
# six      新竹
# Name: 縣市, dtype: object

# %%
frame.loc['one']
# Out:
# 縣市      台北
# 人口     2.2
# 年份    2000
# Name: one, dtype: object

# %%
data = {
    '縣市': ['台北','台北','台北', '新竹', '新竹', '新竹'],
    '年份': [2000, 2001, 2002, 2001, 2002, 2003],
    '人口': [2.2, 2.5, 2.7, 1.1, 1.5, 2.0]
}
frame = pd.DataFrame(data,
                     columns = ['縣市', '人口', '年份', '負債'],
                     index=['one', 'two', 'three', 'four', 'five', 'six'])
frame
# Out:
#        縣市   人口    年份   負債
# one    台北  2.2  2000  NaN
# two    台北  2.5  2001  NaN
# three  台北  2.7  2002  NaN
# four   新竹  1.1  2001  NaN
# five   新竹  1.5  2002  NaN
# six    新竹  2.0  2003  NaN

# %%
frame['負債'] = 16.5
frame
# Out:
#        縣市   人口    年份    負債
# one    台北  2.2  2000  16.5
# two    台北  2.5  2001  16.5
# three  台北  2.7  2002  16.5
# four   新竹  1.1  2001  16.5
# five   新竹  1.5  2002  16.5
# six    新竹  2.0  2003  16.5

# %%
frame['負債'] = np.arange(6.)
frame
# Out:
#        縣市   人口    年份   負債
# one    台北  2.2  2000  0.0
# two    台北  2.5  2001  1.0
# three  台北  2.7  2002  2.0
# four   新竹  1.1  2001  3.0
# five   新竹  1.5  2002  4.0
# six    新竹  2.0  2003  5.0

# %%
ndArray = np.random.rand(6)*100
frame['負債'] = ndArray.astype(np.int64)
frame
# Out:
#        縣市   人口    年份  負債
# one    台北  2.2  2000  22
# two    台北  2.5  2001  44
# three  台北  2.7  2002  62
# four   新竹  1.1  2001  62
# five   新竹  1.5  2002  65
# six    新竹  2.0  2003  99

# %%
#新增欄位
frame['新開發區'] = frame['縣市'] == '新竹'
frame
# Out:
#        縣市   人口    年份  負債   新開發區
# one    台北  2.2  2000  22  False
# two    台北  2.5  2001  44  False
# three  台北  2.7  2002  62  False
# four   新竹  1.1  2001  62   True
# five   新竹  1.5  2002  65   True
# six    新竹  2.0  2003  99   True

# %%
#刪除欄位
del frame['新開發區']
frame
# Out:
#        縣市   人口    年份  負債
# one    台北  2.2  2000  22
# two    台北  2.5  2001  44
# three  台北  2.7  2002  62
# four   新竹  1.1  2001  62
# five   新竹  1.5  2002  65
# six    新竹  2.0  2003  99

# %%
serial1 = frame['負債']
serial1['one'] = 55
serial1
frame
# Out:
# <ipython-input-31-38984bffce1f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   serial1['one'] = 55
#        縣市   人口    年份  負債
# one    台北  2.2  2000  55
# two    台北  2.5  2001  44
# three  台北  2.7  2002  62
# four   新竹  1.1  2001  62
# five   新竹  1.5  2002  65
# six    新竹  2.0  2003  99

# %%
serial1 = frame['負債'].copy()
serial1['one'] = 70
serial1
frame
# Out:
#        縣市   人口    年份  負債
# one    台北  2.2  2000  55
# two    台北  2.5  2001  44
# three  台北  2.7  2002  62
# four   新竹  1.1  2001  62
# five   新竹  1.5  2002  65
# six    新竹  2.0  2003  99

# %%
serial1.name
# Out:
# '負債'

# %%
pop = {'台北':{2001:2.4, 2002:2.9},
      '高雄':{2000:1.5, 2001:1.7, 2002:3.6}}
frame3 = pd.DataFrame(pop)
frame3
# Out:
#        台北   高雄
# 2001  2.4  1.7
# 2002  2.9  3.6
# 2000  NaN  1.5

# %%
frame4 = frame3.T
frame4
# Out:
#     2001  2002  2000
# 台北   2.4   2.9   NaN
# 高雄   1.7   3.6   1.5

# %%
frame4
# Out:
#     2001  2002  2000
# 台北   2.4   2.9   NaN
# 高雄   1.7   3.6   1.5

# %%
#建立完成後，只可以使用columns來排序
frame4.columns = [2000, 2001, 2002]
frame4
# Out:
#     2000  2001  2002
# 台北   2.4   2.9   NaN
# 高雄   1.7   3.6   1.5

# %%
frame3.index.name='年份'
frame3.columns.name='縣市'
frame3
# Out:
# 縣市     台北   高雄
# 年份
# 2001  2.4  1.7
# 2002  2.9  3.6
# 2000  NaN  1.5

# %%
#取出numpy(ndArray)
frame3.values
# Out:
# array([[2.4, 1.7],
#        [2.9, 3.6],
#        [nan, 1.5]])

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50, 101, size=(50, 5))
scores_df = pd.DataFrame(scores,
                         columns=['國文','英文','數學','地理','歷史'],
                        index = range(1, 51))
scores_df.index.name='座號'
scores_df.columns.name='科目'
scores_df
# Out:
# 科目   國文   英文   數學   地理  歷史
# 座號
# 1    89   77   65   68  59
# 2    72   55  100   80  58
# 3    81   75   79   51  51
# 4   100   86   79   70  81
# 5    93   87   50   88  75
# 6    86   91   52   58  85
# 7    60   98   76   77  79
# 8    82   87   96   82  62
# 9    58   57   56   52  87
# 10   59   64   63   59  53
# 11   67   50   97   95  91
# 12   98   73   88   79  80
# 13   87   60   89   96  60
# 14   96   85   58   88  86
# 15   61   69   60   86  59
# 16   79   80   59   66  67
# 17   95   97   54   95  74
# 18   96   67   52   72  82
# 19   71   84   97   75  74
# 20   98   81   53   55  96
# 21   98   70   98   58  86
# 22   74   90   63   84  83
# 23   58   83   88   50  73
# 24   66   78   91   98  54
# 25   67   75   95   92  77
# 26   70   54   61   75  66
# 27   73   87   89   74  91
# 28   67   85   91   94  66
# 29   88   70   60   65  60
# 30   85   82   50   71  54
# 31   62   93   56   75  68
# 32   89   78   58   65  90
# 33   87   99   99   53  62
# 34   75   79   81   65  68
# 35   79   62   58   74  72
# 36   60   66   67   77  57
# 37   51   90   75   76  83
# 38   54   72   69   62  68
# 39   74   81   66   89  70
# 40   97   61   94   70  66
# 41   90   77   82   57  86
# 42   81   69   79   85  53
# 43   57   86   69   59  77
# 44   66   50   82   90  91
# 45   56   95   86   81  87
# 46   70   89   81   52  93
# 47   90   52   60   71  98
# 48   68   81   94   83  60
# 49   91  100   91   74  93
# 50   50   75   62  100  92
