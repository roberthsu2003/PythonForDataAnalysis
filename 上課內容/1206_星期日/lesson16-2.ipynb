# %%
import numpy as np
import pandas as pd
scores = np.random.randint(low=50,high=101,size=(50,5))
scores_pd = pd.DataFrame(scores,i)
# Out:
# array([[ 52,  90,  75,  77,  79],
#        [ 81,  64,  69,  59,  97],
#        [ 63,  86,  59,  64,  98],
#        [ 62,  82,  94,  80,  63],
#        [ 70,  86,  95,  61,  50],
#        [ 76,  92,  91,  86,  82],
#        [ 87,  71,  83,  84,  72],
#        [ 57,  87,  53,  94,  89],
#        [ 70,  70, 100,  65,  60],
#        [ 66,  65,  58,  74,  89],
#        [ 80,  80,  58,  68,  58],
#        [ 90,  63,  57,  60,  88],
#        [ 87,  56,  57,  95,  98],
#        [ 80,  91,  95,  50,  53],
#        [ 88,  80,  79,  80,  76],
#        [ 82,  65,  63,  85,  66],
#        [ 65,  90,  54,  50,  79],
#        [ 97,  74,  74,  64,  77],
#        [ 51,  78,  50,  59,  79],
#        [ 60,  62,  72,  91,  53],
#        [ 96,  83,  81,  53,  50],
#        [ 91,  69,  50,  64,  85],
#        [ 64,  70,  92,  98,  69],
#        [ 64,  56,  79,  68,  82],
#        [ 55,  84,  51,  69,  74],
#        [ 80,  57,  78,  54,  55],
#        [ 68,  97,  54,  80,  99],
# ...
