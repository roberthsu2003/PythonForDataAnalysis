# %%
import csv
import numpy as np
import pandas as pd

def convertToInt(s):
    try:
        return int(s)
    except:
        return 0

def convertToFloat(s):
    try:
        return float(s)
    except:
        return 0.0

datalist = []
with open('各鄉鎮市區人口密度.csv',encoding='utf-8') as file:
    rows = csv.reader(file)
    for row in rows:
        if row[0] == '106' or row[0] == '統計年':
            if row[0] == '106':                
                row[2] = convertToInt(row[2])
                row[3] = convertToFloat(row[3])
                row[4] = convertToInt(row[4])
            datalist.append(row)
    
title=datalist.pop(0)
dataFrame = pd.DataFrame(datalist, columns = title)
# Out:
#     統計年     區域別   年底人口數      土地面積   人口密度
# 0   106  新北市板橋區  551480   23.1373  23835
# 1   106  新北市三重區  387484   16.3170  23747
# 2   106  新北市中和區  413590   20.1440  20532
# 3   106  新北市永和區  222585    5.7138  38956
# 4   106  新北市新莊區  416524   19.7383  21102
# 5   106  新北市新店區  302089  120.2255   2513
# 6   106  新北市樹林區  184149   33.1288   5559
# 7   106  新北市鶯歌區   86593   21.1248   4099
# 8   106  新北市三峽區  114926  191.4508    600
# 9   106  新北市淡水區  169597   70.6565   2400
# 10  106  新北市汐止區  199321   71.2354   2798

# %%
dataFrame.loc[:10]
# Out:
#     統計年     區域別   年底人口數      土地面積   人口密度
# 0   106  新北市板橋區  551480   23.1373  23835
# 1   106  新北市三重區  387484   16.3170  23747
# 2   106  新北市中和區  413590   20.1440  20532
# 3   106  新北市永和區  222585    5.7138  38956
# 4   106  新北市新莊區  416524   19.7383  21102
# 5   106  新北市新店區  302089  120.2255   2513
# 6   106  新北市樹林區  184149   33.1288   5559
# 7   106  新北市鶯歌區   86593   21.1248   4099
# 8   106  新北市三峽區  114926  191.4508    600
# 9   106  新北市淡水區  169597   70.6565   2400
# 10  106  新北市汐止區  199321   71.2354   2798

# %%
dataFrame[dataFrame['年底人口數'] > 400000]
# Out:
#     統計年     區域別   年底人口數     土地面積   人口密度
# 0   106  新北市板橋區  551480  23.1373  23835
# 2   106  新北市中和區  413590  20.1440  20532
# 4   106  新北市新莊區  416524  19.7383  21102
# 41  106  桃園市桃園區  440840  34.8046  12666
# 42  106  桃園市中壢區  405216  76.5200   5296

# %%
dataFrame[dataFrame['土地面積'] > 500]
# Out:
#      統計年     區域別  年底人口數       土地面積  人口密度
# 82   106  臺中市和平區  10949  1037.8192    11
# 156  106  高雄市桃源區   4246   928.9800     5
# 168  106  宜蘭縣大同鄉   6102   657.5442     9
# 169  106  宜蘭縣南澳鄉   5900   740.6520     8
# 181  106  新竹縣尖石鄉   9543   527.5795    18
# 200  106  苗栗縣泰安鄉   5883   614.5127    10
# 238  106  南投縣信義鄉  16253  1422.4188    11
# 239  106  南投縣仁愛鄉  15748  1273.5312    12
# 323  106  臺東縣海端鄉   4222   880.0382     5
# 337  106  花蓮縣秀林鄉  15889  1641.8555    10
# 338  106  花蓮縣萬榮鄉   6384   618.4910    10
# 339  106  花蓮縣卓溪鄉   6066  1021.3130     6
