# %%
str1 = "This is Python Tutorial, there"
search1 = "Python"
str1.find(search1)
search2 = "not"
if str1.find(search2) != -1:
    print("有這個字串",search2)
else:
    print("沒有這個字串",search2)
# Out:
# 沒有這個字串 not

# %%
str4 = "python-java-c++-ruby" 
list1 = str4.split('-')
print(list1)
# Out:
# ['python', 'java', 'c++', 'ruby']

# %%
":".join(list1)
# Out:
# 'python:java:c++:ruby'

# %%
"-".join("Python")
# Out:
# 'P-y-t-h-o-n'

# %%
setup = 'a duck goes into a bar...'
setup.strip('.')
# Out:
# 'a duck goes into a bar'

# %%
setup = "   Microsoft    "
setup.strip()
# Out:
# 'Microsoft'

# %%
import re
strTest = "hello a123456789 python"
mabj = re.search(r'[a-zA-Z]\d{9}', strTest , re.I)
if mabj:
    print("比對有這個字串")
    print('字串是',mabj.group())
else:
    print("沒有比對成功")
# Out:
# 比對有這個字串
# 字串是 a123456789

# %%
import re
taiwanId = input('請輸入身份證字號:')
mobj = re.match(r'^[A-Z]\d{9}$',taiwanId, re.I)
if (mobj):
    print(taiwanId, "正確")
else:
    print(taiwanId, "有誤")
# Out:
# 請輸入身份證字號:a123456789
# a123456789 正確

# %%
import re
emails = input('請輸入多筆email:')
getEmails = re.findall(r'\w+[.|\w]\w+@\w+[.]\w+[.|\w+]\w+',emails)
print('取出的email有:')
for email in getEmails:
    print(email)
# Out:
# 請輸入多筆email:bogusemail123@sillymail.com, adas, sdfdfd@, gmail.com, robert@gmail.com
# 取出的email有:
# bogusemail123@sillymail.com
# robert@gmail.com
